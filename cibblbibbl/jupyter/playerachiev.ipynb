# %%
import collections
import copy
import datetime
import itertools

import json
import pathlib
import re
from pprint import pprint

import nest_asyncio
nest_asyncio.apply()
import texttable

import pytourney
import pyfumbbl
import cibblbibbl
# Out:
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_aerodynamicaim/00046409/12512893.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_aerodynamicaim/00046409/12512893.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_aerodynamicaim/00046409/12512893.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_aerodynamicaim/00046409/12512893.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bps_hog/00042038/11448588.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bps_hog/00042038/11448588.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bps_hog/00042038/11448588.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bps_hog/00042038/11474441.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bps_hog/00042038/11474441.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bps_hog/00042038/11474441.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bps_hog/00042038/11445736.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bps_hog/00042038/11445736.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bps_hog/00042038/11445736.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bps_hog/00042038/11439894.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bps_hog/00042038/11439894.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bps_hog/00042038/11439894.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bps_oc/00042040/11512469.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bps_oc/00042040/11512469.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bps_oc/00042040/11512469.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bps_oc/00042040/11448237.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bps_oc/00042040/11448237.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bps_oc/00042040/11448237.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bps_oc/00042040/11493901.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bps_oc/00042040/11493901.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bps_oc/00042040/11493901.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bps_oc/00042040/11448250.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bps_oc/00042040/11448250.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bps_oc/00042040/11448250.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bps_oc/00042040/11472249.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bps_oc/00042040/11472249.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bps_oc/00042040/11472249.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bps_oc/00042040/11439819.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bps_oc/00042040/11439819.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bps_oc/00042040/11439819.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bps_oc/00042040/11448238.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bps_oc/00042040/11448238.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bps_oc/00042040/11448238.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bps_oc/00042040/11451910.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bps_oc/00042040/11451910.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bps_oc/00042040/11451910.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bps_oc/00042040/11472250.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bps_oc/00042040/11472250.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bps_oc/00042040/11472250.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bps_pc/00042041/11439616.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bps_pc/00042041/11439616.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bps_pc/00042041/11439616.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bps_pc/00042041/11439624.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bps_pc/00042041/11439624.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bps_pc/00042041/11439624.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bps_pc/00042041/11585952.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bps_pc/00042041/11585952.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bps_pc/00042041/11585952.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bps_pc/00042041/11454923.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bps_pc/00042041/11454923.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bps_pc/00042041/11454923.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bps_pc/00042041/11432424.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bps_pc/00042041/11432424.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bps_pc/00042041/11432424.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bps_pc/00042041/11446496.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bps_pc/00042041/11446496.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bps_pc/00042041/11446496.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bpa_copper/00042425/11646910.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bpa_copper/00042425/11646910.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bpa_copper/00042425/11646910.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bpa_copper/00042425/11633507.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bpa_copper/00042425/11633507.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bpa_copper/00042425/11633507.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bpa_copper/00042425/11603005.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bpa_copper/00042425/11603005.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bpa_copper/00042425/11603005.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bpa_copper/00042425/11621105.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bpa_copper/00042425/11621105.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bpa_copper/00042425/11621105.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bpa_copper/00042425/11646901.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bpa_copper/00042425/11646901.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bpa_copper/00042425/11646901.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bpa_copper/00042425/11633512.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bpa_copper/00042425/11633512.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bpa_copper/00042425/11633512.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bpa_copper/00042425/11621104.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bpa_copper/00042425/11621104.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bpa_copper/00042425/11621104.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bpa_bronze/00042426/11512890.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bpa_bronze/00042426/11512890.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bpa_bronze/00042426/11512890.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bpa_bronze/00042426/11590769.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bpa_bronze/00042426/11590769.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bpa_bronze/00042426/11590769.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bpa_bronze/00042426/11582135.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bpa_bronze/00042426/11582135.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bpa_bronze/00042426/11582135.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bpa_bronze/00042426/11512909.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bpa_bronze/00042426/11512909.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bpa_bronze/00042426/11512909.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bpa_bronze/00042426/11693781.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bpa_bronze/00042426/11693781.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bpa_bronze/00042426/11693781.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bpa_bronze/00042426/11657983.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bpa_bronze/00042426/11657983.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bpa_bronze/00042426/11657983.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bpa_bronze/00042426/11436778.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bpa_bronze/00042426/11436778.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bpa_bronze/00042426/11436778.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bpa_bronze/00042426/11512894.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bpa_bronze/00042426/11512894.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bpa_bronze/00042426/11512894.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bpa_bronze/00042426/11582133.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bpa_bronze/00042426/11582133.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bpa_bronze/00042426/11582133.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bpa_silver/00042427/11594138.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bpa_silver/00042427/11594138.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bpa_silver/00042427/11594138.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bpa_silver/00042427/11463885.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bpa_silver/00042427/11463885.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bpa_silver/00042427/11463885.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bpa_silver/00042427/11456001.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bpa_silver/00042427/11456001.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bpa_silver/00042427/11456001.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bpa_silver/00042427/11439893.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bpa_silver/00042427/11439893.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bpa_silver/00042427/11439893.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bpa_silver/00042427/11512672.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bpa_silver/00042427/11512672.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bpa_silver/00042427/11512672.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bpa_gold/00042428/11512469.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bpa_gold/00042428/11512469.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bpa_gold/00042428/11512469.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bpa_gold/00042428/11512476.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bpa_gold/00042428/11512476.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bpa_gold/00042428/11512476.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bpa_gold/00042428/11448253.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bpa_gold/00042428/11448253.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bpa_gold/00042428/11448253.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bpa_gold/00042428/11472250.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bpa_gold/00042428/11472250.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bpa_gold/00042428/11472250.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bpa_gold/00042428/11446496.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bpa_gold/00042428/11446496.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bpa_gold/00042428/11446496.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bpa_gold/00042428/STAR-7714.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bpa_gold/00042428/STAR-7714.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bpa_gold/00042428/STAR-7714.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bpa_gold/00042428/11448236.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bpa_gold/00042428/11448236.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bpa_gold/00042428/11448236.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bp_youngbloods/00042529/11664919.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bp_youngbloods/00042529/11664919.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bp_youngbloods/00042529/11664919.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bp_youngbloods/00042529/11669889.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bp_youngbloods/00042529/11669889.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bp_youngbloods/00042529/11669889.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bp_youngbloods/00042529/11656868.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bp_youngbloods/00042529/11656868.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bp_youngbloods/00042529/11656868.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bp_youngbloods/00042529/11667467.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bp_youngbloods/00042529/11667467.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bp_youngbloods/00042529/11667467.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bp_youngbloods/00042529/11664915.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bp_youngbloods/00042529/11664915.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bp_youngbloods/00042529/11664915.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bp_youngbloods/00042660/11686466.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bp_youngbloods/00042660/11686466.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bp_youngbloods/00042660/11686466.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bp_youngbloods/00042660/11697667.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bp_youngbloods/00042660/11697667.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bp_youngbloods/00042660/11697667.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bp_youngbloods/00042660/11698446.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bp_youngbloods/00042660/11698446.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bp_youngbloods/00042660/11698446.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bp_youngbloods/00042660/11705502.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bp_youngbloods/00042660/11705502.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bp_youngbloods/00042660/11705502.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bp_youngbloods/00042660/11686465.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bp_youngbloods/00042660/11686465.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bp_youngbloods/00042660/11686465.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bp_youngbloods/00042660/11698448.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bp_youngbloods/00042660/11698448.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bp_youngbloods/00042660/11698448.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bp_youngbloods/00042660/11700282.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bp_youngbloods/00042660/11700282.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bp_youngbloods/00042660/11700282.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bp_youngbloods/00042660/11698447.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bp_youngbloods/00042660/11698447.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bp_youngbloods/00042660/11698447.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bp_youngbloods/00042660/11700283.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bp_youngbloods/00042660/11700283.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bp_youngbloods/00042660/11700283.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bp_youngbloods/00042748/11713837.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bp_youngbloods/00042748/11713837.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bp_youngbloods/00042748/11713837.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bp_youngbloods/00042748/11709005.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bp_youngbloods/00042748/11709005.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bp_youngbloods/00042748/11709005.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bp_youngbloods/00042748/11721711.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bp_youngbloods/00042748/11721711.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bp_youngbloods/00042748/11721711.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bp_youngbloods/00042748/11721713.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bp_youngbloods/00042748/11721713.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bp_youngbloods/00042748/11721713.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bp_youngbloods/00042748/11724300.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bp_youngbloods/00042748/11724300.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bp_youngbloods/00042748/11724300.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bp_youngbloods/00042748/11721717.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bp_youngbloods/00042748/11721717.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bp_youngbloods/00042748/11721717.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bp_youngbloods/00042748/11724299.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bp_youngbloods/00042748/11724299.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bp_youngbloods/00042748/11724299.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bps_lc/00043149/11825655.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bps_lc/00043149/11825655.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bps_lc/00043149/11825655.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bps_lc/00043149/11828954.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bps_lc/00043149/11828954.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bps_lc/00043149/11828954.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bps_lc/00043149/STAR-7561.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bps_lc/00043149/STAR-7561.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bps_lc/00043149/STAR-7561.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bps_bc/00043150/11791176.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bps_bc/00043150/11791176.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bps_bc/00043150/11791176.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bps_bc/00043150/11849925.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bps_bc/00043150/11849925.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bps_bc/00043150/11849925.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bps_bc/00043150/11836559.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bps_bc/00043150/11836559.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bps_bc/00043150/11836559.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bps_bc/00043150/11818495.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bps_bc/00043150/11818495.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bps_bc/00043150/11818495.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bps_bc/00043150/11737365.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bps_bc/00043150/11737365.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bps_bc/00043150/11737365.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bps_bc/00043150/11791210.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bps_bc/00043150/11791210.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bps_bc/00043150/11791210.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bps_cbe/00043151/11737245.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bps_cbe/00043151/11737245.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bps_cbe/00043151/11737245.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bps_cbe/00043151/11446518.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bps_cbe/00043151/11446518.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bps_cbe/00043151/11446518.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bps_cbe/00043151/11787823.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bps_cbe/00043151/11787823.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bps_cbe/00043151/11787823.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bps_cbe/00043151/11785649.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bps_cbe/00043151/11785649.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bps_cbe/00043151/11785649.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bps_cbe/00043151/11582112.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bps_cbe/00043151/11582112.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bps_cbe/00043151/11582112.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bps_cbe/00043151/11800288.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bps_cbe/00043151/11800288.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bps_cbe/00043151/11800288.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bps_cbe/00043151/11667457.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bps_cbe/00043151/11667457.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bps_cbe/00043151/11667457.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bps_cbe/00043152/11713837.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bps_cbe/00043152/11713837.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bps_cbe/00043152/11713837.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bps_cbe/00043152/11756335.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bps_cbe/00043152/11756335.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bps_cbe/00043152/11756335.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bps_cbe/00043152/11737076.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bps_cbe/00043152/11737076.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bps_cbe/00043152/11737076.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bps_cbe/00043152/11713847.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bps_cbe/00043152/11713847.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bps_cbe/00043152/11713847.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bps_cbe/00043152/11859010.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bps_cbe/00043152/11859010.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bps_cbe/00043152/11859010.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bps_cbe/00043152/11758478.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bps_cbe/00043152/11758478.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bps_cbe/00043152/11758478.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bps_cbe/00043152/11758496.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bps_cbe/00043152/11758496.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bps_cbe/00043152/11758496.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bps_cbe/00043152/11737077.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bps_cbe/00043152/11737077.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bps_cbe/00043152/11737077.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bps_cbe/00043152/11746799.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bps_cbe/00043152/11746799.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bps_cbe/00043152/11746799.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bps_acc/00043153/11743258.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bps_acc/00043153/11743258.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bps_acc/00043153/11743258.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bps_acc/00043153/11809763.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bps_acc/00043153/11809763.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bps_acc/00043153/11809763.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bps_acc/00043153/11624586.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bps_acc/00043153/11624586.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bps_acc/00043153/11624586.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bps_acc/00043153/11835792.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bps_acc/00043153/11835792.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bps_acc/00043153/11835792.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bps_acc/00043153/11439893.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bps_acc/00043153/11439893.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bps_acc/00043153/11439893.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bps_acc/00043153/11698447.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bps_acc/00043153/11698447.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bps_acc/00043153/11698447.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bps_acc/00043153/11432424.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bps_acc/00043153/11432424.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bps_acc/00043153/11432424.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bps_acc/00043153/11698446.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bps_acc/00043153/11698446.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bps_acc/00043153/11698446.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bps_cvi/00043154/11582132.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bps_cvi/00043154/11582132.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bps_cvi/00043154/11582132.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bps_cvi/00043154/11709012.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bps_cvi/00043154/11709012.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bps_cvi/00043154/11709012.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bps_cvi/00043154/11582133.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bps_cvi/00043154/11582133.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bps_cvi/00043154/11582133.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bps_cvi/00043154/11721716.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bps_cvi/00043154/11721716.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bps_cvi/00043154/11721716.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bps_cvi/00043154/11456001.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bps_cvi/00043154/11456001.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bps_cvi/00043154/11456001.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bps_cvi/00043154/11747839.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bps_cvi/00043154/11747839.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bps_cvi/00043154/11747839.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bps_cvi/00043154/11754146.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bps_cvi/00043154/11754146.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bps_cvi/00043154/11754146.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bps_cvi/00043154/11700282.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bps_cvi/00043154/11700282.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bps_cvi/00043154/11700282.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bps_cvi/00043154/11765180.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bps_cvi/00043154/11765180.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bps_cvi/00043154/11765180.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bps_cvi/00043154/11455994.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bps_cvi/00043154/11455994.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bps_cvi/00043154/11455994.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bps_cvi/00043154/11439819.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bps_cvi/00043154/11439819.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bps_cvi/00043154/11439819.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bpa_marble/00043561/11849916.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bpa_marble/00043561/11849916.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bpa_marble/00043561/11849916.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bpa_marble/00043561/11828950.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bpa_marble/00043561/11828950.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bpa_marble/00043561/11828950.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bpa_marble/00043561/11875955.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bpa_marble/00043561/11875955.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bpa_marble/00043561/11875955.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bpa_marble/00043561/11942024.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bpa_marble/00043561/11942024.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bpa_marble/00043561/11942024.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bpa_marble/00043561/11828954.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bpa_marble/00043561/11828954.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bpa_marble/00043561/11828954.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bpa_marble/00043561/11908766.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bpa_marble/00043561/11908766.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bpa_marble/00043561/11908766.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bpa_iron/00043562/11839377.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bpa_iron/00043562/11839377.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bpa_iron/00043562/11839377.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bpa_iron/00043562/11759478.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bpa_iron/00043562/11759478.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bpa_iron/00043562/11759478.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bpa_iron/00043562/11776453.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bpa_iron/00043562/11776453.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bpa_iron/00043562/11776453.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bpa_iron/00043562/11898319.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bpa_iron/00043562/11898319.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bpa_iron/00043562/11898319.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bpa_iron/00043562/11825656.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bpa_iron/00043562/11825656.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bpa_iron/00043562/11825656.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bpa_iron/00043562/11757572.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bpa_iron/00043562/11757572.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bpa_iron/00043562/11757572.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bpa_tin/00043563/11439090.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bpa_tin/00043563/11439090.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bpa_tin/00043563/11439090.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bpa_tin/00043563/11756582.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bpa_tin/00043563/11756582.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bpa_tin/00043563/11756582.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bpa_tin/00043563/11766246.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bpa_tin/00043563/11766246.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bpa_tin/00043563/11766246.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bpa_tin/00043563/11744440.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bpa_tin/00043563/11744440.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bpa_tin/00043563/11744440.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bpa_tin/00043563/11756629.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bpa_tin/00043563/11756629.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bpa_tin/00043563/11756629.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bpa_copper/00043564/11754410.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bpa_copper/00043564/11754410.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bpa_copper/00043564/11754410.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bpa_copper/00043564/11699147.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bpa_copper/00043564/11699147.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bpa_copper/00043564/11699147.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bpa_copper/00043564/11791220.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bpa_copper/00043564/11791220.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bpa_copper/00043564/11791220.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bpa_copper/00043564/11783522.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bpa_copper/00043564/11783522.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bpa_copper/00043564/11783522.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bpa_copper/00043564/11754422.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bpa_copper/00043564/11754422.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bpa_copper/00043564/11754422.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bpa_copper/00043564/11558616.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bpa_copper/00043564/11558616.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bpa_copper/00043564/11558616.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bpa_copper/00043564/11747837.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bpa_copper/00043564/11747837.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bpa_copper/00043564/11747837.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bpa_copper/00043564/11743266.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bpa_copper/00043564/11743266.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bpa_copper/00043564/11743266.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bpa_bronze/00043565/11721710.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bpa_bronze/00043565/11721710.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_bpa_bronze/00043565/11721710.json') True
# ...
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_targeteliminated/00045881/12413274.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_targeteliminated/00045881/12413274.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_targeteliminated/00045881/12413274.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_targeteliminated/00045881/12413274.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_targeteliminated/00045881/12413274.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_targeteliminated/00045881/12413274.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_targeteliminated/00045881/12413274.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_targeteliminated/00045881/12413274.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_targeteliminated/00045882/12454883.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_targeteliminated/00045882/12454883.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_targeteliminated/00045882/12454883.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_targeteliminated/00045882/12454883.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_targeteliminated/00045882/12454883.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_targeteliminated/00045882/12454883.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_targeteliminated/00045882/12454883.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_targeteliminated/00045882/12454883.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_targeteliminated/00045882/12454883.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_targeteliminated/00045883/12117792.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_targeteliminated/00045883/12117792.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_targeteliminated/00045883/12117792.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_targeteliminated/00045883/12117792.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_targeteliminated/00045883/12117792.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_targeteliminated/00045883/12117792.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_targeteliminated/00045883/12117792.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_targeteliminated/00045883/12117792.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_targeteliminated/00045883/12117792.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_targeteliminated/00045883/12165569.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_targeteliminated/00045883/12165569.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_targeteliminated/00045883/12165569.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_targeteliminated/00045883/12165569.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_targeteliminated/00045883/12165569.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_targeteliminated/00045883/12165569.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_targeteliminated/00045883/12165569.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_targeteliminated/00045883/12165569.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_targeteliminated/00045883/12165569.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_targeteliminated/00045883/12235198.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_targeteliminated/00045883/12235198.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_targeteliminated/00045883/12235198.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_targeteliminated/00045883/12235198.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_targeteliminated/00045883/12235198.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_targeteliminated/00045883/12235198.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_targeteliminated/00045883/12235198.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_targeteliminated/00045883/12235198.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_targeteliminated/00045883/12235198.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_targeteliminated/00045884/12536762.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_targeteliminated/00045884/12536762.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_targeteliminated/00045884/12536762.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_targeteliminated/00045884/12536762.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_targeteliminated/00045884/12536762.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_targeteliminated/00045884/12536762.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_targeteliminated/00045884/12536762.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_targeteliminated/00045884/12536762.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_targeteliminated/00045884/12536762.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_targeteliminated/00045885/12037796.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_targeteliminated/00045885/12037796.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_targeteliminated/00045885/12037796.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_targeteliminated/00045885/12037796.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_targeteliminated/00045885/12037796.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_targeteliminated/00045885/12037796.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_targeteliminated/00045885/12037796.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_targeteliminated/00045885/12037796.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_targeteliminated/00045885/12037796.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_targeteliminated/00046392/11807607.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_targeteliminated/00046392/11807607.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_targeteliminated/00046392/11807607.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_targeteliminated/00046392/11807607.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_targeteliminated/00046392/11807607.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_targeteliminated/00046392/11807607.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_targeteliminated/00046392/11807607.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_targeteliminated/00046392/11807607.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_targeteliminated/00046392/11807607.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_targeteliminated/00046395/12173155.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_targeteliminated/00046395/12173155.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_targeteliminated/00046395/12173155.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_targeteliminated/00046395/12173155.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_targeteliminated/00046395/12173155.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_targeteliminated/00046395/12173155.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_targeteliminated/00046395/12173155.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_targeteliminated/00046395/12173155.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_targeteliminated/00046395/12173155.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_targeteliminated/00046398/12037810.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_targeteliminated/00046398/12037810.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_targeteliminated/00046398/12037810.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_targeteliminated/00046398/12037810.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_targeteliminated/00046398/12037810.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_targeteliminated/00046398/12037810.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_targeteliminated/00046398/12037810.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_targeteliminated/00046398/12037810.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_targeteliminated/00046398/12037810.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_targeteliminated/00046705/12537777.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_targeteliminated/00046705/12537777.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_targeteliminated/00046705/12537777.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_targeteliminated/00046705/12537777.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_targeteliminated/00046705/12537777.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_targeteliminated/00046705/12537777.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_targeteliminated/00046705/12537777.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_targeteliminated/00046705/12537777.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_targeteliminated/00046705/12537777.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_targeteliminated/00046707/12104982.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_targeteliminated/00046707/12104982.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_targeteliminated/00046707/12104982.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_targeteliminated/00046707/12104982.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_targeteliminated/00046707/12104982.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_targeteliminated/00046707/12104982.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_targeteliminated/00046707/12104982.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_targeteliminated/00046707/12104982.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_targeteliminated/00046707/12104982.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_targeteliminated/00046709/12473316.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_targeteliminated/00046709/12473316.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_targeteliminated/00046709/12473316.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_targeteliminated/00046710/12281784.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_targeteliminated/00046710/12281784.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_targeteliminated/00046710/12281784.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_targeteliminated/00046710/12281784.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_targeteliminated/00046710/12281784.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_targeteliminated/00046710/12281784.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_targeteliminated/00046710/12281784.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_targeteliminated/00046710/12281784.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_targeteliminated/00046710/12281784.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_targeteliminated/00047062/12122276.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_targeteliminated/00047062/12122276.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_targeteliminated/00047062/12122276.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_targeteliminated/00047062/12122276.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_targeteliminated/00047062/12122276.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_targeteliminated/00047062/12122276.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_targeteliminated/00047062/12122276.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_targeteliminated/00047062/12122276.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_targeteliminated/00047062/12122276.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_targeteliminated/00042428/RAISED-7385_11446521_11936975.json') True
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cibbl/achievement/pa_targeteliminated/00042428/11936975.json') True

# %%
G = cibblbibbl.CIBBL
Achievement = cibblbibbl.achievement.Achievement
Team = cibblbibbl.team.Team
player = cibblbibbl.player.player
Match = cibblbibbl.match.Match
Matchup = cibblbibbl.matchup.Matchup
Replay = cibblbibbl.replay.Replay

# %%
S = {Te.roster_name for Te in G.teams}
for s in sorted(S):
    print(f'{s}: ')
# Out:
# Albion:
# Amazon:
# Araby:
# Avelorn:
# Beastmen:
# Black Dwarf:
# Blood Dragon:
# Border Princes:
# Bretonnian:
# Cathay:
# Centigor:
# Chaos:
# Chaos Dwarf:
# Chaos Pact:
# Clan Eshin:
# Clan Mors:
# Clan Moulder:
# Clan Pestilens:
# Clan Skryre:
# Daemons of Khorne:
# Daemons of Malal:
# Daemons of Nurgle:
# Daemons of Slaanesh:
# Daemons of Tzeentch:
# Dark Elf:
# Dryad:
# Dwarf:
# Elemental - Air:
# Elemental - Earth:
# Elemental - Fire:
# Elemental - Water:
# Engineers:
# Estalia:
# Ethereal:
# Fimir:
# Forest Goblin:
# Four Nations:
# Giant:
# Gnome:
# Goblin:
# Half-Elf:
# Halfling:
# High Elf:
# Hobgoblin:
# Hobgoblin Slavers:
# Human:
# Hung:
# Ironbreakers:
# Ka-Sabar:
# Khainite Assassins:
# Khemri:
# Khorne:
# Kingdoms of Ind:
# Kislev:
# Kurgan:
# Kurnous:
# Lahmian:
# Lizardman:
# Lumbria:
# Lybaras:
# Mahrak:
# Malal:
# Myrmidia:
# Nautican:
# Necrarch:
# Necromantic:
# Night Goblin:
# Nippon:
# Norse:
# Norse Dwarf:
# Northern Nippon:
# Numas:
# Nurgle:
# Ogre:
# Ogre Kingdom:
# Orc:
# Orc Big 'Un:
# Pirates of Sartosa:
# Pro Elf:
# Pygmy:
# Rasetra:
# Relic Slann:
# Savage Orc:
# Sea Elf:
# Simyin:
# Sisters of Sigmar:
# Skaven:
# Skink:
# Slaanesh:
# Slann:
# Slayer:
# Snakemen:
# Snotling:
# Sons of Stromfels:
# Spawn of Chaos:
# Squig:
# Strigoi:
# Tilea:
# Treemen:
# Tzeentch:
# Undead:
# Undead Pirates:
# Underworld:
# Vampire:
# Von Carstein:
# Were:
# Witch Elf:
# Wood Elf:
# Zandri:
# Zoat:

# %%
Pl = player('RAISED-7392_12022010_12496642')  # raise on last match

# %%
T = G.tournaments["43567"]

# %%
T.bestplayers()
# Out:
# {'Blocks': NormalPlayer('11869550'),
#  'Casualties': NormalPlayer('11472247'),
#  'Completions': None,
#  'Fouls': NormalPlayer('11439806'),
#  'Interceptions': None,
#  'MVP': NormalPlayer('11809828'),
#  'Pass': NormalPlayer('11582135'),
#  'Rush': NormalPlayer('11472270'),
#  'SPP': NormalPlayer('11700282'),
#  'Touchdowns': None,
#  'Turns': NormalPlayer('11812909'),
#  'Scoring Thrower': NormalPlayer('11812909'),
#  'Triple': NormalPlayer('11582133'),
#  'Allrounder': None,
#  'Blocking Thrower': NormalPlayer('11582133'),
#  'Blocking Scorer': None}

# %%
sorted(T.rawplayerperformances())
# Out:
# [NormalPlayer('11439794'),
#  NormalPlayer('11439806'),
#  NormalPlayer('11439812'),
#  NormalPlayer('11439814'),
#  NormalPlayer('11439819'),
#  NormalPlayer('11439891'),
#  NormalPlayer('11439893'),
#  NormalPlayer('11439894'),
#  NormalPlayer('11439896'),
#  NormalPlayer('11439902'),
#  NormalPlayer('11439904'),
#  NormalPlayer('11440506'),
#  NormalPlayer('11446516'),
#  NormalPlayer('11446518'),
#  NormalPlayer('11446521'),
#  NormalPlayer('11448229'),
#  NormalPlayer('11448237'),
#  NormalPlayer('11448238'),
#  NormalPlayer('11448253'),
#  NormalPlayer('11448588'),
#  NormalPlayer('11472246'),
#  NormalPlayer('11472247'),
#  NormalPlayer('11472248'),
#  NormalPlayer('11472250'),
#  NormalPlayer('11472254'),
#  NormalPlayer('11472255'),
#  NormalPlayer('11472256'),
#  NormalPlayer('11472262'),
#  NormalPlayer('11472270'),
#  NormalPlayer('11474441'),
#  NormalPlayer('11494637'),
#  NormalPlayer('11494706'),
#  NormalPlayer('11502188'),
#  NormalPlayer('11506400'),
#  NormalPlayer('11512661'),
#  NormalPlayer('11512662'),
#  NormalPlayer('11512667'),
#  NormalPlayer('11512668'),
#  NormalPlayer('11512674'),
#  NormalPlayer('11512677'),
#  NormalPlayer('11567694'),
#  NormalPlayer('11582128'),
#  NormalPlayer('11582129'),
#  NormalPlayer('11582131'),
#  NormalPlayer('11582132'),
#  NormalPlayer('11582133'),
#  NormalPlayer('11582134'),
#  NormalPlayer('11582135'),
#  NormalPlayer('11582136'),
#  NormalPlayer('11582137'),
#  NormalPlayer('11582139'),
#  NormalPlayer('11596541'),
#  NormalPlayer('11596545'),
#  NormalPlayer('11624586'),
#  NormalPlayer('11630133'),
#  NormalPlayer('11657983'),
#  NormalPlayer('11658789'),
#  NormalPlayer('11694784'),
#  NormalPlayer('11696881'),
#  NormalPlayer('11698849'),
#  NormalPlayer('11700282'),
#  NormalPlayer('11700284'),
#  NormalPlayer('11700285'),
#  NormalPlayer('11700318'),
#  NormalPlayer('11700319'),
#  NormalPlayer('11700323'),
#  NormalPlayer('11706066'),
#  NormalPlayer('11706068'),
#  NormalPlayer('11710872'),
#  NormalPlayer('11720018'),
#  NormalPlayer('11730736'),
#  NormalPlayer('11734615'),
#  NormalPlayer('11750105'),
#  NormalPlayer('11753833'),
#  NormalPlayer('11771306'),
#  NormalPlayer('11775641'),
#  NormalPlayer('11775889'),
#  NormalPlayer('11777457'),
#  NormalPlayer('11780487'),
#  NormalPlayer('11787823'),
#  NormalPlayer('11795536'),
#  NormalPlayer('11797056'),
#  NormalPlayer('11801400'),
#  NormalPlayer('11809199'),
#  NormalPlayer('11809828'),
#  NormalPlayer('11812909'),
#  NormalPlayer('11850036'),
#  NormalPlayer('11853135'),
#  NormalPlayer('11859092'),
#  NormalPlayer('11869550'),
#  NormalPlayer('11873740'),
#  NormalPlayer('11873914'),
#  NormalPlayer('11874342'),
#  NormalPlayer('11876840'),
#  NormalPlayer('11877930'),
#  NormalPlayer('11880164'),
#  NormalPlayer('11884612'),
#  NormalPlayer('11884680'),
#  NormalPlayer('11886203'),
#  NormalPlayer('11895977'),
#  NormalPlayer('11903196'),
#  NormalPlayer('11903197'),
#  NormalPlayer('11905351'),
#  NormalPlayer('11921959'),
#  NormalPlayer('11921960'),
#  NormalPlayer('11930893'),
#  RaisedDeadPlayer('RAISED-7385_11795536_11933869'),
#  NormalPlayer('11933869'),
#  RaisedDeadPlayer('RAISED-7385_11446521_11936975'),
#  NormalPlayer('11936975'),
#  NormalPlayer('11937296'),
#  NormalPlayer('11937297'),
#  NormalPlayer('11937298'),
#  NormalPlayer('11937299'),
#  NormalPlayer('11937388'),
#  NormalPlayer('11937389'),
#  NormalPlayer('11937390'),
#  NormalPlayer('11937391'),
#  NormalPlayer('11937392'),
#  RaisedDeadPlayer('RAISED-7385_11853135_11941952'),
#  NormalPlayer('11941952'),
#  NormalPlayer('11941954'),
#  NormalPlayer('11941955'),
#  NormalPlayer('11941956'),
#  NormalPlayer('11941957'),
#  NormalPlayer('11941958'),
#  NormalPlayer('11941959'),
#  NormalPlayer('11944032'),
#  NormalPlayer('11944052'),
#  NormalPlayer('11944094'),
#  NormalPlayer('11944095'),
#  NormalPlayer('11971992'),
#  NormalPlayer('11975101'),
#  NormalPlayer('11975476'),
#  NormalPlayer('11979002'),
#  NormalPlayer('11979086'),
#  NormalPlayer('11981047'),
#  NormalPlayer('11981048'),
#  NormalPlayer('11981049'),
#  NormalPlayer('11981050'),
#  NormalPlayer('11981051'),
#  NormalPlayer('11981052'),
#  NormalPlayer('11986716'),
#  NormalPlayer('11986735'),
#  NormalPlayer('11997627'),
#  NormalPlayer('12004052'),
#  NormalPlayer('12004053'),
#  NormalPlayer('12011733'),
#  NormalPlayer('12011734'),
#  NormalPlayer('12011735'),
#  NormalPlayer('12015155'),
#  NormalPlayer('12015157'),
#  NormalPlayer('12015158'),
#  NormalPlayer('12015159'),
#  NormalPlayer('12015160'),
#  NormalPlayer('12023438'),
#  StarPlayer('STAR-7535'),
#  StarPlayer('STAR-7546'),
#  StarPlayer('STAR-7565'),
#  StarPlayer('STAR-7571'),
#  StarPlayer('STAR-7660'),
#  StarPlayer('STAR-7719'),
#  MercenaryPlayer('MERC-7305-3082'),
#  MercenaryPlayer('MERC-7305-3213'),
#  MercenaryPlayer('MERC-7305-3499'),
#  MercenaryPlayer('MERC-7305-3656'),
#  MercenaryPlayer('MERC-7305-3995'),
#  MercenaryPlayer('MERC-7331-1344'),
#  MercenaryPlayer('MERC-7501-2767'),
#  MercenaryPlayer('MERC-7506-3699')]

# %%
T.playerperformancesources()
# Out:
# {NormalPlayer('11439891'): {NormalPlayer('11439891')},
#  NormalPlayer('11439893'): {NormalPlayer('11439893')},
#  NormalPlayer('11439894'): {NormalPlayer('11439894')},
#  NormalPlayer('11439896'): {NormalPlayer('11439896')},
#  NormalPlayer('11439902'): {NormalPlayer('11439902')},
#  NormalPlayer('11439904'): {NormalPlayer('11439904')},
#  NormalPlayer('11448588'): {NormalPlayer('11448588')},
#  NormalPlayer('11474441'): {NormalPlayer('11474441')},
#  NormalPlayer('11506400'): {NormalPlayer('11506400')},
#  NormalPlayer('11624586'): {NormalPlayer('11624586')},
#  NormalPlayer('11694784'): {NormalPlayer('11694784')},
#  NormalPlayer('11775641'): {NormalPlayer('11775641')},
#  NormalPlayer('11859092'): {NormalPlayer('11859092')},
#  NormalPlayer('11873914'): {NormalPlayer('11873914')},
#  NormalPlayer('11895977'): {NormalPlayer('11895977')},
#  NormalPlayer('11582128'): {NormalPlayer('11582128')},
#  NormalPlayer('11582129'): {NormalPlayer('11582129')},
#  NormalPlayer('11582131'): {NormalPlayer('11582131')},
#  NormalPlayer('11582132'): {NormalPlayer('11582132')},
#  NormalPlayer('11582133'): {NormalPlayer('11582133')},
#  NormalPlayer('11582134'): {NormalPlayer('11582134')},
#  NormalPlayer('11582135'): {NormalPlayer('11582135')},
#  NormalPlayer('11582136'): {NormalPlayer('11582136')},
#  NormalPlayer('11582137'): {NormalPlayer('11582137')},
#  NormalPlayer('11582139'): {NormalPlayer('11582139')},
#  NormalPlayer('11657983'): {NormalPlayer('11657983')},
#  NormalPlayer('11777457'): {NormalPlayer('11777457')},
#  MercenaryPlayer('MERC-7331-1344'): {MercenaryPlayer('MERC-7331-1344')},
#  NormalPlayer('11446516'): {NormalPlayer('11446516')},
#  NormalPlayer('11446518'): {NormalPlayer('11446518')},
#  NormalPlayer('11494637'): {NormalPlayer('11494637')},
#  NormalPlayer('11596541'): {NormalPlayer('11596541')},
#  NormalPlayer('11596545'): {NormalPlayer('11596545')},
#  NormalPlayer('11696881'): {NormalPlayer('11696881')},
#  NormalPlayer('11706066'): {NormalPlayer('11706066')},
#  NormalPlayer('11706068'): {NormalPlayer('11706068')},
#  NormalPlayer('11787823'): {NormalPlayer('11787823')},
#  NormalPlayer('11809199'): {NormalPlayer('11809199')},
#  NormalPlayer('11873740'): {NormalPlayer('11873740')},
#  NormalPlayer('11880164'): {NormalPlayer('11880164')},
#  NormalPlayer('11921959'): {NormalPlayer('11921959')},
#  NormalPlayer('11921960'): {NormalPlayer('11921960')},
#  NormalPlayer('11472246'): {NormalPlayer('11472246')},
#  NormalPlayer('11472247'): {NormalPlayer('11472247')},
#  NormalPlayer('11472248'): {NormalPlayer('11472248')},
#  NormalPlayer('11472250'): {NormalPlayer('11472250')},
#  NormalPlayer('11472254'): {NormalPlayer('11472254')},
#  NormalPlayer('11472255'): {NormalPlayer('11472255')},
#  NormalPlayer('11472256'): {NormalPlayer('11472256')},
#  NormalPlayer('11472262'): {NormalPlayer('11472262')},
#  NormalPlayer('11472270'): {NormalPlayer('11472270')},
#  NormalPlayer('11658789'): {NormalPlayer('11658789')},
#  NormalPlayer('11720018'): {NormalPlayer('11720018')},
#  NormalPlayer('11730736'): {NormalPlayer('11730736')},
#  NormalPlayer('11809828'): {NormalPlayer('11809828')},
#  NormalPlayer('11905351'): {NormalPlayer('11905351')},
#  NormalPlayer('11439794'): {NormalPlayer('11439794')},
#  NormalPlayer('11439806'): {NormalPlayer('11439806')},
#  NormalPlayer('11439812'): {NormalPlayer('11439812')},
#  NormalPlayer('11439814'): {NormalPlayer('11439814')},
#  NormalPlayer('11439819'): {NormalPlayer('11439819')},
#  NormalPlayer('11440506'): {NormalPlayer('11440506')},
#  NormalPlayer('11502188'): {NormalPlayer('11502188')},
#  NormalPlayer('11567694'): {NormalPlayer('11567694')},
#  NormalPlayer('11698849'): {NormalPlayer('11698849')},
#  NormalPlayer('11750105'): {NormalPlayer('11750105')},
#  NormalPlayer('11780487'): {NormalPlayer('11780487')},
#  NormalPlayer('11797056'): {NormalPlayer('11797056')},
#  NormalPlayer('11876840'): {NormalPlayer('11876840')},
#  NormalPlayer('11884612'): {NormalPlayer('11884612')},
#  NormalPlayer('11884680'): {NormalPlayer('11884680')},
#  NormalPlayer('11448229'): {NormalPlayer('11448229')},
#  NormalPlayer('11448237'): {NormalPlayer('11448237')},
#  NormalPlayer('11448238'): {NormalPlayer('11448238')},
#  NormalPlayer('11448253'): {NormalPlayer('11448253')},
#  NormalPlayer('11494706'): {NormalPlayer('11494706')},
#  NormalPlayer('11801400'): {NormalPlayer('11801400')},
#  NormalPlayer('11869550'): {NormalPlayer('11869550')},
#  NormalPlayer('11886203'): {NormalPlayer('11886203')},
#  NormalPlayer('11903196'): {NormalPlayer('11903196')},
#  NormalPlayer('11903197'): {NormalPlayer('11903197')},
#  StarPlayer('STAR-7719'): {StarPlayer('STAR-7719')},
#  NormalPlayer('11512661'): {NormalPlayer('11512661')},
#  NormalPlayer('11512662'): {NormalPlayer('11512662')},
#  NormalPlayer('11512667'): {NormalPlayer('11512667')},
#  NormalPlayer('11512668'): {NormalPlayer('11512668')},
#  NormalPlayer('11512674'): {NormalPlayer('11512674')},
#  NormalPlayer('11512677'): {NormalPlayer('11512677')},
#  NormalPlayer('11630133'): {NormalPlayer('11630133')},
#  NormalPlayer('11710872'): {NormalPlayer('11710872')},
#  NormalPlayer('11753833'): {NormalPlayer('11753833')},
#  NormalPlayer('11771306'): {NormalPlayer('11771306')},
#  NormalPlayer('11877930'): {NormalPlayer('11877930')},
#  NormalPlayer('11700282'): {NormalPlayer('11700282')},
#  NormalPlayer('11700284'): {NormalPlayer('11700284')},
#  NormalPlayer('11700285'): {NormalPlayer('11700285')},
#  NormalPlayer('11700318'): {NormalPlayer('11700318')},
#  NormalPlayer('11700319'): {NormalPlayer('11700319')},
#  NormalPlayer('11700323'): {NormalPlayer('11700323')},
#  NormalPlayer('11734615'): {NormalPlayer('11734615')},
#  NormalPlayer('11775889'): {NormalPlayer('11775889')},
#  NormalPlayer('11812909'): {NormalPlayer('11812909')},
#  NormalPlayer('11850036'): {NormalPlayer('11850036')},
#  NormalPlayer('11874342'): {NormalPlayer('11874342')},
#  NormalPlayer('11930893'): {NormalPlayer('11930893')},
#  MercenaryPlayer('MERC-7506-3699'): {MercenaryPlayer('MERC-7506-3699')},
#  NormalPlayer('11933869'): {NormalPlayer('11795536'),
#   RaisedDeadPlayer('RAISED-7385_11795536_11933869'),
#   NormalPlayer('11933869')},
#  NormalPlayer('11937296'): {NormalPlayer('11937296')},
#  NormalPlayer('11937297'): {NormalPlayer('11937297')},
#  NormalPlayer('11937298'): {NormalPlayer('11937298')},
#  NormalPlayer('11937299'): {NormalPlayer('11937299')},
#  MercenaryPlayer('MERC-7305-3082'): {MercenaryPlayer('MERC-7305-3082')},
#  StarPlayer('STAR-7565'): {StarPlayer('STAR-7565')},
#  NormalPlayer('11937389'): {NormalPlayer('11937389')},
#  NormalPlayer('11937390'): {NormalPlayer('11937390')},
#  NormalPlayer('11937391'): {NormalPlayer('11937391')},
#  NormalPlayer('11937392'): {NormalPlayer('11937392')},
#  MercenaryPlayer('MERC-7305-3213'): {MercenaryPlayer('MERC-7305-3213')},
#  NormalPlayer('11936975'): {NormalPlayer('11446521'),
#   RaisedDeadPlayer('RAISED-7385_11446521_11936975'),
#   NormalPlayer('11936975')},
#  MercenaryPlayer('MERC-7501-2767'): {MercenaryPlayer('MERC-7501-2767')},
#  NormalPlayer('11937388'): {NormalPlayer('11937388')},
#  NormalPlayer('11944032'): {NormalPlayer('11944032')},
#  NormalPlayer('11944052'): {NormalPlayer('11944052')},
#  NormalPlayer('11941952'): {NormalPlayer('11853135'),
#   RaisedDeadPlayer('RAISED-7385_11853135_11941952'),
#   NormalPlayer('11941952')},
#  NormalPlayer('11975101'): {NormalPlayer('11975101')},
#  NormalPlayer('11975476'): {NormalPlayer('11975476')},
#  NormalPlayer('11979002'): {NormalPlayer('11979002')},
#  NormalPlayer('11979086'): {NormalPlayer('11979086')},
#  NormalPlayer('11941954'): {NormalPlayer('11941954')},
#  NormalPlayer('11941955'): {NormalPlayer('11941955')},
#  NormalPlayer('11941956'): {NormalPlayer('11941956')},
#  NormalPlayer('11941957'): {NormalPlayer('11941957')},
#  NormalPlayer('11941958'): {NormalPlayer('11941958')},
#  NormalPlayer('11941959'): {NormalPlayer('11941959')},
#  NormalPlayer('11971992'): {NormalPlayer('11971992')},
#  NormalPlayer('11986716'): {NormalPlayer('11986716')},
#  StarPlayer('STAR-7571'): {StarPlayer('STAR-7571')},
#  NormalPlayer('11997627'): {NormalPlayer('11997627')},
#  StarPlayer('STAR-7535'): {StarPlayer('STAR-7535')},
#  NormalPlayer('11944094'): {NormalPlayer('11944094')},
#  NormalPlayer('11944095'): {NormalPlayer('11944095')},
#  NormalPlayer('12004052'): {NormalPlayer('12004052')},
#  NormalPlayer('12004053'): {NormalPlayer('12004053')},
#  NormalPlayer('11986735'): {NormalPlayer('11986735')},
#  NormalPlayer('12011733'): {NormalPlayer('12011733')},
#  NormalPlayer('12011734'): {NormalPlayer('12011734')},
#  NormalPlayer('12011735'): {NormalPlayer('12011735')},
#  NormalPlayer('11981047'): {NormalPlayer('11981047')},
#  NormalPlayer('11981048'): {NormalPlayer('11981048')},
#  NormalPlayer('11981049'): {NormalPlayer('11981049')},
#  NormalPlayer('11981050'): {NormalPlayer('11981050')},
#  NormalPlayer('11981051'): {NormalPlayer('11981051')},
#  NormalPlayer('11981052'): {NormalPlayer('11981052')},
#  MercenaryPlayer('MERC-7305-3499'): {MercenaryPlayer('MERC-7305-3499')},
#  StarPlayer('STAR-7660'): {StarPlayer('STAR-7660')},
#  NormalPlayer('12015155'): {NormalPlayer('12015155')},
#  NormalPlayer('12015157'): {NormalPlayer('12015157')},
#  NormalPlayer('12015158'): {NormalPlayer('12015158')},
#  NormalPlayer('12015159'): {NormalPlayer('12015159')},
#  NormalPlayer('12015160'): {NormalPlayer('12015160')},
#  MercenaryPlayer('MERC-7305-3656'): {MercenaryPlayer('MERC-7305-3656')},
#  MercenaryPlayer('MERC-7305-3995'): {MercenaryPlayer('MERC-7305-3995')},
#  NormalPlayer('12023438'): {NormalPlayer('12023438')},
#  NormalPlayer('12196576'): {RaisedDeadPlayer('RAISED-7373_STAR-7546_12196576'),
#   StarPlayer('STAR-7546')}}

# %%
T.bestplayers()
# Out:
# {'Blocks': NormalPlayer('11869550'),
#  'Casualties': NormalPlayer('11472247'),
#  'Completions': None,
#  'Fouls': NormalPlayer('11439806'),
#  'Interceptions': None,
#  'MVP': NormalPlayer('11809828'),
#  'Pass': NormalPlayer('11582135'),
#  'Rush': NormalPlayer('11472270'),
#  'SPP': NormalPlayer('11700282'),
#  'Touchdowns': None,
#  'Turns': NormalPlayer('11812909'),
#  'Triple': NormalPlayer('11582133'),
#  'Allrounder': None,
#  'Blocking Scorer': None,
#  'Scoring Thrower': NormalPlayer('11812909'),
#  'Blocking Thrower': NormalPlayer('11582133')}

# %%
Ma = Match(Pl.config["prevdeadmatchId"])
Mu = Ma.matchup
T = self = Mu.tournament
T
# Out:
# Tournament('cibbl', '45883')

# %%
print(cibblbibbl.tournament.export.playerperformances.plaintext.export(T))
# Out:
#              Name                             Team                ★P   Td   Cs   It   Cp   Fo   BS   BT   ST   Tr   Ar
# ======================================================================================================================
# Itekuyet                         Scions of Neferata               35    2   12                   2
# Abel Sturm                       Vlad's Vampheroes                27    2    3                   2
# Kentetenka                       Scions of Neferata               26    7
# "Ambisinister" Xander            Vostok Iron Head                 25    6    1              1    1
# Bartholomew of the Northern      Seekers of Transcendence         24    5    1         2    4    1    1    2    1
# Frazsa Grimhand                  Black Monolith Worshippers       22        11
# Cyprian Drake                    Vlad's Vampheroes                21    1    4                   1
# Masaharta                        Scions of Neferata               19    3
# Foni Piemondon                   Dukes of Earthquake Valley       18    1                   2
# Ahmose                           Scions of Neferata               16    2    1         8         1    1    2    1
# B-ssh'rkhh'm "Loosetongue"       K'r'shh Sl'ppr'ss                15    3              1                   1
# Oris Devistator                  Black Monolith Worshippers       15
# Marquis Agulliar                 Vlad's Vampheroes                14    3
# Meret Scuffedon                  Dukes of Earthquake Valley       14    2    1         1         1    1    1    1
# The Irreverent Sindri            Vostok Iron Head                 14         2
# Senenmut                         Scions of Neferata               14         2
# The Painted Warlock              Seekers of Transcendence         13    1                   1
# K'nn'th "Strangler" Ptnntcl      K'r'shh Sl'ppr'ss                13         4
# Gertrude, Beast of the Moors     Vostok Iron Head                 13         4
# Krank Cracker                    Black Monolith Worshippers       12         5    1
# Coron Shottelodon                Dukes of Earthquake Valley       11    3              2                   2
# Ferrimora of the Waxing Moon     Seekers of Transcendence         11         3              1
# Draco Gore                       Vlad's Vampheroes                10    2    2                   2
# Spohras                          Court of Shu                     10    1    1                   1
# Dtr'vssr "Mamba" Vrddfls         K'r'shh Sl'ppr'ss                10    1    1                   1
# GRaarzas                         Black Monolith Worshippers       10
# Dunkl Meer                       Court of Shu                      9    1              1    1              1
# The Notorious Jerk               Vostok Iron Head                  9         2
# Balthasar the Youthful           Seekers of Transcendence          9         2
# Blu Ash                          Court of Shu                      9         1         2              1
# Ghras Paingiver                  Black Monolith Worshippers        8    2    1                   1
# Dialor the Noble                 Black Monolith Worshippers        8    2    1                   1
# "Featherweight" Gunnar           Vostok Iron Head                  8    2    1                   1
# Squishy Bob                      Black Monolith Worshippers        8    1
# N-r-ng "Spiral" Kbrrr'll'        K'r'shh Sl'ppr'ss                 8    1
# Melith Astenodon                 Dukes of Earthquake Valley        8    1
# Stonemuncher the Ancient         Black Monolith Worshippers        8         4
# Dark Hummus                      Court of Shu                      8                   3    1
# Draco the Ascendent              Seekers of Transcendence          7    1    2                   1
# Khras the Enslaved               Black Monolith Worshippers        7         2         3              2
# V'rr-nv'rry "Sunny"              K'r'shh Sl'ppr'ss                 7         1
# Silk                             Seekers of Transcendence          7         1
# Halvdan Halvarson                Vostok Iron Head                  7         1
# D'ssh-t "Moon Nostril" Ptnmlr    K'r'shh Sl'ppr'ss                 7         1
# Turpin of Vostok                 Vostok Iron Head                  7                   2
# Sirias the Agile                 Black Monolith Worshippers        7                   2
# R'th's'k "Whirly" Mssrbr         K'r'shh Sl'ppr'ss                 6    2
# Clay Dip                         Court of Shu                      6         3              2
# Valanduil of House Meliane,      Seekers of Transcendence          6         3
# The Indignant Kirkwood           Vostok Iron Head                  6         3
# Fojamee                          Court of Shu                      6                   1    1
# Retho Tungsodon                  Dukes of Earthquake Valley        6                   1
# Minth Lippidon                   Dukes of Earthquake Valley        6                   1
# Elemest                          Court of Shu                      6                   1
# T'ng "Lefty" Clbrr               K'r'shh Sl'ppr'ss                 5    1    1                   1
# *Whip-crack sound effect         Seekers of Transcendence          5         2         1    1         1
# Heni Hethurin                    Dukes of Earthquake Valley        5                   5    1
# Gorbad Faceclompah               Seekers of Transcendence          5                        7
# R'th's'k "Green Wall" Ammdtss    K'r'shh Sl'ppr'ss                 5
# Leveggoe                         Court of Shu                      5
# Janthuur                         Vlad's Vampheroes                 5
# Bunefer                          Scions of Neferata                5
# Konrad the Enchanter             Seekers of Transcendence          4         2              1
# Poppy Merribuck                  Seekers of Transcendence          4         2
# Ph'rn "Quick Tail" Vzz-Sttn      K'r'shh Sl'ppr'ss                 4         2
# Mirilan Antegobon                Dukes of Earthquake Valley        4         2
# Haldor Halvarson                 Vostok Iron Head                  4         2
# Aush                             Court of Shu                      4         2
# Angus Porterhouse                                                  4         2
# Adenes Fujo                      Court of Shu                      4         2
# Gottlieb Thälmann of Averland    Seekers of Transcendence          3    1                   3
# Wuwuhuwu                         Court of Shu                      3    1                   1
# The Xenith of Devotion           Seekers of Transcendence          3    1                   1
# Lembit Opik                      Seekers of Transcendence          3    1                   1
# C'dm'qsz "Focus" Ntrll           K'r'shh Sl'ppr'ss                 3    1
# Nis Atman                        Court of Shu                      2         1              2
# Kettil the Gourmand              Vostok Iron Head                  2         1              2
# V'sn "Opal" N'tr'c-tssll't       K'r'shh Sl'ppr'ss                 2         1              1
# Prr'n "Sparkly" Clbrrdrrccl      K'r'shh Sl'ppr'ss                 2         1              1
# Mercenary Thrall #3245                                             2         1              1
# Hrkas Prouddeath                 Black Monolith Worshippers        2         1              1
# Demitrius II                     Vlad's Vampheroes                 2         1              1
# Spliff Skyrim                    Black Monolith Worshippers        2         1
# Merenre                          Scions of Neferata                2         1
# Mercenary Constrictor #2035                                        2         1
# Lucien                           Vlad's Vampheroes                 2         1
# Ch'nn'r "Big Boa" Qll-Crvn       K'r'shh Sl'ppr'ss                 2         1
# Mercenary Air Elemental #1776                                      2              1
# Melchior                         Vlad's Vampheroes                 2              1
# Orja Coldless                    Black Monolith Worshippers        1                   1    2
# Reto Heturin I                   Dukes of Earthquake Valley        1                   1
# Sssues Ej                        Court of Shu                                               5
# Pix Vamox                        Court of Shu                                               3
# Igor The Surgeon                 Vostok Iron Head                                           3
# Vizesh                           Court of Shu                                               2
# Mos Passat                       Court of Shu                                               2
# Langley the Doomed               Vostok Iron Head                                           2
# Grazabire Lust'igor              Vlad's Vampheroes                                          2
# Sever Cumfeorm                   Vlad's Vampheroes                                          1
# Seskal II                        Vlad's Vampheroes                                          1
# Re'hotpe                         Scions of Neferata                                         1
# Mercenary Air Elemental #1807                                                               1
# Grasna Bonebreaker               Black Monolith Worshippers                                 1
# Enslaved Pirosa                  Black Monolith Worshippers                                 1

# %%
performances = T.extraplayerperformances(join=True)

# %%
performances

# %%
Sjs = list(performances.keys())

# %%
performances = cibblbibbl.tournament.performance.trans(performances)
performances
# Out:
# {NormalPlayer('12219671'): {'Completions': 0,
#   'Casualties': 12,
#   'Interceptions': 0,
#   'SPP': 35,
#   'Blocks': 77,
#   'Pass': 0,
#   'MVP': 1,
#   'Rush': 19,
#   'Turnms': 101,
#   'Fouls': 0,
#   'Touchdowns': 2,
#   'perf': [('D', 4024740),
#    ('D', 4026666),
#    ('W', 4029149),
#    ('W', 4031992),
#    ('L', 4033076),
#    ('W', 4034603),
#    ('W', 4037448)],
#   'team': Team(903654),
#   'type': 'R',
#   'name': 'Itekuyet',
#   'Blocking Thrower': 0,
#   'Blocking Scorer': 2,
#   'Scoring Thrower': 0,
#   'Triple': 0,
#   'Allrounder': 0},
#  NormalPlayer('12219673'): {'Completions': 8,
#   'Casualties': 1,
#   'Interceptions': 0,
#   'SPP': 16,
#   'Blocks': 6,
#   'Pass': 18,
#   'MVP': 0,
#   'Rush': 116,
#   'Turnms': 99,
#   'Fouls': 0,
#   'Touchdowns': 2,
#   'perf': [('D', 4024740),
#    ('D', 4026666),
#    ('W', 4029149),
#    ('W', 4031992),
#    ('L', 4033076),
#    ('W', 4034603),
#    ('W', 4037448)],
#   'team': Team(903654),
#   'type': 'R',
#   'name': 'Ahmose',
#   'Blocking Thrower': 1,
#   'Blocking Scorer': 1,
#   'Scoring Thrower': 2,
#   'Triple': 1,
#   'Allrounder': 0},
#  NormalPlayer('12219676'): {'Completions': 0,
#   'Casualties': 2,
#   'Interceptions': 0,
#   'SPP': 14,
#   'Blocks': 48,
#   'Pass': -1,
#   'MVP': 2,
#   'Rush': 0,
#   'Turnms': 97,
#   'Fouls': 0,
#   'Touchdowns': 0,
#   'perf': [('D', 4024740),
#    ('D', 4026666),
#    ('W', 4029149),
#    ('W', 4031992),
#    ('L', 4033076),
#    ('W', 4034603),
#    ('W', 4037448)],
#   'team': Team(903654),
#   'type': 'R',
#   'name': 'Senenmut',
#   'Blocking Thrower': 0,
#   'Blocking Scorer': 0,
#   'Scoring Thrower': 0,
#   'Triple': 0,
#   'Allrounder': 0},
#  NormalPlayer('12219677'): {'Completions': 0,
#   'Casualties': 0,
#   'Interceptions': 0,
#   'SPP': 0,
#   'Blocks': 4,
#   'Pass': 0,
#   'MVP': 0,
#   'Rush': 0,
#   'Turnms': 61,
#   'Fouls': 0,
#   'Touchdowns': 0,
#   'perf': [('D', 4024740),
#    ('D', 4026666),
#    ('W', 4029149),
#    ('W', 4031992),
#    ('L', 4033076)],
#   'team': Team(903654),
#   'type': 'R',
#   'name': 'Weshptah',
#   'retired': True,
#   'Blocking Thrower': 0,
#   'Blocking Scorer': 0,
#   'Scoring Thrower': 0,
#   'Triple': 0,
#   'Allrounder': 0},
#  NormalPlayer('12219678'): {'Completions': 0,
#   'Casualties': 1,
#   'Interceptions': 0,
#   'SPP': 2,
#   'Blocks': 28,
#   'Pass': 0,
#   'MVP': 0,
#   'Rush': 0,
#   'Turnms': 81,
#   'Fouls': 0,
#   'Touchdowns': 0,
#   'perf': [('D', 4024740),
#    ('D', 4026666),
#    ('W', 4029149),
#    ('W', 4031992),
#    ('L', 4033076),
#    ('W', 4034603),
#    ('W', 4037448)],
#   'team': Team(903654),
#   'type': 'R',
#   'name': 'Merenre',
#   'Blocking Thrower': 0,
#   'Blocking Scorer': 0,
#   'Scoring Thrower': 0,
#   'Triple': 0,
#   'Allrounder': 0},
#  NormalPlayer('12219681'): {'Completions': 0,
#   'Casualties': 0,
#   'Interceptions': 0,
#   'SPP': 0,
#   'Blocks': 4,
#   'Pass': 0,
#   'MVP': 0,
#   'Rush': 0,
#   'Turnms': 63,
#   'Fouls': 0,
#   'Touchdowns': 0,
#   'perf': [('D', 4024740),
#    ('D', 4026666),
#    ('W', 4029149),
#    ('W', 4031992),
#    ('L', 4033076),
#    ('W', 4034603),
#    ('W', 4037448)],
#   'team': Team(903654),
#   'type': 'R',
#   'name': 'Haremhab',
#   'Blocking Thrower': 0,
#   'Blocking Scorer': 0,
#   'Scoring Thrower': 0,
#   'Triple': 0,
#   'Allrounder': 0},
#  NormalPlayer('12219683'): {'Completions': 0,
#   'Casualties': 0,
#   'Interceptions': 0,
#   'SPP': 0,
#   'Blocks': 2,
#   'Pass': -1,
#   'MVP': 0,
#   'Rush': 3,
#   'Turnms': 53,
#   'Fouls': 0,
#   'Touchdowns': 0,
#   'perf': [('D', 4024740),
#    ('D', 4026666),
#    ('W', 4029149),
#    ('W', 4031992),
#    ('L', 4033076),
#    ('W', 4034603),
#    ('W', 4037448)],
#   'team': Team(903654),
#   'type': 'R',
#   'name': 'Intef',
#   'Blocking Thrower': 0,
#   'Blocking Scorer': 0,
#   'Scoring Thrower': 0,
#   'Triple': 0,
#   'Allrounder': 0},
#  NormalPlayer('12219684'): {'Completions': 0,
#   'Casualties': 0,
#   'Interceptions': 0,
#   'SPP': 0,
#   'Blocks': 4,
#   'Pass': 0,
#   'MVP': 0,
#   'Rush': 0,
#   'Turnms': 30,
#   'Fouls': 0,
#   'Touchdowns': 0,
#   'perf': [('D', 4024740),
#    ('D', 4026666),
#    ('W', 4029149),
#    ('W', 4031992),
#    ('L', 4033076),
#    ('W', 4034603),
#    ('W', 4037448)],
#   'team': Team(903654),
#   'type': 'R',
#   'name': 'Sihathor',
#   'Blocking Thrower': 0,
#   'Blocking Scorer': 0,
#   'Scoring Thrower': 0,
#   'Triple': 0,
#   'Allrounder': 0},
#  NormalPlayer('12227199'): {'Completions': 0,
#   'Casualties': 0,
#   'Interceptions': 0,
#   'SPP': 26,
#   'Blocks': 10,
#   'Pass': 1,
#   'MVP': 1,
#   'Rush': 82,
#   'Turnms': 96,
#   'Fouls': 0,
#   'Touchdowns': 7,
#   'perf': [('D', 4024740),
#    ('D', 4026666),
#    ('W', 4029149),
#    ('W', 4031992),
#    ('L', 4033076),
#    ('W', 4034603),
#    ('W', 4037448)],
#   'team': Team(903654),
#   'type': 'R',
#   'name': 'Kentetenka',
#   'Blocking Thrower': 0,
#   'Blocking Scorer': 0,
#   'Scoring Thrower': 0,
#   'Triple': 0,
#   'Allrounder': 0},
#  NormalPlayer('12318457'): {'Completions': 0,
#   'Casualties': 0,
#   'Interceptions': 0,
#   'SPP': 0,
#   'Blocks': 4,
#   'Pass': 0,
#   'MVP': 0,
#   'Rush': 0,
#   'Turnms': 76,
#   'Fouls': 0,
#   'Touchdowns': 0,
#   'perf': [('D', 4024740),
#    ('D', 4026666),
#    ('W', 4029149),
#    ('W', 4031992),
#    ('L', 4033076),
#    ('W', 4034603),
#    ('W', 4037448)],
#   'team': Team(903654),
#   'type': 'R',
#   'name': 'Setka',
#   'Blocking Thrower': 0,
#   'Blocking Scorer': 0,
#   'Scoring Thrower': 0,
#   'Triple': 0,
#   'Allrounder': 0},
#  NormalPlayer('12319538'): {'Completions': 0,
#   'Casualties': 0,
#   'Interceptions': 0,
#   'SPP': 0,
#   'Blocks': 5,
#   'Pass': 1,
#   'MVP': 0,
#   'Rush': 6,
#   'Turnms': 69,
#   'Fouls': 1,
#   'Touchdowns': 0,
#   'perf': [('D', 4024740),
#    ('D', 4026666),
#    ('W', 4029149),
#    ('W', 4031992),
#    ('L', 4033076),
#    ('W', 4034603),
#    ('W', 4037448)],
#   'team': Team(903654),
#   'type': 'R',
#   'name': "Re'hotpe",
#   'Blocking Thrower': 0,
#   'Blocking Scorer': 0,
#   'Scoring Thrower': 0,
#   'Triple': 0,
#   'Allrounder': 0},
#  NormalPlayer('12346893'): {'Completions': 0,
#   'Casualties': 0,
#   'Interceptions': 0,
#   'SPP': 0,
#   'Blocks': 4,
#   'Pass': 0,
#   'MVP': 0,
#   'Rush': 0,
#   'Turnms': 9,
#   'Fouls': 0,
#   'Touchdowns': 0,
#   'perf': [('D', 4024740), ('D', 4026666)],
#   'team': Team(903654),
#   'type': 'R',
#   'name': 'Nebemakhet',
#   'dead': [2, 2, 'blocked', '12117790'],
#   'Blocking Thrower': 0,
#   'Blocking Scorer': 0,
#   'Scoring Thrower': 0,
#   'Triple': 0,
#   'Allrounder': 0},
#  NormalPlayer('12367633'): {'Completions': 0,
#   'Casualties': 0,
#   'Interceptions': 0,
#   'SPP': 19,
#   'Blocks': 9,
#   'Pass': 0,
#   'MVP': 2,
#   'Rush': 29,
#   'Turnms': 100,
#   'Fouls': 0,
#   'Touchdowns': 3,
#   'perf': [('D', 4024740),
#    ('D', 4026666),
#    ('W', 4029149),
#    ('W', 4031992),
#    ('L', 4033076),
#    ('W', 4034603),
#    ('W', 4037448)],
#   'team': Team(903654),
#   'type': 'R',
#   'name': 'Masaharta',
#   'Blocking Thrower': 0,
#   'Blocking Scorer': 0,
#   'Scoring Thrower': 0,
#   'Triple': 0,
#   'Allrounder': 0},
#  NormalPlayer('12443530'): {'Completions': 0,
#   'Casualties': 0,
#   'Interceptions': 0,
#   'SPP': 0,
#   'Blocks': 4,
#   'Pass': 0,
#   'MVP': 0,
#   'Rush': 0,
#   'Turnms': 40,
#   'Fouls': 0,
#   'Touchdowns': 0,
#   'perf': [('D', 4024740),
#    ('D', 4026666),
#    ('W', 4029149),
#    ('W', 4031992),
#    ('L', 4033076),
#    ('W', 4034603),
#    ('W', 4037448)],
#   'team': Team(903654),
#   'type': 'R',
#   'name': 'Nofret',
#   'Blocking Thrower': 0,
#   'Blocking Scorer': 0,
#   'Scoring Thrower': 0,
#   'Triple': 0,
#   'Allrounder': 0},
#  NormalPlayer('12323836'): {'Completions': 0,
#   'Casualties': 3,
#   'Interceptions': 0,
#   'SPP': 27,
#   'Blocks': 49,
#   'Pass': 1,
#   'MVP': 3,
#   'Rush': 44,
#   'Turnms': 91,
#   'Fouls': 0,
#   'Touchdowns': 2,
#   'perf': [('D', 4024740),
#    ('D', 4026367),
#    ('W', 4030781),
#    ('W', 4030969),
#    ('W', 4032572),
#    ('D', 4033652),
#    ('W', 4041379)],
#   'team': Team(910344),
#   'type': 'R',
#   'name': 'Abel Sturm',
#   'Blocking Thrower': 0,
#   'Blocking Scorer': 2,
#   'Scoring Thrower': 0,
#   'Triple': 0,
#   'Allrounder': 0},
#  NormalPlayer('12323837'): {'Completions': 0,
#   'Casualties': 2,
#   'Interceptions': 0,
#   'SPP': 10,
#   'Blocks': 32,
#   'Pass': 0,
#   'MVP': 0,
#   'Rush': 35,
#   'Turnms': 79,
#   'Fouls': 0,
#   'Touchdowns': 2,
#   'perf': [('D', 4024740),
#    ('D', 4026367),
#    ('W', 4030781),
#    ('W', 4030969),
#    ('W', 4032572),
#    ('D', 4033652)],
#   'team': Team(910344),
#   'type': 'R',
#   'name': 'Draco Gore',
#   'retired': True,
#   'Blocking Thrower': 0,
#   'Blocking Scorer': 2,
#   'Scoring Thrower': 0,
#   'Triple': 0,
#   'Allrounder': 0},
#  NormalPlayer('12323839'): {'Completions': 0,
#   'Casualties': 0,
#   'Interceptions': 0,
#   'SPP': 14,
#   'Blocks': 41,
#   'Pass': 1,
#   'MVP': 1,
#   'Rush': 71,
#   'Turnms': 101,
#   'Fouls': 0,
#   'Touchdowns': 3,
#   'perf': [('D', 4024740),
#    ('D', 4026367),
#    ('W', 4030781),
#    ('W', 4030969),
#    ('W', 4032572),
#    ('D', 4033652),
#    ('W', 4041379)],
#   'team': Team(910344),
#   'type': 'R',
#   'name': 'Marquis Agulliar',
#   'Blocking Thrower': 0,
#   'Blocking Scorer': 0,
#   'Scoring Thrower': 0,
#   'Triple': 0,
#   'Allrounder': 0},
#  NormalPlayer('12323842'): {'Completions': 0,
#   'Casualties': 0,
#   'Interceptions': 1,
#   'SPP': 2,
#   'Blocks': 5,
#   'Pass': 0,
#   'MVP': 0,
#   'Rush': 2,
#   'Turnms': 46,
#   'Fouls': 0,
#   'Touchdowns': 0,
#   'perf': [('D', 4024740),
#    ('D', 4026367),
#    ('W', 4030781),
#    ('W', 4030969),
#    ('W', 4032572),
#    ('D', 4033652),
#    ('W', 4041379)],
#   'team': Team(910344),
#   'type': 'R',
#   'name': 'Melchior',
#   'Blocking Thrower': 0,
#   'Blocking Scorer': 0,
#   'Scoring Thrower': 0,
#   'Triple': 0,
#   'Allrounder': 0},
#  NormalPlayer('12323844'): {'Completions': 0,
#   'Casualties': 0,
#   'Interceptions': 0,
#   'SPP': 0,
#   'Blocks': 6,
#   'Pass': 0,
#   'MVP': 0,
#   'Rush': 0,
#   'Turnms': 54,
#   'Fouls': 0,
#   'Touchdowns': 0,
#   'perf': [('D', 4024740),
#    ('D', 4026367),
#    ('W', 4030781),
#    ('W', 4030969),
#    ('W', 4032572),
#    ('D', 4033652),
#    ('W', 4041379)],
#   'team': Team(910344),
#   'type': 'R',
#   'name': 'Doru',
#   'Blocking Thrower': 0,
#   'Blocking Scorer': 0,
#   'Scoring Thrower': 0,
#   'Triple': 0,
#   'Allrounder': 0},
#  NormalPlayer('12323845'): {'Completions': 0,
#   'Casualties': 0,
#   'Interceptions': 0,
#   'SPP': 0,
#   'Blocks': 2,
#   'Pass': 0,
#   'MVP': 0,
#   'Rush': 0,
#   'Turnms': 10,
#   'Fouls': 0,
#   'Touchdowns': 0,
#   'perf': [('D', 4024740), ('D', 4026367), ('W', 4030781)],
#   'team': Team(910344),
#   'type': 'R',
#   'name': 'Cassius',
#   'retired': True,
#   'Blocking Thrower': 0,
#   'Blocking Scorer': 0,
#   'Scoring Thrower': 0,
#   'Triple': 0,
#   'Allrounder': 0},
#  NormalPlayer('12323847'): {'Completions': 0,
#   'Casualties': 1,
#   'Interceptions': 0,
#   'SPP': 2,
#   'Blocks': 7,
#   'Pass': 0,
#   'MVP': 0,
#   'Rush': 0,
#   'Turnms': 48,
#   'Fouls': 0,
#   'Touchdowns': 0,
#   'perf': [('D', 4024740),
#    ('D', 4026367),
#    ('W', 4030781),
#    ('W', 4030969),
#    ('W', 4032572),
#    ('D', 4033652),
#    ('W', 4041379)],
#   'team': Team(910344),
#   'type': 'R',
#   'name': 'Lucien',
#   'Blocking Thrower': 0,
#   'Blocking Scorer': 0,
#   'Scoring Thrower': 0,
#   'Triple': 0,
#   'Allrounder': 0},
#  NormalPlayer('12325681'): {'Completions': 0,
#   'Casualties': 0,
#   'Interceptions': 0,
#   'SPP': 0,
#   'Blocks': 22,
#   'Pass': 0,
#   'MVP': 0,
#   'Rush': 0,
#   'Turnms': 68,
#   'Fouls': 2,
#   'Touchdowns': 0,
#   'perf': [('D', 4024740),
#    ('D', 4026367),
#    ('W', 4030781),
#    ('W', 4030969),
#    ('W', 4032572),
#    ('D', 4033652),
#    ('W', 4041379)],
#   'team': Team(910344),
#   'type': 'R',
#   'name': "Grazabire Lust'igor",
#   'Blocking Thrower': 0,
#   'Blocking Scorer': 0,
#   'Scoring Thrower': 0,
#   'Triple': 0,
#   'Allrounder': 0},
#  NormalPlayer('12339037'): {'Completions': 0,
#   'Casualties': 0,
#   'Interceptions': 0,
#   'SPP': 0,
#   'Blocks': 4,
#   'Pass': 0,
#   'MVP': 0,
#   'Rush': 0,
#   'Turnms': 21,
#   'Fouls': 0,
#   'Touchdowns': 0,
#   'perf': [('D', 4024740), ('D', 4026367), ('W', 4030781)],
#   'team': Team(910344),
#   'type': 'R',
#   'name': 'Damien Jr.',
#   'dead': [1, 8, 'blocked', '12158269'],
#   'Blocking Thrower': 0,
#   'Blocking Scorer': 0,
#   'Scoring Thrower': 0,
#   'Triple': 0,
#   'Allrounder': 0},
#  NormalPlayer('12350186'): {'Completions': 0,
#   'Casualties': 0,
#   'Interceptions': 0,
#   'SPP': 0,
#   'Blocks': 8,
#   'Pass': 0,
#   'MVP': 0,
#   'Rush': 0,
#   'Turnms': 37,
#   'Fouls': 1,
#   'Touchdowns': 0,
#   'perf': [('D', 4024740),
#    ('D', 4026367),
#    ('W', 4030781),
#    ('W', 4030969),
#    ('W', 4032572),
#    ('D', 4033652),
#    ('W', 4041379)],
#   'team': Team(910344),
#   'type': 'R',
#   'name': 'Sever Cumfeorm',
#   'Blocking Thrower': 0,
#   'Blocking Scorer': 0,
#   'Scoring Thrower': 0,
#   'Triple': 0,
#   'Allrounder': 0},
#  NormalPlayer('12352367'): {'Completions': 0,
#   'Casualties': 4,
#   'Interceptions': 0,
#   'SPP': 21,
#   'Blocks': 63,
#   'Pass': 1,
#   'MVP': 2,
#   'Rush': 29,
#   'Turnms': 92,
#   'Fouls': 0,
#   'Touchdowns': 1,
#   'perf': [('D', 4024740),
#    ('D', 4026367),
#    ('W', 4030781),
#    ('W', 4030969),
#    ('W', 4032572),
#    ('D', 4033652),
#    ('W', 4041379)],
#   'team': Team(910344),
#   'type': 'R',
#   'name': 'Cyprian Drake',
#   'Blocking Thrower': 0,
#   'Blocking Scorer': 1,
#   'Scoring Thrower': 0,
#   'Triple': 0,
#   'Allrounder': 0},
#  NormalPlayer('12352368'): {'Completions': 0,
#   'Casualties': 0,
#   'Interceptions': 0,
#   'SPP': 0,
#   'Blocks': 0,
#   'Pass': 0,
#   'MVP': 0,
#   'Rush': 0,
#   'Turnms': 5,
#   'Fouls': 0,
#   'Touchdowns': 0,
#   'perf': [('D', 4024740)],
#   'team': Team(910344),
#   'type': 'R',
#   'name': 'Seskal',
#   'retired': True,
#   'Blocking Thrower': 0,
#   'Blocking Scorer': 0,
#   'Scoring Thrower': 0,
#   'Triple': 0,
#   'Allrounder': 0},
#  NormalPlayer('12358967'): {'Completions': 0,
#   'Casualties': 0,
#   'Interceptions': 0,
#   'SPP': 0,
#   'Blocks': 8,
#   'Pass': 0,
#   'MVP': 0,
#   'Rush': 0,
#   'Turnms': 61,
#   'Fouls': 0,
#   'Touchdowns': 0,
#   'perf': [('D', 4024740),
#    ('D', 4026367),
#    ('W', 4030781),
#    ('W', 4030969),
#    ('W', 4032572),
#    ('D', 4033652),
#    ('W', 4041379)],
#   'team': Team(910344),
#   'type': 'R',
#   'name': 'Ascelin II',
#   'Blocking Thrower': 0,
#   'Blocking Scorer': 0,
#   'Scoring Thrower': 0,
#   'Triple': 0,
#   'Allrounder': 0},
#  NormalPlayer('12431641'): {'Completions': 0,
#   'Casualties': 0,
#   'Interceptions': 0,
#   'SPP': 5,
#   'Blocks': 10,
#   'Pass': 0,
#   'MVP': 1,
#   'Rush': 0,
#   'Turnms': 50,
#   'Fouls': 0,
#   'Touchdowns': 0,
#   'perf': [('D', 4024740),
#    ('D', 4026367),
#    ('W', 4030781),
#    ('W', 4030969),
#    ('W', 4032572),
#    ('D', 4033652),
#    ('W', 4041379)],
#   'team': Team(910344),
#   'type': 'R',
#   'name': 'Janthuur',
#   'Blocking Thrower': 0,
#   'Blocking Scorer': 0,
#   'Scoring Thrower': 0,
#   'Triple': 0,
#   'Allrounder': 0},
#  NormalPlayer('12458539'): {'Completions': 0,
#   'Casualties': 0,
#   'Interceptions': 0,
#   'SPP': 0,
#   'Blocks': 7,
#   'Pass': 0,
#   'MVP': 0,
#   'Rush': 0,
#   'Turnms': 26,
#   'Fouls': 0,
#   'Touchdowns': 0,
#   'perf': [('D', 4024740), ('D', 4026367)],
#   'team': Team(910344),
#   'type': 'R',
#   'name': 'Mauthis',
#   'retired': True,
#   'Blocking Thrower': 0,
#   'Blocking Scorer': 0,
#   'Scoring Thrower': 0,
#   'Triple': 0,
#   'Allrounder': 0},
#  NormalPlayer('11892405'): {'Completions': 0,
#   'Casualties': 1,
#   'Interceptions': 0,
#   'SPP': 8,
#   'Blocks': 26,
#   'Pass': 0,
#   'MVP': 0,
#   'Rush': 32,
#   'Turnms': 73,
#   'Fouls': 0,
#   'Touchdowns': 2,
#   'perf': [('L', 4024847),
#    ('D', 4029013),
#    ('W', 4029542),
#    ('L', 4031344),
#    ('W', 4033076),
#    ('W', 4034337),
#    ('L', 4041379)],
#   'team': Team(883051),
#   'type': 'R',
#   'name': '"Featherweight" Gunnar',
#   'Blocking Thrower': 0,
#   'Blocking Scorer': 1,
#   'Scoring Thrower': 0,
#   'Triple': 0,
#   'Allrounder': 0},
#  NormalPlayer('11892424'): {'Completions': 0,
#   'Casualties': 0,
#   'Interceptions': 0,
#   'SPP': 0,
#   'Blocks': 30,
#   'Pass': 0,
#   'MVP': 0,
#   'Rush': 0,
#   'Turnms': 80,
#   'Fouls': 0,
#   'Touchdowns': 0,
#   'perf': [('L', 4024847),
#    ('D', 4029013),
#    ('W', 4029542),
#    ('L', 4031344),
#    ('W', 4033076),
#    ('W', 4034337),
#    ('L', 4041379)],
#   'team': Team(883051),
#   'type': 'R',
#   'name': 'Dag of The Mire',
#   'Blocking Thrower': 0,
#   'Blocking Scorer': 0,
#   'Scoring Thrower': 0,
#   'Triple': 0,
#   'Allrounder': 0},
#  NormalPlayer('11892428'): {'Completions': 0,
#   'Casualties': 0,
#   'Interceptions': 0,
#   'SPP': 0,
#   'Blocks': 8,
#   'Pass': 0,
#   'MVP': 0,
#   'Rush': 0,
#   'Turnms': 32,
#   'Fouls': 0,
#   'Touchdowns': 0,
#   'perf': [('L', 4024847),
#    ('D', 4029013),
#    ('W', 4029542),
#    ('L', 4031344),
#    ('W', 4033076),
#    ('W', 4034337),
#    ('L', 4041379)],
#   'team': Team(883051),
#   'type': 'R',
#   'name': 'Folke Ninth-Son',
#   'Blocking Thrower': 0,
#   'Blocking Scorer': 0,
#   'Scoring Thrower': 0,
#   'Triple': 0,
#   'Allrounder': 0},
#  NormalPlayer('11892429'): {'Completions': 0,
#   'Casualties': 0,
#   'Interceptions': 0,
#   'SPP': 0,
#   'Blocks': 3,
#   'Pass': 0,
#   'MVP': 0,
#   'Rush': 0,
#   'Turnms': 11,
#   'Fouls': 0,
#   'Touchdowns': 0,
#   'perf': [('L', 4024847), ('D', 4029013)],
#   'team': Team(883051),
#   'type': 'R',
#   'name': 'Geir the Fisherman',
#   'retired': True,
#   'Blocking Thrower': 0,
#   'Blocking Scorer': 0,
#   'Scoring Thrower': 0,
#   'Triple': 0,
#   'Allrounder': 0},
#  NormalPlayer('11947871'): {'Completions': 0,
#   'Casualties': 1,
#   'Interceptions': 0,
#   'SPP': 25,
#   'Blocks': 22,
#   'Pass': 0,
#   'MVP': 1,
#   'Rush': 108,
#   'Turnms': 96,
#   'Fouls': 1,
#   'Touchdowns': 6,
#   'perf': [('L', 4024847),
#    ('D', 4029013),
#    ('W', 4029542),
#    ('L', 4031344),
#    ('W', 4033076),
#    ('W', 4034337),
#    ('L', 4041379)],
#   'team': Team(883051),
#   'type': 'R',
#   'name': '"Ambisinister" Xander',
#   'Blocking Thrower': 0,
#   'Blocking Scorer': 1,
#   'Scoring Thrower': 0,
#   'Triple': 0,
#   'Allrounder': 0},
#  NormalPlayer('11950136'): {'Completions': 0,
#   'Casualties': 2,
#   'Interceptions': 0,
#   'SPP': 9,
#   'Blocks': 13,
#   'Pass': 0,
#   'MVP': 1,
#   'Rush': 0,
#   'Turnms': 28,
#   'Fouls': 0,
#   'Touchdowns': 0,
#   'perf': [('L', 4024847), ('D', 4029013), ('W', 4029542), ('L', 4031344)],
#   'team': Team(883051),
#   'type': 'R',
#   'name': 'The Notorious Jerk',
#   'dead': [1, 5, 'blocked', 'STAR-7545'],
#   'Blocking Thrower': 0,
#   'Blocking Scorer': 0,
#   'Scoring Thrower': 0,
#   'Triple': 0,
#   'Allrounder': 0},
#  NormalPlayer('12130906'): {'Completions': 0,
#   'Casualties': 2,
#   'Interceptions': 0,
#   'SPP': 4,
#   'Blocks': 30,
#   'Pass': 0,
#   'MVP': 0,
#   'Rush': 0,
#   'Turnms': 81,
#   'Fouls': 0,
#   'Touchdowns': 0,
#   'perf': [('L', 4024847),
#    ('D', 4029013),
#    ('W', 4029542),
#    ('L', 4031344),
#    ('W', 4033076),
#    ('W', 4034337),
#    ('L', 4041379)],
#   'team': Team(883051),
#   'type': 'R',
#   'name': 'Haldor Halvarson',
#   'Blocking Thrower': 0,
#   'Blocking Scorer': 0,
#   'Scoring Thrower': 0,
#   'Triple': 0,
#   'Allrounder': 0},
#  NormalPlayer('12169214'): {'Completions': 0,
#   'Casualties': 0,
#   'Interceptions': 0,
#   'SPP': 0,
#   'Blocks': 7,
#   'Pass': 0,
#   'MVP': 0,
#   'Rush': 0,
#   'Turnms': 34,
#   'Fouls': 3,
#   'Touchdowns': 0,
#   'perf': [('L', 4024847),
#    ('D', 4029013),
#    ('W', 4029542),
#    ('L', 4031344),
#    ('W', 4033076),
#    ('W', 4034337),
#    ('L', 4041379)],
#   'team': Team(883051),
#   'type': 'R',
#   'name': 'Igor The Surgeon',
#   'Blocking Thrower': 0,
#   'Blocking Scorer': 0,
#   'Scoring Thrower': 0,
#   'Triple': 0,
#   'Allrounder': 0},
#  NormalPlayer('12169228'): {'Completions': 0,
#   'Casualties': 0,
#   'Interceptions': 0,
#   'SPP': 0,
#   'Blocks': 14,
#   'Pass': -1,
#   'MVP': 0,
#   'Rush': 13,
#   'Turnms': 65,
#   'Fouls': 0,
#   'Touchdowns': 0,
#   'perf': [('L', 4024847),
#    ('D', 4029013),
#    ('W', 4029542),
#    ('L', 4031344),
#    ('W', 4033076),
#    ('W', 4034337),
#    ('L', 4041379)],
#   'team': Team(883051),
#   'type': 'R',
#   'name': 'Jary The Younger',
#   'Blocking Thrower': 0,
#   'Blocking Scorer': 0,
#   'Scoring Thrower': 0,
#   'Triple': 0,
#   'Allrounder': 0},
#  NormalPlayer('12245045'): {'Completions': 0,
#   'Casualties': 4,
#   'Interceptions': 0,
#   'SPP': 13,
#   'Blocks': 41,
#   'Pass': 0,
#   'MVP': 1,
#   'Rush': 0,
#   'Turnms': 98,
#   'Fouls': 0,
#   'Touchdowns': 0,
#   'perf': [('L', 4024847),
#    ('D', 4029013),
#    ('W', 4029542),
#    ('L', 4031344),
#    ('W', 4033076),
#    ('W', 4034337),
#    ('L', 4041379)],
#   'team': Team(883051),
#   'type': 'B',
#   'name': 'Gertrude, Beast of the Moors',
#   'Blocking Thrower': 0,
#   'Blocking Scorer': 0,
#   'Scoring Thrower': 0,
#   'Triple': 0,
#   'Allrounder': 0},
#  NormalPlayer('12340698'): {'Completions': 2,
#   'Casualties': 0,
#   'Interceptions': 0,
#   'SPP': 7,
#   'Blocks': 8,
#   'Pass': -1,
#   'MVP': 1,
#   'Rush': 26,
#   'Turnms': 64,
#   'Fouls': 0,
#   'Touchdowns': 0,
#   'perf': [('L', 4024847),
#    ('D', 4029013),
#    ('W', 4029542),
#    ('L', 4031344),
#    ('W', 4033076),
#    ('W', 4034337),
#    ('L', 4041379)],
#   'team': Team(883051),
#   'type': 'R',
#   'name': 'Turpin of Vostok',
#   'Blocking Thrower': 0,
#   'Blocking Scorer': 0,
#   'Scoring Thrower': 0,
#   'Triple': 0,
#   'Allrounder': 0},
#  NormalPlayer('12348482'): {'Completions': 0,
#   'Casualties': 1,
#   'Interceptions': 0,
#   'SPP': 2,
#   'Blocks': 15,
#   'Pass': 0,
#   'MVP': 0,
#   'Rush': 0,
#   'Turnms': 62,
#   'Fouls': 2,
#   'Touchdowns': 0,
#   'perf': [('L', 4024847),
#    ('D', 4029013),
#    ('W', 4029542),
#    ('L', 4031344),
#    ('W', 4033076),
#    ('W', 4034337),
#    ('L', 4041379)],
#   'team': Team(883051),
#   'type': 'R',
#   'name': 'Kettil the Gourmand',
#   'Blocking Thrower': 0,
#   'Blocking Scorer': 0,
#   'Scoring Thrower': 0,
#   'Triple': 0,
#   'Allrounder': 0},
#  NormalPlayer('12348483'): {'Completions': 0,
#   'Casualties': 0,
#   'Interceptions': 0,
#   'SPP': 0,
#   'Blocks': 21,
#   'Pass': 0,
#   'MVP': 0,
#   'Rush': 0,
#   'Turnms': 73,
#   'Fouls': 2,
#   'Touchdowns': 0,
#   'perf': [('L', 4024847),
#    ('D', 4029013),
#    ('W', 4029542),
#    ('L', 4031344),
#    ('W', 4033076),
#    ('W', 4034337),
#    ('L', 4041379)],
#   'team': Team(883051),
#   'type': 'R',
#   'name': 'Langley the Doomed',
#   'Blocking Thrower': 0,
#   'Blocking Scorer': 0,
#   'Scoring Thrower': 0,
#   'Triple': 0,
#   'Allrounder': 0},
#  NormalPlayer('12402229'): {'Completions': 0,
#   'Casualties': 2,
#   'Interceptions': 0,
#   'SPP': 14,
#   'Blocks': 25,
#   'Pass': 0,
#   'MVP': 2,
#   'Rush': 0,
#   'Turnms': 82,
#   'Fouls': 0,
#   'Touchdowns': 0,
#   'perf': [('L', 4024847),
#    ('D', 4029013),
#    ('W', 4029542),
#    ('L', 4031344),
#    ('W', 4033076),
#    ('W', 4034337),
#    ('L', 4041379)],
#   'team': Team(883051),
#   'type': 'R',
#   'name': 'The Irreverent Sindri',
#   'Blocking Thrower': 0,
#   'Blocking Scorer': 0,
#   'Scoring Thrower': 0,
#   'Triple': 0,
#   'Allrounder': 0},
#  NormalPlayer('12424263'): {'Completions': 0,
#   'Casualties': 1,
#   'Interceptions': 0,
#   'SPP': 7,
#   'Blocks': 26,
#   'Pass': 0,
#   'MVP': 1,
#   'Rush': 0,
#   'Turnms': 97,
#   'Fouls': 0,
#   'Touchdowns': 0,
#   'perf': [('L', 4024847),
#    ('D', 4029013),
#    ('W', 4029542),
#    ('L', 4031344),
#    ('W', 4033076),
#    ('W', 4034337),
#    ('L', 4041379)],
#   'team': Team(883051),
#   'type': 'R',
#   'name': 'Halvdan Halvarson',
#   'Blocking Thrower': 0,
#   'Blocking Scorer': 0,
#   'Scoring Thrower': 0,
#   'Triple': 0,
#   'Allrounder': 0},
#  NormalPlayer('12173110'): {'Completions': 0,
#   'Casualties': 4,
#   'Interceptions': 0,
#   'SPP': 8,
#   'Blocks': 24,
#   'Pass': 0,
#   'MVP': 0,
#   'Rush': 0,
#   'Turnms': 98,
#   'Fouls': 0,
#   'Touchdowns': 0,
#   'perf': [('W', 4024847),
#    ('W', 4027540),
#    ('W', 4027982),
#    ('L', 4031147),
#    ('L', 4032572),
#    ('L', 4036761),
#    ('L', 4037448)],
#   'team': Team(900747),
#   'type': 'B',
#   'name': 'Stonemuncher the Ancient',
#   'Blocking Thrower': 0,
#   'Blocking Scorer': 0,
#   'Scoring Thrower': 0,
#   'Triple': 0,
#   'Allrounder': 0},
#  NormalPlayer('12173143'): {'Completions': 0,
#   'Casualties': 1,
#   'Interceptions': 0,
#   'SPP': 8,
#   'Blocks': 8,
#   'Pass': 1,
#   'MVP': 0,
#   'Rush': 45,
#   'Turnms': 47,
#   'Fouls': 0,
#   'Touchdowns': 2,
#   'perf': [('W', 4024847), ('W', 4027540), ('W', 4027982)],
#   'team': Team(900747),
#   'type': 'R',
#   'name': 'Dialor the Noble',
#   'dead': [2, 6, 'fouled', '12117792'],
#   'Blocking Thrower': 0,
#   'Blocking Scorer': 1,
#   'Scoring Thrower': 0,
#   'Triple': 0,
#   'Allrounder': 0},
#  NormalPlayer('12173145'): {'Completions': 3,
#   'Casualties': 2,
#   'Interceptions': 0,
#   'SPP': 7,
#   'Blocks': 13,
#   'Pass': 10,
#   'MVP': 0,
#   'Rush': 62,
#   'Turnms': 86,
#   'Fouls': 0,
#   'Touchdowns': 0,
#   'perf': [('W', 4024847),
#    ('W', 4027540),
#    ('W', 4027982),
#    ('L', 4031147),
#    ('L', 4032572),
#    ('L', 4036761),
#    ('L', 4037448)],
#   'team': Team(900747),
#   'type': 'R',
#   'name': 'Khras the Enslaved',
#   'Blocking Thrower': 2,
#   'Blocking Scorer': 0,
#   'Scoring Thrower': 0,
#   'Triple': 0,
#   'Allrounder': 0},
#  NormalPlayer('12173151'): {'Completions': 0,
#   'Casualties': 1,
#   'Interceptions': 0,
#   'SPP': 2,
#   'Blocks': 16,
#   'Pass': 0,
#   'MVP': 0,
#   'Rush': 9,
#   'Turnms': 91,
#   'Fouls': 1,
#   'Touchdowns': 0,
#   'perf': [('W', 4024847),
#    ('W', 4027540),
#    ('W', 4027982),
#    ('L', 4031147),
#    ('L', 4032572),
#    ('L', 4036761),
#    ('L', 4037448)],
#   'team': Team(900747),
#   'type': 'R',
#   'name': 'Hrkas Prouddeath',
#   'Blocking Thrower': 0,
#   'Blocking Scorer': 0,
#   'Scoring Thrower': 0,
#   'Triple': 0,
#   'Allrounder': 0},
#  NormalPlayer('12173153'): {'Completions': 0,
#   'Casualties': 1,
#   'Interceptions': 0,
#   'SPP': 8,
#   'Blocks': 14,
#   'Pass': 0,
#   'MVP': 0,
#   'Rush': 16,
#   'Turnms': 97,
#   'Fouls': 0,
#   'Touchdowns': 2,
#   'perf': [('W', 4024847),
#    ('W', 4027540),
#    ('W', 4027982),
#    ('L', 4031147),
#    ('L', 4032572),
#    ('L', 4036761),
#    ('L', 4037448)],
#   'team': Team(900747),
#   'type': 'R',
#   'name': 'Ghras Paingiver',
#   'Blocking Thrower': 0,
#   'Blocking Scorer': 1,
#   'Scoring Thrower': 0,
#   'Triple': 0,
#   'Allrounder': 0},
#  NormalPlayer('12173155'): {'Completions': 0,
#   'Casualties': 11,
#   'Interceptions': 0,
#   'SPP': 22,
#   'Blocks': 91,
#   'Pass': 0,
#   'MVP': 0,
#   'Rush': 0,
#   'Turnms': 114,
#   'Fouls': 0,
#   'Touchdowns': 0,
#   'perf': [('W', 4024847),
#    ('W', 4027540),
#    ('W', 4027982),
#    ('L', 4031147),
#    ('L', 4032572),
#    ('L', 4036761),
#    ('L', 4037448)],
#   'team': Team(900747),
#   'type': 'R',
#   'name': 'Frazsa Grimhand',
#   'Blocking Thrower': 0,
#   'Blocking Scorer': 0,
#   'Scoring Thrower': 0,
#   'Triple': 0,
#   'Allrounder': 0},
#  NormalPlayer('12296160'): {'Completions': 0,
#   'Casualties': 5,
#   'Interceptions': 1,
#   'SPP': 12,
#   'Blocks': 38,
#   'Pass': 0,
#   'MVP': 0,
#   'Rush': 0,
#   'Turnms': 114,
#   'Fouls': 0,
#   'Touchdowns': 0,
#   'perf': [('W', 4024847),
#    ('W', 4027540),
#    ('W', 4027982),
#    ('L', 4031147),
#    ('L', 4032572),
#    ('L', 4036761),
#    ('L', 4037448)],
#   'team': Team(900747),
#   'type': 'B',
#   'name': 'Krank Cracker',
#   'Blocking Thrower': 0,
#   'Blocking Scorer': 0,
#   'Scoring Thrower': 0,
#   'Triple': 0,
#   'Allrounder': 0},
#  NormalPlayer('12320799'): {'Completions': 0,
#   'Casualties': 0,
#   'Interceptions': 0,
#   'SPP': 10,
#   'Blocks': 39,
#   'Pass': 0,
#   'MVP': 2,
#   'Rush': 0,
#   'Turnms': 100,
#   'Fouls': 0,
#   'Touchdowns': 0,
#   'perf': [('W', 4024847),
#    ('W', 4027540),
#    ('W', 4027982),
#    ('L', 4031147),
#    ('L', 4032572),
#    ('L', 4036761),
#    ('L', 4037448)],
#   'team': Team(900747),
#   'type': 'R',
#   'name': 'GRaarzas',
#   'Blocking Thrower': 0,
#   'Blocking Scorer': 0,
#   'Scoring Thrower': 0,
#   'Triple': 0,
#   'Allrounder': 0},
#  NormalPlayer('12399357'): {'Completions': 1,
#   'Casualties': 0,
#   'Interceptions': 0,
#   'SPP': 1,
#   'Blocks': 10,
#   'Pass': -1,
#   'MVP': 0,
#   'Rush': 4,
#   'Turnms': 70,
#   'Fouls': 2,
#   'Touchdowns': 0,
#   'perf': [('W', 4024847),
#    ('W', 4027540),
#    ('W', 4027982),
#    ('L', 4031147),
#    ('L', 4032572),
#    ('L', 4036761),
#    ('L', 4037448)],
#   'team': Team(900747),
#   'type': 'R',
#   'name': 'Orja Coldless',
#   'Blocking Thrower': 0,
#   'Blocking Scorer': 0,
#   'Scoring Thrower': 0,
#   'Triple': 0,
#   'Allrounder': 0},
#  NormalPlayer('12399358'): {'Completions': 0,
#   'Casualties': 0,
#   'Interceptions': 0,
#   'SPP': 0,
#   'Blocks': 11,
#   'Pass': 0,
#   'MVP': 0,
#   'Rush': 6,
#   'Turnms': 75,
#   'Fouls': 0,
#   'Touchdowns': 0,
#   'perf': [('W', 4024847),
#    ('W', 4027540),
#    ('W', 4027982),
#    ('L', 4031147),
#    ('L', 4032572),
#    ('L', 4036761),
#    ('L', 4037448)],
#   'team': Team(900747),
#   'type': 'R',
#   'name': 'Hairy Chrizz',
#   'Blocking Thrower': 0,
#   'Blocking Scorer': 0,
#   'Scoring Thrower': 0,
#   'Triple': 0,
#   'Allrounder': 0},
#  NormalPlayer('12399363'): {'Completions': 0,
#   'Casualties': 0,
#   'Interceptions': 0,
#   'SPP': 8,
#   'Blocks': 0,
#   'Pass': 0,
#   'MVP': 1,
#   'Rush': 0,
#   'Turnms': 27,
#   'Fouls': 0,
#   'Touchdowns': 1,
#   'perf': [('W', 4024847),
#    ('W', 4027540),
#    ('W', 4027982),
#    ('L', 4031147),
#    ('L', 4032572),
#    ('L', 4036761),
#    ('L', 4037448)],
#   'team': Team(900747),
#   'type': 'R',
#   'name': 'Squishy Bob',
#   'Blocking Thrower': 0,
#   'Blocking Scorer': 0,
#   'Scoring Thrower': 0,
#   'Triple': 0,
#   'Allrounder': 0},
#  NormalPlayer('12422174'): {'Completions': 0,
#   'Casualties': 0,
#   'Interceptions': 0,
#   'SPP': 15,
#   'Blocks': 12,
#   'Pass': 0,
#   'MVP': 3,
#   'Rush': 0,
#   'Turnms': 31,
#   'Fouls': 0,
#   'Touchdowns': 0,
#   'perf': [('W', 4024847),
#    ('W', 4027540),
#    ('W', 4027982),
#    ('L', 4031147),
#    ('L', 4032572),
#    ('L', 4036761),
#    ('L', 4037448)],
#   'team': Team(900747),
#   'type': 'R',
#   'name': 'Oris Devistator',
#   'Blocking Thrower': 0,
#   'Blocking Scorer': 0,
#   'Scoring Thrower': 0,
#   'Triple': 0,
#   'Allrounder': 0},
#  NormalPlayer('12450012'): {'Completions': 0,
#   'Casualties': 1,
#   'Interceptions': 0,
#   'SPP': 2,
#   'Blocks': 6,
#   'Pass': 0,
#   'MVP': 0,
#   'Rush': 0,
#   'Turnms': 33,
#   'Fouls': 0,
#   'Touchdowns': 0,
#   'perf': [('W', 4024847),
#    ('W', 4027540),
#    ('W', 4027982),
#    ('L', 4031147),
#    ('L', 4032572),
#    ('L', 4036761),
#    ('L', 4037448)],
#   'team': Team(900747),
#   'type': 'R',
#   'name': 'Spliff Skyrim',
#   'Blocking Thrower': 0,
#   'Blocking Scorer': 0,
#   'Scoring Thrower': 0,
#   'Triple': 0,
#   'Allrounder': 0},
#  NormalPlayer('12450013'): {'Completions': 0,
#   'Casualties': 0,
#   'Interceptions': 0,
#   'SPP': 0,
#   'Blocks': 10,
#   'Pass': 0,
#   'MVP': 0,
#   'Rush': 0,
#   'Turnms': 22,
#   'Fouls': 1,
#   'Touchdowns': 0,
#   'perf': [('W', 4024847),
#    ('W', 4027540),
#    ('W', 4027982),
#    ('L', 4031147),
#    ('L', 4032572),
#    ('L', 4036761),
#    ('L', 4037448)],
#   'team': Team(900747),
#   'type': 'R',
#   'name': 'Grasna Bonebreaker',
#   'Blocking Thrower': 0,
#   'Blocking Scorer': 0,
#   'Scoring Thrower': 0,
#   'Triple': 0,
#   'Allrounder': 0},
#  NormalPlayer('12022005'): {'Completions': 0,
#   'Casualties': 0,
#   'Interceptions': 0,
#   'SPP': 0,
#   'Blocks': 28,
#   'Pass': 0,
#   'MVP': 0,
#   'Rush': 4,
#   'Turnms': 100,
#   'Fouls': 0,
#   'Touchdowns': 0,
#   'perf': [('D', 4025662),
#    ('D', 4026367),
#    ('L', 4029542),
#    ('W', 4031147),
#    ('D', 4032047),
#    ('L', 4034603),
#    ('L', 4037369)],
#   'team': Team(891237),
#   'type': 'R',
#   'name': 'Swan Alphon',
#   'Blocking Thrower': 0,
#   'Blocking Scorer': 0,
#   'Scoring Thrower': 0,
#   'Triple': 0,
#   'Allrounder': 0},
#  NormalPlayer('12022006'): {'Completions': 5,
#   'Casualties': 0,
#   'Interceptions': 0,
#   'SPP': 5,
#   'Blocks': 16,
#   'Pass': 10,
#   'MVP': 0,
#   'Rush': 26,
#   'Turnms': 92,
#   'Fouls': 1,
#   'Touchdowns': 0,
#   'perf': [('D', 4025662),
#    ('D', 4026367),
#    ('L', 4029542),
#    ('W', 4031147),
#    ('D', 4032047),
#    ('L', 4034603),
#    ('L', 4037369)],
#   'team': Team(891237),
#   'type': 'R',
#   'name': 'Heni Hethurin',
#   'Blocking Thrower': 0,
#   'Blocking Scorer': 0,
#   'Scoring Thrower': 0,
#   'Triple': 0,
#   'Allrounder': 0},
#  NormalPlayer('12022008'): {'Completions': 0,
#   'Casualties': 0,
#   'Interceptions': 0,
#   'SPP': 0,
#   'Blocks': 16,
#   'Pass': 0,
#   'MVP': 0,
#   'Rush': 0,
#   'Turnms': 55,
#   'Fouls': 0,
#   'Touchdowns': 0,
#   'perf': [('D', 4025662),
#    ('D', 4026367),
#    ('L', 4029542),
#    ('W', 4031147),
#    ('D', 4032047),
#    ('L', 4034603),
#    ('L', 4037369)],
#   'team': Team(891237),
#   'type': 'R',
#   'name': 'Tety Goweston',
#   'Blocking Thrower': 0,
#   'Blocking Scorer': 0,
#   'Scoring Thrower': 0,
#   'Triple': 0,
#   'Allrounder': 0},
#  NormalPlayer('12022022'): {'Completions': 0,
#   'Casualties': 2,
#   'Interceptions': 0,
#   'SPP': 4,
#   'Blocks': 32,
#   'Pass': 0,
#   'MVP': 0,
#   'Rush': 0,
#   'Turnms': 101,
#   'Fouls': 0,
#   'Touchdowns': 0,
#   'perf': [('D', 4025662),
#    ('D', 4026367),
#    ('L', 4029542),
#    ('W', 4031147),
#    ('D', 4032047),
#    ('L', 4034603),
#    ('L', 4037369)],
#   'team': Team(891237),
#   'type': 'R',
#   'name': 'Mirilan Antegobon',
#   'Blocking Thrower': 0,
#   'Blocking Scorer': 0,
#   'Scoring Thrower': 0,
#   'Triple': 0,
#   'Allrounder': 0},
#  NormalPlayer('12104982'): {'Completions': 1,
#   'Casualties': 1,
#   'Interceptions': 0,
#   'SPP': 14,
#   'Blocks': 38,
#   'Pass': 3,
#   'MVP': 1,
#   'Rush': 45,
#   'Turnms': 78,
#   'Fouls': 0,
#   'Touchdowns': 2,
#   'perf': [('D', 4025662),
#    ('D', 4026367),
#    ('L', 4029542),
#    ('W', 4031147),
#    ('D', 4032047),
#    ('L', 4034603),
#    ('L', 4037369)],
#   'team': Team(891237),
#   'type': 'R',
#   'name': 'Meret Scuffedon',
#   'Blocking Thrower': 1,
#   'Blocking Scorer': 1,
#   'Scoring Thrower': 1,
#   'Triple': 1,
#   'Allrounder': 0},
#  NormalPlayer('12162547'): {'Completions': 0,
#   'Casualties': 0,
#   'Interceptions': 0,
#   'SPP': 18,
#   'Blocks': 14,
#   'Pass': 0,
#   'MVP': 3,
#   'Rush': 17,
#   'Turnms': 72,
#   'Fouls': 2,
#   'Touchdowns': 1,
#   'perf': [('D', 4025662),
#    ('D', 4026367),
#    ('L', 4029542),
#    ('W', 4031147),
#    ('D', 4032047),
#    ('L', 4034603),
#    ('L', 4037369)],
#   'team': Team(891237),
#   'type': 'R',
#   'name': 'Foni Piemondon',
#   'Blocking Thrower': 0,
#   'Blocking Scorer': 0,
#   'Scoring Thrower': 0,
#   'Triple': 0,
#   'Allrounder': 0},
#  NormalPlayer('12219903'): {'Completions': 0,
#   'Casualties': 0,
#   'Interceptions': 0,
#   'SPP': 0,
#   'Blocks': 0,
#   'Pass': 0,
#   'MVP': 0,
#   'Rush': 0,
#   'Turnms': 1,
#   'Fouls': 0,
#   'Touchdowns': 0,
#   'perf': [('D', 4025662)],
#   'team': Team(891237),
#   'type': 'R',
#   'name': 'Rebo Rebelodon',
#   'dead': [1, 2, 'blocked', '12117788'],
#   'Blocking Thrower': 0,
#   'Blocking Scorer': 0,
#   'Scoring Thrower': 0,
#   'Triple': 0,
#   'Allrounder': 0},
#  NormalPlayer('12229237'): {'Completions': 2,
#   'Casualties': 0,
#   'Interceptions': 0,
#   'SPP': 11,
#   'Blocks': 13,
#   'Pass': 1,
#   'MVP': 0,
#   'Rush': 60,
#   'Turnms': 96,
#   'Fouls': 0,
#   'Touchdowns': 3,
#   'perf': [('D', 4025662),
#    ('D', 4026367),
#    ('L', 4029542),
#    ('W', 4031147),
#    ('D', 4032047),
#    ('L', 4034603),
#    ('L', 4037369)],
#   'team': Team(891237),
#   'type': 'R',
#   'name': 'Coron Shottelodon',
#   'Blocking Thrower': 0,
#   'Blocking Scorer': 0,
#   'Scoring Thrower': 2,
#   'Triple': 0,
#   'Allrounder': 0},
#  NormalPlayer('12354844'): {'Completions': 0,
#   'Casualties': 0,
#   'Interceptions': 0,
#   'SPP': 0,
#   'Blocks': 6,
#   'Pass': 0,
#   'MVP': 0,
#   'Rush': 0,
#   'Turnms': 54,
#   'Fouls': 0,
#   'Touchdowns': 0,
#   'perf': [('D', 4025662), ('D', 4026367), ('L', 4029542), ('W', 4031147)],
#   'team': Team(891237),
#   'type': 'R',
#   'name': 'Heni Heturin Jr.',
#   'dead': [2, 6, 'blocked', '12173155'],
#   'Blocking Thrower': 0,
#   'Blocking Scorer': 0,
#   'Scoring Thrower': 0,
#   'Triple': 0,
#   'Allrounder': 0},
#  NormalPlayer('12360754'): {'Completions': 0,
#   'Casualties': 0,
#   'Interceptions': 0,
#   'SPP': 8,
#   'Blocks': 45,
#   'Pass': 0,
#   'MVP': 1,
#   'Rush': 17,
#   'Turnms': 79,
#   'Fouls': 0,
#   'Touchdowns': 1,
#   'perf': [('D', 4025662),
#    ('D', 4026367),
#    ('L', 4029542),
#    ('W', 4031147),
#    ('D', 4032047),
#    ('L', 4034603),
#    ('L', 4037369)],
#   'team': Team(891237),
#   'type': 'R',
#   'name': 'Melith Astenodon',
#   'Blocking Thrower': 0,
#   'Blocking Scorer': 0,
#   'Scoring Thrower': 0,
#   'Triple': 0,
#   'Allrounder': 0},
#  NormalPlayer('12492950'): {'Completions': 1,
#   'Casualties': 0,
#   'Interceptions': 0,
#   'SPP': 6,
#   'Blocks': 13,
#   'Pass': 1,
#   'MVP': 1,
#   'Rush': 7,
#   'Turnms': 73,
#   'Fouls': 0,
#   'Touchdowns': 0,
#   'perf': [('D', 4025662),
#    ('D', 4026367),
#    ('L', 4029542),
#    ('W', 4031147),
#    ('D', 4032047),
#    ('L', 4034603),
#    ('L', 4037369)],
#   'team': Team(891237),
#   'type': 'R',
#   'name': 'Minth Lippidon',
#   'Blocking Thrower': 0,
#   'Blocking Scorer': 0,
#   'Scoring Thrower': 0,
#   'Triple': 0,
#   'Allrounder': 0},
#  NormalPlayer('12117786'): {'Completions': 0,
#   'Casualties': 0,
#   'Interceptions': 0,
#   'SPP': 5,
#   'Blocks': 4,
#   'Pass': 0,
#   'MVP': 1,
#   'Rush': 0,
#   'Turnms': 44,
#   'Fouls': 7,
#   'Touchdowns': 0,
#   'perf': [('D', 4025662),
#    ('D', 4026666),
#    ('L', 4027982),
#    ('W', 4031344),
#    ('W', 4033320),
#    ('D', 4033652),
#    ('L', 4034549)],
#   'team': Team(896972),
#   'type': 'R',
#   'name': 'Gorbad Faceclompah',
#   'dead': [2, 1, 'blocked', '12165569'],
#   'Blocking Thrower': 0,
#   'Blocking Scorer': 0,
#   'Scoring Thrower': 0,
#   'Triple': 0,
#   'Allrounder': 0},
#  NormalPlayer('12117788'): {'Completions': 0,
#   'Casualties': 2,
#   'Interceptions': 0,
#   'SPP': 4,
#   'Blocks': 34,
#   'Pass': 0,
#   'MVP': 0,
#   'Rush': 0,
#   'Turnms': 72,
#   'Fouls': 0,
#   'Touchdowns': 0,
#   'perf': [('D', 4025662),
#    ('D', 4026666),
#    ('L', 4027982),
#    ('W', 4031344),
#    ('W', 4033320),
#    ('D', 4033652),
#    ('L', 4034549)],
#   'team': Team(896972),
#   'type': 'R',
#   'name': 'Poppy Merribuck',
#   'Blocking Thrower': 0,
#   'Blocking Scorer': 0,
#   'Scoring Thrower': 0,
#   'Triple': 0,
#   'Allrounder': 0},
#  NormalPlayer('12117790'): {'Completions': 0,
#   'Casualties': 2,
#   'Interceptions': 0,
#   'SPP': 9,
#   'Blocks': 46,
#   'Pass': 0,
#   'MVP': 1,
#   'Rush': 0,
#   'Turnms': 78,
#   'Fouls': 0,
#   'Touchdowns': 0,
#   'perf': [('D', 4025662),
#    ('D', 4026666),
#    ('L', 4027982),
#    ('W', 4031344),
#    ('W', 4033320),
#    ('D', 4033652),
#    ('L', 4034549)],
#   'team': Team(896972),
#   'type': 'R',
#   'name': 'Balthasar the Youthful',
#   'Blocking Thrower': 0,
#   'Blocking Scorer': 0,
#   'Scoring Thrower': 0,
#   'Triple': 0,
#   'Allrounder': 0},
#  NormalPlayer('12117791'): {'Completions': 0,
#   'Casualties': 2,
#   'Interceptions': 0,
#   'SPP': 4,
#   'Blocks': 12,
#   'Pass': 0,
#   'MVP': 0,
#   'Rush': 0,
#   'Turnms': 49,
#   'Fouls': 1,
#   'Touchdowns': 0,
#   'perf': [('D', 4025662),
#    ('D', 4026666),
#    ('L', 4027982),
#    ('W', 4031344),
#    ('W', 4033320),
#    ('D', 4033652),
#    ('L', 4034549)],
#   'team': Team(896972),
#   'type': 'R',
#   'name': 'Konrad the Enchanter',
#   'Blocking Thrower': 0,
#   'Blocking Scorer': 0,
#   'Scoring Thrower': 0,
#   'Triple': 0,
#   'Allrounder': 0},
#  NormalPlayer('12117792'): {'Completions': 0,
#   'Casualties': 0,
#   'Interceptions': 0,
#   'SPP': 3,
#   'Blocks': 11,
#   'Pass': 1,
#   'MVP': 0,
#   'Rush': 12,
#   'Turnms': 63,
#   'Fouls': 3,
#   'Touchdowns': 1,
#   'perf': [('D', 4025662),
#    ('D', 4026666),
#    ('L', 4027982),
#    ('W', 4031344),
#    ('W', 4033320),
#    ('D', 4033652),
#    ('L', 4034549)],
#   'team': Team(896972),
#   'type': 'R',
#   'name': 'Gottlieb Thälmann of Averland',
#   'Blocking Thrower': 0,
#   'Blocking Scorer': 0,
#   'Scoring Thrower': 0,
#   'Triple': 0,
#   'Allrounder': 0},
#  NormalPlayer('12117795'): {'Completions': 0,
#   'Casualties': 3,
#   'Interceptions': 0,
#   'SPP': 11,
#   'Blocks': 37,
#   'Pass': 0,
#   'MVP': 1,
#   'Rush': -1,
#   'Turnms': 101,
#   'Fouls': 1,
#   'Touchdowns': 0,
#   'perf': [('D', 4025662),
#    ('D', 4026666),
#    ('L', 4027982),
#    ('W', 4031344),
#    ('W', 4033320),
#    ('D', 4033652),
#    ('L', 4034549)],
#   'team': Team(896972),
#   'type': 'R',
#   'name': 'Ferrimora of the Waxing Moon',
#   'dead': [2, 5, 'fouled', '12121974'],
#   'Blocking Thrower': 0,
#   'Blocking Scorer': 0,
#   'Scoring Thrower': 0,
#   'Triple': 0,
#   'Allrounder': 0},
#  NormalPlayer('12117802'): {'Completions': 0,
#   'Casualties': 0,
#   'Interceptions': 0,
#   'SPP': 0,
#   'Blocks': 13,
#   'Pass': 2,
#   'MVP': 0,
#   'Rush': 46,
#   'Turnms': 69,
#   'Fouls': 0,
#   'Touchdowns': 0,
#   'perf': [('D', 4025662),
#    ('D', 4026666),
#    ('L', 4027982),
#    ('W', 4031344),
#    ('W', 4033320),
#    ('D', 4033652),
#    ('L', 4034549)],
#   'team': Team(896972),
#   'type': 'R',
#   'name': 'Urkrasour the Obedient',
#   'Blocking Thrower': 0,
#   'Blocking Scorer': 0,
#   'Scoring Thrower': 0,
#   'Triple': 0,
#   'Allrounder': 0},
#  NormalPlayer('12173327'): {'Completions': 0,
#   'Casualties': 2,
#   'Interceptions': 0,
#   'SPP': 7,
#   'Blocks': 36,
#   'Pass': 0,
#   'MVP': 0,
#   'Rush': 8,
#   'Turnms': 89,
#   'Fouls': 0,
#   'Touchdowns': 1,
#   'perf': [('D', 4025662),
#    ('D', 4026666),
#    ('L', 4027982),
#    ('W', 4031344),
#    ('W', 4033320),
#    ('D', 4033652),
#    ('L', 4034549)],
#   'team': Team(896972),
#   'type': 'R',
#   'name': 'Draco the Ascendent',
#   'Blocking Thrower': 0,
#   'Blocking Scorer': 1,
#   'Scoring Thrower': 0,
#   'Triple': 0,
#   'Allrounder': 0},
#  NormalPlayer('12179724'): {'Completions': 0,
#   'Casualties': 0,
#   'Interceptions': 0,
#   'SPP': 3,
#   'Blocks': 29,
#   'Pass': 0,
#   'MVP': 0,
#   'Rush': 7,
#   'Turnms': 74,
#   'Fouls': 1,
#   'Touchdowns': 1,
#   'perf': [('D', 4025662),
#    ('D', 4026666),
#    ('L', 4027982),
#    ('W', 4031344),
#    ('W', 4033320),
#    ('D', 4033652),
#    ('L', 4034549)],
#   'team': Team(896972),
#   'type': 'R',
#   'name': 'The Xenith of Devotion',
#   'Blocking Thrower': 0,
#   'Blocking Scorer': 0,
#   'Scoring Thrower': 0,
#   'Triple': 0,
#   'Allrounder': 0},
#  NormalPlayer('12230477'): {'Completions': 1,
#   'Casualties': 2,
#   'Interceptions': 0,
#   'SPP': 5,
#   'Blocks': 31,
#   'Pass': 1,
#   'MVP': 0,
#   'Rush': 3,
#   'Turnms': 74,
#   'Fouls': 1,
#   'Touchdowns': 0,
#   'perf': [('D', 4025662),
#    ('D', 4026666),
#    ('L', 4027982),
#    ('W', 4031344),
#    ('W', 4033320),
#    ('D', 4033652),
#    ('L', 4034549)],
#   'team': Team(896972),
#   'type': 'R',
#   'name': '*Whip-crack sound effect followed by whinnying horse*',
#   'Blocking Thrower': 1,
#   'Blocking Scorer': 0,
#   'Scoring Thrower': 0,
#   'Triple': 0,
#   'Allrounder': 0},
#  NormalPlayer('12235198'): {'Completions': 0,
#   'Casualties': 3,
#   'Interceptions': 0,
#   'SPP': 6,
#   'Blocks': 45,
#   'Pass': 0,
#   'MVP': 0,
#   'Rush': 0,
#   'Turnms': 82,
#   'Fouls': 0,
#   'Touchdowns': 0,
#   'perf': [('D', 4025662),
#    ('D', 4026666),
#    ('L', 4027982),
#    ('W', 4031344),
#    ('W', 4033320),
#    ('D', 4033652),
#    ('L', 4034549)],
#   'team': Team(896972),
#   'type': 'R',
#   'name': 'Valanduil of House Meliane, reborn',
#   'Blocking Thrower': 0,
#   'Blocking Scorer': 0,
#   'Scoring Thrower': 0,
#   'Triple': 0,
#   'Allrounder': 0},
#  NormalPlayer('12357064'): {'Completions': 0,
#   'Casualties': 0,
#   'Interceptions': 0,
#   'SPP': 13,
#   'Blocks': 7,
#   'Pass': 0,
#   'MVP': 2,
#   'Rush': 11,
#   'Turnms': 35,
#   'Fouls': 1,
#   'Touchdowns': 1,
#   'perf': [('D', 4025662),
#    ('D', 4026666),
#    ('L', 4027982),
#    ('W', 4031344),
#    ('W', 4033320),
#    ('D', 4033652),
#    ('L', 4034549)],
#   'team': Team(896972),
#   'type': 'R',
#   'name': 'The Painted Warlock',
#   'Blocking Thrower': 0,
#   'Blocking Scorer': 0,
#   'Scoring Thrower': 0,
#   'Triple': 0,
#   'Allrounder': 0},
#  NormalPlayer('12402972'): {'Completions': 0,
#   'Casualties': 0,
#   'Interceptions': 0,
#   'SPP': 3,
#   'Blocks': 17,
#   'Pass': 1,
#   'MVP': 0,
#   'Rush': 28,
#   'Turnms': 56,
#   'Fouls': 1,
#   'Touchdowns': 1,
#   'perf': [('D', 4025662),
#    ('D', 4026666),
#    ('L', 4027982),
#    ('W', 4031344),
#    ('W', 4033320),
#    ('D', 4033652),
#    ('L', 4034549)],
#   'team': Team(896972),
#   'type': 'R',
#   'name': 'Lembit Opik',
#   'Blocking Thrower': 0,
#   'Blocking Scorer': 0,
#   'Scoring Thrower': 0,
#   'Triple': 0,
#   'Allrounder': 0},
#  NormalPlayer('12451233'): {'Completions': 0,
#   'Casualties': 1,
#   'Interceptions': 0,
#   'SPP': 7,
#   'Blocks': 3,
#   'Pass': 0,
#   'MVP': 1,
#   'Rush': 6,
#   'Turnms': 32,
#   'Fouls': 0,
#   'Touchdowns': 0,
#   'perf': [('D', 4025662),
#    ('D', 4026666),
#    ('L', 4027982),
#    ('W', 4031344),
#    ('W', 4033320),
#    ('D', 4033652),
#    ('L', 4034549)],
#   'team': Team(896972),
#   'type': 'R',
#   'name': 'Silk',
#   'Blocking Thrower': 0,
#   'Blocking Scorer': 0,
#   'Scoring Thrower': 0,
#   'Triple': 0,
#   'Allrounder': 0},
#  NormalPlayer('12464407'): {'Completions': 2,
#   'Casualties': 1,
#   'Interceptions': 0,
#   'SPP': 24,
#   'Blocks': 17,
#   'Pass': 5,
#   'MVP': 1,
#   'Rush': 100,
#   'Turnms': 95,
#   'Fouls': 4,
#   'Touchdowns': 5,
#   'perf': [('D', 4025662),
#    ('D', 4026666),
#    ('L', 4027982),
#    ('W', 4031344),
#    ('W', 4033320),
#    ('D', 4033652),
#    ('L', 4034549)],
#   'team': Team(896972),
#   'type': 'R',
#   'name': 'Bartholomew of the Northern Tower',
#   'Blocking Thrower': 1,
#   'Blocking Scorer': 1,
#   'Scoring Thrower': 2,
#   'Triple': 1,
#   'Allrounder': 0},
#  StarPlayer('STAR-7545'): {'Completions': 0,
#   'Casualties': 2,
#   'Interceptions': 0,
#   'SPP': 4,
#   'Blocks': 14,
#   'Pass': 0,
#   'MVP': 0,
#   'Rush': 0,
#   'Turnms': 31,
#   'Fouls': 0,
#   'Touchdowns': 0,
#   'perf': [('D', 4025662), ('W', 4031344)],
#   'team': Team(896972),
#   'type': 'S',
#   'name': 'Angus Porterhouse',
#   'Blocking Thrower': 0,
#   'Blocking Scorer': 0,
#   'Scoring Thrower': 0,
#   'Triple': 0,
#   'Allrounder': 0},
#  NormalPlayer('12121959'): {'Completions': 0,
#   'Casualties': 1,
#   'Interceptions': 0,
#   'SPP': 2,
#   'Blocks': 32,
#   'Pass': 0,
#   'MVP': 0,
#   'Rush': 0,
#   'Turnms': 95,
#   'Fouls': 2,
#   'Touchdowns': 0,
#   'perf': [('L', 4026342),
#    ('L', 4027540),
#    ('L', 4029149),
#    ('L', 4030969),
#    ('D', 4032047),
#    ('L', 4034337),
#    ('W', 4034549)],
#   'team': Team(897353),
#   'type': 'R',
#   'name': 'Nis Atman',
#   'Blocking Thrower': 0,
#   'Blocking Scorer': 0,
#   'Scoring Thrower': 0,
#   'Triple': 0,
#   'Allrounder': 0},
#  NormalPlayer('12121960'): {'Completions': 0,
#   'Casualties': 0,
#   'Interceptions': 0,
#   'SPP': 0,
#   'Blocks': 0,
#   'Pass': 0,
#   'MVP': 0,
#   'Rush': 0,
#   'Turnms': 6,
#   'Fouls': 5,
#   'Touchdowns': 0,
#   'perf': [('L', 4026342), ('L', 4027540)],
#   'team': Team(897353),
#   'type': 'R',
#   'name': 'Sssues Ej',
#   'retired': True,
#   'Blocking Thrower': 0,
#   'Blocking Scorer': 0,
#   'Scoring Thrower': 0,
#   'Triple': 0,
#   'Allrounder': 0},
#  NormalPlayer('12121974'): {'Completions': 0,
#   'Casualties': 0,
#   'Interceptions': 0,
#   'SPP': 0,
#   'Blocks': 26,
#   'Pass': 0,
#   'MVP': 0,
#   'Rush': -2,
#   'Turnms': 90,
#   'Fouls': 3,
#   'Touchdowns': 0,
#   'perf': [('L', 4026342),
#    ('L', 4027540),
#    ('L', 4029149),
#    ('L', 4030969),
#    ('D', 4032047),
#    ('L', 4034337),
#    ('W', 4034549)],
#   'team': Team(897353),
#   'type': 'R',
#   'name': 'Pix Vamox',
#   'Blocking Thrower': 0,
#   'Blocking Scorer': 0,
#   'Scoring Thrower': 0,
#   'Triple': 0,
#   'Allrounder': 0},
#  NormalPlayer('12139096'): {'Completions': 0,
#   'Casualties': 0,
#   'Interceptions': 0,
#   'SPP': 0,
#   'Blocks': 0,
#   'Pass': 0,
#   'MVP': 0,
#   'Rush': 13,
#   'Turnms': 16,
#   'Fouls': 2,
#   'Touchdowns': 0,
#   'perf': [('L', 4026342),
#    ('L', 4027540),
#    ('L', 4029149),
#    ('L', 4030969),
#    ('D', 4032047),
#    ('L', 4034337),
#    ('W', 4034549)],
#   'team': Team(897353),
#   'type': 'R',
#   'name': 'Mos Passat',
#   'Blocking Thrower': 0,
#   'Blocking Scorer': 0,
#   'Scoring Thrower': 0,
#   'Triple': 0,
#   'Allrounder': 0},
#  NormalPlayer('12139099'): {'Completions': 2,
#   'Casualties': 1,
#   'Interceptions': 0,
#   'SPP': 9,
#   'Blocks': 14,
#   'Pass': 3,
#   'MVP': 1,
#   'Rush': 2,
#   'Turnms': 33,
#   'Fouls': 0,
#   'Touchdowns': 0,
#   'perf': [('L', 4026342),
#    ('L', 4027540),
#    ('L', 4029149),
#    ('L', 4030969),
#    ('D', 4032047),
#    ('L', 4034337),
#    ('W', 4034549)],
#   'team': Team(897353),
#   'type': 'R',
#   'name': 'Blu Ash',
#   'Blocking Thrower': 1,
#   'Blocking Scorer': 0,
#   'Scoring Thrower': 0,
#   'Triple': 0,
#   'Allrounder': 0},
#  NormalPlayer('12165569'): {'Completions': 0,
#   'Casualties': 2,
#   'Interceptions': 0,
#   'SPP': 4,
#   'Blocks': 39,
#   'Pass': 0,
#   'MVP': 0,
#   'Rush': 14,
#   'Turnms': 105,
#   'Fouls': 0,
#   'Touchdowns': 0,
#   'perf': [('L', 4026342),
#    ('L', 4027540),
#    ('L', 4029149),
#    ('L', 4030969),
#    ('D', 4032047),
#    ('L', 4034337),
#    ('W', 4034549)],
#   'team': Team(897353),
#   'type': 'R',
#   'name': 'Adenes Fujo',
#   'Blocking Thrower': 0,
#   'Blocking Scorer': 0,
#   'Scoring Thrower': 0,
#   'Triple': 0,
#   'Allrounder': 0},
#  NormalPlayer('12288426'): {'Completions': 0,
#   'Casualties': 3,
#   'Interceptions': 0,
#   'SPP': 6,
#   'Blocks': 23,
#   'Pass': 0,
#   'MVP': 0,
#   'Rush': -1,
#   'Turnms': 89,
#   'Fouls': 2,
#   'Touchdowns': 0,
#   'perf': [('L', 4026342),
#    ('L', 4027540),
#    ('L', 4029149),
#    ('L', 4030969),
#    ('D', 4032047),
#    ('L', 4034337),
#    ('W', 4034549)],
#   'team': Team(897353),
#   'type': 'R',
#   'name': 'Clay Dip',
#   'Blocking Thrower': 0,
#   'Blocking Scorer': 0,
#   'Scoring Thrower': 0,
#   'Triple': 0,
#   'Allrounder': 0},
#  NormalPlayer('12362496'): {'Completions': 0,
#   'Casualties': 0,
#   'Interceptions': 0,
#   'SPP': 0,
#   'Blocks': 3,
#   'Pass': 0,
#   'MVP': 0,
#   'Rush': 0,
#   'Turnms': 18,
#   'Fouls': 2,
#   'Touchdowns': 0,
#   'perf': [('L', 4026342), ('L', 4027540)],
#   'team': Team(897353),
#   'type': 'R',
#   'name': 'Vizesh',
#   'retired': True,
#   'Blocking Thrower': 0,
#   'Blocking Scorer': 0,
#   'Scoring Thrower': 0,
#   'Triple': 0,
#   'Allrounder': 0},
#  NormalPlayer('12362498'): {'Completions': 0,
#   'Casualties': 0,
#   'Interceptions': 0,
#   'SPP': 3,
#   'Blocks': 6,
#   'Pass': 0,
#   'MVP': 0,
#   'Rush': 19,
#   'Turnms': 34,
#   'Fouls': 1,
#   'Touchdowns': 1,
#   'perf': [('L', 4026342),
#    ('L', 4027540),
#    ('L', 4029149),
#    ('L', 4030969),
#    ('D', 4032047),
#    ('L', 4034337),
#    ('W', 4034549)],
#   'team': Team(897353),
#   'type': 'R',
#   'name': 'Wuwuhuwu',
#   'Blocking Thrower': 0,
# ...
#   'Interceptions': 0,
#   'SPP': 0,
#   'Blocks': 0,
#   'Pass': 0,
#   'MVP': 0,
#   'Rush': 0,
#   'Turnms': 2,
#   'Fouls': 0,
#   'Touchdowns': 0,
#   'perf': [('L', 4030781)],
#   'team': Team(899682),
#   'type': 'J',
#   'name': 'David Weakfield',
#   'retired': True,
#   'Blocking Thrower': 0,
#   'Blocking Scorer': 0,
#   'Scoring Thrower': 0,
#   'Triple': 0,
#   'Allrounder': 0},
#  NormalPlayer('12519733'): {'Completions': 0,
#   'Casualties': 1,
#   'Interceptions': 0,
#   'SPP': 2,
#   'Blocks': 10,
#   'Pass': 0,
#   'MVP': 0,
#   'Rush': 0,
#   'Turnms': 53,
#   'Fouls': 1,
#   'Touchdowns': 0,
#   'perf': [('W', 4030781),
#    ('W', 4030969),
#    ('W', 4032572),
#    ('D', 4033652),
#    ('W', 4041379)],
#   'team': Team(910344),
#   'type': 'R',
#   'name': 'Demitrius II',
#   'Blocking Thrower': 0,
#   'Blocking Scorer': 0,
#   'Scoring Thrower': 0,
#   'Triple': 0,
#   'Allrounder': 0},
#  MercenaryPlayer('MERC-7444-2428'): {'Completions': 0,
#   'Casualties': 0,
#   'Interceptions': 0,
#   'SPP': 0,
#   'Blocks': 2,
#   'Pass': 0,
#   'MVP': 0,
#   'Rush': 0,
#   'Turnms': 12,
#   'Fouls': 0,
#   'Touchdowns': 0,
#   'perf': [('L', 4030969)],
#   'team': Team(897353),
#   'type': 'M',
#   'name': 'Merc Air Elemental 4',
#   'Blocking Thrower': 0,
#   'Blocking Scorer': 0,
#   'Scoring Thrower': 0,
#   'Triple': 0,
#   'Allrounder': 0},
#  MercenaryPlayer('MERC-7444-2680'): {'Completions': 0,
#   'Casualties': 0,
#   'Interceptions': 0,
#   'SPP': 0,
#   'Blocks': 2,
#   'Pass': 0,
#   'MVP': 0,
#   'Rush': 0,
#   'Turnms': 12,
#   'Fouls': 0,
#   'Touchdowns': 0,
#   'perf': [('L', 4030969)],
#   'team': Team(897353),
#   'type': 'M',
#   'name': 'Merc Air Elemental 5',
#   'Blocking Thrower': 0,
#   'Blocking Scorer': 0,
#   'Scoring Thrower': 0,
#   'Triple': 0,
#   'Allrounder': 0},
#  MercenaryPlayer('MERC-7444-3217'): {'Completions': 0,
#   'Casualties': 0,
#   'Interceptions': 0,
#   'SPP': 0,
#   'Blocks': 2,
#   'Pass': 0,
#   'MVP': 0,
#   'Rush': 0,
#   'Turnms': 15,
#   'Fouls': 0,
#   'Touchdowns': 0,
#   'perf': [('L', 4030969)],
#   'team': Team(897353),
#   'type': 'M',
#   'name': 'Merc Air Elemental 3',
#   'Blocking Thrower': 0,
#   'Blocking Scorer': 0,
#   'Scoring Thrower': 0,
#   'Triple': 0,
#   'Allrounder': 0},
#  MercenaryPlayer('MERC-7444-3727'): {'Completions': 0,
#   'Casualties': 0,
#   'Interceptions': 0,
#   'SPP': 0,
#   'Blocks': 2,
#   'Pass': 0,
#   'MVP': 0,
#   'Rush': 0,
#   'Turnms': 15,
#   'Fouls': 0,
#   'Touchdowns': 0,
#   'perf': [('L', 4030969)],
#   'team': Team(897353),
#   'type': 'M',
#   'name': 'Merc Air Elemental 1',
#   'Blocking Thrower': 0,
#   'Blocking Scorer': 0,
#   'Scoring Thrower': 0,
#   'Triple': 0,
#   'Allrounder': 0},
#  MercenaryPlayer('MERC-7444-3892'): {'Completions': 0,
#   'Casualties': 0,
#   'Interceptions': 0,
#   'SPP': 0,
#   'Blocks': 3,
#   'Pass': 0,
#   'MVP': 0,
#   'Rush': 0,
#   'Turnms': 15,
#   'Fouls': 0,
#   'Touchdowns': 0,
#   'perf': [('L', 4030969)],
#   'team': Team(897353),
#   'type': 'M',
#   'name': 'Merc Air Elemental 2',
#   'Blocking Thrower': 0,
#   'Blocking Scorer': 0,
#   'Scoring Thrower': 0,
#   'Triple': 0,
#   'Allrounder': 0},
#  NormalPlayer('12519811'): {'Completions': 0,
#   'Casualties': 0,
#   'Interceptions': 0,
#   'SPP': 0,
#   'Blocks': 3,
#   'Pass': 0,
#   'MVP': 0,
#   'Rush': 0,
#   'Turnms': 10,
#   'Fouls': 0,
#   'Touchdowns': 0,
#   'perf': [('W', 4030969)],
#   'team': Team(910344),
#   'type': 'R',
#   'name': 'Cassius II',
#   'dead': [2, 3, 'blocked', '12288426'],
#   'Blocking Thrower': 0,
#   'Blocking Scorer': 0,
#   'Scoring Thrower': 0,
#   'Triple': 0,
#   'Allrounder': 0},
#  NormalPlayer('12520380'): {'Completions': 0,
#   'Casualties': 0,
#   'Interceptions': 0,
#   'SPP': 0,
#   'Blocks': 6,
#   'Pass': 0,
#   'MVP': 0,
#   'Rush': 0,
#   'Turnms': 30,
#   'Fouls': 0,
#   'Touchdowns': 0,
#   'perf': [('W', 4030969), ('W', 4032572), ('D', 4033652), ('W', 4041379)],
#   'team': Team(910344),
#   'type': 'R',
#   'name': 'Damien Snr',
#   'Blocking Thrower': 0,
#   'Blocking Scorer': 0,
#   'Scoring Thrower': 0,
#   'Triple': 0,
#   'Allrounder': 0},
#  NormalPlayer('12513768'): {'Completions': 1,
#   'Casualties': 0,
#   'Interceptions': 0,
#   'SPP': 6,
#   'Blocks': 6,
#   'Pass': 0,
#   'MVP': 1,
#   'Rush': 11,
#   'Turnms': 46,
#   'Fouls': 0,
#   'Touchdowns': 0,
#   'perf': [('W', 4031147), ('D', 4032047), ('L', 4034603), ('L', 4037369)],
#   'team': Team(891237),
#   'type': 'R',
#   'name': 'Retho Tungsodon',
#   'Blocking Thrower': 0,
#   'Blocking Scorer': 0,
#   'Scoring Thrower': 0,
#   'Triple': 0,
#   'Allrounder': 0},
#  StarPlayer('STAR-7581'): {'Completions': 0,
#   'Casualties': 0,
#   'Interceptions': 0,
#   'SPP': 0,
#   'Blocks': 2,
#   'Pass': 0,
#   'MVP': 0,
#   'Rush': 0,
#   'Turnms': 3,
#   'Fouls': 0,
#   'Touchdowns': 0,
#   'perf': [('L', 4031147), ('L', 4037448)],
#   'team': Team(900747),
#   'type': 'S',
#   'name': 'Ugroth Bolgrot',
#   'Blocking Thrower': 0,
#   'Blocking Scorer': 0,
#   'Scoring Thrower': 0,
#   'Triple': 0,
#   'Allrounder': 0},
#  NormalPlayer('12521602'): {'Completions': 1,
#   'Casualties': 0,
#   'Interceptions': 0,
#   'SPP': 1,
#   'Blocks': 3,
#   'Pass': -1,
#   'MVP': 0,
#   'Rush': 8,
#   'Turnms': 28,
#   'Fouls': 0,
#   'Touchdowns': 0,
#   'perf': [('D', 4032047), ('L', 4034603), ('L', 4037369)],
#   'team': Team(891237),
#   'type': 'R',
#   'name': 'Reto Heturin I',
#   'Blocking Thrower': 0,
#   'Blocking Scorer': 0,
#   'Scoring Thrower': 0,
#   'Triple': 0,
#   'Allrounder': 0},
#  NormalPlayer('12525812'): {'Completions': 0,
#   'Casualties': 0,
#   'Interceptions': 0,
#   'SPP': 0,
#   'Blocks': 1,
#   'Pass': 0,
#   'MVP': 0,
#   'Rush': 0,
#   'Turnms': 16,
#   'Fouls': 0,
#   'Touchdowns': 0,
#   'perf': [('D', 4032047)],
#   'team': Team(891237),
#   'type': 'J',
#   'name': 'Brian Hardwing',
#   'retired': True,
#   'Blocking Thrower': 0,
#   'Blocking Scorer': 0,
#   'Scoring Thrower': 0,
#   'Triple': 0,
#   'Allrounder': 0},
#  MercenaryPlayer('MERC-7444-0529'): {'Completions': 0,
#   'Casualties': 0,
#   'Interceptions': 0,
#   'SPP': 0,
#   'Blocks': 1,
#   'Pass': 0,
#   'MVP': 0,
#   'Rush': 0,
#   'Turnms': 2,
#   'Fouls': 0,
#   'Touchdowns': 0,
#   'perf': [('D', 4032047)],
#   'team': Team(897353),
#   'type': 'M',
#   'name': 'Merc Air Elemental 1',
#   'Blocking Thrower': 0,
#   'Blocking Scorer': 0,
#   'Scoring Thrower': 0,
#   'Triple': 0,
#   'Allrounder': 0},
#  MercenaryPlayer('MERC-7444-1790'): {'Completions': 0,
#   'Casualties': 0,
#   'Interceptions': 0,
#   'SPP': 0,
#   'Blocks': 1,
#   'Pass': 0,
#   'MVP': 0,
#   'Rush': 0,
#   'Turnms': 16,
#   'Fouls': 0,
#   'Touchdowns': 0,
#   'perf': [('D', 4032047)],
#   'team': Team(897353),
#   'type': 'M',
#   'name': 'Merc Air Elemental 4',
#   'Blocking Thrower': 0,
#   'Blocking Scorer': 0,
#   'Scoring Thrower': 0,
#   'Triple': 0,
#   'Allrounder': 0},
#  MercenaryPlayer('MERC-7444-1807'): {'Completions': 0,
#   'Casualties': 0,
#   'Interceptions': 0,
#   'SPP': 0,
#   'Blocks': 3,
#   'Pass': 0,
#   'MVP': 0,
#   'Rush': 0,
#   'Turnms': 14,
#   'Fouls': 1,
#   'Touchdowns': 0,
#   'perf': [('D', 4032047)],
#   'team': Team(897353),
#   'type': 'M',
#   'name': 'Merc Air Elemental 3',
#   'Blocking Thrower': 0,
#   'Blocking Scorer': 0,
#   'Scoring Thrower': 0,
#   'Triple': 0,
#   'Allrounder': 0},
#  MercenaryPlayer('MERC-7444-3066'): {'Completions': 0,
#   'Casualties': 0,
#   'Interceptions': 0,
#   'SPP': 0,
#   'Blocks': 2,
#   'Pass': 0,
#   'MVP': 0,
#   'Rush': 0,
#   'Turnms': 11,
#   'Fouls': 0,
#   'Touchdowns': 0,
#   'perf': [('D', 4032047)],
#   'team': Team(897353),
#   'type': 'M',
#   'name': 'Merc Air Elemental 5',
#   'Blocking Thrower': 0,
#   'Blocking Scorer': 0,
#   'Scoring Thrower': 0,
#   'Triple': 0,
#   'Allrounder': 0},
#  MercenaryPlayer('MERC-7444-3110'): {'Completions': 0,
#   'Casualties': 0,
#   'Interceptions': 0,
#   'SPP': 0,
#   'Blocks': 0,
#   'Pass': 0,
#   'MVP': 0,
#   'Rush': 0,
#   'Turnms': 8,
#   'Fouls': 0,
#   'Touchdowns': 0,
#   'perf': [('D', 4032047)],
#   'team': Team(897353),
#   'type': 'M',
#   'name': 'Merc Air Elemental 2',
#   'Blocking Thrower': 0,
#   'Blocking Scorer': 0,
#   'Scoring Thrower': 0,
#   'Triple': 0,
#   'Allrounder': 0},
#  NormalPlayer('12521600'): {'Completions': 2,
#   'Casualties': 0,
#   'Interceptions': 0,
#   'SPP': 7,
#   'Blocks': 3,
#   'Pass': -5,
#   'MVP': 1,
#   'Rush': 18,
#   'Turnms': 40,
#   'Fouls': 0,
#   'Touchdowns': 0,
#   'perf': [('L', 4032572), ('L', 4036761), ('L', 4037448)],
#   'team': Team(900747),
#   'type': 'R',
#   'name': 'Sirias the Agile',
#   'Blocking Thrower': 0,
#   'Blocking Scorer': 0,
#   'Scoring Thrower': 0,
#   'Triple': 0,
#   'Allrounder': 0},
#  NormalPlayer('12522638'): {'Completions': 0,
#   'Casualties': 3,
#   'Interceptions': 0,
#   'SPP': 6,
#   'Blocks': 13,
#   'Pass': 0,
#   'MVP': 0,
#   'Rush': 0,
#   'Turnms': 47,
#   'Fouls': 0,
#   'Touchdowns': 0,
#   'perf': [('W', 4033076), ('W', 4034337), ('L', 4041379)],
#   'team': Team(883051),
#   'type': 'R',
#   'name': 'The Indignant Kirkwood',
#   'Blocking Thrower': 0,
#   'Blocking Scorer': 0,
#   'Scoring Thrower': 0,
#   'Triple': 0,
#   'Allrounder': 0},
#  StarPlayer('STAR-7537'): {'Completions': 0,
#   'Casualties': 0,
#   'Interceptions': 0,
#   'SPP': 0,
#   'Blocks': 2,
#   'Pass': 0,
#   'MVP': 0,
#   'Rush': 0,
#   'Turnms': 16,
#   'Fouls': 0,
#   'Touchdowns': 0,
#   'perf': [('L', 4033076)],
#   'team': Team(903654),
#   'type': 'S',
#   'name': 'Crazy Igor',
#   'Blocking Thrower': 0,
#   'Blocking Scorer': 0,
#   'Scoring Thrower': 0,
#   'Triple': 0,
#   'Allrounder': 0},
#  NormalPlayer('12535865'): {'Completions': 0,
#   'Casualties': 2,
#   'Interceptions': 0,
#   'SPP': 4,
#   'Blocks': 7,
#   'Pass': 0,
#   'MVP': 0,
#   'Rush': 1,
#   'Turnms': 21,
#   'Fouls': 0,
#   'Touchdowns': 0,
#   'perf': [('L', 4034337), ('W', 4034549)],
#   'team': Team(897353),
#   'type': 'R',
#   'name': 'Aush',
#   'Blocking Thrower': 0,
#   'Blocking Scorer': 0,
#   'Scoring Thrower': 0,
#   'Triple': 0,
#   'Allrounder': 0},
#  MercenaryPlayer('MERC-7444-0557'): {'Completions': 0,
#   'Casualties': 0,
#   'Interceptions': 0,
#   'SPP': 0,
#   'Blocks': 1,
#   'Pass': 0,
#   'MVP': 0,
#   'Rush': 0,
#   'Turnms': 5,
#   'Fouls': 0,
#   'Touchdowns': 0,
#   'perf': [('L', 4034337)],
#   'team': Team(897353),
#   'type': 'M',
#   'name': 'Merc Air Elemental 3',
#   'Blocking Thrower': 0,
#   'Blocking Scorer': 0,
#   'Scoring Thrower': 0,
#   'Triple': 0,
#   'Allrounder': 0},
#  MercenaryPlayer('MERC-7444-1067'): {'Completions': 0,
#   'Casualties': 0,
#   'Interceptions': 0,
#   'SPP': 0,
#   'Blocks': 0,
#   'Pass': 0,
#   'MVP': 0,
#   'Rush': 0,
#   'Turnms': 3,
#   'Fouls': 0,
#   'Touchdowns': 0,
#   'perf': [('L', 4034337)],
#   'team': Team(897353),
#   'type': 'M',
#   'name': 'Merc Air Elemental 1',
#   'dead': [1, 4, 'blocked', '12522638'],
#   'Blocking Thrower': 0,
#   'Blocking Scorer': 0,
#   'Scoring Thrower': 0,
#   'Triple': 0,
#   'Allrounder': 0},
#  MercenaryPlayer('MERC-7444-1400'): {'Completions': 0,
#   'Casualties': 0,
#   'Interceptions': 0,
#   'SPP': 0,
#   'Blocks': 2,
#   'Pass': 0,
#   'MVP': 0,
#   'Rush': 0,
#   'Turnms': 16,
#   'Fouls': 0,
#   'Touchdowns': 0,
#   'perf': [('L', 4034337)],
#   'team': Team(897353),
#   'type': 'M',
#   'name': 'Merc Air Elemental 4',
#   'Blocking Thrower': 0,
#   'Blocking Scorer': 0,
#   'Scoring Thrower': 0,
#   'Triple': 0,
#   'Allrounder': 0},
#  MercenaryPlayer('MERC-7444-1616'): {'Completions': 0,
#   'Casualties': 0,
#   'Interceptions': 0,
#   'SPP': 0,
#   'Blocks': 1,
#   'Pass': 0,
#   'MVP': 0,
#   'Rush': 0,
#   'Turnms': 6,
#   'Fouls': 0,
#   'Touchdowns': 0,
#   'perf': [('L', 4034337)],
#   'team': Team(897353),
#   'type': 'M',
#   'name': 'Merc Air Elemental 2',
#   'Blocking Thrower': 0,
#   'Blocking Scorer': 0,
#   'Scoring Thrower': 0,
#   'Triple': 0,
#   'Allrounder': 0},
#  NormalPlayer('12536828'): {'Completions': 0,
#   'Casualties': 1,
#   'Interceptions': 0,
#   'SPP': 10,
#   'Blocks': 1,
#   'Pass': 0,
#   'MVP': 1,
#   'Rush': 12,
#   'Turnms': 11,
#   'Fouls': 0,
#   'Touchdowns': 1,
#   'perf': [('W', 4034549)],
#   'team': Team(897353),
#   'type': 'R',
#   'name': 'Spohras',
#   'Blocking Thrower': 0,
#   'Blocking Scorer': 1,
#   'Scoring Thrower': 0,
#   'Triple': 0,
#   'Allrounder': 0},
#  MercenaryPlayer('MERC-7444-0351'): {'Completions': 0,
#   'Casualties': 0,
#   'Interceptions': 0,
#   'SPP': 0,
#   'Blocks': 0,
#   'Pass': 0,
#   'MVP': 0,
#   'Rush': 0,
#   'Turnms': 3,
#   'Fouls': 0,
#   'Touchdowns': 0,
#   'perf': [('W', 4034549)],
#   'team': Team(897353),
#   'type': 'M',
#   'name': 'Merc Air Elemental 1',
#   'Blocking Thrower': 0,
#   'Blocking Scorer': 0,
#   'Scoring Thrower': 0,
#   'Triple': 0,
#   'Allrounder': 0},
#  MercenaryPlayer('MERC-7444-2913'): {'Completions': 0,
#   'Casualties': 0,
#   'Interceptions': 0,
#   'SPP': 0,
#   'Blocks': 4,
#   'Pass': 0,
#   'MVP': 0,
#   'Rush': 0,
#   'Turnms': 5,
#   'Fouls': 0,
#   'Touchdowns': 0,
#   'perf': [('W', 4034549)],
#   'team': Team(897353),
#   'type': 'M',
#   'name': 'Merc Air Elemental 3',
#   'Blocking Thrower': 0,
#   'Blocking Scorer': 0,
#   'Scoring Thrower': 0,
#   'Triple': 0,
#   'Allrounder': 0},
#  MercenaryPlayer('MERC-7444-3588'): {'Completions': 0,
#   'Casualties': 0,
#   'Interceptions': 0,
#   'SPP': 0,
#   'Blocks': 1,
#   'Pass': 0,
#   'MVP': 0,
#   'Rush': 0,
#   'Turnms': 6,
#   'Fouls': 0,
#   'Touchdowns': 0,
#   'perf': [('W', 4034549)],
#   'team': Team(897353),
#   'type': 'M',
#   'name': 'Merc Air Elemental 2',
#   'Blocking Thrower': 0,
#   'Blocking Scorer': 0,
#   'Scoring Thrower': 0,
#   'Triple': 0,
#   'Allrounder': 0},
#  NormalPlayer('12531227'): {'Completions': 0,
#   'Casualties': 0,
#   'Interceptions': 0,
#   'SPP': 5,
#   'Blocks': 8,
#   'Pass': 0,
#   'MVP': 1,
#   'Rush': 0,
#   'Turnms': 32,
#   'Fouls': 0,
#   'Touchdowns': 0,
#   'perf': [('W', 4036761), ('W', 4037369)],
#   'team': Team(899682),
#   'type': 'R',
#   'name': 'R\'th\'s\'k "Green Wall" Ammdtss',
#   'Blocking Thrower': 0,
#   'Blocking Scorer': 0,
#   'Scoring Thrower': 0,
#   'Triple': 0,
#   'Allrounder': 0},
#  NormalPlayer('12551905'): {'Completions': 0,
#   'Casualties': 0,
#   'Interceptions': 0,
#   'SPP': 0,
#   'Blocks': 1,
#   'Pass': 0,
#   'MVP': 0,
#   'Rush': 0,
#   'Turnms': 18,
#   'Fouls': 0,
#   'Touchdowns': 0,
#   'perf': [('W', 4037369)],
#   'team': Team(899682),
#   'type': 'R',
#   'name': 'M-k-k "White eyes" Vprr',
#   'Blocking Thrower': 0,
#   'Blocking Scorer': 0,
#   'Scoring Thrower': 0,
#   'Triple': 0,
#   'Allrounder': 0},
#  NormalPlayer('12537131'): {'Completions': 0,
#   'Casualties': 0,
#   'Interceptions': 0,
#   'SPP': 0,
#   'Blocks': 2,
#   'Pass': 0,
#   'MVP': 0,
#   'Rush': 0,
#   'Turnms': 12,
#   'Fouls': 0,
#   'Touchdowns': 0,
#   'perf': [('W', 4037448)],
#   'team': Team(903654),
#   'type': 'R',
#   'name': 'Aahotepre',
#   'Blocking Thrower': 0,
#   'Blocking Scorer': 0,
#   'Scoring Thrower': 0,
#   'Triple': 0,
#   'Allrounder': 0},
#  NormalPlayer('12537132'): {'Completions': 0,
#   'Casualties': 0,
#   'Interceptions': 0,
#   'SPP': 0,
#   'Blocks': 0,
#   'Pass': 0,
#   'MVP': 0,
#   'Rush': 0,
#   'Turnms': 17,
#   'Fouls': 0,
#   'Touchdowns': 0,
#   'perf': [('W', 4037448)],
#   'team': Team(903654),
#   'type': 'R',
#   'name': 'Heqanakht',
#   'Blocking Thrower': 0,
#   'Blocking Scorer': 0,
#   'Scoring Thrower': 0,
#   'Triple': 0,
#   'Allrounder': 0},
#  NormalPlayer('12551997'): {'Completions': 0,
#   'Casualties': 0,
#   'Interceptions': 0,
#   'SPP': 0,
#   'Blocks': 7,
#   'Pass': 0,
#   'MVP': 0,
#   'Rush': 0,
#   'Turnms': 16,
#   'Fouls': 0,
#   'Touchdowns': 0,
#   'perf': [('W', 4041379)],
#   'team': Team(910344),
#   'type': 'R',
#   'name': 'Isaiah Gore',
#   'Blocking Thrower': 0,
#   'Blocking Scorer': 0,
#   'Scoring Thrower': 0,
#   'Triple': 0,
#   'Allrounder': 0},
#  NormalPlayer('12552000'): {'Completions': 0,
#   'Casualties': 0,
#   'Interceptions': 0,
#   'SPP': 0,
#   'Blocks': 0,
#   'Pass': 0,
#   'MVP': 0,
#   'Rush': 0,
#   'Turnms': 0,
#   'Fouls': 0,
#   'Touchdowns': 0,
#   'perf': [('W', 4041379)],
#   'team': Team(910344),
#   'type': 'R',
#   'name': 'Jorin',
#   'Blocking Thrower': 0,
#   'Blocking Scorer': 0,
#   'Scoring Thrower': 0,
#   'Triple': 0,
#   'Allrounder': 0},
#  MercenaryPlayer('MERC-7391-3245'): {'Completions': 0,
#   'Casualties': 1,
#   'Interceptions': 0,
#   'SPP': 2,
#   'Blocks': 2,
#   'Pass': 0,
#   'MVP': 0,
#   'Rush': 0,
#   'Turnms': 16,
#   'Fouls': 1,
#   'Touchdowns': 0,
#   'perf': [('W', 4041379)],
#   'team': Team(910344),
#   'type': 'M',
#   'name': 'Merc Thrall 1',
#   'Blocking Thrower': 0,
#   'Blocking Scorer': 0,
#   'Scoring Thrower': 0,
#   'Triple': 0,
#   'Allrounder': 0},
#  NormalPlayer('12496642'): {'Completions': 0,
#   'Casualties': 0,
#   'Interceptions': 0,
#   'SPP': 0,
#   'Blocks': 5,
#   'Pass': 0,
#   'MVP': 0,
#   'Rush': 0,
#   'Turnms': 28,
#   'Fouls': 0,
#   'Touchdowns': 0,
#   'perf': [('D', 4025662), ('D', 4026367)],
#   'retired': True,
#   'name': 'Dew Midhon',
#   'team': Team(910344),
#   'type': 'R',
#   'Blocking Thrower': 0,
#   'Blocking Scorer': 0,
#   'Scoring Thrower': 0,
#   'Triple': 0,
#   'Allrounder': 0}}

# %%
order = default_order = (
    "SPP",
    "Touchdowns",
    "Casualties",
    "Interceptions",
    "Completions",
    "Fouls",
    "Blocking Scorer",
    "Blocking Thrower",
    "Scoring Thrower",
    "Triple",
    "Allrounder",
)

# %%
performancekeytrans = {
    "Blocks": "blocks",
    "Touchdowns": "td",
    "SPP": "spp",
    "Fouls": "fouls",
    "Interceptions": "int",
    "Completions": "comp",
    "Casualties": "cas",
    "MVP": "mvp",
    "Pass": "pass",
    "Rush": "rush",
    "Turnms": "turns",
}

# %%
performances[Sjs[0]][order[0]]
# Out:
# 35

# %%
ordered = sorted(performances,
    key=lambda Sj: tuple(performances[Sj][name] for name in order),
    reverse=True,
)

# %%
#T = self = G.tournaments["44074"]

# %%
standings = T.standings()
pprint(standings)
# Out:
# [{'cas': 14,
#   'casdiff': -4,
#   'cto': -1,
#   'hth': -1,
#   'perf': [('D', 4024740),
#            ('D', 4026367),
#            ('W', 4030781),
#            ('W', 4030969),
#            ('W', 4032572),
#            ('D', 4033652),
#            ('W', 4041379)],
#   'prestige': 150,
#   'pts': 15,
#   'score': 8,
#   'scorediff': 5,
#   'td': 8,
#   'tddiff': 5,
#   'team': Team(910344)},
#  {'cas': 17,
#   'casdiff': 4,
#   'cto': -1,
#   'hth': -1,
#   'perf': [('D', 4024740),
#            ('D', 4026666),
#            ('W', 4029149),
#            ('W', 4031992),
#            ('L', 4033076),
#            ('W', 4034603),
#            ('W', 4037448)],
#   'prestige': 140,
#   'pts': 14,
#   'score': 14,
#   'scorediff': 8,
#   'td': 14,
#   'tddiff': 8,
#   'team': Team(903654)},
#  {'cas': 14,
#   'casdiff': -4,
#   'cto': -1,
#   'hth': 1,
#   'perf': [('W', 4026342),
#            ('D', 4029013),
#            ('L', 4030781),
#            ('L', 4031992),
#            ('L', 4033320),
#            ('W', 4036761),
#            ('W', 4037369)],
#   'prestige': 100,
#   'pts': 10,
#   'score': 9,
#   'scorediff': 2,
#   'td': 9,
#   'tddiff': 2,
#   'team': Team(899682)},
#  {'cas': 19,
#   'casdiff': 2,
#   'cto': -1,
#   'hth': 1,
#   'perf': [('L', 4024847),
#            ('D', 4029013),
#            ('W', 4029542),
#            ('L', 4031344),
#            ('W', 4033076),
#            ('W', 4034337),
#            ('L', 4041379)],
#   'prestige': 100,
#   'pts': 10,
#   'score': 8,
#   'scorediff': 1,
#   'td': 8,
#   'tddiff': 1,
#   'team': Team(883051)},
#  {'cas': 28,
#   'casdiff': 11,
#   'cto': -1,
#   'hth': 1,
#   'perf': [('W', 4024847),
#            ('W', 4027540),
#            ('W', 4027982),
#            ('L', 4031147),
#            ('L', 4032572),
#            ('L', 4036761),
#            ('L', 4037448)],
#   'prestige': 90,
#   'pts': 9,
#   'score': 5,
#   'scorediff': -3,
#   'td': 5,
#   'tddiff': -3,
#   'team': Team(900747)},
#  {'cas': 24,
#   'casdiff': 7,
#   'cto': -1,
#   'hth': 2,
#   'perf': [('D', 4025662),
#            ('D', 4026666),
#            ('L', 4027982),
#            ('W', 4031344),
#            ('W', 4033320),
#            ('D', 4033652),
#            ('L', 4034549)],
#   'prestige': 90,
#   'pts': 9,
#   'score': 10,
#   'scorediff': 1,
#   'td': 10,
#   'tddiff': 1,
#   'team': Team(896972)},
#  {'cas': 3,
#   'casdiff': -9,
#   'cto': -1,
#   'hth': -1,
#   'perf': [('D', 4025662),
#            ('D', 4026367),
#            ('L', 4029542),
#            ('W', 4031147),
#            ('D', 4032047),
#            ('L', 4034603),
#            ('L', 4037369)],
#   'prestige': 60,
#   'pts': 6,
#   'score': 7,
#   'scorediff': -4,
#   'td': 7,
#   'tddiff': -4,
#   'team': Team(891237)},
#  {'cas': 13,
#   'casdiff': -7,
#   'cto': -1,
#   'hth': -1,
#   'perf': [('L', 4026342),
#            ('L', 4027540),
#            ('L', 4029149),
#            ('L', 4030969),
#            ('D', 4032047),
#            ('L', 4034337),
#            ('W', 4034549)],
#   'prestige': 40,
#   'pts': 4,
#   'score': 3,
#   'scorediff': -10,
#   'td': 3,
#   'tddiff': -10,
#   'team': Team(897353)}]

# %%
d = {}
for ds in self.standings():
    Te = ds["team"]
    perf = ds["perf"]
    for r, matchId in reversed(perf):
        if matchId:
            d[Te] = cibblbibbl.match.Match(matchId)
            break
    else:
        d[Te] = None

# %%
d
# Out:
# {Team(910344): Match(4041379),
#  Team(903654): Match(4037448),
#  Team(899682): Match(4037369),
#  Team(883051): Match(4041379),
#  Team(900747): Match(4037448),
#  Team(896972): Match(4034549),
#  Team(891237): Match(4037369),
#  Team(897353): Match(4034549)}

# %%
list(reversed(perf))
# Out:
# [('W', 4034549),
#  ('L', 4034337),
#  ('D', 4032047),
#  ('L', 4030969),
#  ('L', 4029149),
#  ('L', 4027540),
#  ('L', 4026342)]

# %%
rawperf = T.rawplayerperformances()
pprint(rawperf)
# Out:
# lastretired Tournament('cibbl', '45883') NormalPlayer('12173153')
# lastretired Tournament('cibbl', '45883') NormalPlayer('12450013')
# {NormalPlayer('11892405'): {'blocks': 26,
#                             'cas': 1,
#                             'comp': 0,
#                             'fouls': 0,
#                             'int': 0,
#                             'mvp': 0,
#                             'name': '"Featherweight" Gunnar',
#                             'pass': 0,
#                             'perf': [('L', 4024847),
#                                      ('D', 4029013),
#                                      ('W', 4029542),
#                                      ('L', 4031344),
#                                      ('W', 4033076),
#                                      ('W', 4034337),
#                                      ('L', 4041379)],
#                             'prespp': 586,
#                             'rush': 32,
#                             'spp': 8,
#                             'td': 2,
#                             'team': Team(883051),
#                             'turns': 73,
#                             'type': 'R'},
#  NormalPlayer('11892424'): {'blocks': 30,
#                             'cas': 0,
#                             'comp': 0,
#                             'fouls': 0,
#                             'int': 0,
#                             'mvp': 0,
#                             'name': 'Dag of The Mire',
#                             'pass': 0,
#                             'perf': [('L', 4024847),
#                                      ('D', 4029013),
#                                      ('W', 4029542),
#                                      ('L', 4031344),
#                                      ('W', 4033076),
#                                      ('W', 4034337),
#                                      ('L', 4041379)],
#                             'prespp': 56,
#                             'rush': 0,
#                             'spp': 0,
#                             'td': 0,
#                             'team': Team(883051),
#                             'turns': 80,
#                             'type': 'R'},
#  NormalPlayer('11892428'): {'blocks': 8,
#                             'cas': 0,
#                             'comp': 0,
#                             'fouls': 0,
#                             'int': 0,
#                             'mvp': 0,
#                             'name': 'Folke Ninth-Son',
#                             'pass': 0,
#                             'perf': [('L', 4024847),
#                                      ('D', 4029013),
#                                      ('W', 4029542),
#                                      ('L', 4031344),
#                                      ('W', 4033076),
#                                      ('W', 4034337),
#                                      ('L', 4041379)],
#                             'prespp': 0,
#                             'rush': 0,
#                             'spp': 0,
#                             'td': 0,
#                             'team': Team(883051),
#                             'turns': 32,
#                             'type': 'R'},
#  NormalPlayer('11892429'): {'blocks': 3,
#                             'cas': 0,
#                             'comp': 0,
#                             'fouls': 0,
#                             'int': 0,
#                             'mvp': 0,
#                             'name': 'Geir the Fisherman',
#                             'pass': 0,
#                             'perf': [('L', 4024847), ('D', 4029013)],
#                             'prespp': 6,
#                             'retired': True,
#                             'rush': 0,
#                             'spp': 0,
#                             'td': 0,
#                             'team': Team(883051),
#                             'turns': 11,
#                             'type': 'R'},
#  NormalPlayer('11947871'): {'blocks': 22,
#                             'cas': 1,
#                             'comp': 0,
#                             'fouls': 1,
#                             'int': 0,
#                             'mvp': 1,
#                             'name': '"Ambisinister" Xander',
#                             'pass': 0,
#                             'perf': [('L', 4024847),
#                                      ('D', 4029013),
#                                      ('W', 4029542),
#                                      ('L', 4031344),
#                                      ('W', 4033076),
#                                      ('W', 4034337),
#                                      ('L', 4041379)],
#                             'prespp': 488,
#                             'rush': 108,
#                             'spp': 25,
#                             'td': 6,
#                             'team': Team(883051),
#                             'turns': 96,
#                             'type': 'R'},
#  NormalPlayer('11950136'): {'blocks': 13,
#                             'cas': 2,
#                             'comp': 0,
#                             'dead': [1, 5, 'blocked', 'STAR-7545'],
#                             'fouls': 0,
#                             'int': 0,
#                             'mvp': 1,
#                             'name': 'The Notorious Jerk',
#                             'pass': 0,
#                             'perf': [('L', 4024847),
#                                      ('D', 4029013),
#                                      ('W', 4029542),
#                                      ('L', 4031344)],
#                             'prespp': 206,
#                             'rush': 0,
#                             'spp': 9,
#                             'td': 0,
#                             'team': Team(883051),
#                             'turns': 28,
#                             'type': 'R'},
#  NormalPlayer('12022005'): {'blocks': 28,
#                             'cas': 0,
#                             'comp': 0,
#                             'fouls': 0,
#                             'int': 0,
#                             'mvp': 0,
#                             'name': 'Swan Alphon',
#                             'pass': 0,
#                             'perf': [('D', 4025662),
#                                      ('D', 4026367),
#                                      ('L', 4029542),
#                                      ('W', 4031147),
#                                      ('D', 4032047),
#                                      ('L', 4034603),
#                                      ('L', 4037369)],
#                             'prespp': 231,
#                             'rush': 4,
#                             'spp': 0,
#                             'td': 0,
#                             'team': Team(891237),
#                             'turns': 100,
#                             'type': 'R'},
#  NormalPlayer('12022006'): {'blocks': 16,
#                             'cas': 0,
#                             'comp': 5,
#                             'fouls': 1,
#                             'int': 0,
#                             'mvp': 0,
#                             'name': 'Heni Hethurin',
#                             'pass': 10,
#                             'perf': [('D', 4025662),
#                                      ('D', 4026367),
#                                      ('L', 4029542),
#                                      ('W', 4031147),
#                                      ('D', 4032047),
#                                      ('L', 4034603),
#                                      ('L', 4037369)],
#                             'prespp': 428,
#                             'rush': 26,
#                             'spp': 5,
#                             'td': 0,
#                             'team': Team(891237),
#                             'turns': 92,
#                             'type': 'R'},
#  NormalPlayer('12022008'): {'blocks': 16,
#                             'cas': 0,
#                             'comp': 0,
#                             'fouls': 0,
#                             'int': 0,
#                             'mvp': 0,
#                             'name': 'Tety Goweston',
#                             'pass': 0,
#                             'perf': [('D', 4025662),
#                                      ('D', 4026367),
#                                      ('L', 4029542),
#                                      ('W', 4031147),
#                                      ('D', 4032047),
#                                      ('L', 4034603),
#                                      ('L', 4037369)],
#                             'prespp': 140,
#                             'rush': 0,
#                             'spp': 0,
#                             'td': 0,
#                             'team': Team(891237),
#                             'turns': 55,
#                             'type': 'R'},
#  NormalPlayer('12022010'): {'blocks': 5,
#                             'cas': 0,
#                             'comp': 0,
#                             'dead': [2, 6, 'blocked', '12323837'],
#                             'fouls': 0,
#                             'int': 0,
#                             'mvp': 0,
#                             'name': 'Dew Midhon',
#                             'pass': 0,
#                             'perf': [('D', 4025662), ('D', 4026367)],
#                             'prespp': 42,
#                             'rush': 0,
#                             'spp': 0,
#                             'td': 0,
#                             'team': Team(891237),
#                             'turns': 28,
#                             'type': 'R'},
#  NormalPlayer('12022022'): {'blocks': 32,
#                             'cas': 2,
#                             'comp': 0,
#                             'fouls': 0,
#                             'int': 0,
#                             'mvp': 0,
#                             'name': 'Mirilan Antegobon',
#                             'pass': 0,
#                             'perf': [('D', 4025662),
#                                      ('D', 4026367),
#                                      ('L', 4029542),
#                                      ('W', 4031147),
#                                      ('D', 4032047),
#                                      ('L', 4034603),
#                                      ('L', 4037369)],
#                             'prespp': 318,
#                             'rush': 0,
#                             'spp': 4,
#                             'td': 0,
#                             'team': Team(891237),
#                             'turns': 101,
#                             'type': 'R'},
#  NormalPlayer('12104982'): {'blocks': 38,
#                             'cas': 1,
#                             'comp': 1,
#                             'fouls': 0,
#                             'int': 0,
#                             'mvp': 1,
#                             'name': 'Meret Scuffedon',
#                             'pass': 3,
#                             'perf': [('D', 4025662),
#                                      ('D', 4026367),
#                                      ('L', 4029542),
#                                      ('W', 4031147),
#                                      ('D', 4032047),
#                                      ('L', 4034603),
#                                      ('L', 4037369)],
#                             'prespp': 274,
#                             'rush': 45,
#                             'spp': 14,
#                             'td': 2,
#                             'team': Team(891237),
#                             'turns': 78,
#                             'type': 'R'},
#  NormalPlayer('12117786'): {'blocks': 4,
#                             'cas': 0,
#                             'comp': 0,
#                             'dead': [2, 1, 'blocked', '12165569'],
#                             'fouls': 7,
#                             'int': 0,
#                             'mvp': 1,
#                             'name': 'Gorbad Faceclompah',
#                             'pass': 0,
#                             'perf': [('D', 4025662),
#                                      ('D', 4026666),
#                                      ('L', 4027982),
#                                      ('W', 4031344),
#                                      ('W', 4033320),
#                                      ('D', 4033652),
#                                      ('L', 4034549)],
#                             'prespp': 125,
#                             'rush': 0,
#                             'spp': 5,
#                             'td': 0,
#                             'team': Team(896972),
#                             'turns': 44,
#                             'type': 'R'},
#  NormalPlayer('12117788'): {'blocks': 34,
#                             'cas': 2,
#                             'comp': 0,
#                             'fouls': 0,
#                             'int': 0,
#                             'mvp': 0,
#                             'name': 'Poppy Merribuck',
#                             'pass': 0,
#                             'perf': [('D', 4025662),
#                                      ('D', 4026666),
#                                      ('L', 4027982),
#                                      ('W', 4031344),
#                                      ('W', 4033320),
#                                      ('D', 4033652),
#                                      ('L', 4034549)],
#                             'prespp': 257,
#                             'rush': 0,
#                             'spp': 4,
#                             'td': 0,
#                             'team': Team(896972),
#                             'turns': 72,
#                             'type': 'R'},
#  NormalPlayer('12117790'): {'blocks': 46,
#                             'cas': 2,
#                             'comp': 0,
#                             'fouls': 0,
#                             'int': 0,
#                             'mvp': 1,
#                             'name': 'Balthasar the Youthful',
#                             'pass': 0,
#                             'perf': [('D', 4025662),
#                                      ('D', 4026666),
#                                      ('L', 4027982),
#                                      ('W', 4031344),
#                                      ('W', 4033320),
#                                      ('D', 4033652),
#                                      ('L', 4034549)],
#                             'prespp': 176,
#                             'rush': 0,
#                             'spp': 9,
#                             'td': 0,
#                             'team': Team(896972),
#                             'turns': 78,
#                             'type': 'R'},
#  NormalPlayer('12117791'): {'blocks': 12,
#                             'cas': 2,
#                             'comp': 0,
#                             'fouls': 1,
#                             'int': 0,
#                             'mvp': 0,
#                             'name': 'Konrad the Enchanter',
#                             'pass': 0,
#                             'perf': [('D', 4025662),
#                                      ('D', 4026666),
#                                      ('L', 4027982),
#                                      ('W', 4031344),
#                                      ('W', 4033320),
#                                      ('D', 4033652),
#                                      ('L', 4034549)],
#                             'prespp': 82,
#                             'rush': 0,
#                             'spp': 4,
#                             'td': 0,
#                             'team': Team(896972),
#                             'turns': 49,
#                             'type': 'R'},
#  NormalPlayer('12117792'): {'blocks': 11,
#                             'cas': 0,
#                             'comp': 0,
#                             'fouls': 3,
#                             'int': 0,
#                             'mvp': 0,
#                             'name': 'Gottlieb Thälmann of Averland',
#                             'pass': 1,
#                             'perf': [('D', 4025662),
#                                      ('D', 4026666),
#                                      ('L', 4027982),
#                                      ('W', 4031344),
#                                      ('W', 4033320),
#                                      ('D', 4033652),
#                                      ('L', 4034549)],
#                             'prespp': 73,
#                             'rush': 12,
#                             'spp': 3,
#                             'td': 1,
#                             'team': Team(896972),
#                             'turns': 63,
#                             'type': 'R'},
#  NormalPlayer('12117795'): {'blocks': 37,
#                             'cas': 3,
#                             'comp': 0,
#                             'dead': [2, 5, 'fouled', '12121974'],
#                             'fouls': 1,
#                             'int': 0,
#                             'mvp': 1,
#                             'name': 'Ferrimora of the Waxing Moon',
#                             'pass': 0,
#                             'perf': [('D', 4025662),
#                                      ('D', 4026666),
#                                      ('L', 4027982),
#                                      ('W', 4031344),
#                                      ('W', 4033320),
#                                      ('D', 4033652),
#                                      ('L', 4034549)],
#                             'prespp': 155,
#                             'rush': -1,
#                             'spp': 11,
#                             'td': 0,
#                             'team': Team(896972),
#                             'turns': 101,
#                             'type': 'R'},
#  NormalPlayer('12117802'): {'blocks': 13,
#                             'cas': 0,
#                             'comp': 0,
#                             'fouls': 0,
#                             'int': 0,
#                             'mvp': 0,
#                             'name': 'Urkrasour the Obedient',
#                             'pass': 2,
#                             'perf': [('D', 4025662),
#                                      ('D', 4026666),
#                                      ('L', 4027982),
#                                      ('W', 4031344),
#                                      ('W', 4033320),
#                                      ('D', 4033652),
#                                      ('L', 4034549)],
#                             'prespp': 203,
#                             'rush': 46,
#                             'spp': 0,
#                             'td': 0,
#                             'team': Team(896972),
#                             'turns': 69,
#                             'type': 'R'},
#  NormalPlayer('12121959'): {'blocks': 32,
#                             'cas': 1,
#                             'comp': 0,
#                             'fouls': 2,
#                             'int': 0,
#                             'mvp': 0,
#                             'name': 'Nis Atman',
#                             'pass': 0,
#                             'perf': [('L', 4026342),
#                                      ('L', 4027540),
#                                      ('L', 4029149),
#                                      ('L', 4030969),
#                                      ('D', 4032047),
#                                      ('L', 4034337),
#                                      ('W', 4034549)],
#                             'prespp': 126,
#                             'rush': 0,
#                             'spp': 2,
#                             'td': 0,
#                             'team': Team(897353),
#                             'turns': 95,
#                             'type': 'R'},
#  NormalPlayer('12121960'): {'blocks': 0,
#                             'cas': 0,
#                             'comp': 0,
#                             'fouls': 5,
#                             'int': 0,
#                             'mvp': 0,
#                             'name': 'Sssues Ej',
#                             'pass': 0,
#                             'perf': [('L', 4026342), ('L', 4027540)],
#                             'prespp': 20,
#                             'retired': True,
#                             'rush': 0,
#                             'spp': 0,
#                             'td': 0,
#                             'team': Team(897353),
#                             'turns': 6,
#                             'type': 'R'},
#  NormalPlayer('12121974'): {'blocks': 26,
#                             'cas': 0,
#                             'comp': 0,
#                             'fouls': 3,
#                             'int': 0,
#                             'mvp': 0,
#                             'name': 'Pix Vamox',
#                             'pass': 0,
#                             'perf': [('L', 4026342),
#                                      ('L', 4027540),
#                                      ('L', 4029149),
#                                      ('L', 4030969),
#                                      ('D', 4032047),
#                                      ('L', 4034337),
#                                      ('W', 4034549)],
#                             'prespp': 0,
#                             'rush': -2,
#                             'spp': 0,
#                             'td': 0,
#                             'team': Team(897353),
#                             'turns': 90,
#                             'type': 'R'},
#  NormalPlayer('12130906'): {'blocks': 30,
#                             'cas': 2,
#                             'comp': 0,
#                             'fouls': 0,
#                             'int': 0,
#                             'mvp': 0,
#                             'name': 'Haldor Halvarson',
#                             'pass': 0,
#                             'perf': [('L', 4024847),
#                                      ('D', 4029013),
#                                      ('W', 4029542),
#                                      ('L', 4031344),
#                                      ('W', 4033076),
#                                      ('W', 4034337),
#                                      ('L', 4041379)],
#                             'prespp': 137,
#                             'rush': 0,
#                             'spp': 4,
#                             'td': 0,
#                             'team': Team(883051),
#                             'turns': 81,
#                             'type': 'R'},
#  NormalPlayer('12139096'): {'blocks': 0,
#                             'cas': 0,
#                             'comp': 0,
#                             'fouls': 2,
#                             'int': 0,
#                             'mvp': 0,
#                             'name': 'Mos Passat',
#                             'pass': 0,
#                             'perf': [('L', 4026342),
#                                      ('L', 4027540),
#                                      ('L', 4029149),
#                                      ('L', 4030969),
#                                      ('D', 4032047),
#                                      ('L', 4034337),
#                                      ('W', 4034549)],
#                             'prespp': 392,
#                             'rush': 13,
#                             'spp': 0,
#                             'td': 0,
#                             'team': Team(897353),
#                             'turns': 16,
#                             'type': 'R'},
#  NormalPlayer('12139099'): {'blocks': 14,
#                             'cas': 1,
#                             'comp': 2,
#                             'fouls': 0,
#                             'int': 0,
#                             'mvp': 1,
#                             'name': 'Blu Ash',
#                             'pass': 3,
#                             'perf': [('L', 4026342),
#                                      ('L', 4027540),
#                                      ('L', 4029149),
#                                      ('L', 4030969),
#                                      ('D', 4032047),
#                                      ('L', 4034337),
#                                      ('W', 4034549)],
#                             'prespp': 312,
#                             'rush': 2,
#                             'spp': 9,
#                             'td': 0,
#                             'team': Team(897353),
#                             'turns': 33,
#                             'type': 'R'},
#  NormalPlayer('12158266'): {'blocks': 6,
#                             'cas': 1,
#                             'comp': 0,
#                             'dead': [1, 8, 'fouled', '12362496'],
#                             'fouls': 0,
#                             'int': 0,
#                             'mvp': 0,
#                             'name': 'Ch\'nn\'r "Big Boa" Qll-Crvn',
#                             'pass': 0,
#                             'perf': [('W', 4026342)],
#                             'prespp': 21,
#                             'rush': 0,
#                             'spp': 2,
#                             'td': 0,
#                             'team': Team(899682),
#                             'turns': 7,
#                             'type': 'R'},
#  NormalPlayer('12158267'): {'blocks': 37,
#                             'cas': 4,
#                             'comp': 0,
#                             'dead': [2, 1, 'blocked', '12235198'],
#                             'fouls': 0,
#                             'int': 0,
#                             'mvp': 1,
#                             'name': 'K\'nn\'th "Strangler" Ptnntcl',
#                             'pass': 0,
#                             'perf': [('W', 4026342),
#                                      ('D', 4029013),
#                                      ('L', 4030781),
#                                      ('L', 4031992),
#                                      ('L', 4033320)],
#                             'prespp': 151,
#                             'rush': 0,
#                             'spp': 13,
#                             'td': 0,
#                             'team': Team(899682),
#                             'turns': 64,
#                             'type': 'R'},
#  NormalPlayer('12158269'): {'blocks': 31,
#                             'cas': 2,
#                             'comp': 0,
#                             'fouls': 0,
#                             'int': 0,
#                             'mvp': 0,
#                             'name': 'Ph\'rn "Quick Tail" Vzz-Sttn',
#                             'pass': 0,
#                             'perf': [('W', 4026342),
#                                      ('D', 4029013),
#                                      ('L', 4030781),
#                                      ('L', 4031992),
#                                      ('L', 4033320),
#                                      ('W', 4036761),
#                                      ('W', 4037369)],
#                             'prespp': 255,
#                             'rush': 1,
#                             'spp': 4,
#                             'td': 0,
#                             'team': Team(899682),
#                             'turns': 93,
#                             'type': 'R'},
#  NormalPlayer('12158272'): {'blocks': 15,
#                             'cas': 1,
#                             'comp': 0,
#                             'fouls': 0,
#                             'int': 0,
#                             'mvp': 0,
#                             'name': 'T\'ng "Lefty" Clbrr',
#                             'pass': 0,
#                             'perf': [('W', 4026342),
#                                      ('D', 4029013),
#                                      ('L', 4030781),
#                                      ('L', 4031992),
#                                      ('L', 4033320),
#                                      ('W', 4036761),
#                                      ('W', 4037369)],
#                             'prespp': 97,
#                             'rush': 12,
#                             'spp': 5,
#                             'td': 1,
#                             'team': Team(899682),
#                             'turns': 59,
#                             'type': 'R'},
#  NormalPlayer('12158279'): {'blocks': 14,
#                             'cas': 1,
#                             'comp': 0,
#                             'fouls': 0,
#                             'int': 0,
#                             'mvp': 1,
#                             'name': 'Dtr\'vssr "Mamba" Vrddfls',
#                             'pass': 0,
#                             'perf': [('W', 4026342),
#                                      ('D', 4029013),
#                                      ('L', 4030781),
#                                      ('L', 4031992),
#                                      ('L', 4033320),
#                                      ('W', 4036761),
#                                      ('W', 4037369)],
#                             'prespp': 190,
#                             'rush': 11,
#                             'spp': 10,
#                             'td': 1,
#                             'team': Team(899682),
#                             'turns': 90,
#                             'type': 'R'},
#  NormalPlayer('12162547'): {'blocks': 14,
#                             'cas': 0,
#                             'comp': 0,
#                             'fouls': 2,
#                             'int': 0,
#                             'mvp': 3,
#                             'name': 'Foni Piemondon',
#                             'pass': 0,
#                             'perf': [('D', 4025662),
#                                      ('D', 4026367),
#                                      ('L', 4029542),
#                                      ('W', 4031147),
#                                      ('D', 4032047),
#                                      ('L', 4034603),
#                                      ('L', 4037369)],
#                             'prespp': 301,
#                             'rush': 17,
#                             'spp': 18,
#                             'td': 1,
#                             'team': Team(891237),
#                             'turns': 72,
#                             'type': 'R'},
#  NormalPlayer('12165569'): {'blocks': 39,
#                             'cas': 2,
#                             'comp': 0,
#                             'fouls': 0,
#                             'int': 0,
#                             'mvp': 0,
#                             'name': 'Adenes Fujo',
#                             'pass': 0,
#                             'perf': [('L', 4026342),
#                                      ('L', 4027540),
#                                      ('L', 4029149),
#                                      ('L', 4030969),
#                                      ('D', 4032047),
#                                      ('L', 4034337),
#                                      ('W', 4034549)],
#                             'prespp': 52,
#                             'rush': 14,
#                             'spp': 4,
#                             'td': 0,
#                             'team': Team(897353),
#                             'turns': 105,
#                             'type': 'R'},
#  NormalPlayer('12169214'): {'blocks': 7,
#                             'cas': 0,
#                             'comp': 0,
#                             'fouls': 3,
#                             'int': 0,
#                             'mvp': 0,
#                             'name': 'Igor The Surgeon',
#                             'pass': 0,
#                             'perf': [('L', 4024847),
#                                      ('D', 4029013),
#                                      ('W', 4029542),
#                                      ('L', 4031344),
#                                      ('W', 4033076),
#                                      ('W', 4034337),
#                                      ('L', 4041379)],
#                             'prespp': 35,
#                             'rush': 0,
#                             'spp': 0,
#                             'td': 0,
#                             'team': Team(883051),
#                             'turns': 34,
#                             'type': 'R'},
#  NormalPlayer('12169228'): {'blocks': 14,
#                             'cas': 0,
#                             'comp': 0,
#                             'fouls': 0,
#                             'int': 0,
#                             'mvp': 0,
#                             'name': 'Jary The Younger',
#                             'pass': -1,
#                             'perf': [('L', 4024847),
#                                      ('D', 4029013),
#                                      ('W', 4029542),
#                                      ('L', 4031344),
#                                      ('W', 4033076),
#                                      ('W', 4034337),
#                                      ('L', 4041379)],
#                             'prespp': 14,
#                             'rush': 13,
#                             'spp': 0,
#                             'td': 0,
#                             'team': Team(883051),
#                             'turns': 65,
#                             'type': 'R'},
#  NormalPlayer('12173110'): {'blocks': 24,
#                             'cas': 4,
#                             'comp': 0,
#                             'fouls': 0,
#                             'int': 0,
#                             'mvp': 0,
#                             'name': 'Stonemuncher the Ancient',
#                             'pass': 0,
#                             'perf': [('W', 4024847),
#                                      ('W', 4027540),
#                                      ('W', 4027982),
#                                      ('L', 4031147),
#                                      ('L', 4032572),
#                                      ('L', 4036761),
#                                      ('L', 4037448)],
#                             'prespp': 99,
#                             'rush': 0,
#                             'spp': 8,
#                             'td': 0,
#                             'team': Team(900747),
#                             'turns': 98,
#                             'type': 'B'},
#  NormalPlayer('12173143'): {'blocks': 8,
#                             'cas': 1,
#                             'comp': 0,
#                             'dead': [2, 6, 'fouled', '12117792'],
#                             'fouls': 0,
#                             'int': 0,
#                             'mvp': 0,
#                             'name': 'Dialor the Noble',
#                             'pass': 1,
#                             'perf': [('W', 4024847),
#                                      ('W', 4027540),
#                                      ('W', 4027982)],
#                             'prespp': 103,
#                             'rush': 45,
#                             'spp': 8,
#                             'td': 2,
#                             'team': Team(900747),
#                             'turns': 47,
#                             'type': 'R'},
#  NormalPlayer('12173145'): {'blocks': 13,
#                             'cas': 2,
#                             'comp': 3,
#                             'fouls': 0,
#                             'int': 0,
#                             'mvp': 0,
#                             'name': 'Khras the Enslaved',
#                             'pass': 10,
#                             'perf': [('W', 4024847),
#                                      ('W', 4027540),
#                                      ('W', 4027982),
#                                      ('L', 4031147),
#                                      ('L', 4032572),
#                                      ('L', 4036761),
#                                      ('L', 4037448)],
#                             'prespp': 244,
#                             'rush': 62,
#                             'spp': 7,
#                             'td': 0,
#                             'team': Team(900747),
#                             'turns': 86,
#                             'type': 'R'},
#  NormalPlayer('12173151'): {'blocks': 16,
#                             'cas': 1,
#                             'comp': 0,
#                             'fouls': 1,
#                             'int': 0,
#                             'mvp': 0,
#                             'name': 'Hrkas Prouddeath',
#                             'pass': 0,
#                             'perf': [('W', 4024847),
#                                      ('W', 4027540),
#                                      ('W', 4027982),
#                                      ('L', 4031147),
#                                      ('L', 4032572),
#                                      ('L', 4036761),
#                                      ('L', 4037448)],
#                             'prespp': 57,
#                             'rush': 9,
#                             'spp': 2,
#                             'td': 0,
#                             'team': Team(900747),
#                             'turns': 91,
#                             'type': 'R'},
#  NormalPlayer('12173153'): {'blocks': 14,
#                             'cas': 1,
#                             'comp': 0,
#                             'fouls': 0,
#                             'int': 0,
#                             'mvp': 0,
#                             'name': 'Ghras Paingiver',
#                             'pass': 0,
#                             'perf': [('W', 4024847),
#                                      ('W', 4027540),
#                                      ('W', 4027982),
#                                      ('L', 4031147),
#                                      ('L', 4032572),
#                                      ('L', 4036761),
#                                      ('L', 4037448)],
#                             'prespp': 257,
#                             'rush': 16,
#                             'spp': 8,
#                             'td': 2,
#                             'team': Team(900747),
#                             'turns': 97,
#                             'type': 'R'},
#  NormalPlayer('12173155'): {'blocks': 91,
#                             'cas': 11,
#                             'comp': 0,
#                             'fouls': 0,
#                             'int': 0,
#                             'mvp': 0,
#                             'name': 'Frazsa Grimhand',
#                             'pass': 0,
#                             'perf': [('W', 4024847),
#                                      ('W', 4027540),
#                                      ('W', 4027982),
#                                      ('L', 4031147),
#                                      ('L', 4032572),
#                                      ('L', 4036761),
#                                      ('L', 4037448)],
#                             'prespp': 292,
#                             'rush': 0,
#                             'spp': 22,
#                             'td': 0,
#                             'team': Team(900747),
#                             'turns': 114,
#                             'type': 'R'},
#  NormalPlayer('12173327'): {'blocks': 36,
#                             'cas': 2,
#                             'comp': 0,
#                             'fouls': 0,
#                             'int': 0,
#                             'mvp': 0,
#                             'name': 'Draco the Ascendent',
#                             'pass': 0,
#                             'perf': [('D', 4025662),
#                                      ('D', 4026666),
#                                      ('L', 4027982),
#                                      ('W', 4031344),
#                                      ('W', 4033320),
#                                      ('D', 4033652),
#                                      ('L', 4034549)],
#                             'prespp': 75,
#                             'rush': 8,
#                             'spp': 7,
#                             'td': 1,
#                             'team': Team(896972),
#                             'turns': 89,
#                             'type': 'R'},
#  NormalPlayer('12179724'): {'blocks': 29,
#                             'cas': 0,
#                             'comp': 0,
#                             'fouls': 1,
#                             'int': 0,
#                             'mvp': 0,
#                             'name': 'The Xenith of Devotion',
#                             'pass': 0,
#                             'perf': [('D', 4025662),
#                                      ('D', 4026666),
#                                      ('L', 4027982),
#                                      ('W', 4031344),
#                                      ('W', 4033320),
#                                      ('D', 4033652),
#                                      ('L', 4034549)],
#                             'prespp': 90,
#                             'rush': 7,
#                             'spp': 3,
#                             'td': 1,
#                             'team': Team(896972),
#                             'turns': 74,
#                             'type': 'R'},
#  NormalPlayer('12191641'): {'blocks': 31,
#                             'cas': 0,
#                             'comp': 0,
#                             'fouls': 0,
#                             'int': 0,
#                             'mvp': 0,
#                             'name': 'C\'dm\'qsz "Focus" Ntrll',
#                             'pass': 0,
#                             'perf': [('W', 4026342),
#                                      ('D', 4029013),
#                                      ('L', 4030781),
#                                      ('L', 4031992),
#                                      ('L', 4033320),
#                                      ('W', 4036761),
#                                      ('W', 4037369)],
#                             'prespp': 140,
#                             'rush': 8,
#                             'spp': 3,
#                             'td': 1,
#                             'team': Team(899682),
#                             'turns': 97,
#                             'type': 'R'},
#  NormalPlayer('12219671'): {'blocks': 77,
#                             'cas': 12,
#                             'comp': 0,
#                             'fouls': 0,
#                             'int': 0,
#                             'mvp': 1,
#                             'name': 'Itekuyet',
#                             'pass': 0,
#                             'perf': [('D', 4024740),
#                                      ('D', 4026666),
#                                      ('W', 4029149),
#                                      ('W', 4031992),
#                                      ('L', 4033076),
#                                      ('W', 4034603),
#                                      ('W', 4037448)],
#                             'prespp': 469,
#                             'rush': 19,
#                             'spp': 35,
#                             'td': 2,
#                             'team': Team(903654),
#                             'turns': 101,
#                             'type': 'R'},
#  NormalPlayer('12219673'): {'blocks': 6,
#                             'cas': 1,
#                             'comp': 8,
#                             'fouls': 0,
#                             'int': 0,
#                             'mvp': 0,
#                             'name': 'Ahmose',
#                             'pass': 18,
#                             'perf': [('D', 4024740),
#                                      ('D', 4026666),
#                                      ('W', 4029149),
#                                      ('W', 4031992),
#                                      ('L', 4033076),
#                                      ('W', 4034603),
#                                      ('W', 4037448)],
#                             'prespp': 387,
#                             'rush': 116,
#                             'spp': 16,
#                             'td': 2,
#                             'team': Team(903654),
#                             'turns': 99,
#                             'type': 'R'},
#  NormalPlayer('12219676'): {'blocks': 48,
#                             'cas': 2,
#                             'comp': 0,
#                             'fouls': 0,
#                             'int': 0,
#                             'mvp': 2,
#                             'name': 'Senenmut',
#                             'pass': -1,
#                             'perf': [('D', 4024740),
#                                      ('D', 4026666),
#                                      ('W', 4029149),
#                                      ('W', 4031992),
#                                      ('L', 4033076),
#                                      ('W', 4034603),
#                                      ('W', 4037448)],
#                             'prespp': 110,
#                             'rush': 0,
#                             'spp': 14,
#                             'td': 0,
#                             'team': Team(903654),
#                             'turns': 97,
#                             'type': 'R'},
#  NormalPlayer('12219677'): {'blocks': 4,
#                             'cas': 0,
#                             'comp': 0,
#                             'fouls': 0,
#                             'int': 0,
#                             'mvp': 0,
#                             'name': 'Weshptah',
#                             'pass': 0,
#                             'perf': [('D', 4024740),
#                                      ('D', 4026666),
#                                      ('W', 4029149),
#                                      ('W', 4031992),
#                                      ('L', 4033076)],
#                             'prespp': 0,
#                             'retired': True,
#                             'rush': 0,
#                             'spp': 0,
#                             'td': 0,
#                             'team': Team(903654),
#                             'turns': 61,
#                             'type': 'R'},
#  NormalPlayer('12219678'): {'blocks': 28,
#                             'cas': 1,
#                             'comp': 0,
#                             'fouls': 0,
#                             'int': 0,
#                             'mvp': 0,
#                             'name': 'Merenre',
#                             'pass': 0,
#                             'perf': [('D', 4024740),
#                                      ('D', 4026666),
#                                      ('W', 4029149),
#                                      ('W', 4031992),
#                                      ('L', 4033076),
#                                      ('W', 4034603),
#                                      ('W', 4037448)],
#                             'prespp': 241,
#                             'rush': 0,
#                             'spp': 2,
#                             'td': 0,
#                             'team': Team(903654),
#                             'turns': 81,
#                             'type': 'R'},
#  NormalPlayer('12219681'): {'blocks': 4,
#                             'cas': 0,
#                             'comp': 0,
#                             'fouls': 0,
#                             'int': 0,
#                             'mvp': 0,
#                             'name': 'Haremhab',
#                             'pass': 0,
#                             'perf': [('D', 4024740),
#                                      ('D', 4026666),
#                                      ('W', 4029149),
#                                      ('W', 4031992),
#                                      ('L', 4033076),
#                                      ('W', 4034603),
#                                      ('W', 4037448)],
#                             'prespp': 0,
#                             'rush': 0,
#                             'spp': 0,
#                             'td': 0,
#                             'team': Team(903654),
#                             'turns': 63,
#                             'type': 'R'},
#  NormalPlayer('12219683'): {'blocks': 2,
#                             'cas': 0,
#                             'comp': 0,
#                             'fouls': 0,
#                             'int': 0,
#                             'mvp': 0,
#                             'name': 'Intef',
#                             'pass': -1,
#                             'perf': [('D', 4024740),
#                                      ('D', 4026666),
# ...
#                                      'perf': [('L', 4034337)],
#                                      'prespp': 0,
#                                      'rush': 0,
#                                      'spp': 0,
#                                      'td': 0,
#                                      'team': Team(897353),
#                                      'turns': 6,
#                                      'type': 'M'},
#  MercenaryPlayer('MERC-7444-1776'): {'blocks': 3,
#                                      'cas': 0,
#                                      'comp': 0,
#                                      'fouls': 0,
#                                      'int': 1,
#                                      'mvp': 0,
#                                      'name': 'Merc Air Elemental 2',
#                                      'pass': 0,
#                                      'perf': [('L', 4029149)],
#                                      'prespp': 0,
#                                      'rush': 3,
#                                      'spp': 2,
#                                      'td': 0,
#                                      'team': Team(897353),
#                                      'turns': 14,
#                                      'type': 'M'},
#  MercenaryPlayer('MERC-7444-1790'): {'blocks': 1,
#                                      'cas': 0,
#                                      'comp': 0,
#                                      'fouls': 0,
#                                      'int': 0,
#                                      'mvp': 0,
#                                      'name': 'Merc Air Elemental 4',
#                                      'pass': 0,
#                                      'perf': [('D', 4032047)],
#                                      'prespp': 0,
#                                      'rush': 0,
#                                      'spp': 0,
#                                      'td': 0,
#                                      'team': Team(897353),
#                                      'turns': 16,
#                                      'type': 'M'},
#  MercenaryPlayer('MERC-7444-1807'): {'blocks': 3,
#                                      'cas': 0,
#                                      'comp': 0,
#                                      'fouls': 1,
#                                      'int': 0,
#                                      'mvp': 0,
#                                      'name': 'Merc Air Elemental 3',
#                                      'pass': 0,
#                                      'perf': [('D', 4032047)],
#                                      'prespp': 0,
#                                      'rush': 0,
#                                      'spp': 0,
#                                      'td': 0,
#                                      'team': Team(897353),
#                                      'turns': 14,
#                                      'type': 'M'},
#  MercenaryPlayer('MERC-7444-2012'): {'blocks': 2,
#                                      'cas': 0,
#                                      'comp': 0,
#                                      'fouls': 0,
#                                      'int': 0,
#                                      'mvp': 0,
#                                      'name': 'Merc Air Elemental 5',
#                                      'pass': 0,
#                                      'perf': [('L', 4029149)],
#                                      'prespp': 0,
#                                      'rush': 0,
#                                      'spp': 0,
#                                      'td': 0,
#                                      'team': Team(897353),
#                                      'turns': 15,
#                                      'type': 'M'},
#  MercenaryPlayer('MERC-7444-2145'): {'blocks': 3,
#                                      'cas': 0,
#                                      'comp': 0,
#                                      'fouls': 0,
#                                      'int': 0,
#                                      'mvp': 0,
#                                      'name': 'Merc Air Elemental 2',
#                                      'pass': 0,
#                                      'perf': [('L', 4027540)],
#                                      'prespp': 0,
#                                      'rush': 0,
#                                      'spp': 0,
#                                      'td': 0,
#                                      'team': Team(897353),
#                                      'turns': 16,
#                                      'type': 'M'},
#  MercenaryPlayer('MERC-7444-2428'): {'blocks': 2,
#                                      'cas': 0,
#                                      'comp': 0,
#                                      'fouls': 0,
#                                      'int': 0,
#                                      'mvp': 0,
#                                      'name': 'Merc Air Elemental 4',
#                                      'pass': 0,
#                                      'perf': [('L', 4030969)],
#                                      'prespp': 0,
#                                      'rush': 0,
#                                      'spp': 0,
#                                      'td': 0,
#                                      'team': Team(897353),
#                                      'turns': 12,
#                                      'type': 'M'},
#  MercenaryPlayer('MERC-7444-2680'): {'blocks': 2,
#                                      'cas': 0,
#                                      'comp': 0,
#                                      'fouls': 0,
#                                      'int': 0,
#                                      'mvp': 0,
#                                      'name': 'Merc Air Elemental 5',
#                                      'pass': 0,
#                                      'perf': [('L', 4030969)],
#                                      'prespp': 0,
#                                      'rush': 0,
#                                      'spp': 0,
#                                      'td': 0,
#                                      'team': Team(897353),
#                                      'turns': 12,
#                                      'type': 'M'},
#  MercenaryPlayer('MERC-7444-2820'): {'blocks': 1,
#                                      'cas': 0,
#                                      'comp': 0,
#                                      'fouls': 0,
#                                      'int': 0,
#                                      'mvp': 0,
#                                      'name': 'Merc Air Elemental 3',
#                                      'pass': 0,
#                                      'perf': [('L', 4027540)],
#                                      'prespp': 0,
#                                      'rush': 0,
#                                      'spp': 0,
#                                      'td': 0,
#                                      'team': Team(897353),
#                                      'turns': 3,
#                                      'type': 'M'},
#  MercenaryPlayer('MERC-7444-2913'): {'blocks': 4,
#                                      'cas': 0,
#                                      'comp': 0,
#                                      'fouls': 0,
#                                      'int': 0,
#                                      'mvp': 0,
#                                      'name': 'Merc Air Elemental 3',
#                                      'pass': 0,
#                                      'perf': [('W', 4034549)],
#                                      'prespp': 0,
#                                      'rush': 0,
#                                      'spp': 0,
#                                      'td': 0,
#                                      'team': Team(897353),
#                                      'turns': 5,
#                                      'type': 'M'},
#  MercenaryPlayer('MERC-7444-3066'): {'blocks': 2,
#                                      'cas': 0,
#                                      'comp': 0,
#                                      'fouls': 0,
#                                      'int': 0,
#                                      'mvp': 0,
#                                      'name': 'Merc Air Elemental 5',
#                                      'pass': 0,
#                                      'perf': [('D', 4032047)],
#                                      'prespp': 0,
#                                      'rush': 0,
#                                      'spp': 0,
#                                      'td': 0,
#                                      'team': Team(897353),
#                                      'turns': 11,
#                                      'type': 'M'},
#  MercenaryPlayer('MERC-7444-3110'): {'blocks': 0,
#                                      'cas': 0,
#                                      'comp': 0,
#                                      'fouls': 0,
#                                      'int': 0,
#                                      'mvp': 0,
#                                      'name': 'Merc Air Elemental 2',
#                                      'pass': 0,
#                                      'perf': [('D', 4032047)],
#                                      'prespp': 0,
#                                      'rush': 0,
#                                      'spp': 0,
#                                      'td': 0,
#                                      'team': Team(897353),
#                                      'turns': 8,
#                                      'type': 'M'},
#  MercenaryPlayer('MERC-7444-3217'): {'blocks': 2,
#                                      'cas': 0,
#                                      'comp': 0,
#                                      'fouls': 0,
#                                      'int': 0,
#                                      'mvp': 0,
#                                      'name': 'Merc Air Elemental 3',
#                                      'pass': 0,
#                                      'perf': [('L', 4030969)],
#                                      'prespp': 0,
#                                      'rush': 0,
#                                      'spp': 0,
#                                      'td': 0,
#                                      'team': Team(897353),
#                                      'turns': 15,
#                                      'type': 'M'},
#  MercenaryPlayer('MERC-7444-3467'): {'blocks': 2,
#                                      'cas': 0,
#                                      'comp': 0,
#                                      'fouls': 0,
#                                      'int': 0,
#                                      'mvp': 0,
#                                      'name': 'Merc Air Elemental 1',
#                                      'pass': 0,
#                                      'perf': [('L', 4029149)],
#                                      'prespp': 0,
#                                      'rush': 0,
#                                      'spp': 0,
#                                      'td': 0,
#                                      'team': Team(897353),
#                                      'turns': 13,
#                                      'type': 'M'},
#  MercenaryPlayer('MERC-7444-3588'): {'blocks': 1,
#                                      'cas': 0,
#                                      'comp': 0,
#                                      'fouls': 0,
#                                      'int': 0,
#                                      'mvp': 0,
#                                      'name': 'Merc Air Elemental 2',
#                                      'pass': 0,
#                                      'perf': [('W', 4034549)],
#                                      'prespp': 0,
#                                      'rush': 0,
#                                      'spp': 0,
#                                      'td': 0,
#                                      'team': Team(897353),
#                                      'turns': 6,
#                                      'type': 'M'},
#  MercenaryPlayer('MERC-7444-3727'): {'blocks': 2,
#                                      'cas': 0,
#                                      'comp': 0,
#                                      'fouls': 0,
#                                      'int': 0,
#                                      'mvp': 0,
#                                      'name': 'Merc Air Elemental 1',
#                                      'pass': 0,
#                                      'perf': [('L', 4030969)],
#                                      'prespp': 0,
#                                      'rush': 0,
#                                      'spp': 0,
#                                      'td': 0,
#                                      'team': Team(897353),
#                                      'turns': 15,
#                                      'type': 'M'},
#  MercenaryPlayer('MERC-7444-3892'): {'blocks': 3,
#                                      'cas': 0,
#                                      'comp': 0,
#                                      'fouls': 0,
#                                      'int': 0,
#                                      'mvp': 0,
#                                      'name': 'Merc Air Elemental 2',
#                                      'pass': 0,
#                                      'perf': [('L', 4030969)],
#                                      'prespp': 0,
#                                      'rush': 0,
#                                      'spp': 0,
#                                      'td': 0,
#                                      'team': Team(897353),
#                                      'turns': 15,
#                                      'type': 'M'},
#  MercenaryPlayer('MERC-7446-0393'): {'blocks': 0,
#                                      'cas': 0,
#                                      'comp': 0,
#                                      'fouls': 0,
#                                      'int': 0,
#                                      'mvp': 0,
#                                      'name': 'Merc Water Elemental 1',
#                                      'pass': 0,
#                                      'perf': [('L', 4027540)],
#                                      'prespp': 0,
#                                      'rush': 0,
#                                      'spp': 0,
#                                      'td': 0,
#                                      'team': Team(897353),
#                                      'turns': 9,
#                                      'type': 'M'},
#  MercenaryPlayer('MERC-7446-3508'): {'blocks': 2,
#                                      'cas': 0,
#                                      'comp': 0,
#                                      'fouls': 0,
#                                      'int': 0,
#                                      'mvp': 0,
#                                      'name': 'Merc Water Elemental 1',
#                                      'pass': 0,
#                                      'perf': [('L', 4026342)],
#                                      'prespp': 0,
#                                      'rush': 0,
#                                      'spp': 0,
#                                      'td': 0,
#                                      'team': Team(897353),
#                                      'turns': 16,
#                                      'type': 'M'},
#  MercenaryPlayer('MERC-7447-2981'): {'blocks': 4,
#                                      'cas': 0,
#                                      'comp': 0,
#                                      'fouls': 0,
#                                      'int': 0,
#                                      'mvp': 0,
#                                      'name': 'Merc Fire Elemental 1',
#                                      'pass': 0,
#                                      'perf': [('L', 4027540)],
#                                      'prespp': 0,
#                                      'rush': 0,
#                                      'spp': 0,
#                                      'td': 0,
#                                      'team': Team(897353),
#                                      'turns': 11,
#                                      'type': 'M'}}

# %%
Pl = player('12173153')
Pl.team.name
# Out:
# 'Black Monolith Worshippers'

# %%
Pl.name
# Out:
# 'Ghras Paingiver'

# %%
pprint(rawperf[player('12022010')])
# Out:
# {'blocks': 5,
#  'cas': 0,
#  'comp': 0,
#  'dead': [2, 6, 'blocked', '12323837'],
#  'fouls': 0,
#  'int': 0,
#  'mvp': 0,
#  'name': 'Dew Midhon',
#  'pass': 0,
#  'perf': [('D', 4025662), ('D', 4026367)],
#  'prespp': 42,
#  'rush': 0,
#  'spp': 0,
#  'td': 0,
#  'team': Team(891237),
#  'turns': 28,
#  'type': 'R'}

# %%
PS = T.playerperformancesources()
pprint(PS)
# Out:
# lastretired Tournament('cibbl', '45883') NormalPlayer('12173153')
# lastretired Tournament('cibbl', '45883') NormalPlayer('12450013')
# {NormalPlayer('11892405'): {NormalPlayer('11892405')},
#  NormalPlayer('11892424'): {NormalPlayer('11892424')},
#  NormalPlayer('11892428'): {NormalPlayer('11892428')},
#  NormalPlayer('11892429'): {NormalPlayer('11892429')},
#  NormalPlayer('11947871'): {NormalPlayer('11947871')},
#  NormalPlayer('11950136'): {NormalPlayer('11950136')},
#  NormalPlayer('12022005'): {NormalPlayer('12022005')},
#  NormalPlayer('12022006'): {NormalPlayer('12022006')},
#  NormalPlayer('12022008'): {NormalPlayer('12022008')},
#  NormalPlayer('12022022'): {NormalPlayer('12022022')},
#  NormalPlayer('12104982'): {NormalPlayer('12104982')},
#  NormalPlayer('12117786'): {NormalPlayer('12117786')},
#  NormalPlayer('12117788'): {NormalPlayer('12117788')},
#  NormalPlayer('12117790'): {NormalPlayer('12117790')},
#  NormalPlayer('12117791'): {NormalPlayer('12117791')},
#  NormalPlayer('12117792'): {NormalPlayer('12117792')},
#  NormalPlayer('12117795'): {NormalPlayer('12117795')},
#  NormalPlayer('12117802'): {NormalPlayer('12117802')},
#  NormalPlayer('12121959'): {NormalPlayer('12121959')},
#  NormalPlayer('12121960'): {NormalPlayer('12121960')},
#  NormalPlayer('12121974'): {NormalPlayer('12121974')},
#  NormalPlayer('12130906'): {NormalPlayer('12130906')},
#  NormalPlayer('12139096'): {NormalPlayer('12139096')},
#  NormalPlayer('12139099'): {NormalPlayer('12139099')},
#  NormalPlayer('12158266'): {NormalPlayer('12158266')},
#  NormalPlayer('12158267'): {NormalPlayer('12158267')},
#  NormalPlayer('12158269'): {NormalPlayer('12158269')},
#  NormalPlayer('12158272'): {NormalPlayer('12158272')},
#  NormalPlayer('12158279'): {NormalPlayer('12158279')},
#  NormalPlayer('12162547'): {NormalPlayer('12162547')},
#  NormalPlayer('12165569'): {NormalPlayer('12165569')},
#  NormalPlayer('12169214'): {NormalPlayer('12169214')},
#  NormalPlayer('12169228'): {NormalPlayer('12169228')},
#  NormalPlayer('12173110'): {NormalPlayer('12173110')},
#  NormalPlayer('12173143'): {NormalPlayer('12173143')},
#  NormalPlayer('12173145'): {NormalPlayer('12173145')},
#  NormalPlayer('12173151'): {NormalPlayer('12173151')},
#  NormalPlayer('12173153'): {NormalPlayer('12173153')},
#  NormalPlayer('12173155'): {NormalPlayer('12173155')},
#  NormalPlayer('12173327'): {NormalPlayer('12173327')},
#  NormalPlayer('12179724'): {NormalPlayer('12179724')},
#  NormalPlayer('12191641'): {NormalPlayer('12191641')},
#  NormalPlayer('12219671'): {NormalPlayer('12219671')},
#  NormalPlayer('12219673'): {NormalPlayer('12219673')},
#  NormalPlayer('12219676'): {NormalPlayer('12219676')},
#  NormalPlayer('12219677'): {NormalPlayer('12219677')},
#  NormalPlayer('12219678'): {NormalPlayer('12219678')},
#  NormalPlayer('12219681'): {NormalPlayer('12219681')},
#  NormalPlayer('12219683'): {NormalPlayer('12219683')},
#  NormalPlayer('12219684'): {NormalPlayer('12219684')},
#  NormalPlayer('12219903'): {NormalPlayer('12219903')},
#  NormalPlayer('12227199'): {NormalPlayer('12227199')},
#  NormalPlayer('12229237'): {NormalPlayer('12229237')},
#  NormalPlayer('12230477'): {NormalPlayer('12230477')},
#  NormalPlayer('12235198'): {NormalPlayer('12235198')},
#  NormalPlayer('12240321'): {NormalPlayer('12240321')},
#  NormalPlayer('12245045'): {NormalPlayer('12245045')},
#  NormalPlayer('12282912'): {NormalPlayer('12282912')},
#  NormalPlayer('12288426'): {NormalPlayer('12288426')},
#  NormalPlayer('12296160'): {NormalPlayer('12296160')},
#  NormalPlayer('12318457'): {NormalPlayer('12318457')},
#  NormalPlayer('12319538'): {NormalPlayer('12319538')},
#  NormalPlayer('12320309'): {NormalPlayer('12320309')},
#  NormalPlayer('12320310'): {NormalPlayer('12320310')},
#  NormalPlayer('12320799'): {NormalPlayer('12320799')},
#  NormalPlayer('12323836'): {NormalPlayer('12323836')},
#  NormalPlayer('12323837'): {NormalPlayer('12323837')},
#  NormalPlayer('12323839'): {NormalPlayer('12323839')},
#  NormalPlayer('12323842'): {NormalPlayer('12323842')},
#  NormalPlayer('12323844'): {NormalPlayer('12323844')},
#  NormalPlayer('12323845'): {NormalPlayer('12323845')},
#  NormalPlayer('12323847'): {NormalPlayer('12323847')},
#  NormalPlayer('12325681'): {NormalPlayer('12325681')},
#  NormalPlayer('12339037'): {NormalPlayer('12339037')},
#  NormalPlayer('12340698'): {NormalPlayer('12340698')},
#  NormalPlayer('12346893'): {NormalPlayer('12346893')},
#  NormalPlayer('12348482'): {NormalPlayer('12348482')},
#  NormalPlayer('12348483'): {NormalPlayer('12348483')},
#  NormalPlayer('12350186'): {NormalPlayer('12350186')},
#  NormalPlayer('12352367'): {NormalPlayer('12352367')},
#  NormalPlayer('12352368'): {NormalPlayer('12352368')},
#  NormalPlayer('12354844'): {NormalPlayer('12354844')},
#  NormalPlayer('12357064'): {NormalPlayer('12357064')},
#  NormalPlayer('12358967'): {NormalPlayer('12358967')},
#  NormalPlayer('12360754'): {NormalPlayer('12360754')},
#  NormalPlayer('12362496'): {NormalPlayer('12362496')},
#  NormalPlayer('12362498'): {NormalPlayer('12362498')},
#  NormalPlayer('12367633'): {NormalPlayer('12367633')},
#  NormalPlayer('12399357'): {NormalPlayer('12399357')},
#  NormalPlayer('12399358'): {NormalPlayer('12399358')},
#  NormalPlayer('12399363'): {NormalPlayer('12399363')},
#  NormalPlayer('12402229'): {NormalPlayer('12402229')},
#  NormalPlayer('12402972'): {NormalPlayer('12402972')},
#  NormalPlayer('12422174'): {NormalPlayer('12422174')},
#  NormalPlayer('12424263'): {NormalPlayer('12424263')},
#  NormalPlayer('12431641'): {NormalPlayer('12431641')},
#  NormalPlayer('12438916'): {NormalPlayer('12438916')},
#  NormalPlayer('12443530'): {NormalPlayer('12443530')},
#  NormalPlayer('12450012'): {NormalPlayer('12450012')},
#  NormalPlayer('12450013'): {NormalPlayer('12450013')},
#  NormalPlayer('12451233'): {NormalPlayer('12451233')},
#  NormalPlayer('12455237'): {NormalPlayer('12455237')},
#  NormalPlayer('12458539'): {NormalPlayer('12458539')},
#  NormalPlayer('12464407'): {NormalPlayer('12464407')},
#  NormalPlayer('12467071'): {NormalPlayer('12467071')},
#  NormalPlayer('12467072'): {NormalPlayer('12467072')},
#  NormalPlayer('12488193'): {NormalPlayer('12488193')},
#  NormalPlayer('12488202'): {NormalPlayer('12488202')},
#  NormalPlayer('12492950'): {NormalPlayer('12492950')},
#  NormalPlayer('12495688'): {NormalPlayer('12495688')},
#  NormalPlayer('12496642'): {NormalPlayer('12022010'),
#                             RaisedDeadPlayer('RAISED-7392_12022010_12496642')},
#  NormalPlayer('12497858'): {NormalPlayer('12497858')},
#  NormalPlayer('12500720'): {NormalPlayer('12500720')},
#  NormalPlayer('12501592'): {NormalPlayer('12501592')},
#  NormalPlayer('12502657'): {NormalPlayer('12502657')},
#  NormalPlayer('12502658'): {NormalPlayer('12502658')},
#  NormalPlayer('12504647'): {NormalPlayer('12504647')},
#  NormalPlayer('12510951'): {NormalPlayer('12510951')},
#  NormalPlayer('12510965'): {NormalPlayer('12510965')},
#  NormalPlayer('12510966'): {NormalPlayer('12510966')},
#  NormalPlayer('12513608'): {NormalPlayer('12513608')},
#  NormalPlayer('12513768'): {NormalPlayer('12513768')},
#  NormalPlayer('12519733'): {NormalPlayer('12519733')},
#  NormalPlayer('12519811'): {NormalPlayer('12519811')},
#  NormalPlayer('12520380'): {NormalPlayer('12520380')},
#  NormalPlayer('12521600'): {NormalPlayer('12521600')},
#  NormalPlayer('12521602'): {NormalPlayer('12521602')},
#  NormalPlayer('12522638'): {NormalPlayer('12522638')},
#  NormalPlayer('12525812'): {NormalPlayer('12525812')},
#  NormalPlayer('12531227'): {NormalPlayer('12531227')},
#  NormalPlayer('12535865'): {NormalPlayer('12535865')},
#  NormalPlayer('12536828'): {NormalPlayer('12536828')},
#  NormalPlayer('12537131'): {NormalPlayer('12537131')},
#  NormalPlayer('12537132'): {NormalPlayer('12537132')},
#  NormalPlayer('12551905'): {NormalPlayer('12551905')},
#  NormalPlayer('12551997'): {NormalPlayer('12551997')},
#  NormalPlayer('12552000'): {NormalPlayer('12552000')},
#  StarPlayer('STAR-7537'): {StarPlayer('STAR-7537')},
#  StarPlayer('STAR-7545'): {StarPlayer('STAR-7545')},
#  StarPlayer('STAR-7581'): {StarPlayer('STAR-7581')},
#  StarPlayer('STAR-7660'): {StarPlayer('STAR-7660')},
#  MercenaryPlayer('MERC-7363-2035'): {MercenaryPlayer('MERC-7363-2035')},
#  MercenaryPlayer('MERC-7391-3245'): {MercenaryPlayer('MERC-7391-3245')},
#  MercenaryPlayer('MERC-7444-0015'): {MercenaryPlayer('MERC-7444-0015')},
#  MercenaryPlayer('MERC-7444-0351'): {MercenaryPlayer('MERC-7444-0351')},
#  MercenaryPlayer('MERC-7444-0529'): {MercenaryPlayer('MERC-7444-0529')},
#  MercenaryPlayer('MERC-7444-0557'): {MercenaryPlayer('MERC-7444-0557')},
#  MercenaryPlayer('MERC-7444-0717'): {MercenaryPlayer('MERC-7444-0717')},
#  MercenaryPlayer('MERC-7444-0886'): {MercenaryPlayer('MERC-7444-0886')},
#  MercenaryPlayer('MERC-7444-1067'): {MercenaryPlayer('MERC-7444-1067')},
#  MercenaryPlayer('MERC-7444-1240'): {MercenaryPlayer('MERC-7444-1240')},
#  MercenaryPlayer('MERC-7444-1400'): {MercenaryPlayer('MERC-7444-1400')},
#  MercenaryPlayer('MERC-7444-1616'): {MercenaryPlayer('MERC-7444-1616')},
#  MercenaryPlayer('MERC-7444-1776'): {MercenaryPlayer('MERC-7444-1776')},
#  MercenaryPlayer('MERC-7444-1790'): {MercenaryPlayer('MERC-7444-1790')},
#  MercenaryPlayer('MERC-7444-1807'): {MercenaryPlayer('MERC-7444-1807')},
#  MercenaryPlayer('MERC-7444-2012'): {MercenaryPlayer('MERC-7444-2012')},
#  MercenaryPlayer('MERC-7444-2145'): {MercenaryPlayer('MERC-7444-2145')},
#  MercenaryPlayer('MERC-7444-2428'): {MercenaryPlayer('MERC-7444-2428')},
#  MercenaryPlayer('MERC-7444-2680'): {MercenaryPlayer('MERC-7444-2680')},
#  MercenaryPlayer('MERC-7444-2820'): {MercenaryPlayer('MERC-7444-2820')},
#  MercenaryPlayer('MERC-7444-2913'): {MercenaryPlayer('MERC-7444-2913')},
#  MercenaryPlayer('MERC-7444-3066'): {MercenaryPlayer('MERC-7444-3066')},
#  MercenaryPlayer('MERC-7444-3110'): {MercenaryPlayer('MERC-7444-3110')},
#  MercenaryPlayer('MERC-7444-3217'): {MercenaryPlayer('MERC-7444-3217')},
#  MercenaryPlayer('MERC-7444-3467'): {MercenaryPlayer('MERC-7444-3467')},
#  MercenaryPlayer('MERC-7444-3588'): {MercenaryPlayer('MERC-7444-3588')},
#  MercenaryPlayer('MERC-7444-3727'): {MercenaryPlayer('MERC-7444-3727')},
#  MercenaryPlayer('MERC-7444-3892'): {MercenaryPlayer('MERC-7444-3892')},
#  MercenaryPlayer('MERC-7446-0393'): {MercenaryPlayer('MERC-7446-0393')},
#  MercenaryPlayer('MERC-7446-3508'): {MercenaryPlayer('MERC-7446-3508')},
#  MercenaryPlayer('MERC-7447-2981'): {MercenaryPlayer('MERC-7447-2981')}}

# %%
perf = T.playerperformances()
pprint(perf)
# Out:
# lastretired Tournament('cibbl', '43565') NormalPlayer('12004119')
# {NormalPlayer('11590768'): {'blocks': 38,
#                             'cas': 1,
#                             'comp': 0,
#                             'fouls': 0,
#                             'int': 0,
#                             'mvp': 2,
#                             'name': 'S. Sang',
#                             'pass': -1,
#                             'perf': [('L', 3928115),
#                                      ('L', 3929535),
#                                      ('L', 3931198),
#                                      ('L', 3935706),
#                                      ('L', 3937119),
#                                      ('L', 3939738)],
#                             'prespp': 191,
#                             'rush': 11,
#                             'spp': 12,
#                             'td': 0,
#                             'team': Team(864291),
#                             'turns': 74,
#                             'type': 'R'},
#  NormalPlayer('11590769'): {'blocks': 17,
#                             'cas': 1,
#                             'comp': 0,
#                             'fouls': 1,
#                             'int': 0,
#                             'mvp': 0,
#                             'name': 'U. Gress',
#                             'pass': 0,
#                             'perf': [('L', 3928115),
#                                      ('L', 3929535),
#                                      ('L', 3931198),
#                                      ('L', 3935706),
#                                      ('L', 3937119),
#                                      ('L', 3939738)],
#                             'prespp': 84,
#                             'rush': 0,
#                             'spp': 2,
#                             'td': 0,
#                             'team': Team(864291),
#                             'turns': 80,
#                             'type': 'R'},
#  NormalPlayer('11590771'): {'blocks': 11,
#                             'cas': 1,
#                             'comp': 0,
#                             'fouls': 1,
#                             'int': 0,
#                             'mvp': 0,
#                             'name': 'Redivor',
#                             'pass': 0,
#                             'perf': [('L', 3928115),
#                                      ('L', 3929535),
#                                      ('L', 3931198),
#                                      ('L', 3935706),
#                                      ('L', 3937119),
#                                      ('L', 3939738)],
#                             'prespp': 76,
#                             'rush': 0,
#                             'spp': 2,
#                             'td': 0,
#                             'team': Team(864291),
#                             'turns': 51,
#                             'type': 'R'},
#  NormalPlayer('11590772'): {'blocks': 19,
#                             'cas': 1,
#                             'comp': 0,
#                             'fouls': 1,
#                             'int': 0,
#                             'mvp': 0,
#                             'name': 'Redimor',
#                             'pass': 0,
#                             'perf': [('L', 3928115),
#                                      ('L', 3929535),
#                                      ('L', 3931198),
#                                      ('L', 3935706),
#                                      ('L', 3937119),
#                                      ('L', 3939738)],
#                             'prespp': 76,
#                             'rush': 0,
#                             'spp': 2,
#                             'td': 0,
#                             'team': Team(864291),
#                             'turns': 77,
#                             'type': 'R'},
#  NormalPlayer('11590773'): {'blocks': 6,
#                             'cas': 0,
#                             'comp': 0,
#                             'fouls': 2,
#                             'int': 0,
#                             'mvp': 1,
#                             'name': 'Chitemor',
#                             'pass': 0,
#                             'perf': [('L', 3928115),
#                                      ('L', 3929535),
#                                      ('L', 3931198),
#                                      ('L', 3935706),
#                                      ('L', 3937119),
#                                      ('L', 3939738)],
#                             'prespp': 10,
#                             'rush': 0,
#                             'spp': 5,
#                             'td': 0,
#                             'team': Team(864291),
#                             'turns': 27,
#                             'type': 'R'},
#  NormalPlayer('11590777'): {'blocks': 16,
#                             'cas': 0,
#                             'comp': 0,
#                             'fouls': 0,
#                             'int': 0,
#                             'mvp': 0,
#                             'name': 'Limortor',
#                             'pass': 0,
#                             'perf': [('L', 3928115),
#                                      ('L', 3929535),
#                                      ('L', 3931198),
#                                      ('L', 3935706),
#                                      ('L', 3937119),
#                                      ('L', 3939738)],
#                             'prespp': 96,
#                             'rush': 0,
#                             'spp': 0,
#                             'td': 0,
#                             'team': Team(864291),
#                             'turns': 65,
#                             'type': 'R'},
#  NormalPlayer('11590778'): {'blocks': 18,
#                             'cas': 1,
#                             'comp': 0,
#                             'dead': [1, 6, 'blocked', '11686464'],
#                             'fouls': 0,
#                             'int': 0,
#                             'mvp': 0,
#                             'name': 'Dissepolor',
#                             'pass': 0,
#                             'perf': [('L', 3928115),
#                                      ('L', 3929535),
#                                      ('L', 3931198),
#                                      ('L', 3935706)],
#                             'prespp': 42,
#                             'rush': 0,
#                             'spp': 2,
#                             'td': 0,
#                             'team': Team(864291),
#                             'turns': 50,
#                             'type': 'R'},
#  NormalPlayer('11590780'): {'blocks': 17,
#                             'cas': 0,
#                             'comp': 0,
#                             'fouls': 0,
#                             'int': 0,
#                             'mvp': 0,
#                             'name': 'Affuquator',
#                             'pass': 0,
#                             'perf': [('L', 3928115),
#                                      ('L', 3929535),
#                                      ('L', 3931198),
#                                      ('L', 3935706),
#                                      ('L', 3937119),
#                                      ('L', 3939738)],
#                             'prespp': 66,
#                             'rush': 0,
#                             'spp': 0,
#                             'td': 0,
#                             'team': Team(864291),
#                             'turns': 79,
#                             'type': 'R'},
#  NormalPlayer('11590781'): {'blocks': 17,
#                             'cas': 1,
#                             'comp': 0,
#                             'fouls': 0,
#                             'int': 0,
#                             'mvp': 0,
#                             'name': 'Dichitemor',
#                             'pass': 0,
#                             'perf': [('L', 3928115),
#                                      ('L', 3929535),
#                                      ('L', 3931198),
#                                      ('L', 3935706),
#                                      ('L', 3937119),
#                                      ('L', 3939738)],
#                             'prespp': 82,
#                             'rush': 0,
#                             'spp': 2,
#                             'td': 0,
#                             'team': Team(864291),
#                             'turns': 91,
#                             'type': 'R'},
#  NormalPlayer('11603005'): {'blocks': 38,
#                             'cas': 0,
#                             'comp': 0,
#                             'fouls': 0,
#                             'int': 0,
#                             'mvp': 1,
#                             'name': 'Ouszz',
#                             'pass': 0,
#                             'perf': [('L', 3924129),
#                                      ('L', 3928397),
#                                      ('L', 3933310),
#                                      ('L', 3933638),
#                                      ('W', 3937119),
#                                      ('L', 3939205)],
#                             'prespp': 207,
#                             'rush': 0,
#                             'spp': 5,
#                             'td': 0,
#                             'team': Team(865063),
#                             'turns': 73,
#                             'type': 'R'},
#  NormalPlayer('11603008'): {'blocks': 4,
#                             'cas': 0,
#                             'comp': 1,
#                             'fouls': 0,
#                             'int': 0,
#                             'mvp': 1,
#                             'name': 'Riptorr',
#                             'pass': 2,
#                             'perf': [('L', 3924129),
#                                      ('L', 3928397),
#                                      ('L', 3933310),
#                                      ('L', 3933638),
#                                      ('W', 3937119),
#                                      ('L', 3939205)],
#                             'prespp': 77,
#                             'rush': 7,
#                             'spp': 6,
#                             'td': 0,
#                             'team': Team(865063),
#                             'turns': 59,
#                             'type': 'R'},
#  NormalPlayer('11603012'): {'blocks': 5,
#                             'cas': 0,
#                             'comp': 0,
#                             'fouls': 4,
#                             'int': 0,
#                             'mvp': 0,
#                             'name': 'Timrr',
#                             'pass': 0,
#                             'perf': [('L', 3924129),
#                                      ('L', 3928397),
#                                      ('L', 3933310),
#                                      ('L', 3933638),
#                                      ('W', 3937119)],
#                             'prespp': 0,
#                             'retired': True,
#                             'rush': 0,
#                             'spp': 0,
#                             'td': 0,
#                             'team': Team(865063),
#                             'turns': 48,
#                             'type': 'R'},
#  NormalPlayer('11603016'): {'blocks': 9,
#                             'cas': 0,
#                             'comp': 0,
#                             'fouls': 0,
#                             'int': 0,
#                             'mvp': 0,
#                             'name': 'Esqds',
#                             'pass': 0,
#                             'perf': [('L', 3924129),
#                                      ('L', 3928397),
#                                      ('L', 3933310),
#                                      ('L', 3933638),
#                                      ('W', 3937119),
#                                      ('L', 3939205)],
#                             'prespp': 96,
#                             'rush': 0,
#                             'spp': 0,
#                             'td': 0,
#                             'team': Team(865063),
#                             'turns': 27,
#                             'type': 'R'},
#  NormalPlayer('11603017'): {'blocks': 26,
#                             'cas': 2,
#                             'comp': 0,
#                             'fouls': 2,
#                             'int': 0,
#                             'mvp': 0,
#                             'name': 'Nert',
#                             'pass': 0,
#                             'perf': [('L', 3924129),
#                                      ('L', 3928397),
#                                      ('L', 3933310),
#                                      ('L', 3933638),
#                                      ('W', 3937119),
#                                      ('L', 3939205)],
#                             'prespp': 124,
#                             'rush': 0,
#                             'spp': 4,
#                             'td': 0,
#                             'team': Team(865063),
#                             'turns': 69,
#                             'type': 'R'},
#  NormalPlayer('11667457'): {'blocks': 14,
#                             'cas': 0,
#                             'comp': 0,
#                             'fouls': 0,
#                             'int': 0,
#                             'mvp': 0,
#                             'name': 'Glicees',
#                             'pass': 0,
#                             'perf': [('D', 3924541),
#                                      ('W', 3928296),
#                                      ('W', 3929535),
#                                      ('W', 3933638),
#                                      ('W', 3936723),
#                                      ('D', 3937171)],
#                             'prespp': 327,
#                             'rush': 115,
#                             'spp': 21,
#                             'td': 7,
#                             'team': Team(869156),
#                             'turns': 87,
#                             'type': 'R'},
#  NormalPlayer('11667458'): {'blocks': 45,
#                             'cas': 4,
#                             'comp': 0,
#                             'fouls': 0,
#                             'int': 0,
#                             'mvp': 2,
#                             'name': 'Xahr',
#                             'pass': 0,
#                             'perf': [('D', 3924541),
#                                      ('W', 3928296),
#                                      ('W', 3929535),
#                                      ('W', 3933638),
#                                      ('W', 3936723),
#                                      ('D', 3937171)],
#                             'prespp': 178,
#                             'rush': 0,
#                             'spp': 18,
#                             'td': 0,
#                             'team': Team(869156),
#                             'turns': 88,
#                             'type': 'R'},
#  NormalPlayer('11667459'): {'blocks': 49,
#                             'cas': 4,
#                             'comp': 0,
#                             'fouls': 0,
#                             'int': 0,
#                             'mvp': 1,
#                             'name': 'Keeth',
#                             'pass': 0,
#                             'perf': [('D', 3924541),
#                                      ('W', 3928296),
#                                      ('W', 3929535),
#                                      ('W', 3933638),
#                                      ('W', 3936723),
#                                      ('D', 3937171)],
#                             'prespp': 191,
#                             'rush': 0,
#                             'spp': 13,
#                             'td': 0,
#                             'team': Team(869156),
#                             'turns': 74,
#                             'type': 'R'},
#  NormalPlayer('11667462'): {'blocks': 53,
#                             'cas': 6,
#                             'comp': 0,
#                             'fouls': 0,
#                             'int': 0,
#                             'mvp': 1,
#                             'name': 'Rozatar',
#                             'pass': 0,
#                             'perf': [('D', 3924541),
#                                      ('W', 3928296),
#                                      ('W', 3929535),
#                                      ('W', 3933638),
#                                      ('W', 3936723),
#                                      ('D', 3937171)],
#                             'prespp': 225,
#                             'rush': 0,
#                             'spp': 17,
#                             'td': 0,
#                             'team': Team(869156),
#                             'turns': 85,
#                             'type': 'R'},
#  NormalPlayer('11667465'): {'blocks': 13,
#                             'cas': 2,
#                             'comp': 0,
#                             'fouls': 0,
#                             'int': 0,
#                             'mvp': 0,
#                             'name': 'Mebas',
#                             'pass': 0,
#                             'perf': [('D', 3924541),
#                                      ('W', 3928296),
#                                      ('W', 3929535),
#                                      ('W', 3933638),
#                                      ('W', 3936723),
#                                      ('D', 3937171)],
#                             'prespp': 112,
#                             'rush': 0,
#                             'spp': 4,
#                             'td': 0,
#                             'team': Team(869156),
#                             'turns': 68,
#                             'type': 'R'},
#  NormalPlayer('11667467'): {'blocks': 20,
#                             'cas': 0,
#                             'comp': 0,
#                             'fouls': 0,
#                             'int': 0,
#                             'mvp': 0,
#                             'name': 'Hralis',
#                             'pass': 0,
#                             'perf': [('D', 3924541),
#                                      ('W', 3928296),
#                                      ('W', 3929535),
#                                      ('W', 3933638),
#                                      ('W', 3936723),
#                                      ('D', 3937171)],
#                             'prespp': 78,
#                             'rush': 21,
#                             'spp': 3,
#                             'td': 1,
#                             'team': Team(869156),
#                             'turns': 71,
#                             'type': 'R'},
#  NormalPlayer('11667468'): {'blocks': 6,
#                             'cas': 0,
#                             'comp': 0,
#                             'fouls': 0,
#                             'int': 0,
#                             'mvp': 0,
#                             'name': 'Nal',
#                             'pass': 0,
#                             'perf': [('D', 3924541),
#                                      ('W', 3928296),
#                                      ('W', 3929535),
#                                      ('W', 3933638),
#                                      ('W', 3936723),
#                                      ('D', 3937171)],
#                             'prespp': 42,
#                             'rush': 0,
#                             'spp': 0,
#                             'td': 0,
#                             'team': Team(869156),
#                             'turns': 65,
#                             'type': 'R'},
#  NormalPlayer('11667471'): {'blocks': 4,
#                             'cas': 0,
#                             'comp': 0,
#                             'fouls': 21,
#                             'int': 0,
#                             'mvp': 1,
#                             'name': 'Acurag',
#                             'pass': 0,
#                             'perf': [('D', 3924541),
#                                      ('W', 3928296),
#                                      ('W', 3929535),
#                                      ('W', 3933638),
#                                      ('W', 3936723),
#                                      ('D', 3937171)],
#                             'prespp': 37,
#                             'rush': 0,
#                             'spp': 5,
#                             'td': 0,
#                             'team': Team(869156),
#                             'turns': 48,
#                             'type': 'R'},
#  NormalPlayer('11670597'): {'blocks': 24,
#                             'cas': 0,
#                             'comp': 0,
#                             'fouls': 0,
#                             'int': 0,
#                             'mvp': 0,
#                             'name': 'Trey Truestone',
#                             'pass': 0,
#                             'perf': [('L', 3924129),
#                                      ('L', 3928397),
#                                      ('L', 3933310),
#                                      ('L', 3933638),
#                                      ('W', 3937119),
#                                      ('L', 3939205)],
#                             'prespp': 54,
#                             'rush': 0,
#                             'spp': 0,
#                             'td': 0,
#                             'team': Team(865063),
#                             'turns': 50,
#                             'type': 'R'},
#  NormalPlayer('11681513'): {'blocks': 11,
#                             'cas': 0,
#                             'comp': 2,
#                             'fouls': 0,
#                             'int': 0,
#                             'mvp': 0,
#                             'name': 'L.A. Biond',
#                             'pass': 1,
#                             'perf': [('L', 3928115),
#                                      ('L', 3929535),
#                                      ('L', 3931198),
#                                      ('L', 3935706),
#                                      ('L', 3937119),
#                                      ('L', 3939738)],
#                             'prespp': 87,
#                             'rush': 33,
#                             'spp': 5,
#                             'td': 1,
#                             'team': Team(864291),
#                             'turns': 79,
#                             'type': 'R'},
#  NormalPlayer('11686464'): {'blocks': 11,
#                             'cas': 2,
#                             'comp': 0,
#                             'fouls': 0,
#                             'int': 0,
#                             'mvp': 0,
#                             'name': 'Zizou Zannanza',
#                             'pass': 0,
#                             'perf': [('L', 3925834),
#                                      ('L', 3927498),
#                                      ('W', 3928397),
#                                      ('W', 3931160),
#                                      ('W', 3935706),
#                                      ('L', 3936723)],
#                             'prespp': 95,
#                             'rush': 27,
#                             'spp': 10,
#                             'td': 2,
#                             'team': Team(870410),
#                             'turns': 48,
#                             'type': 'R'},
#  NormalPlayer('11686465'): {'blocks': 17,
#                             'cas': 1,
#                             'comp': 0,
#                             'fouls': 0,
#                             'int': 0,
#                             'mvp': 0,
#                             'name': 'King Pepi',
#                             'pass': 0,
#                             'perf': [('L', 3925834),
#                                      ('L', 3927498),
#                                      ('W', 3928397),
#                                      ('W', 3931160),
#                                      ('W', 3935706),
#                                      ('L', 3936723)],
#                             'prespp': 119,
#                             'rush': 27,
#                             'spp': 5,
#                             'td': 1,
#                             'team': Team(870410),
#                             'turns': 87,
#                             'type': 'R'},
#  NormalPlayer('11686466'): {'blocks': 27,
#                             'cas': 1,
#                             'comp': 0,
#                             'fouls': 0,
#                             'int': 0,
#                             'mvp': 2,
#                             'name': 'Wazza Rudamun',
#                             'pass': 0,
#                             'perf': [('L', 3925834),
#                                      ('L', 3927498),
#                                      ('W', 3928397),
#                                      ('W', 3931160),
#                                      ('W', 3935706),
#                                      ('L', 3936723)],
#                             'prespp': 185,
#                             'rush': 67,
#                             'spp': 18,
#                             'td': 2,
#                             'team': Team(870410),
#                             'turns': 85,
#                             'type': 'R'},
#  NormalPlayer('11686468'): {'blocks': 3,
#                             'cas': 0,
#                             'comp': 0,
#                             'fouls': 8,
#                             'int': 0,
#                             'mvp': 1,
#                             'name': 'Ruud Devil Neserkauhor',
#                             'pass': 0,
#                             'perf': [('L', 3925834),
#                                      ('L', 3927498),
#                                      ('W', 3928397),
#                                      ('W', 3931160),
#                                      ('W', 3935706),
#                                      ('L', 3936723)],
#                             'prespp': 22,
#                             'rush': 0,
#                             'spp': 5,
#                             'td': 0,
#                             'team': Team(870410),
#                             'turns': 26,
#                             'type': 'R'},
#  NormalPlayer('11686470'): {'blocks': 32,
#                             'cas': 1,
#                             'comp': 0,
#                             'fouls': 0,
#                             'int': 0,
#                             'mvp': 0,
#                             'name': 'De Zulk Analmaye',
#                             'pass': 0,
#                             'perf': [('L', 3925834),
#                                      ('L', 3927498),
#                                      ('W', 3928397),
#                                      ('W', 3931160),
#                                      ('W', 3935706),
#                                      ('L', 3936723)],
#                             'prespp': 40,
#                             'rush': 0,
#                             'spp': 2,
#                             'td': 0,
#                             'team': Team(870410),
#                             'turns': 75,
#                             'type': 'R'},
#  NormalPlayer('11686471'): {'blocks': 1,
#                             'cas': 0,
#                             'comp': 0,
#                             'dead': [1, 1, 'blocked', '11721710'],
#                             'fouls': 0,
#                             'int': 0,
#                             'mvp': 0,
#                             'name': 'Zapah Manio Bebiankh',
#                             'pass': 0,
#                             'perf': [('L', 3925834), ('L', 3927498)],
#                             'prespp': 4,
#                             'rush': 0,
#                             'spp': 0,
#                             'td': 0,
#                             'team': Team(870410),
#                             'turns': 6,
#                             'type': 'R'},
#  NormalPlayer('11686476'): {'blocks': 6,
#                             'cas': 0,
#                             'comp': 0,
#                             'fouls': 0,
#                             'int': 0,
#                             'mvp': 0,
#                             'name': 'Guard of the Arsenal',
#                             'pass': 0,
#                             'perf': [('L', 3925834)],
#                             'prespp': 18,
#                             'retired': True,
#                             'rush': 0,
#                             'spp': 0,
#                             'td': 0,
#                             'team': Team(870410),
#                             'turns': 7,
#                             'type': 'R'},
#  NormalPlayer('11686477'): {'blocks': 39,
#                             'cas': 3,
#                             'comp': 0,
#                             'fouls': 0,
#                             'int': 0,
#                             'mvp': 0,
#                             'name': 'Guard of the Reds',
#                             'pass': 0,
#                             'perf': [('L', 3925834),
#                                      ('L', 3927498),
#                                      ('W', 3928397),
#                                      ('W', 3931160),
#                                      ('W', 3935706),
#                                      ('L', 3936723)],
#                             'prespp': 64,
#                             'rush': 6,
#                             'spp': 6,
#                             'td': 0,
#                             'team': Team(870410),
#                             'turns': 84,
#                             'type': 'R'},
#  NormalPlayer('11686481'): {'blocks': 34,
#                             'cas': 2,
#                             'comp': 0,
#                             'fouls': 0,
#                             'int': 0,
#                             'mvp': 0,
#                             'name': 'Protector of the Toffees',
#                             'pass': 0,
#                             'perf': [('L', 3925834),
#                                      ('L', 3927498),
#                                      ('W', 3928397),
#                                      ('W', 3931160),
#                                      ('W', 3935706),
#                                      ('L', 3936723)],
#                             'prespp': 204,
#                             'rush': 0,
#                             'spp': 4,
#                             'td': 0,
#                             'team': Team(870410),
#                             'turns': 87,
#                             'type': 'R'},
#  NormalPlayer('11705502'): {'blocks': 6,
#                             'cas': 0,
#                             'comp': 0,
#                             'dead': [1, 2, 'blocked', '11713837'],
#                             'fouls': 4,
#                             'int': 0,
#                             'mvp': 0,
#                             'name': 'Lirah Meni',
#                             'pass': 0,
#                             'perf': [('L', 3925834),
#                                      ('L', 3927498),
#                                      ('W', 3928397),
#                                      ('W', 3931160)],
#                             'prespp': 28,
#                             'rush': 0,
#                             'spp': 0,
#                             'td': 0,
#                             'team': Team(870410),
#                             'turns': 26,
#                             'type': 'R'},
#  NormalPlayer('11708391'): {'blocks': 29,
#                             'cas': 5,
#                             'comp': 0,
#                             'fouls': 0,
#                             'int': 0,
#                             'mvp': 1,
#                             'name': 'Eraclio',
#                             'pass': 0,
#                             'perf': [('L', 3928115),
#                                      ('L', 3929535),
#                                      ('L', 3931198),
#                                      ('L', 3935706),
#                                      ('L', 3937119),
#                                      ('L', 3939738)],
#                             'prespp': 86,
#                             'rush': 0,
#                             'spp': 15,
#                             'td': 0,
#                             'team': Team(864291),
#                             'turns': 71,
#                             'type': 'R'},
#  NormalPlayer('11713837'): {'blocks': 52,
#                             'cas': 10,
#                             'comp': 0,
#                             'fouls': 0,
#                             'int': 0,
#                             'mvp': 2,
#                             'name': 'Carol I',
#                             'pass': 0,
#                             'perf': [('W', 3924129),
#                                      ('W', 3928115),
#                                      ('L', 3930132),
#                                      ('L', 3931160),
#                                      ('L', 3936136),
#                                      ('D', 3937171)],
#                             'prespp': 423,
#                             'rush': 4,
#                             'spp': 33,
#                             'td': 1,
#                             'team': Team(872044),
#                             'turns': 75,
#                             'type': 'R'},
#  NormalPlayer('11713838'): {'blocks': 34,
#                             'cas': 2,
#                             'comp': 0,
#                             'fouls': 0,
#                             'int': 0,
#                             'mvp': 0,
#                             'name': 'Ferdinand I',
#                             'pass': 0,
#                             'perf': [('W', 3924129),
#                                      ('W', 3928115),
#                                      ('L', 3930132),
#                                      ('L', 3931160),
#                                      ('L', 3936136),
#                                      ('D', 3937171)],
#                             'prespp': 188,
#                             'rush': 4,
#                             'spp': 4,
#                             'td': 0,
#                             'team': Team(872044),
#                             'turns': 70,
#                             'type': 'R'},
#  NormalPlayer('11713840'): {'blocks': 7,
#                             'cas': 0,
#                             'comp': 4,
#                             'fouls': 0,
#                             'int': 0,
#                             'mvp': 1,
#                             'name': 'Burggraf of Nuremberg',
#                             'pass': 16,
#                             'perf': [('W', 3924129),
#                                      ('W', 3928115),
#                                      ('L', 3930132),
#                                      ('L', 3931160),
#                                      ('L', 3936136),
#                                      ('D', 3937171)],
#                             'prespp': 139,
#                             'rush': 88,
#                             'spp': 21,
#                             'td': 4,
#                             'team': Team(872044),
#                             'turns': 74,
#                             'type': 'R'},
#  NormalPlayer('11713845'): {'blocks': 3,
#                             'cas': 0,
#                             'comp': 0,
#                             'dead': [1, 1, 'blocked', '11686470'],
#                             'fouls': 2,
#                             'int': 0,
#                             'mvp': 0,
#                             'name': 'Constantin',
#                             'pass': 0,
#                             'perf': [('W', 3924129),
#                                      ('W', 3928115),
#                                      ('L', 3930132),
#                                      ('L', 3931160)],
#                             'prespp': 28,
#                             'rush': 0,
#                             'spp': 0,
#                             'td': 0,
#                             'team': Team(872044),
#                             'turns': 20,
#                             'type': 'R'},
#  NormalPlayer('11713847'): {'blocks': 9,
#                             'cas': 0,
#                             'comp': 0,
#                             'fouls': 1,
#                             'int': 0,
#                             'mvp': 0,
#                             'name': 'Grigore',
#                             'pass': 0,
#                             'perf': [('W', 3924129),
#                                      ('W', 3928115),
#                                      ('L', 3930132),
#                                      ('L', 3931160),
#                                      ('L', 3936136),
#                                      ('D', 3937171)],
#                             'prespp': 0,
#                             'rush': 0,
#                             'spp': 0,
#                             'td': 0,
#                             'team': Team(872044),
#                             'turns': 45,
#                             'type': 'R'},
#  NormalPlayer('11714360'): {'blocks': 6,
#                             'cas': 0,
#                             'comp': 0,
#                             'fouls': 10,
#                             'int': 0,
#                             'mvp': 1,
#                             'name': 'Eratosthenes',
#                             'pass': 0,
#                             'perf': [('L', 3925834),
#                                      ('L', 3927498),
#                                      ('W', 3928397),
#                                      ('W', 3931160),
#                                      ('W', 3935706),
#                                      ('L', 3936723)],
#                             'prespp': 37,
#                             'rush': 0,
#                             'spp': 5,
#                             'td': 0,
#                             'team': Team(870410),
#                             'turns': 40,
#                             'type': 'R'},
#  NormalPlayer('11721709'): {'blocks': 18,
#                             'cas': 3,
#                             'comp': 0,
#                             'fouls': 1,
#                             'int': 0,
#                             'mvp': 2,
#                             'name': 'Acer Steelroot',
#                             'pass': 0,
#                             'perf': [('D', 3924541),
#                                      ('W', 3927498),
#                                      ('W', 3931198),
#                                      ('W', 3936136),
#                                      ('D', 3937370),
#                                      ('W', 3939205)],
#                             'prespp': 119,
#                             'rush': 0,
#                             'spp': 16,
#                             'td': 0,
#                             'team': Team(872475),
#                             'turns': 59,
#                             'type': 'R'},
#  NormalPlayer('11721710'): {'blocks': 68,
#                             'cas': 5,
#                             'comp': 0,
#                             'fouls': 4,
#                             'int': 0,
#                             'mvp': 0,
#                             'name': 'Judge Juniperus',
#                             'pass': 0,
#                             'perf': [('D', 3924541),
#                                      ('W', 3927498),
#                                      ('W', 3931198),
#                                      ('W', 3936136),
#                                      ('D', 3937370),
#                                      ('W', 3939205)],
#                             'prespp': 226,
#                             'rush': 0,
#                             'spp': 10,
#                             'td': 0,
#                             'team': Team(872475),
#                             'turns': 95,
#                             'type': 'R'},
#  NormalPlayer('11721711'): {'blocks': 40,
#                             'cas': 0,
#                             'comp': 0,
#                             'fouls': 2,
#                             'int': 0,
#                             'mvp': 2,
#                             'name': 'Sylvestris Pikebranch',
#                             'pass': 0,
#                             'perf': [('D', 3924541),
#                                      ('W', 3927498),
#                                      ('W', 3931198),
#                                      ('W', 3936136),
#                                      ('D', 3937370),
#                                      ('W', 3939205)],
#                             'prespp': 101,
#                             'rush': 0,
#                             'spp': 10,
#                             'td': 0,
#                             'team': Team(872475),
#                             'turns': 88,
#                             'type': 'R'},
#  NormalPlayer('11721712'): {'blocks': 40,
#                             'cas': 1,
#                             'comp': 0,
#                             'fouls': 0,
#                             'int': 0,
#                             'mvp': 1,
#                             'name': 'Larix Darkbark',
#                             'pass': 0,
#                             'perf': [('D', 3924541),
#                                      ('W', 3927498),
#                                      ('W', 3931198),
#                                      ('W', 3936136),
#                                      ('D', 3937370),
#                                      ('W', 3939205)],
#                             'prespp': 150,
#                             'rush': 0,
#                             'spp': 7,
#                             'td': 0,
#                             'team': Team(872475),
#                             'turns': 95,
#                             'type': 'R'},
#  NormalPlayer('11721713'): {'blocks': 41,
#                             'cas': 4,
#                             'comp': 0,
#                             'fouls': 0,
#                             'int': 0,
#                             'mvp': 1,
#                             'name': 'Betula the Last Pendulum',
#                             'pass': 0,
#                             'perf': [('D', 3924541),
#                                      ('W', 3927498),
#                                      ('W', 3931198),
#                                      ('W', 3936136),
#                                      ('D', 3937370),
#                                      ('W', 3939205)],
#                             'prespp': 153,
#                             'rush': 0,
#                             'spp': 13,
#                             'td': 0,
#                             'team': Team(872475),
#                             'turns': 80,
#                             'type': 'R'},
#  NormalPlayer('11721714'): {'blocks': 47,
#                             'cas': 3,
#                             'comp': 0,
#                             'fouls': 3,
#                             'int': 0,
#                             'mvp': 0,
#                             'name': 'Picea the Piercer',
#                             'pass': 0,
#                             'perf': [('D', 3924541),
#                                      ('W', 3927498),
#                                      ('W', 3931198),
#                                      ('W', 3936136),
#                                      ('D', 3937370),
#                                      ('W', 3939205)],
#                             'prespp': 112,
#                             'rush': 0,
#                             'spp': 6,
#                             'td': 0,
#                             'team': Team(872475),
#                             'turns': 95,
#                             'type': 'R'},
#  NormalPlayer('11721716'): {'blocks': 1,
#                             'cas': 0,
#                             'comp': 0,
#                             'fouls': 20,
#                             'int': 0,
#                             'mvp': 0,
#                             'name': 'Rubus the Drinker of Blood',
#                             'pass': 0,
#                             'perf': [('D', 3924541),
#                                      ('W', 3927498),
#                                      ('W', 3931198),
#                                      ('W', 3936136),
#                                      ('D', 3937370),
#                                      ('W', 3939205)],
#                             'prespp': 60,
#                             'rush': 0,
#                             'spp': 0,
#                             'td': 0,
#                             'team': Team(872475),
#                             'turns': 46,
#                             'type': 'R'},
#  NormalPlayer('11721718'): {'blocks': 1,
#                             'cas': 0,
#                             'comp': 0,
#                             'dead': [2, 4, 'blocked', '11667465'],
#                             'fouls': 0,
#                             'int': 0,
#                             'mvp': 0,
#                             'name': 'Mummified Maianthemum',
#                             'pass': 0,
#                             'perf': [('D', 3924541)],
#                             'prespp': 3,
#                             'rush': 12,
#                             'spp': 0,
#                             'td': 0,
#                             'team': Team(872475),
#                             'turns': 10,
#                             'type': 'R'},
#  NormalPlayer('11733652'): {'blocks': 32,
#                             'cas': 1,
#                             'comp': 0,
#                             'fouls': 1,
#                             'int': 0,
#                             'mvp': 0,
#                             'name': 'Rocket Ramesses II',
#                             'pass': 0,
#                             'perf': [('L', 3925834),
#                                      ('L', 3927498),
#                                      ('W', 3928397),
#                                      ('W', 3931160),
#                                      ('W', 3935706),
#                                      ('L', 3936723)],
#                             'prespp': 30,
#                             'rush': 0,
#                             'spp': 2,
#                             'td': 0,
#                             'team': Team(870410),
#                             'turns': 89,
#                             'type': 'R'},
#  NormalPlayer('11737245'): {'blocks': 30,
#                             'cas': 1,
#                             'comp': 0,
#                             'fouls': 0,
#                             'int': 0,
#                             'mvp': 1,
#                             'name': 'Zhorthix Swiftfoot',
#                             'pass': 0,
#                             'perf': [('W', 3925834),
#                                      ('L', 3928296),
#                                      ('W', 3930132),
#                                      ('W', 3933310),
#                                      ('D', 3937370),
#                                      ('W', 3939738)],
#                             'prespp': 293,
#                             'rush': 13,
#                             'spp': 10,
#                             'td': 1,
#                             'team': Team(873361),
#                             'turns': 58,
#                             'type': 'R'},
#  NormalPlayer('11737248'): {'blocks': 46,
#                             'cas': 3,
#                             'comp': 0,
#                             'fouls': 0,
#                             'int': 0,
#                             'mvp': 2,
#                             'name': 'Nirghux Stormpaw',
#                             'pass': 0,
#                             'perf': [('W', 3925834),
#                                      ('L', 3928296),
#                                      ('W', 3930132),
#                                      ('W', 3933310),
#                                      ('D', 3937370),
#                                      ('W', 3939738)],
#                             'prespp': 145,
#                             'rush': 0,
#                             'spp': 19,
#                             'td': 1,
#                             'team': Team(873361),
#                             'turns': 63,
#                             'type': 'R'},
#  NormalPlayer('11737249'): {'blocks': 32,
# ...
#                                      ('W', 3937119),
#                                      ('L', 3939205)],
#                             'prespp': 34,
#                             'rush': 55,
#                             'spp': 16,
#                             'td': 3,
#                             'team': Team(865063),
#                             'turns': 70,
#                             'type': 'R'},
#  NormalPlayer('11941138'): {'blocks': 2,
#                             'cas': 0,
#                             'comp': 0,
#                             'fouls': 0,
#                             'int': 0,
#                             'mvp': 0,
#                             'name': 'Fredrick Hideoustree',
#                             'pass': 0,
#                             'perf': [('L', 3928397)],
#                             'prespp': 0,
#                             'retired': True,
#                             'rush': 0,
#                             'spp': 0,
#                             'td': 0,
#                             'team': Team(865063),
#                             'turns': 10,
#                             'type': 'J'},
#  NormalPlayer('11941139'): {'blocks': 3,
#                             'cas': 0,
#                             'comp': 0,
#                             'fouls': 0,
#                             'int': 0,
#                             'mvp': 0,
#                             'name': 'Cory Hotfield',
#                             'pass': 0,
#                             'perf': [('L', 3928397),
#                                      ('L', 3933310),
#                                      ('L', 3933638),
#                                      ('W', 3937119),
#                                      ('L', 3939205)],
#                             'prespp': 0,
#                             'rush': 0,
#                             'spp': 0,
#                             'td': 0,
#                             'team': Team(865063),
#                             'turns': 18,
#                             'type': 'J'},
#  NormalPlayer('11946731'): {'blocks': 1,
#                             'cas': 0,
#                             'comp': 1,
#                             'fouls': 2,
#                             'int': 0,
#                             'mvp': 0,
#                             'name': 'Eleonore-Magdalena',
#                             'pass': 6,
#                             'perf': [('L', 3930132),
#                                      ('L', 3931160),
#                                      ('L', 3936136),
#                                      ('D', 3937171)],
#                             'prespp': 0,
#                             'rush': 1,
#                             'spp': 1,
#                             'td': 0,
#                             'team': Team(872044),
#                             'turns': 42,
#                             'type': 'R'},
#  NormalPlayer('11952445'): {'blocks': 0,
#                             'cas': 0,
#                             'comp': 0,
#                             'fouls': 1,
#                             'int': 0,
#                             'mvp': 0,
#                             'name': 'Paul Vileshield',
#                             'pass': 0,
#                             'perf': [('W', 3930132)],
#                             'prespp': 0,
#                             'retired': True,
#                             'rush': 0,
#                             'spp': 0,
#                             'td': 0,
#                             'team': Team(873361),
#                             'turns': 0,
#                             'type': 'J'},
#  NormalPlayer('11953214'): {'blocks': 2,
#                             'cas': 1,
#                             'comp': 0,
#                             'fouls': 1,
#                             'int': 0,
#                             'mvp': 0,
#                             'name': 'Wilhelmina Amalia',
#                             'pass': 0,
#                             'perf': [('L', 3931160),
#                                      ('L', 3936136),
#                                      ('D', 3937171)],
#                             'prespp': 0,
#                             'rush': 0,
#                             'spp': 2,
#                             'td': 0,
#                             'team': Team(872044),
#                             'turns': 20,
#                             'type': 'R'},
#  NormalPlayer('11953217'): {'blocks': 2,
#                             'cas': 0,
#                             'comp': 0,
#                             'fouls': 1,
#                             'int': 0,
#                             'mvp': 0,
#                             'name': 'Andrei',
#                             'pass': 0,
#                             'perf': [('L', 3931160),
#                                      ('L', 3936136),
#                                      ('D', 3937171)],
#                             'prespp': 0,
#                             'rush': 0,
#                             'spp': 0,
#                             'td': 0,
#                             'team': Team(872044),
#                             'turns': 31,
#                             'type': 'R'},
#  NormalPlayer('11971397'): {'blocks': 5,
#                             'cas': 0,
#                             'comp': 0,
#                             'fouls': 0,
#                             'int': 0,
#                             'mvp': 0,
#                             'name': 'Vincent Weaklightning',
#                             'pass': 0,
#                             'perf': [('L', 3933310),
#                                      ('L', 3933638),
#                                      ('W', 3937119),
#                                      ('L', 3939205)],
#                             'prespp': 0,
#                             'rush': 0,
#                             'spp': 0,
#                             'td': 0,
#                             'team': Team(865063),
#                             'turns': 34,
#                             'type': 'J'},
#  NormalPlayer('11971444'): {'blocks': 0,
#                             'cas': 0,
#                             'comp': 0,
#                             'fouls': 0,
#                             'int': 0,
#                             'mvp': 0,
#                             'name': 'Nazgor Decvac',
#                             'pass': 0,
#                             'perf': [('D', 3937370), ('W', 3939738)],
#                             'prespp': 0,
#                             'rush': 0,
#                             'spp': 0,
#                             'td': 0,
#                             'team': Team(873361),
#                             'turns': 2,
#                             'type': 'R'},
#  NormalPlayer('11971445'): {'blocks': 4,
#                             'cas': 0,
#                             'comp': 0,
#                             'fouls': 0,
#                             'int': 0,
#                             'mvp': 0,
#                             'name': 'Decthog Taogdhaz',
#                             'pass': 0,
#                             'perf': [('D', 3937370), ('W', 3939738)],
#                             'prespp': 0,
#                             'rush': 0,
#                             'spp': 0,
#                             'td': 0,
#                             'team': Team(873361),
#                             'turns': 24,
#                             'type': 'R'},
#  NormalPlayer('11983863'): {'blocks': 2,
#                             'cas': 0,
#                             'comp': 0,
#                             'fouls': 0,
#                             'int': 0,
#                             'mvp': 0,
#                             'name': 'Kalsir',
#                             'pass': 0,
#                             'perf': [('W', 3936723), ('D', 3937171)],
#                             'prespp': 0,
#                             'rush': 0,
#                             'spp': 0,
#                             'td': 0,
#                             'team': Team(869156),
#                             'turns': 29,
#                             'type': 'R'},
#  NormalPlayer('11985989'): {'blocks': 1,
#                             'cas': 0,
#                             'comp': 0,
#                             'fouls': 0,
#                             'int': 0,
#                             'mvp': 0,
#                             'name': 'Stefon',
#                             'pass': 0,
#                             'perf': [('L', 3936136), ('D', 3937171)],
#                             'prespp': 0,
#                             'rush': 0,
#                             'spp': 0,
#                             'td': 0,
#                             'team': Team(872044),
#                             'turns': 21,
#                             'type': 'R'},
#  NormalPlayer('11986045'): {'blocks': 0,
#                             'cas': 0,
#                             'comp': 0,
#                             'fouls': 0,
#                             'int': 0,
#                             'mvp': 0,
#                             'name': 'Dryopteris the Pale',
#                             'pass': 0,
#                             'perf': [('D', 3937370), ('W', 3939205)],
#                             'prespp': 3,
#                             'rush': 19,
#                             'spp': 3,
#                             'td': 1,
#                             'team': Team(872475),
#                             'turns': 19,
#                             'type': 'R'},
#  NormalPlayer('11986350'): {'blocks': 0,
#                             'cas': 0,
#                             'comp': 0,
#                             'fouls': 0,
#                             'int': 0,
#                             'mvp': 1,
#                             'name': 'Carol II',
#                             'pass': 0,
#                             'perf': [('D', 3937171)],
#                             'prespp': 0,
#                             'rush': 0,
#                             'spp': 5,
#                             'td': 0,
#                             'team': Team(872044),
#                             'turns': 6,
#                             'type': 'R'},
#  NormalPlayer('11988806'): {'blocks': 2,
#                             'cas': 0,
#                             'comp': 0,
#                             'fouls': 0,
#                             'int': 0,
#                             'mvp': 0,
#                             'name': 'The last Goat',
#                             'pass': 0,
#                             'perf': [('L', 3936723)],
#                             'prespp': 0,
#                             'rush': 0,
#                             'spp': 0,
#                             'td': 0,
#                             'team': Team(870410),
#                             'turns': 6,
#                             'type': 'R'},
#  NormalPlayer('11990844'): {'blocks': 2,
#                             'cas': 1,
#                             'comp': 0,
#                             'fouls': 0,
#                             'int': 0,
#                             'mvp': 0,
#                             'name': 'Linfer',
#                             'pass': 0,
#                             'perf': [('L', 3939205)],
#                             'prespp': 0,
#                             'rush': 0,
#                             'spp': 5,
#                             'td': 1,
#                             'team': Team(865063),
#                             'turns': 16,
#                             'type': 'R'},
#  NormalPlayer('12004119'): {'blocks': 1,
#                             'cas': 0,
#                             'comp': 0,
#                             'fouls': 0,
#                             'int': 0,
#                             'mvp': 0,
#                             'name': 'Julius Weakeagle',
#                             'pass': 0,
#                             'perf': [('W', 3939738)],
#                             'prespp': 0,
#                             'rush': 0,
#                             'spp': 0,
#                             'td': 0,
#                             'team': Team(873361),
#                             'turns': 8,
#                             'type': 'J'},
#  StarPlayer('STAR-7548'): {'blocks': 3,
#                            'cas': 0,
#                            'comp': 0,
#                            'fouls': 0,
#                            'int': 0,
#                            'mvp': 0,
#                            'name': 'Hack Enslash',
#                            'pass': 0,
#                            'perf': [('L', 3927498)],
#                            'prespp': 0,
#                            'rush': 0,
#                            'spp': 0,
#                            'td': 0,
#                            'team': Team(870410),
#                            'turns': 8,
#                            'type': 'S'},
#  StarPlayer('STAR-7561'): {'blocks': 0,
#                            'cas': 0,
#                            'comp': 1,
#                            'fouls': 0,
#                            'int': 0,
#                            'mvp': 0,
#                            'name': 'Lewdgrip Whiparm',
#                            'pass': 5,
#                            'perf': [('W', 3930132)],
#                            'prespp': 0,
#                            'rush': 6,
#                            'spp': 1,
#                            'td': 0,
#                            'team': Team(873361),
#                            'turns': 7,
#                            'type': 'S'},
#  StarPlayer('STAR-7562'): {'blocks': 3,
#                            'cas': 0,
#                            'comp': 0,
#                            'dead': [2, 1, 'fouled', '11667471'],
#                            'fouls': 0,
#                            'int': 0,
#                            'mvp': 0,
#                            'name': 'Gorlem Goreblade',
#                            'pass': 0,
#                            'perf': [('L', 3928296)],
#                            'prespp': 0,
#                            'rush': 0,
#                            'spp': 0,
#                            'td': 0,
#                            'team': Team(873361),
#                            'turns': 9,
#                            'type': 'S'},
#  StarPlayer('STAR-7576'): {'blocks': 6,
#                            'cas': 0,
#                            'comp': 0,
#                            'fouls': 0,
#                            'int': 0,
#                            'mvp': 0,
#                            'name': 'Setekh',
#                            'pass': 0,
#                            'perf': [('L', 3935706)],
#                            'prespp': 0,
#                            'rush': 0,
#                            'spp': 0,
#                            'td': 0,
#                            'team': Team(864291),
#                            'turns': 15,
#                            'type': 'S'},
#  StarPlayer('STAR-7578'): {'blocks': 2,
#                            'cas': 0,
#                            'comp': 0,
#                            'fouls': 0,
#                            'int': 0,
#                            'mvp': 0,
#                            'name': 'Sinnedbad',
#                            'pass': 0,
#                            'perf': [('L', 3935706)],
#                            'prespp': 0,
#                            'rush': 0,
#                            'spp': 0,
#                            'td': 0,
#                            'team': Team(864291),
#                            'turns': 7,
#                            'type': 'S'},
#  StarPlayer('STAR-7664'): {'blocks': 3,
#                            'cas': 0,
#                            'comp': 0,
#                            'fouls': 0,
#                            'int': 0,
#                            'mvp': 0,
#                            'name': 'Duke Luthor Von Hawkfire',
#                            'pass': 0,
#                            'perf': [('W', 3925834)],
#                            'prespp': 0,
#                            'rush': 0,
#                            'spp': 0,
#                            'td': 0,
#                            'team': Team(873361),
#                            'turns': 16,
#                            'type': 'S'}}

# %%
T = G.tournaments["44074"]

# %%
T.bestplayers()
# Out:
# {'Touchdowns': NormalPlayer('12030024'),
#  'SPP': NormalPlayer('12030024'),
#  'Fouls': NormalPlayer('12052334'),
#  'Interceptions': NormalPlayer('11956884'),
#  'Completions': NormalPlayer('11940513'),
#  'Casualties': None,
#  'Allrounder': NormalPlayer('11956884'),
#  'Blocking Thrower': None,
#  'Triple': NormalPlayer('11939705'),
#  'Scoring Thrower': NormalPlayer('11938039'),
#  'Blocking Scorer': NormalPlayer('12031251')}

# %%
eperf = T.extraplayerperformances()
pprint(eperf)
# Out:
# {NormalPlayer('11936932'): {'Allrounder': 0,
#                             'Blocking Scorer': 0,
#                             'Blocking Thrower': 0,
#                             'Scoring Thrower': 0,
#                             'Triple': 0},
#  NormalPlayer('11936933'): {'Allrounder': 0,
#                             'Blocking Scorer': 1,
#                             'Blocking Thrower': 1,
#                             'Scoring Thrower': 2,
#                             'Triple': 1},
#  NormalPlayer('11936937'): {'Allrounder': 0,
#                             'Blocking Scorer': 0,
#                             'Blocking Thrower': 0,
#                             'Scoring Thrower': 1,
#                             'Triple': 0},
#  NormalPlayer('11936939'): {'Allrounder': 0,
#                             'Blocking Scorer': 0,
#                             'Blocking Thrower': 0,
#                             'Scoring Thrower': 0,
#                             'Triple': 0},
#  NormalPlayer('11936944'): {'Allrounder': 0,
#                             'Blocking Scorer': 0,
#                             'Blocking Thrower': 0,
#                             'Scoring Thrower': 0,
#                             'Triple': 0},
#  NormalPlayer('11936947'): {'Allrounder': 0,
#                             'Blocking Scorer': 0,
#                             'Blocking Thrower': 0,
#                             'Scoring Thrower': 0,
#                             'Triple': 0},
#  NormalPlayer('11936950'): {'Allrounder': 0,
#                             'Blocking Scorer': 0,
#                             'Blocking Thrower': 0,
#                             'Scoring Thrower': 0,
#                             'Triple': 0},
#  NormalPlayer('11936952'): {'Allrounder': 0,
#                             'Blocking Scorer': 0,
#                             'Blocking Thrower': 0,
#                             'Scoring Thrower': 0,
#                             'Triple': 0},
#  NormalPlayer('11936954'): {'Allrounder': 0,
#                             'Blocking Scorer': 0,
#                             'Blocking Thrower': 0,
#                             'Scoring Thrower': 0,
#                             'Triple': 0},
#  NormalPlayer('11936955'): {'Allrounder': 0,
#                             'Blocking Scorer': 0,
#                             'Blocking Thrower': 0,
#                             'Scoring Thrower': 1,
#                             'Triple': 0},
#  NormalPlayer('11938003'): {'Allrounder': 0,
#                             'Blocking Scorer': 1,
#                             'Blocking Thrower': 0,
#                             'Scoring Thrower': 0,
#                             'Triple': 0},
#  NormalPlayer('11938007'): {'Allrounder': 0,
#                             'Blocking Scorer': 1,
#                             'Blocking Thrower': 0,
#                             'Scoring Thrower': 0,
#                             'Triple': 0},
#  NormalPlayer('11938008'): {'Allrounder': 0,
#                             'Blocking Scorer': 0,
#                             'Blocking Thrower': 0,
#                             'Scoring Thrower': 0,
#                             'Triple': 0},
#  NormalPlayer('11938010'): {'Allrounder': 0,
#                             'Blocking Scorer': 1,
#                             'Blocking Thrower': 0,
#                             'Scoring Thrower': 0,
#                             'Triple': 0},
#  NormalPlayer('11938039'): {'Allrounder': 0,
#                             'Blocking Scorer': 0,
#                             'Blocking Thrower': 0,
#                             'Scoring Thrower': 3,
#                             'Triple': 0},
#  NormalPlayer('11938045'): {'Allrounder': 0,
#                             'Blocking Scorer': 0,
#                             'Blocking Thrower': 0,
#                             'Scoring Thrower': 0,
#                             'Triple': 0},
#  NormalPlayer('11938051'): {'Allrounder': 0,
#                             'Blocking Scorer': 0,
#                             'Blocking Thrower': 0,
#                             'Scoring Thrower': 0,
#                             'Triple': 0},
#  NormalPlayer('11938060'): {'Allrounder': 0,
#                             'Blocking Scorer': 0,
#                             'Blocking Thrower': 0,
#                             'Scoring Thrower': 0,
#                             'Triple': 0},
#  NormalPlayer('11938068'): {'Allrounder': 0,
#                             'Blocking Scorer': 0,
#                             'Blocking Thrower': 0,
#                             'Scoring Thrower': 0,
#                             'Triple': 0},
#  NormalPlayer('11939696'): {'Allrounder': 0,
#                             'Blocking Scorer': 1,
#                             'Blocking Thrower': 1,
#                             'Scoring Thrower': 1,
#                             'Triple': 1},
#  NormalPlayer('11939705'): {'Allrounder': 0,
#                             'Blocking Scorer': 2,
#                             'Blocking Thrower': 2,
#                             'Scoring Thrower': 2,
#                             'Triple': 2},
#  NormalPlayer('11939711'): {'Allrounder': 0,
#                             'Blocking Scorer': 1,
#                             'Blocking Thrower': 0,
#                             'Scoring Thrower': 0,
#                             'Triple': 0},
#  NormalPlayer('11939712'): {'Allrounder': 0,
#                             'Blocking Scorer': 1,
#                             'Blocking Thrower': 0,
#                             'Scoring Thrower': 0,
#                             'Triple': 0},
#  NormalPlayer('11939715'): {'Allrounder': 0,
#                             'Blocking Scorer': 0,
#                             'Blocking Thrower': 0,
#                             'Scoring Thrower': 0,
#                             'Triple': 0},
#  NormalPlayer('11939716'): {'Allrounder': 0,
#                             'Blocking Scorer': 0,
#                             'Blocking Thrower': 0,
#                             'Scoring Thrower': 0,
#                             'Triple': 0},
#  NormalPlayer('11939717'): {'Allrounder': 0,
#                             'Blocking Scorer': 0,
#                             'Blocking Thrower': 0,
#                             'Scoring Thrower': 0,
#                             'Triple': 0},
#  NormalPlayer('11939720'): {'Allrounder': 0,
#                             'Blocking Scorer': 0,
#                             'Blocking Thrower': 0,
#                             'Scoring Thrower': 0,
#                             'Triple': 0},
#  NormalPlayer('11940509'): {'Allrounder': 0,
#                             'Blocking Scorer': 0,
#                             'Blocking Thrower': 0,
#                             'Scoring Thrower': 0,
#                             'Triple': 0},
#  NormalPlayer('11940510'): {'Allrounder': 0,
#                             'Blocking Scorer': 0,
#                             'Blocking Thrower': 0,
#                             'Scoring Thrower': 0,
#                             'Triple': 0},
#  NormalPlayer('11940511'): {'Allrounder': 0,
#                             'Blocking Scorer': 1,
#                             'Blocking Thrower': 0,
#                             'Scoring Thrower': 0,
#                             'Triple': 0},
#  NormalPlayer('11940512'): {'Allrounder': 0,
#                             'Blocking Scorer': 0,
#                             'Blocking Thrower': 0,
#                             'Scoring Thrower': 0,
#                             'Triple': 0},
#  NormalPlayer('11940513'): {'Allrounder': 0,
#                             'Blocking Scorer': 0,
#                             'Blocking Thrower': 0,
#                             'Scoring Thrower': 1,
#                             'Triple': 0},
#  NormalPlayer('11940514'): {'Allrounder': 0,
#                             'Blocking Scorer': 1,
#                             'Blocking Thrower': 0,
#                             'Scoring Thrower': 0,
#                             'Triple': 0},
#  NormalPlayer('11940516'): {'Allrounder': 0,
#                             'Blocking Scorer': 0,
#                             'Blocking Thrower': 0,
#                             'Scoring Thrower': 0,
#                             'Triple': 0},
#  NormalPlayer('11940517'): {'Allrounder': 0,
#                             'Blocking Scorer': 0,
#                             'Blocking Thrower': 0,
#                             'Scoring Thrower': 0,
#                             'Triple': 0},
#  NormalPlayer('11940518'): {'Allrounder': 0,
#                             'Blocking Scorer': 0,
#                             'Blocking Thrower': 0,
#                             'Scoring Thrower': 0,
#                             'Triple': 0},
#  NormalPlayer('11950923'): {'Allrounder': 0,
#                             'Blocking Scorer': 0,
#                             'Blocking Thrower': 0,
#                             'Scoring Thrower': 0,
#                             'Triple': 0},
#  NormalPlayer('11956884'): {'Allrounder': 1,
#                             'Blocking Scorer': 1,
#                             'Blocking Thrower': 1,
#                             'Scoring Thrower': 1,
#                             'Triple': 1},
#  NormalPlayer('11964772'): {'Allrounder': 0,
#                             'Blocking Scorer': 0,
#                             'Blocking Thrower': 0,
#                             'Scoring Thrower': 0,
#                             'Triple': 0},
#  NormalPlayer('11974838'): {'Allrounder': 0,
#                             'Blocking Scorer': 0,
#                             'Blocking Thrower': 0,
#                             'Scoring Thrower': 0,
#                             'Triple': 0},
#  NormalPlayer('11974839'): {'Allrounder': 0,
#                             'Blocking Scorer': 0,
#                             'Blocking Thrower': 0,
#                             'Scoring Thrower': 0,
#                             'Triple': 0},
#  NormalPlayer('11974840'): {'Allrounder': 0,
#                             'Blocking Scorer': 0,
#                             'Blocking Thrower': 0,
#                             'Scoring Thrower': 0,
#                             'Triple': 0},
#  NormalPlayer('11974841'): {'Allrounder': 0,
#                             'Blocking Scorer': 0,
#                             'Blocking Thrower': 0,
#                             'Scoring Thrower': 0,
#                             'Triple': 0},
#  NormalPlayer('11974844'): {'Allrounder': 0,
#                             'Blocking Scorer': 1,
#                             'Blocking Thrower': 2,
#                             'Scoring Thrower': 1,
#                             'Triple': 1},
#  NormalPlayer('11974846'): {'Allrounder': 0,
#                             'Blocking Scorer': 0,
#                             'Blocking Thrower': 0,
#                             'Scoring Thrower': 1,
#                             'Triple': 0},
#  NormalPlayer('11974850'): {'Allrounder': 0,
#                             'Blocking Scorer': 0,
#                             'Blocking Thrower': 0,
#                             'Scoring Thrower': 0,
#                             'Triple': 0},
#  NormalPlayer('11974853'): {'Allrounder': 0,
#                             'Blocking Scorer': 0,
#                             'Blocking Thrower': 0,
#                             'Scoring Thrower': 0,
#                             'Triple': 0},
#  NormalPlayer('11975460'): {'Allrounder': 0,
#                             'Blocking Scorer': 2,
#                             'Blocking Thrower': 0,
#                             'Scoring Thrower': 0,
#                             'Triple': 0},
#  NormalPlayer('11975493'): {'Allrounder': 0,
#                             'Blocking Scorer': 0,
#                             'Blocking Thrower': 1,
#                             'Scoring Thrower': 0,
#                             'Triple': 0},
#  NormalPlayer('11980511'): {'Allrounder': 0,
#                             'Blocking Scorer': 0,
#                             'Blocking Thrower': 0,
#                             'Scoring Thrower': 0,
#                             'Triple': 0},
#  NormalPlayer('12022003'): {'Allrounder': 0,
#                             'Blocking Scorer': 0,
#                             'Blocking Thrower': 0,
#                             'Scoring Thrower': 0,
#                             'Triple': 0},
#  NormalPlayer('12022005'): {'Allrounder': 0,
#                             'Blocking Scorer': 1,
#                             'Blocking Thrower': 0,
#                             'Scoring Thrower': 0,
#                             'Triple': 0},
#  NormalPlayer('12022006'): {'Allrounder': 0,
#                             'Blocking Scorer': 0,
#                             'Blocking Thrower': 0,
#                             'Scoring Thrower': 1,
#                             'Triple': 0},
#  NormalPlayer('12022007'): {'Allrounder': 0,
#                             'Blocking Scorer': 0,
#                             'Blocking Thrower': 0,
#                             'Scoring Thrower': 0,
#                             'Triple': 0},
#  NormalPlayer('12022008'): {'Allrounder': 0,
#                             'Blocking Scorer': 0,
#                             'Blocking Thrower': 0,
#                             'Scoring Thrower': 0,
#                             'Triple': 0},
#  NormalPlayer('12022009'): {'Allrounder': 0,
#                             'Blocking Scorer': 0,
#                             'Blocking Thrower': 0,
#                             'Scoring Thrower': 0,
#                             'Triple': 0},
#  NormalPlayer('12022010'): {'Allrounder': 0,
#                             'Blocking Scorer': 0,
#                             'Blocking Thrower': 0,
#                             'Scoring Thrower': 0,
#                             'Triple': 0},
#  NormalPlayer('12022012'): {'Allrounder': 0,
#                             'Blocking Scorer': 0,
#                             'Blocking Thrower': 0,
#                             'Scoring Thrower': 0,
#                             'Triple': 0},
#  NormalPlayer('12022014'): {'Allrounder': 0,
#                             'Blocking Scorer': 0,
#                             'Blocking Thrower': 0,
#                             'Scoring Thrower': 0,
#                             'Triple': 0},
#  NormalPlayer('12022015'): {'Allrounder': 0,
#                             'Blocking Scorer': 0,
#                             'Blocking Thrower': 0,
#                             'Scoring Thrower': 0,
#                             'Triple': 0},
#  NormalPlayer('12022022'): {'Allrounder': 0,
#                             'Blocking Scorer': 0,
#                             'Blocking Thrower': 0,
#                             'Scoring Thrower': 0,
#                             'Triple': 0},
#  NormalPlayer('12029207'): {'Allrounder': 0,
#                             'Blocking Scorer': 0,
#                             'Blocking Thrower': 0,
#                             'Scoring Thrower': 0,
#                             'Triple': 0},
#  NormalPlayer('12030024'): {'Allrounder': 0,
#                             'Blocking Scorer': 0,
#                             'Blocking Thrower': 0,
#                             'Scoring Thrower': 1,
#                             'Triple': 0},
#  NormalPlayer('12031251'): {'Allrounder': 0,
#                             'Blocking Scorer': 3,
#                             'Blocking Thrower': 0,
#                             'Scoring Thrower': 0,
#                             'Triple': 0},
#  NormalPlayer('12031757'): {'Allrounder': 0,
#                             'Blocking Scorer': 0,
#                             'Blocking Thrower': 0,
#                             'Scoring Thrower': 0,
#                             'Triple': 0},
#  NormalPlayer('12031758'): {'Allrounder': 0,
#                             'Blocking Scorer': 0,
#                             'Blocking Thrower': 0,
#                             'Scoring Thrower': 0,
#                             'Triple': 0},
#  NormalPlayer('12036206'): {'Allrounder': 0,
#                             'Blocking Scorer': 0,
#                             'Blocking Thrower': 0,
#                             'Scoring Thrower': 0,
#                             'Triple': 0},
#  NormalPlayer('12036207'): {'Allrounder': 0,
#                             'Blocking Scorer': 0,
#                             'Blocking Thrower': 0,
#                             'Scoring Thrower': 0,
#                             'Triple': 0},
#  NormalPlayer('12037429'): {'Allrounder': 0,
#                             'Blocking Scorer': 1,
#                             'Blocking Thrower': 0,
#                             'Scoring Thrower': 0,
#                             'Triple': 0},
#  NormalPlayer('12043532'): {'Allrounder': 0,
#                             'Blocking Scorer': 0,
#                             'Blocking Thrower': 0,
#                             'Scoring Thrower': 0,
#                             'Triple': 0},
#  NormalPlayer('12043865'): {'Allrounder': 0,
#                             'Blocking Scorer': 0,
#                             'Blocking Thrower': 0,
#                             'Scoring Thrower': 1,
#                             'Triple': 0},
#  NormalPlayer('12045982'): {'Allrounder': 0,
#                             'Blocking Scorer': 0,
#                             'Blocking Thrower': 0,
#                             'Scoring Thrower': 0,
#                             'Triple': 0},
#  NormalPlayer('12048780'): {'Allrounder': 0,
#                             'Blocking Scorer': 0,
#                             'Blocking Thrower': 0,
#                             'Scoring Thrower': 0,
#                             'Triple': 0},
#  NormalPlayer('12048781'): {'Allrounder': 0,
#                             'Blocking Scorer': 0,
#                             'Blocking Thrower': 0,
#                             'Scoring Thrower': 0,
#                             'Triple': 0},
#  NormalPlayer('12048789'): {'Allrounder': 0,
#                             'Blocking Scorer': 0,
#                             'Blocking Thrower': 0,
#                             'Scoring Thrower': 0,
#                             'Triple': 0},
#  NormalPlayer('12051057'): {'Allrounder': 0,
#                             'Blocking Scorer': 0,
#                             'Blocking Thrower': 0,
#                             'Scoring Thrower': 0,
#                             'Triple': 0},
#  NormalPlayer('12051225'): {'Allrounder': 0,
#                             'Blocking Scorer': 0,
#                             'Blocking Thrower': 0,
#                             'Scoring Thrower': 0,
#                             'Triple': 0},
#  NormalPlayer('12051226'): {'Allrounder': 0,
#                             'Blocking Scorer': 0,
#                             'Blocking Thrower': 0,
#                             'Scoring Thrower': 0,
#                             'Triple': 0},
#  NormalPlayer('12052334'): {'Allrounder': 0,
#                             'Blocking Scorer': 0,
#                             'Blocking Thrower': 0,
#                             'Scoring Thrower': 0,
#                             'Triple': 0},
#  NormalPlayer('12052336'): {'Allrounder': 0,
#                             'Blocking Scorer': 0,
#                             'Blocking Thrower': 0,
#                             'Scoring Thrower': 0,
#                             'Triple': 0},
#  NormalPlayer('12060811'): {'Allrounder': 0,
#                             'Blocking Scorer': 0,
#                             'Blocking Thrower': 0,
#                             'Scoring Thrower': 0,
#                             'Triple': 0},
#  NormalPlayer('12060812'): {'Allrounder': 0,
#                             'Blocking Scorer': 0,
#                             'Blocking Thrower': 0,
#                             'Scoring Thrower': 0,
#                             'Triple': 0},
#  NormalPlayer('12060813'): {'Allrounder': 0,
#                             'Blocking Scorer': 0,
#                             'Blocking Thrower': 0,
#                             'Scoring Thrower': 0,
#                             'Triple': 0},
#  NormalPlayer('12060967'): {'Allrounder': 0,
#                             'Blocking Scorer': 0,
#                             'Blocking Thrower': 0,
#                             'Scoring Thrower': 0,
#                             'Triple': 0},
#  NormalPlayer('12073163'): {'Allrounder': 0,
#                             'Blocking Scorer': 0,
#                             'Blocking Thrower': 0,
#                             'Scoring Thrower': 0,
#                             'Triple': 0},
#  NormalPlayer('12075526'): {'Allrounder': 0,
#                             'Blocking Scorer': 0,
#                             'Blocking Thrower': 0,
#                             'Scoring Thrower': 0,
#                             'Triple': 0},
#  NormalPlayer('12076860'): {'Allrounder': 0,
#                             'Blocking Scorer': 0,
#                             'Blocking Thrower': 0,
#                             'Scoring Thrower': 0,
#                             'Triple': 0},
#  NormalPlayer('12077340'): {'Allrounder': 0,
#                             'Blocking Scorer': 0,
#                             'Blocking Thrower': 0,
#                             'Scoring Thrower': 0,
#                             'Triple': 0},
#  NormalPlayer('12078020'): {'Allrounder': 0,
#                             'Blocking Scorer': 0,
#                             'Blocking Thrower': 0,
#                             'Scoring Thrower': 0,
#                             'Triple': 0},
#  NormalPlayer('12080816'): {'Allrounder': 0,
#                             'Blocking Scorer': 0,
#                             'Blocking Thrower': 0,
#                             'Scoring Thrower': 0,
#                             'Triple': 0},
#  NormalPlayer('12083299'): {'Allrounder': 0,
#                             'Blocking Scorer': 0,
#                             'Blocking Thrower': 0,
#                             'Scoring Thrower': 0,
#                             'Triple': 0},
#  NormalPlayer('12101731'): {'Allrounder': 0,
#                             'Blocking Scorer': 0,
#                             'Blocking Thrower': 0,
#                             'Scoring Thrower': 0,
#                             'Triple': 0},
#  NormalPlayer('12102628'): {'Allrounder': 0,
#                             'Blocking Scorer': 0,
#                             'Blocking Thrower': 0,
#                             'Scoring Thrower': 0,
#                             'Triple': 0},
#  NormalPlayer('12102629'): {'Allrounder': 0,
#                             'Blocking Scorer': 0,
#                             'Blocking Thrower': 0,
#                             'Scoring Thrower': 0,
#                             'Triple': 0},
#  NormalPlayer('12104982'): {'Allrounder': 0,
#                             'Blocking Scorer': 0,
#                             'Blocking Thrower': 0,
#                             'Scoring Thrower': 0,
#                             'Triple': 0},
#  NormalPlayer('12104983'): {'Allrounder': 0,
#                             'Blocking Scorer': 0,
#                             'Blocking Thrower': 0,
#                             'Scoring Thrower': 0,
#                             'Triple': 0},
#  NormalPlayer('12104984'): {'Allrounder': 0,
#                             'Blocking Scorer': 0,
#                             'Blocking Thrower': 0,
#                             'Scoring Thrower': 0,
#                             'Triple': 0},
#  NormalPlayer('12115692'): {'Allrounder': 0,
#                             'Blocking Scorer': 0,
#                             'Blocking Thrower': 0,
#                             'Scoring Thrower': 0,
#                             'Triple': 0},
#  NormalPlayer('12121173'): {'Allrounder': 0,
#                             'Blocking Scorer': 0,
#                             'Blocking Thrower': 0,
#                             'Scoring Thrower': 0,
#                             'Triple': 0},
#  NormalPlayer('12121174'): {'Allrounder': 0,
#                             'Blocking Scorer': 0,
#                             'Blocking Thrower': 0,
#                             'Scoring Thrower': 0,
#                             'Triple': 0},
#  NormalPlayer('12121175'): {'Allrounder': 0,
#                             'Blocking Scorer': 0,
#                             'Blocking Thrower': 0,
#                             'Scoring Thrower': 0,
#                             'Triple': 0},
#  StarPlayer('STAR-7553'): {'Allrounder': 0,
#                            'Blocking Scorer': 0,
#                            'Blocking Thrower': 0,
#                            'Scoring Thrower': 0,
#                            'Triple': 0},
#  StarPlayer('STAR-7555'): {'Allrounder': 0,
#                            'Blocking Scorer': 0,
#                            'Blocking Thrower': 0,
#                            'Scoring Thrower': 0,
#                            'Triple': 0},
#  StarPlayer('STAR-7568'): {'Allrounder': 0,
#                            'Blocking Scorer': 0,
#                            'Blocking Thrower': 0,
#                            'Scoring Thrower': 0,
#                            'Triple': 0},
#  MercenaryPlayer('MERC-7397-4031'): {'Allrounder': 0,
#                                      'Blocking Scorer': 0,
#                                      'Blocking Thrower': 0,
#                                      'Scoring Thrower': 0,
#                                      'Triple': 0}}

# %%
max(d["Triple"] for d in eperf.values())
# Out:
# 2

# %%
for Pl in sorted(eperf, key=lambda Pl: eperf[Pl]["Triple"], reverse=True):
    print(Pl)
    print(eperf[Pl])
    print()
# Out:
# NormalPlayer('11939705')
# {'Blocking Thrower': 2, 'Blocking Scorer': 2, 'Scoring Thrower': 2, 'Triple': 2, 'Allrounder': 0}
#
# NormalPlayer('11936933')
# {'Blocking Thrower': 1, 'Blocking Scorer': 1, 'Scoring Thrower': 2, 'Triple': 1, 'Allrounder': 0}
#
# NormalPlayer('11974844')
# {'Blocking Thrower': 2, 'Blocking Scorer': 1, 'Scoring Thrower': 1, 'Triple': 1, 'Allrounder': 0}
#
# NormalPlayer('11939696')
# {'Blocking Thrower': 1, 'Blocking Scorer': 1, 'Scoring Thrower': 1, 'Triple': 1, 'Allrounder': 0}
#
# NormalPlayer('11956884')
# {'Blocking Thrower': 1, 'Blocking Scorer': 1, 'Scoring Thrower': 1, 'Triple': 1, 'Allrounder': 1}
#
# NormalPlayer('11936932')
# {'Blocking Thrower': 0, 'Blocking Scorer': 0, 'Scoring Thrower': 0, 'Triple': 0, 'Allrounder': 0}
#
# NormalPlayer('11936937')
# {'Blocking Thrower': 0, 'Blocking Scorer': 0, 'Scoring Thrower': 1, 'Triple': 0, 'Allrounder': 0}
#
# NormalPlayer('11936939')
# {'Blocking Thrower': 0, 'Blocking Scorer': 0, 'Scoring Thrower': 0, 'Triple': 0, 'Allrounder': 0}
#
# NormalPlayer('11936944')
# {'Blocking Thrower': 0, 'Blocking Scorer': 0, 'Scoring Thrower': 0, 'Triple': 0, 'Allrounder': 0}
#
# NormalPlayer('11936947')
# {'Blocking Thrower': 0, 'Blocking Scorer': 0, 'Scoring Thrower': 0, 'Triple': 0, 'Allrounder': 0}
#
# NormalPlayer('11936950')
# {'Blocking Thrower': 0, 'Blocking Scorer': 0, 'Scoring Thrower': 0, 'Triple': 0, 'Allrounder': 0}
#
# NormalPlayer('11936952')
# {'Blocking Thrower': 0, 'Blocking Scorer': 0, 'Scoring Thrower': 0, 'Triple': 0, 'Allrounder': 0}
#
# NormalPlayer('11936954')
# {'Blocking Thrower': 0, 'Blocking Scorer': 0, 'Scoring Thrower': 0, 'Triple': 0, 'Allrounder': 0}
#
# NormalPlayer('11936955')
# {'Blocking Thrower': 0, 'Blocking Scorer': 0, 'Scoring Thrower': 1, 'Triple': 0, 'Allrounder': 0}
#
# NormalPlayer('11950923')
# {'Blocking Thrower': 0, 'Blocking Scorer': 0, 'Scoring Thrower': 0, 'Triple': 0, 'Allrounder': 0}
#
# NormalPlayer('12036206')
# {'Blocking Thrower': 0, 'Blocking Scorer': 0, 'Scoring Thrower': 0, 'Triple': 0, 'Allrounder': 0}
#
# NormalPlayer('12036207')
# {'Blocking Thrower': 0, 'Blocking Scorer': 0, 'Scoring Thrower': 0, 'Triple': 0, 'Allrounder': 0}
#
# StarPlayer('STAR-7555')
# {'Blocking Thrower': 0, 'Blocking Scorer': 0, 'Scoring Thrower': 0, 'Triple': 0, 'Allrounder': 0}
#
# NormalPlayer('11938003')
# {'Blocking Thrower': 0, 'Blocking Scorer': 1, 'Scoring Thrower': 0, 'Triple': 0, 'Allrounder': 0}
#
# NormalPlayer('11938007')
# {'Blocking Thrower': 0, 'Blocking Scorer': 1, 'Scoring Thrower': 0, 'Triple': 0, 'Allrounder': 0}
#
# NormalPlayer('11938008')
# {'Blocking Thrower': 0, 'Blocking Scorer': 0, 'Scoring Thrower': 0, 'Triple': 0, 'Allrounder': 0}
#
# NormalPlayer('11938010')
# {'Blocking Thrower': 0, 'Blocking Scorer': 1, 'Scoring Thrower': 0, 'Triple': 0, 'Allrounder': 0}
#
# NormalPlayer('11938039')
# {'Blocking Thrower': 0, 'Blocking Scorer': 0, 'Scoring Thrower': 3, 'Triple': 0, 'Allrounder': 0}
#
# NormalPlayer('11938045')
# {'Blocking Thrower': 0, 'Blocking Scorer': 0, 'Scoring Thrower': 0, 'Triple': 0, 'Allrounder': 0}
#
# NormalPlayer('11938051')
# {'Blocking Thrower': 0, 'Blocking Scorer': 0, 'Scoring Thrower': 0, 'Triple': 0, 'Allrounder': 0}
#
# NormalPlayer('11938060')
# {'Blocking Thrower': 0, 'Blocking Scorer': 0, 'Scoring Thrower': 0, 'Triple': 0, 'Allrounder': 0}
#
# NormalPlayer('11938068')
# {'Blocking Thrower': 0, 'Blocking Scorer': 0, 'Scoring Thrower': 0, 'Triple': 0, 'Allrounder': 0}
#
# NormalPlayer('11964772')
# {'Blocking Thrower': 0, 'Blocking Scorer': 0, 'Scoring Thrower': 0, 'Triple': 0, 'Allrounder': 0}
#
# NormalPlayer('12031251')
# {'Blocking Thrower': 0, 'Blocking Scorer': 3, 'Scoring Thrower': 0, 'Triple': 0, 'Allrounder': 0}
#
# NormalPlayer('11940509')
# {'Blocking Thrower': 0, 'Blocking Scorer': 0, 'Scoring Thrower': 0, 'Triple': 0, 'Allrounder': 0}
#
# NormalPlayer('11940510')
# {'Blocking Thrower': 0, 'Blocking Scorer': 0, 'Scoring Thrower': 0, 'Triple': 0, 'Allrounder': 0}
#
# NormalPlayer('11940511')
# {'Blocking Thrower': 0, 'Blocking Scorer': 1, 'Scoring Thrower': 0, 'Triple': 0, 'Allrounder': 0}
#
# NormalPlayer('11940512')
# {'Blocking Thrower': 0, 'Blocking Scorer': 0, 'Scoring Thrower': 0, 'Triple': 0, 'Allrounder': 0}
#
# NormalPlayer('11940513')
# {'Blocking Thrower': 0, 'Blocking Scorer': 0, 'Scoring Thrower': 1, 'Triple': 0, 'Allrounder': 0}
#
# NormalPlayer('11940514')
# {'Blocking Thrower': 0, 'Blocking Scorer': 1, 'Scoring Thrower': 0, 'Triple': 0, 'Allrounder': 0}
#
# NormalPlayer('11940516')
# {'Blocking Thrower': 0, 'Blocking Scorer': 0, 'Scoring Thrower': 0, 'Triple': 0, 'Allrounder': 0}
#
# NormalPlayer('11940517')
# {'Blocking Thrower': 0, 'Blocking Scorer': 0, 'Scoring Thrower': 0, 'Triple': 0, 'Allrounder': 0}
#
# NormalPlayer('11940518')
# {'Blocking Thrower': 0, 'Blocking Scorer': 0, 'Scoring Thrower': 0, 'Triple': 0, 'Allrounder': 0}
#
# NormalPlayer('12029207')
# {'Blocking Thrower': 0, 'Blocking Scorer': 0, 'Scoring Thrower': 0, 'Triple': 0, 'Allrounder': 0}
#
# NormalPlayer('12037429')
# {'Blocking Thrower': 0, 'Blocking Scorer': 1, 'Scoring Thrower': 0, 'Triple': 0, 'Allrounder': 0}
#
# NormalPlayer('12045982')
# {'Blocking Thrower': 0, 'Blocking Scorer': 0, 'Scoring Thrower': 0, 'Triple': 0, 'Allrounder': 0}
#
# MercenaryPlayer('MERC-7397-4031')
# {'Blocking Thrower': 0, 'Blocking Scorer': 0, 'Scoring Thrower': 0, 'Triple': 0, 'Allrounder': 0}
#
# NormalPlayer('11974838')
# {'Blocking Thrower': 0, 'Blocking Scorer': 0, 'Scoring Thrower': 0, 'Triple': 0, 'Allrounder': 0}
#
# NormalPlayer('11974839')
# {'Blocking Thrower': 0, 'Blocking Scorer': 0, 'Scoring Thrower': 0, 'Triple': 0, 'Allrounder': 0}
#
# NormalPlayer('11974840')
# {'Blocking Thrower': 0, 'Blocking Scorer': 0, 'Scoring Thrower': 0, 'Triple': 0, 'Allrounder': 0}
#
# NormalPlayer('11974841')
# {'Blocking Thrower': 0, 'Blocking Scorer': 0, 'Scoring Thrower': 0, 'Triple': 0, 'Allrounder': 0}
#
# NormalPlayer('11974846')
# {'Blocking Thrower': 0, 'Blocking Scorer': 0, 'Scoring Thrower': 1, 'Triple': 0, 'Allrounder': 0}
#
# NormalPlayer('11974850')
# {'Blocking Thrower': 0, 'Blocking Scorer': 0, 'Scoring Thrower': 0, 'Triple': 0, 'Allrounder': 0}
#
# NormalPlayer('11974853')
# {'Blocking Thrower': 0, 'Blocking Scorer': 0, 'Scoring Thrower': 0, 'Triple': 0, 'Allrounder': 0}
#
# NormalPlayer('11975460')
# {'Blocking Thrower': 0, 'Blocking Scorer': 2, 'Scoring Thrower': 0, 'Triple': 0, 'Allrounder': 0}
#
# NormalPlayer('11975493')
# {'Blocking Thrower': 1, 'Blocking Scorer': 0, 'Scoring Thrower': 0, 'Triple': 0, 'Allrounder': 0}
#
# NormalPlayer('11980511')
# {'Blocking Thrower': 0, 'Blocking Scorer': 0, 'Scoring Thrower': 0, 'Triple': 0, 'Allrounder': 0}
#
# NormalPlayer('12043532')
# {'Blocking Thrower': 0, 'Blocking Scorer': 0, 'Scoring Thrower': 0, 'Triple': 0, 'Allrounder': 0}
#
# NormalPlayer('12043865')
# {'Blocking Thrower': 0, 'Blocking Scorer': 0, 'Scoring Thrower': 1, 'Triple': 0, 'Allrounder': 0}
#
# NormalPlayer('11939711')
# {'Blocking Thrower': 0, 'Blocking Scorer': 1, 'Scoring Thrower': 0, 'Triple': 0, 'Allrounder': 0}
#
# NormalPlayer('11939712')
# {'Blocking Thrower': 0, 'Blocking Scorer': 1, 'Scoring Thrower': 0, 'Triple': 0, 'Allrounder': 0}
#
# NormalPlayer('11939715')
# {'Blocking Thrower': 0, 'Blocking Scorer': 0, 'Scoring Thrower': 0, 'Triple': 0, 'Allrounder': 0}
#
# NormalPlayer('11939716')
# {'Blocking Thrower': 0, 'Blocking Scorer': 0, 'Scoring Thrower': 0, 'Triple': 0, 'Allrounder': 0}
#
# NormalPlayer('11939717')
# {'Blocking Thrower': 0, 'Blocking Scorer': 0, 'Scoring Thrower': 0, 'Triple': 0, 'Allrounder': 0}
#
# NormalPlayer('11939720')
# {'Blocking Thrower': 0, 'Blocking Scorer': 0, 'Scoring Thrower': 0, 'Triple': 0, 'Allrounder': 0}
#
# NormalPlayer('12030024')
# {'Blocking Thrower': 0, 'Blocking Scorer': 0, 'Scoring Thrower': 1, 'Triple': 0, 'Allrounder': 0}
#
# NormalPlayer('12031757')
# {'Blocking Thrower': 0, 'Blocking Scorer': 0, 'Scoring Thrower': 0, 'Triple': 0, 'Allrounder': 0}
#
# NormalPlayer('12031758')
# {'Blocking Thrower': 0, 'Blocking Scorer': 0, 'Scoring Thrower': 0, 'Triple': 0, 'Allrounder': 0}
#
# NormalPlayer('12022003')
# {'Blocking Thrower': 0, 'Blocking Scorer': 0, 'Scoring Thrower': 0, 'Triple': 0, 'Allrounder': 0}
#
# NormalPlayer('12022005')
# {'Blocking Thrower': 0, 'Blocking Scorer': 1, 'Scoring Thrower': 0, 'Triple': 0, 'Allrounder': 0}
#
# NormalPlayer('12022006')
# {'Blocking Thrower': 0, 'Blocking Scorer': 0, 'Scoring Thrower': 1, 'Triple': 0, 'Allrounder': 0}
#
# NormalPlayer('12022007')
# {'Blocking Thrower': 0, 'Blocking Scorer': 0, 'Scoring Thrower': 0, 'Triple': 0, 'Allrounder': 0}
#
# NormalPlayer('12022008')
# {'Blocking Thrower': 0, 'Blocking Scorer': 0, 'Scoring Thrower': 0, 'Triple': 0, 'Allrounder': 0}
#
# NormalPlayer('12022009')
# {'Blocking Thrower': 0, 'Blocking Scorer': 0, 'Scoring Thrower': 0, 'Triple': 0, 'Allrounder': 0}
#
# NormalPlayer('12022010')
# {'Blocking Thrower': 0, 'Blocking Scorer': 0, 'Scoring Thrower': 0, 'Triple': 0, 'Allrounder': 0}
#
# NormalPlayer('12022012')
# {'Blocking Thrower': 0, 'Blocking Scorer': 0, 'Scoring Thrower': 0, 'Triple': 0, 'Allrounder': 0}
#
# NormalPlayer('12022014')
# {'Blocking Thrower': 0, 'Blocking Scorer': 0, 'Scoring Thrower': 0, 'Triple': 0, 'Allrounder': 0}
#
# NormalPlayer('12022015')
# {'Blocking Thrower': 0, 'Blocking Scorer': 0, 'Scoring Thrower': 0, 'Triple': 0, 'Allrounder': 0}
#
# NormalPlayer('12022022')
# {'Blocking Thrower': 0, 'Blocking Scorer': 0, 'Scoring Thrower': 0, 'Triple': 0, 'Allrounder': 0}
#
# NormalPlayer('12051057')
# {'Blocking Thrower': 0, 'Blocking Scorer': 0, 'Scoring Thrower': 0, 'Triple': 0, 'Allrounder': 0}
#
# NormalPlayer('12048780')
# {'Blocking Thrower': 0, 'Blocking Scorer': 0, 'Scoring Thrower': 0, 'Triple': 0, 'Allrounder': 0}
#
# NormalPlayer('12048781')
# {'Blocking Thrower': 0, 'Blocking Scorer': 0, 'Scoring Thrower': 0, 'Triple': 0, 'Allrounder': 0}
#
# NormalPlayer('12048789')
# {'Blocking Thrower': 0, 'Blocking Scorer': 0, 'Scoring Thrower': 0, 'Triple': 0, 'Allrounder': 0}
#
# NormalPlayer('12060811')
# {'Blocking Thrower': 0, 'Blocking Scorer': 0, 'Scoring Thrower': 0, 'Triple': 0, 'Allrounder': 0}
#
# NormalPlayer('12060812')
# {'Blocking Thrower': 0, 'Blocking Scorer': 0, 'Scoring Thrower': 0, 'Triple': 0, 'Allrounder': 0}
#
# NormalPlayer('12060813')
# {'Blocking Thrower': 0, 'Blocking Scorer': 0, 'Scoring Thrower': 0, 'Triple': 0, 'Allrounder': 0}
#
# StarPlayer('STAR-7568')
# {'Blocking Thrower': 0, 'Blocking Scorer': 0, 'Scoring Thrower': 0, 'Triple': 0, 'Allrounder': 0}
#
# NormalPlayer('12051225')
# {'Blocking Thrower': 0, 'Blocking Scorer': 0, 'Scoring Thrower': 0, 'Triple': 0, 'Allrounder': 0}
#
# NormalPlayer('12051226')
# {'Blocking Thrower': 0, 'Blocking Scorer': 0, 'Scoring Thrower': 0, 'Triple': 0, 'Allrounder': 0}
#
# NormalPlayer('12073163')
# {'Blocking Thrower': 0, 'Blocking Scorer': 0, 'Scoring Thrower': 0, 'Triple': 0, 'Allrounder': 0}
#
# NormalPlayer('12060967')
# {'Blocking Thrower': 0, 'Blocking Scorer': 0, 'Scoring Thrower': 0, 'Triple': 0, 'Allrounder': 0}
#
# NormalPlayer('12077340')
# {'Blocking Thrower': 0, 'Blocking Scorer': 0, 'Scoring Thrower': 0, 'Triple': 0, 'Allrounder': 0}
#
# NormalPlayer('12080816')
# {'Blocking Thrower': 0, 'Blocking Scorer': 0, 'Scoring Thrower': 0, 'Triple': 0, 'Allrounder': 0}
#
# NormalPlayer('12052334')
# {'Blocking Thrower': 0, 'Blocking Scorer': 0, 'Scoring Thrower': 0, 'Triple': 0, 'Allrounder': 0}
#
# NormalPlayer('12052336')
# {'Blocking Thrower': 0, 'Blocking Scorer': 0, 'Scoring Thrower': 0, 'Triple': 0, 'Allrounder': 0}
#
# NormalPlayer('12078020')
# {'Blocking Thrower': 0, 'Blocking Scorer': 0, 'Scoring Thrower': 0, 'Triple': 0, 'Allrounder': 0}
#
# NormalPlayer('12102628')
# {'Blocking Thrower': 0, 'Blocking Scorer': 0, 'Scoring Thrower': 0, 'Triple': 0, 'Allrounder': 0}
#
# NormalPlayer('12102629')
# {'Blocking Thrower': 0, 'Blocking Scorer': 0, 'Scoring Thrower': 0, 'Triple': 0, 'Allrounder': 0}
#
# NormalPlayer('12075526')
# {'Blocking Thrower': 0, 'Blocking Scorer': 0, 'Scoring Thrower': 0, 'Triple': 0, 'Allrounder': 0}
#
# NormalPlayer('12076860')
# {'Blocking Thrower': 0, 'Blocking Scorer': 0, 'Scoring Thrower': 0, 'Triple': 0, 'Allrounder': 0}
#
# NormalPlayer('12101731')
# {'Blocking Thrower': 0, 'Blocking Scorer': 0, 'Scoring Thrower': 0, 'Triple': 0, 'Allrounder': 0}
#
# NormalPlayer('12083299')
# {'Blocking Thrower': 0, 'Blocking Scorer': 0, 'Scoring Thrower': 0, 'Triple': 0, 'Allrounder': 0}
#
# NormalPlayer('12104982')
# {'Blocking Thrower': 0, 'Blocking Scorer': 0, 'Scoring Thrower': 0, 'Triple': 0, 'Allrounder': 0}
#
# NormalPlayer('12104983')
# {'Blocking Thrower': 0, 'Blocking Scorer': 0, 'Scoring Thrower': 0, 'Triple': 0, 'Allrounder': 0}
#
# NormalPlayer('12104984')
# {'Blocking Thrower': 0, 'Blocking Scorer': 0, 'Scoring Thrower': 0, 'Triple': 0, 'Allrounder': 0}
#
# NormalPlayer('12115692')
# {'Blocking Thrower': 0, 'Blocking Scorer': 0, 'Scoring Thrower': 0, 'Triple': 0, 'Allrounder': 0}
#
# NormalPlayer('12121173')
# {'Blocking Thrower': 0, 'Blocking Scorer': 0, 'Scoring Thrower': 0, 'Triple': 0, 'Allrounder': 0}
#
# NormalPlayer('12121174')
# {'Blocking Thrower': 0, 'Blocking Scorer': 0, 'Scoring Thrower': 0, 'Triple': 0, 'Allrounder': 0}
#
# NormalPlayer('12121175')
# {'Blocking Thrower': 0, 'Blocking Scorer': 0, 'Scoring Thrower': 0, 'Triple': 0, 'Allrounder': 0}
#
# StarPlayer('STAR-7553')
# {'Blocking Thrower': 0, 'Blocking Scorer': 0, 'Scoring Thrower': 0, 'Triple': 0, 'Allrounder': 0}

# %%
pprint(perf[player('12496642')])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-34-507dde1bad88> in <module>
# ----> 1 pprint(perf[player('12496642')])
#
# KeyError: NormalPlayer('12496642')

# %%
Pl = player('12496642')

# %%
Pl.team.name
# Out:
# "Vlad's Vampheroes"

# %%
Pl.prev
# Out:
# RaisedDeadPlayer('RAISED-7392_12022010_12496642')

# %%
players = set(rawperf)

# %%
deadplayers = {Pl for Pl, d in rawperf.items() if d.get("dead")}
deadplayers
# Out:
# {NormalPlayer('11950136'),
#  NormalPlayer('12022010'),
#  NormalPlayer('12117786'),
#  NormalPlayer('12117795'),
#  NormalPlayer('12158266'),
#  NormalPlayer('12158267'),
#  NormalPlayer('12173143'),
#  NormalPlayer('12219903'),
#  NormalPlayer('12339037'),
#  NormalPlayer('12346893'),
#  NormalPlayer('12354844'),
#  NormalPlayer('12438916'),
#  NormalPlayer('12501592'),
#  NormalPlayer('12519811'),
#  MercenaryPlayer('MERC-7444-0015'),
#  MercenaryPlayer('MERC-7444-1067')}

# %%
for Pl in deadplayers:
    print(Pl, Pl.nexts)
# Out:
# NormalPlayer('11950136') set()
# NormalPlayer('12339037') set()
# NormalPlayer('12158266') set()
# NormalPlayer('12346893') set()
# NormalPlayer('12117795') set()
# NormalPlayer('12438916') set()
# NormalPlayer('12173143') set()
# NormalPlayer('12158267') set()
# MercenaryPlayer('MERC-7444-1067') set()
# NormalPlayer('12354844') set()
# NormalPlayer('12519811') set()
# NormalPlayer('12219903') set()
# MercenaryPlayer('MERC-7444-0015') set()
# NormalPlayer('12501592') set()
# NormalPlayer('12022010') {RaisedDeadPlayer('RAISED-7392_12022010_12496642')}
# NormalPlayer('12117786') set()

# %%
perfsources = {Pl: {Pl} for Pl in players}
delete = set()
for Pl in sorted(deadplayers):
    if Pl in delete:
        continue
    if not Pl.nexts:
        continue
    for Pl1 in Pl.nexts:
      if isinstance(Pl1, cibblbibbl.player.RaisedDeadPlayer) and Pl1.nexts:
        for Pl2 in Pl1.nexts:
            perfsources[Pl2] = perfsources.get(Pl2, set()) | {Pl, Pl1}
            delete |= {Pl, Pl1}
      else:
        perfsources[Pl1] = perfsources.get(Pl1, set()) | {Pl,}
        delete |= {Pl}
perfsources = {Pl: S for Pl, S in perfsources.items() if Pl not in delete} 
perfsources
# Out:
# {NormalPlayer('12504647'): {NormalPlayer('12504647')},
#  MercenaryPlayer('MERC-7444-1240'): {MercenaryPlayer('MERC-7444-1240')},
#  MercenaryPlayer('MERC-7444-3727'): {MercenaryPlayer('MERC-7444-3727')},
#  MercenaryPlayer('MERC-7444-1790'): {MercenaryPlayer('MERC-7444-1790')},
#  NormalPlayer('12130906'): {NormalPlayer('12130906')},
#  NormalPlayer('12357064'): {NormalPlayer('12357064')},
#  MercenaryPlayer('MERC-7444-2820'): {MercenaryPlayer('MERC-7444-2820')},
#  NormalPlayer('12522638'): {NormalPlayer('12522638')},
#  NormalPlayer('12510951'): {NormalPlayer('12510951')},
#  NormalPlayer('12399358'): {NormalPlayer('12399358')},
#  NormalPlayer('12173155'): {NormalPlayer('12173155')},
#  NormalPlayer('12219681'): {NormalPlayer('12219681')},
#  NormalPlayer('12121959'): {NormalPlayer('12121959')},
#  MercenaryPlayer('MERC-7444-3467'): {MercenaryPlayer('MERC-7444-3467')},
#  MercenaryPlayer('MERC-7444-1807'): {MercenaryPlayer('MERC-7444-1807')},
#  NormalPlayer('12438916'): {NormalPlayer('12438916')},
#  NormalPlayer('12219684'): {NormalPlayer('12219684')},
#  NormalPlayer('12443530'): {NormalPlayer('12443530')},
#  MercenaryPlayer('MERC-7446-0393'): {MercenaryPlayer('MERC-7446-0393')},
#  NormalPlayer('12537131'): {NormalPlayer('12537131')},
#  NormalPlayer('12162547'): {NormalPlayer('12162547')},
#  NormalPlayer('12219673'): {NormalPlayer('12219673')},
#  NormalPlayer('12173153'): {NormalPlayer('12173153')},
#  NormalPlayer('12179724'): {NormalPlayer('12179724')},
#  NormalPlayer('11892424'): {NormalPlayer('11892424')},
#  NormalPlayer('12240321'): {NormalPlayer('12240321')},
#  MercenaryPlayer('MERC-7447-2981'): {MercenaryPlayer('MERC-7447-2981')},
#  NormalPlayer('12320309'): {NormalPlayer('12320309')},
#  NormalPlayer('12245045'): {NormalPlayer('12245045')},
#  MercenaryPlayer('MERC-7444-3066'): {MercenaryPlayer('MERC-7444-3066')},
#  MercenaryPlayer('MERC-7444-3217'): {MercenaryPlayer('MERC-7444-3217')},
#  NormalPlayer('12525812'): {NormalPlayer('12525812')},
#  NormalPlayer('12219677'): {NormalPlayer('12219677')},
#  NormalPlayer('12502657'): {NormalPlayer('12502657')},
#  MercenaryPlayer('MERC-7444-1067'): {MercenaryPlayer('MERC-7444-1067')},
#  NormalPlayer('12219683'): {NormalPlayer('12219683')},
#  MercenaryPlayer('MERC-7444-1776'): {MercenaryPlayer('MERC-7444-1776')},
#  NormalPlayer('12022006'): {NormalPlayer('12022006')},
#  NormalPlayer('12022005'): {NormalPlayer('12022005')},
#  MercenaryPlayer('MERC-7444-1616'): {MercenaryPlayer('MERC-7444-1616')},
#  MercenaryPlayer('MERC-7444-3588'): {MercenaryPlayer('MERC-7444-3588')},
#  NormalPlayer('12513768'): {NormalPlayer('12513768')},
#  MercenaryPlayer('MERC-7444-2913'): {MercenaryPlayer('MERC-7444-2913')},
#  NormalPlayer('12536828'): {NormalPlayer('12536828')},
#  NormalPlayer('12117791'): {NormalPlayer('12117791')},
#  NormalPlayer('11892428'): {NormalPlayer('11892428')},
#  MercenaryPlayer('MERC-7391-3245'): {MercenaryPlayer('MERC-7391-3245')},
#  NormalPlayer('12121974'): {NormalPlayer('12121974')},
#  NormalPlayer('12219676'): {NormalPlayer('12219676')},
#  NormalPlayer('12492950'): {NormalPlayer('12492950')},
#  NormalPlayer('12451233'): {NormalPlayer('12451233')},
#  NormalPlayer('12323847'): {NormalPlayer('12323847')},
#  NormalPlayer('12117802'): {NormalPlayer('12117802')},
#  NormalPlayer('12488202'): {NormalPlayer('12488202')},
#  NormalPlayer('12022022'): {NormalPlayer('12022022')},
#  NormalPlayer('12350186'): {NormalPlayer('12350186')},
#  NormalPlayer('12431641'): {NormalPlayer('12431641')},
#  NormalPlayer('12323844'): {NormalPlayer('12323844')},
#  NormalPlayer('12173327'): {NormalPlayer('12173327')},
#  NormalPlayer('12173151'): {NormalPlayer('12173151')},
#  NormalPlayer('12320799'): {NormalPlayer('12320799')},
#  StarPlayer('STAR-7660'): {StarPlayer('STAR-7660')},
#  StarPlayer('STAR-7545'): {StarPlayer('STAR-7545')},
#  NormalPlayer('12169228'): {NormalPlayer('12169228')},
#  NormalPlayer('12455237'): {NormalPlayer('12455237')},
#  NormalPlayer('12537132'): {NormalPlayer('12537132')},
#  NormalPlayer('12367633'): {NormalPlayer('12367633')},
#  NormalPlayer('12158272'): {NormalPlayer('12158272')},
#  NormalPlayer('12227199'): {NormalPlayer('12227199')},
#  MercenaryPlayer('MERC-7363-2035'): {MercenaryPlayer('MERC-7363-2035')},
#  NormalPlayer('12402229'): {NormalPlayer('12402229')},
#  NormalPlayer('12399363'): {NormalPlayer('12399363')},
#  NormalPlayer('12531227'): {NormalPlayer('12531227')},
#  NormalPlayer('12399357'): {NormalPlayer('12399357')},
#  NormalPlayer('12521600'): {NormalPlayer('12521600')},
#  NormalPlayer('12535865'): {NormalPlayer('12535865')},
#  NormalPlayer('12117786'): {NormalPlayer('12117786')},
#  NormalPlayer('12325681'): {NormalPlayer('12325681')},
#  NormalPlayer('12467071'): {NormalPlayer('12467071')},
#  NormalPlayer('12422174'): {NormalPlayer('12422174')},
#  NormalPlayer('12139096'): {NormalPlayer('12139096')},
#  MercenaryPlayer('MERC-7444-0015'): {MercenaryPlayer('MERC-7444-0015')},
#  NormalPlayer('11892429'): {NormalPlayer('11892429')},
#  MercenaryPlayer('MERC-7444-2428'): {MercenaryPlayer('MERC-7444-2428')},
#  NormalPlayer('11892405'): {NormalPlayer('11892405')},
#  NormalPlayer('12402972'): {NormalPlayer('12402972')},
#  NormalPlayer('12319538'): {NormalPlayer('12319538')},
#  NormalPlayer('12502658'): {NormalPlayer('12502658')},
#  NormalPlayer('12219678'): {NormalPlayer('12219678')},
#  NormalPlayer('12360754'): {NormalPlayer('12360754')},
#  NormalPlayer('12282912'): {NormalPlayer('12282912')},
#  NormalPlayer('12450012'): {NormalPlayer('12450012')},
#  NormalPlayer('12173145'): {NormalPlayer('12173145')},
#  NormalPlayer('12296160'): {NormalPlayer('12296160')},
#  NormalPlayer('12219671'): {NormalPlayer('12219671')},
#  NormalPlayer('12501592'): {NormalPlayer('12501592')},
#  NormalPlayer('12340698'): {NormalPlayer('12340698')},
#  MercenaryPlayer('MERC-7444-0717'): {MercenaryPlayer('MERC-7444-0717')},
#  NormalPlayer('12173143'): {NormalPlayer('12173143')},
#  NormalPlayer('12219903'): {NormalPlayer('12219903')},
#  NormalPlayer('12348482'): {NormalPlayer('12348482')},
#  NormalPlayer('12519733'): {NormalPlayer('12519733')},
#  NormalPlayer('12117792'): {NormalPlayer('12117792')},
#  NormalPlayer('12165569'): {NormalPlayer('12165569')},
#  NormalPlayer('12022008'): {NormalPlayer('12022008')},
#  NormalPlayer('12117795'): {NormalPlayer('12117795')},
#  NormalPlayer('12358967'): {NormalPlayer('12358967')},
#  StarPlayer('STAR-7581'): {StarPlayer('STAR-7581')},
#  MercenaryPlayer('MERC-7444-2680'): {MercenaryPlayer('MERC-7444-2680')},
#  MercenaryPlayer('MERC-7444-0529'): {MercenaryPlayer('MERC-7444-0529')},
#  NormalPlayer('12158267'): {NormalPlayer('12158267')},
#  NormalPlayer('12121960'): {NormalPlayer('12121960')},
#  NormalPlayer('12346893'): {NormalPlayer('12346893')},
#  NormalPlayer('12104982'): {NormalPlayer('12104982')},
#  NormalPlayer('12488193'): {NormalPlayer('12488193')},
#  MercenaryPlayer('MERC-7444-0351'): {MercenaryPlayer('MERC-7444-0351')},
#  NormalPlayer('12117788'): {NormalPlayer('12117788')},
#  MercenaryPlayer('MERC-7444-2145'): {MercenaryPlayer('MERC-7444-2145')},
#  MercenaryPlayer('MERC-7444-0886'): {MercenaryPlayer('MERC-7444-0886')},
#  NormalPlayer('12519811'): {NormalPlayer('12519811')},
#  NormalPlayer('12230477'): {NormalPlayer('12230477')},
#  NormalPlayer('12288426'): {NormalPlayer('12288426')},
#  NormalPlayer('12362496'): {NormalPlayer('12362496')},
#  NormalPlayer('12323839'): {NormalPlayer('12323839')},
#  NormalPlayer('12323842'): {NormalPlayer('12323842')},
#  NormalPlayer('12497858'): {NormalPlayer('12497858')},
#  MercenaryPlayer('MERC-7444-1400'): {MercenaryPlayer('MERC-7444-1400')},
#  NormalPlayer('12323845'): {NormalPlayer('12323845')},
#  NormalPlayer('12500720'): {NormalPlayer('12500720')},
#  NormalPlayer('12339037'): {NormalPlayer('12339037')},
#  NormalPlayer('12510966'): {NormalPlayer('12510966')},
#  NormalPlayer('12158266'): {NormalPlayer('12158266')},
#  NormalPlayer('12551997'): {NormalPlayer('12551997')},
#  NormalPlayer('12318457'): {NormalPlayer('12318457')},
#  NormalPlayer('11947871'): {NormalPlayer('11947871')},
#  NormalPlayer('12348483'): {NormalPlayer('12348483')},
#  NormalPlayer('12467072'): {NormalPlayer('12467072')},
#  NormalPlayer('12235198'): {NormalPlayer('12235198')},
#  NormalPlayer('12464407'): {NormalPlayer('12464407')},
#  NormalPlayer('12450013'): {NormalPlayer('12450013')},
#  NormalPlayer('12552000'): {NormalPlayer('12552000')},
#  NormalPlayer('12551905'): {NormalPlayer('12551905')},
#  NormalPlayer('12323836'): {NormalPlayer('12323836')},
#  NormalPlayer('12458539'): {NormalPlayer('12458539')},
#  MercenaryPlayer('MERC-7444-3110'): {MercenaryPlayer('MERC-7444-3110')},
#  NormalPlayer('12173110'): {NormalPlayer('12173110')},
#  NormalPlayer('12352367'): {NormalPlayer('12352367')},
#  NormalPlayer('12362498'): {NormalPlayer('12362498')},
#  NormalPlayer('12229237'): {NormalPlayer('12229237')},
#  NormalPlayer('12158279'): {NormalPlayer('12158279')},
#  MercenaryPlayer('MERC-7444-3892'): {MercenaryPlayer('MERC-7444-3892')},
#  NormalPlayer('12354844'): {NormalPlayer('12354844')},
#  MercenaryPlayer('MERC-7446-3508'): {MercenaryPlayer('MERC-7446-3508')},
#  MercenaryPlayer('MERC-7444-0557'): {MercenaryPlayer('MERC-7444-0557')},
#  NormalPlayer('12158269'): {NormalPlayer('12158269')},
#  MercenaryPlayer('MERC-7444-2012'): {MercenaryPlayer('MERC-7444-2012')},
#  NormalPlayer('12191641'): {NormalPlayer('12191641')},
#  NormalPlayer('12139099'): {NormalPlayer('12139099')},
#  NormalPlayer('12424263'): {NormalPlayer('12424263')},
#  NormalPlayer('12320310'): {NormalPlayer('12320310')},
#  NormalPlayer('12323837'): {NormalPlayer('12323837')},
#  NormalPlayer('12520380'): {NormalPlayer('12520380')},
#  NormalPlayer('12510965'): {NormalPlayer('12510965')},
#  StarPlayer('STAR-7537'): {StarPlayer('STAR-7537')},
#  NormalPlayer('12513608'): {NormalPlayer('12513608')},
#  NormalPlayer('11950136'): {NormalPlayer('11950136')},
#  NormalPlayer('12352368'): {NormalPlayer('12352368')},
#  NormalPlayer('12495688'): {NormalPlayer('12495688')},
#  NormalPlayer('12169214'): {NormalPlayer('12169214')},
#  NormalPlayer('12521602'): {NormalPlayer('12521602')},
#  NormalPlayer('12117790'): {NormalPlayer('12117790')},
#  NormalPlayer('12496642'): {NormalPlayer('12022010'),
#   RaisedDeadPlayer('RAISED-7392_12022010_12496642')}}

# %%
sorted(perfsources)
# Out:
# [NormalPlayer('11892405'),
#  NormalPlayer('11892424'),
#  NormalPlayer('11892428'),
#  NormalPlayer('11892429'),
#  NormalPlayer('11947871'),
#  NormalPlayer('11950136'),
#  NormalPlayer('12022005'),
#  NormalPlayer('12022006'),
#  NormalPlayer('12022008'),
#  NormalPlayer('12022022'),
#  NormalPlayer('12104982'),
#  NormalPlayer('12117786'),
#  NormalPlayer('12117788'),
#  NormalPlayer('12117790'),
#  NormalPlayer('12117791'),
#  NormalPlayer('12117792'),
#  NormalPlayer('12117795'),
#  NormalPlayer('12117802'),
#  NormalPlayer('12121959'),
#  NormalPlayer('12121960'),
#  NormalPlayer('12121974'),
#  NormalPlayer('12130906'),
#  NormalPlayer('12139096'),
#  NormalPlayer('12139099'),
#  NormalPlayer('12158266'),
#  NormalPlayer('12158267'),
#  NormalPlayer('12158269'),
#  NormalPlayer('12158272'),
#  NormalPlayer('12158279'),
#  NormalPlayer('12162547'),
#  NormalPlayer('12165569'),
#  NormalPlayer('12169214'),
#  NormalPlayer('12169228'),
#  NormalPlayer('12173110'),
#  NormalPlayer('12173143'),
#  NormalPlayer('12173145'),
#  NormalPlayer('12173151'),
#  NormalPlayer('12173153'),
#  NormalPlayer('12173155'),
#  NormalPlayer('12173327'),
#  NormalPlayer('12179724'),
#  NormalPlayer('12191641'),
#  NormalPlayer('12219671'),
#  NormalPlayer('12219673'),
#  NormalPlayer('12219676'),
#  NormalPlayer('12219677'),
#  NormalPlayer('12219678'),
#  NormalPlayer('12219681'),
#  NormalPlayer('12219683'),
#  NormalPlayer('12219684'),
#  NormalPlayer('12219903'),
#  NormalPlayer('12227199'),
#  NormalPlayer('12229237'),
#  NormalPlayer('12230477'),
#  NormalPlayer('12235198'),
#  NormalPlayer('12240321'),
#  NormalPlayer('12245045'),
#  NormalPlayer('12282912'),
#  NormalPlayer('12288426'),
#  NormalPlayer('12296160'),
#  NormalPlayer('12318457'),
#  NormalPlayer('12319538'),
#  NormalPlayer('12320309'),
#  NormalPlayer('12320310'),
#  NormalPlayer('12320799'),
#  NormalPlayer('12323836'),
#  NormalPlayer('12323837'),
#  NormalPlayer('12323839'),
#  NormalPlayer('12323842'),
#  NormalPlayer('12323844'),
#  NormalPlayer('12323845'),
#  NormalPlayer('12323847'),
#  NormalPlayer('12325681'),
#  NormalPlayer('12339037'),
#  NormalPlayer('12340698'),
#  NormalPlayer('12346893'),
#  NormalPlayer('12348482'),
#  NormalPlayer('12348483'),
#  NormalPlayer('12350186'),
#  NormalPlayer('12352367'),
#  NormalPlayer('12352368'),
#  NormalPlayer('12354844'),
#  NormalPlayer('12357064'),
#  NormalPlayer('12358967'),
#  NormalPlayer('12360754'),
#  NormalPlayer('12362496'),
#  NormalPlayer('12362498'),
#  NormalPlayer('12367633'),
#  NormalPlayer('12399357'),
#  NormalPlayer('12399358'),
#  NormalPlayer('12399363'),
#  NormalPlayer('12402229'),
#  NormalPlayer('12402972'),
#  NormalPlayer('12422174'),
#  NormalPlayer('12424263'),
#  NormalPlayer('12431641'),
#  NormalPlayer('12438916'),
#  NormalPlayer('12443530'),
#  NormalPlayer('12450012'),
#  NormalPlayer('12450013'),
#  NormalPlayer('12451233'),
#  NormalPlayer('12455237'),
#  NormalPlayer('12458539'),
#  NormalPlayer('12464407'),
#  NormalPlayer('12467071'),
#  NormalPlayer('12467072'),
#  NormalPlayer('12488193'),
#  NormalPlayer('12488202'),
#  NormalPlayer('12492950'),
#  NormalPlayer('12495688'),
#  NormalPlayer('12496642'),
#  NormalPlayer('12497858'),
#  NormalPlayer('12500720'),
#  NormalPlayer('12501592'),
#  NormalPlayer('12502657'),
#  NormalPlayer('12502658'),
#  NormalPlayer('12504647'),
#  NormalPlayer('12510951'),
#  NormalPlayer('12510965'),
#  NormalPlayer('12510966'),
#  NormalPlayer('12513608'),
#  NormalPlayer('12513768'),
#  NormalPlayer('12519733'),
#  NormalPlayer('12519811'),
#  NormalPlayer('12520380'),
#  NormalPlayer('12521600'),
#  NormalPlayer('12521602'),
#  NormalPlayer('12522638'),
#  NormalPlayer('12525812'),
#  NormalPlayer('12531227'),
#  NormalPlayer('12535865'),
#  NormalPlayer('12536828'),
#  NormalPlayer('12537131'),
#  NormalPlayer('12537132'),
#  NormalPlayer('12551905'),
#  NormalPlayer('12551997'),
#  NormalPlayer('12552000'),
#  StarPlayer('STAR-7537'),
#  StarPlayer('STAR-7545'),
#  StarPlayer('STAR-7581'),
#  StarPlayer('STAR-7660'),
#  MercenaryPlayer('MERC-7363-2035'),
#  MercenaryPlayer('MERC-7391-3245'),
#  MercenaryPlayer('MERC-7444-0015'),
#  MercenaryPlayer('MERC-7444-0351'),
#  MercenaryPlayer('MERC-7444-0529'),
#  MercenaryPlayer('MERC-7444-0557'),
#  MercenaryPlayer('MERC-7444-0717'),
#  MercenaryPlayer('MERC-7444-0886'),
#  MercenaryPlayer('MERC-7444-1067'),
#  MercenaryPlayer('MERC-7444-1240'),
#  MercenaryPlayer('MERC-7444-1400'),
#  MercenaryPlayer('MERC-7444-1616'),
#  MercenaryPlayer('MERC-7444-1776'),
#  MercenaryPlayer('MERC-7444-1790'),
#  MercenaryPlayer('MERC-7444-1807'),
#  MercenaryPlayer('MERC-7444-2012'),
#  MercenaryPlayer('MERC-7444-2145'),
#  MercenaryPlayer('MERC-7444-2428'),
#  MercenaryPlayer('MERC-7444-2680'),
#  MercenaryPlayer('MERC-7444-2820'),
#  MercenaryPlayer('MERC-7444-2913'),
#  MercenaryPlayer('MERC-7444-3066'),
#  MercenaryPlayer('MERC-7444-3110'),
#  MercenaryPlayer('MERC-7444-3217'),
#  MercenaryPlayer('MERC-7444-3467'),
#  MercenaryPlayer('MERC-7444-3588'),
#  MercenaryPlayer('MERC-7444-3727'),
#  MercenaryPlayer('MERC-7444-3892'),
#  MercenaryPlayer('MERC-7446-0393'),
#  MercenaryPlayer('MERC-7446-3508'),
#  MercenaryPlayer('MERC-7447-2981')]

# %%
cibblbibbl._init_existing_players
# Out:
# frozenset({RaisedDeadPlayer('RAISED-7154_11456003_11460719'),
#            NormalPlayer('11460719'),
#            RaisedDeadPlayer('RAISED-7154_STAR-7564_11699071'),
#            NormalPlayer('11699071'),
#            RaisedDeadPlayer('RAISED-7240_11709016_0'),
#            NormalPlayer('11744536'),
#            NormalPlayer('11744537'),
#            NormalPlayer('11747061'),
#            RaisedDeadPlayer('RAISED-7154_11624587_11747108'),
#            NormalPlayer('11747108'),
#            NormalPlayer('11765469'),
#            NormalPlayer('11791157'),
#            NormalPlayer('11814852'),
#            RaisedDeadPlayer('RAISED-7385_STAR-7542_11850036'),
#            NormalPlayer('11850036'),
#            RaisedDeadPlayer('RAISED-7240_11903019_0'),
#            RaisedDeadPlayer('RAISED-7385_11795536_11933869'),
#            NormalPlayer('11933869'),
#            RaisedDeadPlayer('RAISED-7385_11446521_11936975'),
#            NormalPlayer('11936975'),
#            NormalPlayer('11940785'),
#            RaisedDeadPlayer('RAISED-7385_11853135_11941952'),
#            NormalPlayer('11941952'),
#            NormalPlayer('11942628'),
#            NormalPlayer('11956674'),
#            NormalPlayer('11961337'),
#            NormalPlayer('11978228'),
#            RaisedDeadPlayer('RAISED-7240_11790140_11985903'),
#            NormalPlayer('11985903'),
#            NormalPlayer('12051832'),
#            RaisedDeadPlayer('RAISED-7373_11828958_12074616'),
#            NormalPlayer('12074616'),
#            NormalPlayer('12138861'),
#            RaisedDeadPlayer('RAISED-7478_12131134_12146724'),
#            NormalPlayer('12146724'),
#            RaisedDeadPlayer('RAISED-7172_12139375_12149401'),
#            NormalPlayer('12149401'),
#            RaisedDeadPlayer('RAISED-7373_12060616_12165177'),
#            NormalPlayer('12165177'),
#            RaisedDeadPlayer('RAISED-7478_12139360_12165388'),
#            NormalPlayer('12165388'),
#            RaisedDeadPlayer('RAISED-7154_12117789_12179723'),
#            NormalPlayer('12179723'),
#            RaisedDeadPlayer('RAISED-7392_12167621_12180472'),
#            NormalPlayer('12180472'),
#            RaisedDeadPlayer('RAISED-7172_12131135_12185402'),
#            NormalPlayer('12185402'),
#            RaisedDeadPlayer('RAISED-7240_12048789_12188138'),
#            NormalPlayer('12188138'),
#            RaisedDeadPlayer('RAISED-7392_12158274_12191636'),
#            NormalPlayer('12191636'),
#            RaisedDeadPlayer('RAISED-7373_STAR-7546_12196576'),
#            NormalPlayer('12196576'),
#            RaisedDeadPlayer('RAISED-7240_12126951_12220462'),
#            NormalPlayer('12220462'),
#            RaisedDeadPlayer('RAISED-7373_12217945_12227408'),
#            NormalPlayer('12227408'),
#            RaisedDeadPlayer('RAISED-7385_11750105_12239687'),
#            NormalPlayer('12239687'),
#            RaisedDeadPlayer('RAISED-7385_12152809_12261744'),
#            NormalPlayer('12261744'),
#            RaisedDeadPlayer('RAISED-7240_12099993_12274224'),
#            NormalPlayer('12274224'),
#            RaisedDeadPlayer('RAISED-7478_12158282_12281353'),
#            NormalPlayer('12281353'),
#            RaisedDeadPlayer('RAISED-7172_12121967_12319951'),
#            NormalPlayer('12319951'),
#            RaisedDeadPlayer('RAISED-7392_12285943_12325681'),
#            NormalPlayer('12325681'),
#            NormalPlayer('12348495'),
#            NormalPlayer('12348496'),
#            NormalPlayer('12349401'),
#            NormalPlayer('12349402'),
#            RaisedDeadPlayer('RAISED-7392_12146168_12350186'),
#            NormalPlayer('12350186'),
#            RaisedDeadPlayer('RAISED-7478_12347712_12353469'),
#            NormalPlayer('12353469'),
#            RaisedDeadPlayer('RAISED-7154_12341147_12357062'),
#            NormalPlayer('12357062'),
#            RaisedDeadPlayer('RAISED-7240_11825659_12362216'),
#            NormalPlayer('12362216'),
#            NormalPlayer('12363942'),
#            NormalPlayer('12372276'),
#            NormalPlayer('12372278'),
#            RaisedDeadPlayer('RAISED-7154_12282467_12405074'),
#            NormalPlayer('12405074'),
#            NormalPlayer('12423015'),
#            RaisedDeadPlayer('RAISED-7478_12285927_12424765'),
#            NormalPlayer('12424765'),
#            RaisedDeadPlayer('RAISED-7392_12315770_12431641'),
#            NormalPlayer('12431641'),
#            RaisedDeadPlayer('RAISED-7373_12278048_12447130'),
#            NormalPlayer('12447130'),
#            RaisedDeadPlayer('RAISED-7392_12293175_12458539'),
#            NormalPlayer('12458539'),
#            RaisedDeadPlayer('RAISED-7385_12426851_12465599'),
#            NormalPlayer('12465599'),
#            NormalPlayer('12467315'),
#            RaisedDeadPlayer('RAISED-7392_12022010_12496642'),
#            NormalPlayer('12496642'),
#            RaisedDeadPlayer('RAISED-7240_12501183_12506569'),
#            NormalPlayer('12506569'),
#            RaisedDeadPlayer('RAISED-7385_12581950_12598016'),
#            NormalPlayer('12598016'),
#            RaisedDeadPlayer('RAISED-7154_12580266_12608838'),
#            NormalPlayer('12608838'),
#            NormalPlayer('12615328'),
#            NormalPlayer('12615329'),
#            RaisedDeadPlayer('RAISED-7392_12550883_12615768'),
#            NormalPlayer('12615768'),
#            NormalPlayer('12618231'),
#            NormalPlayer('12618232'),
#            RaisedDeadPlayer('RAISED-7240_12555005_12618916'),
#            NormalPlayer('12618916'),
#            NormalPlayer('12636777'),
#            RaisedDeadPlayer('RAISED-7385_12593624_12646986'),
#            NormalPlayer('12646986'),
#            NormalPlayer('12664618'),
#            RaisedDeadPlayer('RAISED-7385_12577744_12667609'),
#            NormalPlayer('12667609'),
#            RaisedDeadPlayer('RAISED-7172_12504898_12669649'),
#            NormalPlayer('12669649'),
#            RaisedDeadPlayer('RAISED-7392_12122275_12691708'),
#            NormalPlayer('12691708'),
#            NormalPlayer('12702407'),
#            RaisedDeadPlayer('RAISED-7373_12514745_12705420'),
#            NormalPlayer('12705420'),
#            RaisedDeadPlayer('RAISED-7172_12720797_12720888'),
#            NormalPlayer('12720888')})
