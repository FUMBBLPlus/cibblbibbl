# %%
import collections.abc
import copy
import datetime
import itertools
import json
import pathlib
import re
from pprint import pprint

import nest_asyncio
nest_asyncio.apply()
import texttable

import pytourney
import pyfumbbl
import cibblbibbl

# %%
G = cibblbibbl.CIBBL
Team = cibblbibbl.team.Team
Player = cibblbibbl.player.Player
player = cibblbibbl.player.player
Match = cibblbibbl.match.Match
Matchup = cibblbibbl.matchup.Matchup
Replay = cibblbibbl.replay.Replay

# %%
Pp = G.players

# %%
Pl = player('RAISED-7154_12341147_12357062')

# %%
Pl.prev
# Out:
# NormalPlayer('12341147', 'The Eternal Dancer')

# %%
for p in sorted(Pp):
    print(p)
# Out:
# NormalPlayer('11432421', 'Peach Blossom Water')
# NormalPlayer('11432422', "Passion's Dragon Controlled")
# NormalPlayer('11432423', 'Clamour of Bees')
# NormalPlayer('11432424', 'After the Lotus Flowers Have Opened')
# NormalPlayer('11432425', 'Scraps of Cloud')
# NormalPlayer('11432426', 'Gathering Water-Chestnuts')
# NormalPlayer('11432427', 'Practice of Mirth')
# NormalPlayer('11432428', 'Lonely Cloud')
# NormalPlayer('11432429', 'Silk Worm Spins')
# NormalPlayer('11432431', 'Once Forever')
# NormalPlayer('11432433', 'Blown Stars')
# NormalPlayer('11436435', 'Khulgez')
# NormalPlayer('11436436', 'Daakhax')
# NormalPlayer('11436437', 'Ghorkrox')
# NormalPlayer('11436438', 'Durzoz')
# NormalPlayer('11436440', 'Agnik the Vengeful')
# NormalPlayer('11436441', 'Yzshard Cinderspawn')
# NormalPlayer('11436444', "Aldo 'The Blast' Sessa")
# NormalPlayer('11436445', "Clay 'Four Fingers' Talluto")
# NormalPlayer('11436446', "Kurt 'The Beast' Wilcher")
# ...

# %%
for Te in G.teams:
    Te.roster.apiget
# Out:
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cache/api-roster/00000883.json') False
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cache/api-roster/00000901.json') False
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cache/api-roster/00001654.json') False
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cache/api-roster/00001294.json') False
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cache/api-roster/00000932.json') False
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cache/api-roster/00000868.json') False
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cache/api-roster/00000881.json') False
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cache/api-roster/00000951.json') False
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cache/api-roster/00000876.json') False
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cache/api-roster/00001752.json') False
# ...

# %%
for Po in cibblbibbl.position.Position.__members__.values():
    Po.apiget

# %%
positionIds = set()
for Te in G.teams:
    r = Te.roster.apiget
    for p in r["positions"] + r ["stars"]:
        positionId = int(p["id"])
        if positionId not in positionIds:
            P = cibblbibbl.position.Position(positionId)
            P.apiget
            positionIds.add(positionId)
# Out:
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cache/api-position/00007549.json') False
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cache/api-position/00009650.json') False
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cache/api-position/00009651.json') False
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cache/api-position/00009652.json') False
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cache/api-position/00009653.json') False
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cache/api-position/00007553.json') False
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cache/api-position/00007574.json') False
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cache/api-position/00007335.json') False
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cache/api-position/00007336.json') False
# on change JSONFile('/home/adam/FUMBBL/cibblbibbl-data/cache/api-position/00007337.json') False
# ...
