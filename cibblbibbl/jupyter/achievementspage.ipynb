# %%
import collections
import copy
import datetime
import itertools
import sys

import json
import pathlib
import re
from pprint import pprint

#import nest_asyncio # cause bugs
#nest_asyncio.apply()
import texttable

import pytourney
import pyfumbbl
import cibblbibbl

from cibblbibbl import bbcode

# %%
show_Ids = True
G = cibblbibbl.CIBBL
Achievement = cibblbibbl.achievement.Achievement
Team = cibblbibbl.team.Team
player = cibblbibbl.player.player
Match = cibblbibbl.match.Match
Matchup = cibblbibbl.matchup.Matchup
Position = cibblbibbl.position.Position
Replay = cibblbibbl.replay.Replay
Season = cibblbibbl.season.Season
Tournament = cibblbibbl.tournament.handler.default.Tournament
NormalPlayer = cibblbibbl.player.NormalPlayer
StarPlayer = cibblbibbl.player.StarPlayer

# %%
json_dump_kwargs = {'ensure_ascii': False, 'indent': '\t', 'sort_keys': True}

# %%
root = pathlib.Path('.')

# %%
w = cibblbibbl.phpwikicode

# %%
fname = "c:\\Users\\Szieberth\\Documents\\Repos\\cibblbibbl-data\\cibbl\\page\\achievements.20100926.wiki.txt"

# %%
G.init()

# %%
Se = max(G.seasons).prev
Se
# Out:
# Season('cibbl', 6, 4)

# %%
def trim_tournament_name(s):
    found = 0
    for i, c in enumerate(s):
        if c in "-–":
            found += 1
        if found == 2:
            return s[i+1:].strip()

# %%
def getcontent(a_cls, link_page=False):
    if isinstance(a_cls, list):
        logo_url, name, description, camelcasename = a_cls
    else:
        C = a_cls.defaultconfig_of_group(G)._data
        logo_url = C.get("logo_url", "")
        logo_url = f'https://fumbbl.com{logo_url}'
        name = C.get("phpwikiname", C["name"])
        description = C.get("phpwikidescription", C["description"])
        camelcasename = C.get("camelcasename")
    if link_page:
        pagename = f'CIBBL-Achievement-{camelcasename}'
        sn = w.url(pagename, name.lstrip("!"))
    else:
        sn = name
    return (
        w.url(logo_url) + w.br() + "\n"
        + w.b(sn) + w.br() + "\n"
        + w.i(description)
    )

# %%
teamac = {}
for k, cls in cibblbibbl.achievement.Achievement.registry.items():
    C = cls.defaultconfig_of_group(G)._data
    if not cls.__members__:
        continue
    if not C.get("description"):
        continue
    if cls.subject_typename == "Team":
        teamac[C["name"]] = cls
teamac["CabalVision Gold Partner"] = [
    "https://fumbbl.com/i/597778",
    "!CabalVision Gold Partner",
    "Awarded to a team which is a consecutive CIBBL member for the last 4 CIBBL Years (16 Seasons). Replaces Silver partnership. Worth 50 Prestige Points to the team as long as the team continously participates in every CIBBL events. Awarded since Year 5 Summer.",
    "CabalVisionGoldPartner",
]
teamac["CabalVision Silver Partner"] = [
    "https://fumbbl.com/i/597779",
    "!CabalVision Silver Partner",
    "Awarded to a team which is a consecutive CIBBL member for the last 2 CIBBL Years (8 Seasons). Worth 25 Prestige Points to the team as long as the team continously participates in every CIBBL events or until it becomes a Gold Partner. Awarded since Year 5 Summer.",
    "CabalVisionSilverPartner",
]

# %%
parts = []
gen = iter(sorted(teamac))
for k in gen:
    content1 = getcontent(teamac[k], True)
    try:
        content2 = getcontent(teamac[next(gen)], True)
    except StopIteration:
        content2 = ""
    parts.append(w.dualcolumn(content1, content2))
teamaccontent = "\n".join(parts)

# %%
playerac = collections.defaultdict(set)
for k, cls in cibblbibbl.achievement.Achievement.registry.items():
    if not cls.__members__:
        continue
    D = cls.defaultconfig_of_group(G)
    C = D._data
    bracket = C.get("bracket")
    if not bracket:
        continue
    playerac[bracket].add(cls)

# %%
bracketorder = [
    "Development",
    "Performance",
    "Best Players of Winter Tournaments",
    "Best Players of Spring Tournaments",
    "Best Players of Summer Tournaments",
    "Best Players of Autumn Tournaments",
    "Other Best Players",
]

# %%
parts = []
for bracket in bracketorder:
    parts.append(f'{w.br()}\n!!{bracket}')
    bracketparts = []
    clss0 = playerac[bracket]
    clss1 = sorted(clss0, key=lambda c: c.defaultconfig_of_group(G)._data.get("bracketsortkey", c.defaultconfig_of_group(G)._data["name"])) 
    gen = iter(clss1)
    for cls in gen:
        content1 = getcontent(cls, True)
        try:
            content2 = getcontent(next(gen), True)
        except StopIteration:
            content2 = ""
        bracketparts.append(w.dualcolumn(content1, content2))
    bracketcontent = "\n".join(bracketparts)
    parts.append(bracketcontent)
playeraccontent = "\n\n\n\n\n".join(parts)

# %%
parts = [
    w.center(w.url("https://fumbbl.com/i/596322")),
    "\n\n",
    w.br(),
    f'!!!Team Achievements',
    w.br(),
    "\n\n\n",
    teamaccontent,
    "\n\n",
    w.br(),
    f'!!!Player Achievements',
    "\n\n\n",
    playeraccontent,
]
content = "\n".join(parts)

# %%
#cibblbibbl.session.helppage.edit("CIBBL-Achievements", content)

# %%
name = 'Crushing Victory'
cls = teamac[name]
C = cls.defaultconfig_of_group(G)._data
aname = C.get("camelcasename",cls.__name__.split("_")[1])
pagename = f'CIBBL-Achievement-{aname}'
m0 = cls.__members__.values()
m1 = sorted(m0, key=lambda a: a.match.Id)
header = ["Tournament", "Match", "Team", "Roster", "Coach", "Prestige"]
header = [w.b(s) for s in header]
align = "CCLLLR"
rows = []
for a in m1:
    if Se < a.tournament.season:
        continue
    if "proposed" in a["status"]:
        continue
    date = f'Y{a.season.year.nr} {a.season.name}'
    tournamentname = trim_tournament_name(a.tournament.shortname)
    tournament = w.tournament(a.tournament, tournamentname)
    stournament = f'{date} – {w.i(tournament)}'
    match = w.url(f'https://fumbbl.com/p/match?id={a.match.Id}', "-".join(str(x) for x in sorted(a.match.scores().values(), reverse=True)))
    team = w.url(f'https://fumbbl.com/p/team?team_id={a.subject.Id}', a.subject.name)
    roster = a.subject.roster_name
    coach = w.url(f'https://fumbbl.com/~{a.subject.coach_name}', a.subject.coach_name)
    prestige = a.prestige(season=Se)
    rows.append([stournament, match, team, roster, coach, prestige])
stable = w.table(rows, align=align, header=header)
parts = [
    "{center\n[https://fumbbl.com/i/646337]%%%\n}",
    w.dualcolumn(getcontent(cls), ""),
    stable,
    "",
]
content = f'\n\n{w.br()}\n\n'.join(parts)
#print(content)
#cibblbibbl.session.helppage.edit(pagename, content)

# %%
print("-"*50)
for name in ('Obsidian Chalice', 'Pearl Chalice', "Winter's Glory"):
    cls = teamac[name]
    C = cls.defaultconfig_of_group(G)._data
    aname = C.get("camelcasename",cls.__name__.split("_")[1])
    pagename = f'CIBBL-Achievement-{aname}'
    m0 = cls.__members__.values()
    m1 = sorted(m0, key=lambda a: (a.season.year.nr, a.season.nr, int(a.tournament.Id), a.subject))
    # TODO tournament importance instead of id
    header = ["Tournament", "Team", "Roster", "Coach"]
    header = [w.b(s) for s in header]
    rows = []
    for a in m1:
        if Se < a.tournament.season:
            continue
        if "proposed" in a["status"]:
            continue
        date = f'Y{a.season.year.nr} {a.season.name}'
        tournamentname = trim_tournament_name(a.tournament.shortname)
        tournament = w.tournament(a.tournament, tournamentname)
        stournament = f'{date} – {w.i(tournament)}'
        team = w.url(f'https://fumbbl.com/p/team?team_id={a.subject.Id}', a.subject.name)
        roster = a.subject.roster_name
        coach = w.url(f'https://fumbbl.com/~{a.subject.coach_name}', a.subject.coach_name)
        rows.append([stournament, team, roster, coach])
    stable = w.table(rows, header=header)
    parts = [
        "{center\n[https://fumbbl.com/i/646337]%%%\n}",
        w.dualcolumn(getcontent(cls), ""),
        stable,
        "",
    ]
    content = f'\n\n{w.br()}\n\n'.join(parts)
    print(pagename)
    print("-"*50)
    #print(content)
    print("-"*50)
    #cibblbibbl.session.helppage.edit(pagename, content) # uncomment to publish
# Out:
# --------------------------------------------------
# CIBBL-Achievement-ObsidianChalice
# --------------------------------------------------
# --------------------------------------------------
# CIBBL-Achievement-PearlChalice
# --------------------------------------------------
# --------------------------------------------------
# CIBBL-Achievement-WintersGlory
# --------------------------------------------------
# --------------------------------------------------

# %%
partners = {
    "gold": cibblbibbl.helper.keydefaultdict((lambda k: k.gold_partner_teams())),
    "silver": cibblbibbl.helper.keydefaultdict((lambda k: k.silver_partner_teams())),
}
newpartners = {"gold": {}, "silver": {}}
endedpartners = {"gold": {}, "silver": {}}
seasons = sorted(se for se in G.seasons if se <= Se)
for S1 in seasons:
    g1 = partners["gold"][S1]
    s1 = partners["silver"][S1]
    S0 = S1.prev
    if S0:
        g0 = partners["gold"][S0]
        s0 = partners["silver"][S0]
    else:
        g0, s0 = set(), set()
    newpartners["gold"][S1] = g1-g0
    newpartners["silver"][S1] = s1-s0
    endedpartners["gold"][S1] = g0-g1
    endedpartners["silver"][S1] = s0-s1|newpartners["gold"][S1]

# %%
partnerships = {"gold": [], "silver": []}
lastp = {"gold": {}, "silver": {}}
for k in ("gold", "silver"):
    for S1 in seasons:
        new = newpartners[k][S1]
        for Te in new:
            lastp[k][Te] = S1
        ended = endedpartners[k][S1]
        for Te in ended:
            try:
                S0 = lastp[k][Te]
            except KeyError: # got gold immediately
                continue
            partnerships[k].append([Te, S0, S1])
            del lastp[k][Te]
    else:
        for Te, S0 in lastp[k].items():
            partnerships[k].append([Te, S0, None])
for k in ("gold", "silver"):
    L = partnerships[k]
    L.sort(key=lambda t: (t[1], t[0].name))
#partnerships

# %%
print("-"*50)
for k in ("gold", "silver"):
    name = f'CabalVision {k.title()} Partner'
    t = teamac[name]
    aname = "".join(name.split())
    pagename = f'CIBBL-Achievement-{aname}'
    header = ["Team", "Roster", "Coach", "Started", "Ended"]
    header = [w.b(s) for s in header]
    L = partnerships[k]
    rows = []
    for Te, S0, S1 in L:
        started = f'Y{S0.year.nr} {S0.name}'
        if S1:
            ended = f'Y{S1.year.nr} {S1.name}'
        else:
            ended = " "
        team = w.url(f'https://fumbbl.com/p/team?team_id={Te.Id}', Te.name)
        roster = Te.roster_name
        coach = w.url(f'https://fumbbl.com/~{Te.coach_name}', Te.coach_name)
        rows.append([team, roster, coach, started, ended])
    stable = w.table(rows, header=header)
    parts = [
        "{center\n[https://fumbbl.com/i/646337]%%%\n}",
        w.dualcolumn(getcontent(t), ""),
        stable,
        "",
    ]
    content = f'\n\n{w.br()}\n\n'.join(parts)
    print(pagename)
    print("-"*50)
    #print(content)
    print("-"*50)
    #cibblbibbl.session.helppage.edit(pagename, content) # uncomment to publish
# Out:
# --------------------------------------------------
# CIBBL-Achievement-CabalVisionGoldPartner
# --------------------------------------------------
# --------------------------------------------------
# CIBBL-Achievement-CabalVisionSilverPartner
# --------------------------------------------------
# --------------------------------------------------

# %%
et = cibblbibbl.achievement.exporttools

# %%
deadstars = set()
for Mu in G.matchups:
    if Se < Mu.season:
        continue
    for teamId, playerId, dpp in Mu.iterdead():
        if playerId.startswith("STAR-"):
            deadstars.add(player(playerId))
deadstars
# Out:
# {StarPlayer('STAR-Angus Porterhouse'),
#  StarPlayer('STAR-Bilerot Vomitflesh'),
#  StarPlayer('STAR-Flint Churnblade'),
#  StarPlayer('STAR-Glart Smashrip Jr.'),
#  StarPlayer('STAR-Gorlem Goreblade'),
#  StarPlayer("STAR-Grak'Ng'Grak Gorthag"),
#  StarPlayer('STAR-Grashnak Blackhoof'),
#  StarPlayer('STAR-Gregor Miessen'),
#  StarPlayer('STAR-Griff Oberwald'),
#  StarPlayer('STAR-Hack Enslash'),
#  StarPlayer('STAR-Helmut Wulf'),
#  StarPlayer('STAR-Hoshi Komi'),
#  StarPlayer('STAR-Lewdgrip Whiparm'),
#  StarPlayer('STAR-Lord Borak the Despoiler'),
#  StarPlayer('STAR-Max Spleenripper'),
#  StarPlayer('STAR-Mighty Zug'),
#  StarPlayer("STAR-Morg 'n' Thorg"),
#  StarPlayer('STAR-Ritter Von Baum'),
#  StarPlayer('STAR-Setekh'),
#  StarPlayer("STAR-Siggi 'The Boot' Schuster"),
#  StarPlayer('STAR-Sinnedbad'),
#  StarPlayer('STAR-Skitter Stab-Stab'),
#  StarPlayer('STAR-Wilhelm Chaney'),
#  StarPlayer('STAR-Zara the Slayer'),
#  StarPlayer('STAR-Ziggi Abschuss')}

# %%
playerstatuses = cibblbibbl.helper.keydefaultdict(lambda Pl: (Pl.status if hasattr(Pl, "status") else ""))
playerpositons = cibblbibbl.helper.keydefaultdict(lambda Pl: Pl.position)
playerpositonnames = cibblbibbl.helper.keydefaultdict(lambda Pl: (playerpositons[Pl].name if hasattr(playerpositons[Pl], "name") else ""))

# %%
with (root/"playerstatuses.json").open("r", encoding="utf8") as f:
    cplayerstatuses = json.load(f)
    for playerId, s in cplayerstatuses.items():
        playerstatuses[player(playerId)] = s
with (root/"playerpositons.json").open("r", encoding="utf8") as f:
    cplayerpositons = json.load(f)
    for playerId, positionId in cplayerpositons.items():
        playerpositons[player(playerId)] = Position(positionId)
with (root/"playerpositonnames.json").open("r", encoding="utf8") as f:
    cplayerpositonnames = json.load(f)
    for playerId, s in cplayerpositonnames.items():
        playerpositonnames[player(playerId)] = s

# %%
with (root/"playerstatuses.json").open("w", encoding="utf8") as f:
    json.dump({Pl.Id: s for Pl, s in playerstatuses.items()}, f, **json_dump_kwargs)
with (root/"playerpositons.json").open("w", encoding="utf8") as f:
    json.dump({Pl.Id: Po.Id for Pl, Po in playerpositons.items() if Po}, f, **json_dump_kwargs)
with (root/"playerpositonnames.json").open("w", encoding="utf8") as f:
    json.dump({Pl.Id: s for Pl, s in playerpositonnames.items()}, f, **json_dump_kwargs)

# %%
print("-"*50)
for bracket, clss in playerac.items():
    for cls in clss:
        D = cls.defaultconfig_of_group(G)
        C = D._data
        aname = C.get("camelcasename",cls.__name__.split("_")[1])
        pagename = f'CIBBL-Achievement-{aname}'
        print(pagename)
        print("-"*50)
        if aname in {"AerodynamicAim", "MeanScoringMachine", "Perfection", "TripleX"}:
            m0 = cls.__members__.values()
            rows = []
            header = ["Tournament", "Match", "Player", "Position", "Team", "Prestige", "Status"]
            header = [w.b(s) for s in header]
            align = "CCCCCCC"
            rows = []
            for a in m0:
                if "transferred" in a["status"]:
                    continue
                if "proposed" in a["status"]:
                    continue
                if Se < a.tournament.season:
                    continue
                date = f'Y{a.season.year.nr} {a.season.name}'
                date = f'Y{a.season.year.nr} {a.season.name}'
                tournamentname = trim_tournament_name(a.tournament.shortname)
                tournament = w.tournament(a.tournament, tournamentname)
                stournament = f'{date} – {w.i(tournament)}'
                team = et.team(a)
                scores = copy.copy(a.match.scores())
                teamofmatch = et.teamofmatch(a)
                oppoteam = et.oppoteam(a, team_=teamofmatch)
                if teamofmatch is None:
                    coach = ""
                    sscores = "?"              
                else:
                    coach = w.url(f'https://fumbbl.com/~{teamofmatch.coach_name}', teamofmatch.coach_name)
                    try:
                        sscores = f'{scores[teamofmatch]}-{scores[oppoteam]}'              
                    except KeyError:
                        sscores = ""
                if team == teamofmatch and hasattr(teamofmatch, "roster_name"):
                    roster = teamofmatch.roster_name
                elif team == "Star Player":
                    roster = team
                    team = teamofmatch
                else:
                    roster = ""
                match = w.url(f'https://fumbbl.com/p/match?id={a.match.Id}', sscores)
                prestige = a.prestige(season=Se)
                player_ = a.subject
                position = playerpositonnames[player_]
                status = playerstatuses[player_]
                if status == "Dead" and player_.nexts:
                    status = "Transf."
                elif player_ in deadstars:
                    status = "Dead"
                splayer = f'{w.player(player_)}'
                sroster = f'{roster}{w.br()}{w.i(position)}'
                steam = f'{w.team(team)}{w.br()}{w.i("(" + coach + ")")}'
                rows.append([stournament, match, splayer, sroster, steam, prestige, status]) 
            stable = w.table(rows, header=header, align=align)
            parts = [
                "{center\n[https://fumbbl.com/i/646337]%%%\n}",
                w.dualcolumn(getcontent(cls), ""),
                stable,
                "",
            ]
            content = f'\n\n{w.br()}\n\n'.join(parts)
            #print(content)
            print("-"*50)
            cibblbibbl.session.helppage.edit(pagename, content) # uncomment to publish
# Out:
# --------------------------------------------------
# CIBBL-Achievement-TargetEliminated
# --------------------------------------------------
# CIBBL-Achievement-MeanScoringMachine
# --------------------------------------------------
# --------------------------------------------------
# CIBBL-Achievement-AerodynamicAim
# --------------------------------------------------
# --------------------------------------------------
# CIBBL-Achievement-BewareSupremeKiller
# --------------------------------------------------
# CIBBL-Achievement-TripleX
# --------------------------------------------------
# --------------------------------------------------
# CIBBL-Achievement-Perfection
# --------------------------------------------------
# --------------------------------------------------
# CIBBL-Achievement-FameKiller
# --------------------------------------------------
# CIBBL-Achievement-ChildOfWinter
# --------------------------------------------------
# CIBBL-Achievement-GreatestOfVileVermin
# --------------------------------------------------
# CIBBL-Achievement-NorthernProwess
# --------------------------------------------------
# CIBBL-Achievement-SpillBloodAndRageOn
# --------------------------------------------------
# CIBBL-Achievement-BullsEye
# --------------------------------------------------
# CIBBL-Achievement-OrientalAesthetics
# --------------------------------------------------
# CIBBL-Achievement-TurnItUpToEleven
# --------------------------------------------------
# CIBBL-Achievement-ElementalMyDear
# --------------------------------------------------
# CIBBL-Achievement-SouthlandSalvation
# --------------------------------------------------
# CIBBL-Achievement-BugmansFinest
# --------------------------------------------------
# CIBBL-Achievement-Horrific
# --------------------------------------------------
# CIBBL-Achievement-EmpiresFameInfamy
# --------------------------------------------------
# CIBBL-Achievement-WithLoveFromLustria
# --------------------------------------------------
# CIBBL-Achievement-CavernClimber
# --------------------------------------------------
# CIBBL-Achievement-WastelandWarrior
# --------------------------------------------------
# CIBBL-Achievement-OldWorldValues
# --------------------------------------------------
# CIBBL-Achievement-TimelessDisplay
# --------------------------------------------------
# CIBBL-Achievement-SnakeCharmer
# --------------------------------------------------
# CIBBL-Achievement-DevastationFromBeyond
# --------------------------------------------------
# CIBBL-Achievement-BloodForTheBloodline
# --------------------------------------------------
# CIBBL-Achievement-WaveRider
# --------------------------------------------------
# CIBBL-Achievement-VerdantVibes
# --------------------------------------------------
# CIBBL-Achievement-BloodRage
# --------------------------------------------------
# CIBBL-Achievement-RisingOutOfCarnage
# --------------------------------------------------
# CIBBL-Achievement-AwakenedAtLast
# --------------------------------------------------
# CIBBL-Achievement-The1Percent
# --------------------------------------------------
# CIBBL-Achievement-Pathfinder
# --------------------------------------------------
# CIBBL-Achievement-FlyingColors
# --------------------------------------------------
# CIBBL-Achievement-ASpecialSpecimenIndeed
# --------------------------------------------------
# CIBBL-Achievement-ThumbUp
# --------------------------------------------------
# CIBBL-Achievement-MasterOfTheWhiteGate
# --------------------------------------------------
# CIBBL-Achievement-GutsNGlory
# --------------------------------------------------
# CIBBL-Achievement-Futuristic
# --------------------------------------------------
# CIBBL-Achievement-FinderOfTheWay
# --------------------------------------------------
# CIBBL-Achievement-LordsOfBalanceObsidian
# --------------------------------------------------
# CIBBL-Achievement-CabalVisionRatingAttraction
# --------------------------------------------------
# CIBBL-Achievement-StylePoints
# --------------------------------------------------
# CIBBL-Achievement-MagicMushroomMuncher
# --------------------------------------------------
# CIBBL-Achievement-LordsOfBalancePearl
# --------------------------------------------------
# CIBBL-Achievement-Gargantuan
# --------------------------------------------------
# CIBBL-Achievement-DeathOrGlory
# --------------------------------------------------
# CIBBL-Achievement-AllYouCanEat
# --------------------------------------------------
# CIBBL-Achievement-Escapist
# --------------------------------------------------
# CIBBL-Achievement-SCRIBBLsOutstandingPerformance
# --------------------------------------------------
# CIBBL-Achievement-BlueEagleAscending
# --------------------------------------------------
# CIBBL-Achievement-IceCold
# --------------------------------------------------
# CIBBL-Achievement-Slasher
# --------------------------------------------------
# CIBBL-Achievement-InspiredDrinker
# --------------------------------------------------
# CIBBL-Achievement-AltdorfCollegeHonoraryGraduate
# --------------------------------------------------
# CIBBL-Achievement-NotWithAWhimperButWithABang
# --------------------------------------------------
# CIBBL-Achievement-WakeUpCall
# --------------------------------------------------
# CIBBL-Achievement-PromiseOfGreatness
# --------------------------------------------------
# CIBBL-Achievement-MarkOfTheDragon
# --------------------------------------------------
# CIBBL-Achievement-NufflesBlessing
# --------------------------------------------------
# CIBBL-Achievement-ExemplarOfGlory
# --------------------------------------------------
# CIBBL-Achievement-Eternal
# --------------------------------------------------
# CIBBL-Achievement-MasterOfTheBlackGate
# --------------------------------------------------
# CIBBL-Achievement-GrowthPotential
# --------------------------------------------------
# CIBBL-Achievement-BlitzingBeauty
# --------------------------------------------------
# CIBBL-Achievement-Sleepless
# --------------------------------------------------
# CIBBL-Achievement-SippingTheWitchesBrew
# --------------------------------------------------
# CIBBL-Achievement-FungusSupreme
# --------------------------------------------------
# CIBBL-Achievement-FirstTry
# --------------------------------------------------
# CIBBL-Achievement-LeatherRebel
# --------------------------------------------------
# CIBBL-Achievement-TerrificMightOfTin
# --------------------------------------------------
# CIBBL-Achievement-SilverExcellence
# --------------------------------------------------
# CIBBL-Achievement-BronzeExcellence
# --------------------------------------------------
# CIBBL-Achievement-GoldExcellence
# --------------------------------------------------
# CIBBL-Achievement-DustDevil
# --------------------------------------------------
# CIBBL-Achievement-StickInTheMud
# --------------------------------------------------
# CIBBL-Achievement-RefinedExcellence
# --------------------------------------------------
# CIBBL-Achievement-CopperExcellence
# --------------------------------------------------
# CIBBL-Achievement-ClothExcellence
# --------------------------------------------------
# CIBBL-Achievement-SolidFoundation
# --------------------------------------------------
# CIBBL-Achievement-ClayExcellence
# --------------------------------------------------
# CIBBL-Achievement-ExcellentOnPaper
# --------------------------------------------------
# CIBBL-Achievement-ForgedGreatness
# --------------------------------------------------
# CIBBL-Achievement-WhispererInTheWoods
# --------------------------------------------------
# CIBBL-Achievement-YouthfulVibrance
# --------------------------------------------------
# CIBBL-Achievement-StarPlayer
# --------------------------------------------------
# CIBBL-Achievement-MegaStarPlayer
# --------------------------------------------------
# CIBBL-Achievement-SuperStarPlayer
# --------------------------------------------------
# CIBBL-Achievement-Legend
# --------------------------------------------------

# %%
print("-"*50)
for bracket, clss in playerac.items():
    for cls in clss:
        D = cls.defaultconfig_of_group(G)
        C = D._data
        aname = C.get("camelcasename",cls.__name__.split("_")[1])
        pagename = f'CIBBL-Achievement-{aname}'
        print(pagename)
        print("-"*50)
        if aname in {"StarPlayer", "SuperStarPlayer", "MegaStarPlayer", "Legend"}:
            m0 = cls.__members__.values()
            m1 = sorted(m0, key=lambda a: (a.season.year.nr, a.season.nr, int(a.tournament.Id), a.subject))
            rows = []
            header = ["Tournament", "Match", "Player", "Position", "Team", "Prestige", "Status"]
            header = [w.b(s) for s in header]
            align = "CCCCCCC"
            rows = []
            for a in m0:
                if "transferred" in a["status"]:
                    continue
                if "proposed" in a["status"]:
                    continue
                if Se < a.tournament.season:
                    continue
                date = f'Y{a.season.year.nr} {a.season.name}'
                date = f'Y{a.season.year.nr} {a.season.name}'
                tournamentname = trim_tournament_name(a.tournament.shortname)
                tournament = w.tournament(a.tournament, tournamentname)
                stournament = f'{date}{w.br()}{w.i(tournament)}'
                team = et.team(a)
                scores = copy.copy(a.match.scores())
                teamofmatch = et.teamofmatch(a)
                oppoteam = et.oppoteam(a, team_=teamofmatch)
                if teamofmatch is None:
                    coach = ""
                    sscores = "?"              
                else:
                    coach = w.url(f'https://fumbbl.com/~{teamofmatch.coach_name}', teamofmatch.coach_name)
                    try:
                        sscores = f'{scores[teamofmatch]}-{scores[oppoteam]}'              
                    except KeyError:
                        sscores = ""
                if team == teamofmatch and hasattr(teamofmatch, "roster_name"):
                    roster = teamofmatch.roster_name
                elif team == "Star Player":
                    roster = team
                    team = teamofmatch
                else:
                    roster = ""
                match = w.url(f'https://fumbbl.com/p/match?id={a.match.Id}', sscores)
                prestige = a.prestige(season=Se)
                player_ = a.subject
                position = playerpositonnames[player_]
                status = playerstatuses[player_]
                if status == "Dead" and player_.nexts:
                    status = "Transf."
                elif player_ in deadstars:
                    status = "Dead"
                splayer = f'{w.player(player_)}'
                sroster = f'{roster}{w.br()}{w.i(position)}'
                steam = f'{w.team(team)}{w.br()}{w.i("(" + coach + ")")}'
                rows.append([stournament, match, splayer, sroster, steam, prestige, status]) 
            stable = w.table(rows, header=header, align=align)
            parts = [
                "{center\n[https://fumbbl.com/i/646337]%%%\n}",
                w.dualcolumn(getcontent(cls), ""),
                stable,
                "",
            ]
            content = f'\n\n{w.br()}\n\n'.join(parts)
            #print(content)
            print("-"*50)
            cibblbibbl.session.helppage.edit(pagename, content) # uncomment to publish
# Out:
# --------------------------------------------------
# CIBBL-Achievement-TargetEliminated
# --------------------------------------------------
# CIBBL-Achievement-MeanScoringMachine
# --------------------------------------------------
# CIBBL-Achievement-AerodynamicAim
# --------------------------------------------------
# CIBBL-Achievement-BewareSupremeKiller
# --------------------------------------------------
# CIBBL-Achievement-TripleX
# --------------------------------------------------
# CIBBL-Achievement-Perfection
# --------------------------------------------------
# CIBBL-Achievement-FameKiller
# --------------------------------------------------
# CIBBL-Achievement-ChildOfWinter
# --------------------------------------------------
# CIBBL-Achievement-GreatestOfVileVermin
# --------------------------------------------------
# CIBBL-Achievement-NorthernProwess
# --------------------------------------------------
# CIBBL-Achievement-SpillBloodAndRageOn
# --------------------------------------------------
# CIBBL-Achievement-BullsEye
# --------------------------------------------------
# CIBBL-Achievement-OrientalAesthetics
# --------------------------------------------------
# CIBBL-Achievement-TurnItUpToEleven
# --------------------------------------------------
# CIBBL-Achievement-ElementalMyDear
# --------------------------------------------------
# CIBBL-Achievement-SouthlandSalvation
# --------------------------------------------------
# CIBBL-Achievement-BugmansFinest
# --------------------------------------------------
# CIBBL-Achievement-Horrific
# --------------------------------------------------
# CIBBL-Achievement-EmpiresFameInfamy
# --------------------------------------------------
# CIBBL-Achievement-WithLoveFromLustria
# --------------------------------------------------
# CIBBL-Achievement-CavernClimber
# --------------------------------------------------
# CIBBL-Achievement-WastelandWarrior
# --------------------------------------------------
# CIBBL-Achievement-OldWorldValues
# --------------------------------------------------
# CIBBL-Achievement-TimelessDisplay
# --------------------------------------------------
# CIBBL-Achievement-SnakeCharmer
# --------------------------------------------------
# CIBBL-Achievement-DevastationFromBeyond
# --------------------------------------------------
# CIBBL-Achievement-BloodForTheBloodline
# --------------------------------------------------
# CIBBL-Achievement-WaveRider
# --------------------------------------------------
# CIBBL-Achievement-VerdantVibes
# --------------------------------------------------
# CIBBL-Achievement-BloodRage
# --------------------------------------------------
# CIBBL-Achievement-RisingOutOfCarnage
# --------------------------------------------------
# CIBBL-Achievement-AwakenedAtLast
# --------------------------------------------------
# CIBBL-Achievement-The1Percent
# --------------------------------------------------
# CIBBL-Achievement-Pathfinder
# --------------------------------------------------
# CIBBL-Achievement-FlyingColors
# --------------------------------------------------
# CIBBL-Achievement-ASpecialSpecimenIndeed
# --------------------------------------------------
# CIBBL-Achievement-ThumbUp
# --------------------------------------------------
# CIBBL-Achievement-MasterOfTheWhiteGate
# --------------------------------------------------
# CIBBL-Achievement-GutsNGlory
# --------------------------------------------------
# CIBBL-Achievement-Futuristic
# --------------------------------------------------
# CIBBL-Achievement-FinderOfTheWay
# --------------------------------------------------
# CIBBL-Achievement-LordsOfBalanceObsidian
# --------------------------------------------------
# CIBBL-Achievement-CabalVisionRatingAttraction
# --------------------------------------------------
# CIBBL-Achievement-StylePoints
# --------------------------------------------------
# CIBBL-Achievement-MagicMushroomMuncher
# --------------------------------------------------
# CIBBL-Achievement-LordsOfBalancePearl
# --------------------------------------------------
# CIBBL-Achievement-Gargantuan
# --------------------------------------------------
# CIBBL-Achievement-DeathOrGlory
# --------------------------------------------------
# CIBBL-Achievement-AllYouCanEat
# --------------------------------------------------
# CIBBL-Achievement-Escapist
# --------------------------------------------------
# CIBBL-Achievement-SCRIBBLsOutstandingPerformance
# --------------------------------------------------
# CIBBL-Achievement-BlueEagleAscending
# --------------------------------------------------
# CIBBL-Achievement-IceCold
# --------------------------------------------------
# CIBBL-Achievement-Slasher
# --------------------------------------------------
# CIBBL-Achievement-InspiredDrinker
# --------------------------------------------------
# CIBBL-Achievement-AltdorfCollegeHonoraryGraduate
# --------------------------------------------------
# CIBBL-Achievement-NotWithAWhimperButWithABang
# --------------------------------------------------
# CIBBL-Achievement-WakeUpCall
# --------------------------------------------------
# CIBBL-Achievement-PromiseOfGreatness
# --------------------------------------------------
# CIBBL-Achievement-MarkOfTheDragon
# --------------------------------------------------
# CIBBL-Achievement-NufflesBlessing
# --------------------------------------------------
# CIBBL-Achievement-ExemplarOfGlory
# --------------------------------------------------
# CIBBL-Achievement-Eternal
# --------------------------------------------------
# CIBBL-Achievement-MasterOfTheBlackGate
# --------------------------------------------------
# CIBBL-Achievement-GrowthPotential
# --------------------------------------------------
# CIBBL-Achievement-BlitzingBeauty
# --------------------------------------------------
# CIBBL-Achievement-Sleepless
# --------------------------------------------------
# CIBBL-Achievement-SippingTheWitchesBrew
# --------------------------------------------------
# CIBBL-Achievement-FungusSupreme
# --------------------------------------------------
# CIBBL-Achievement-FirstTry
# --------------------------------------------------
# CIBBL-Achievement-LeatherRebel
# --------------------------------------------------
# CIBBL-Achievement-TerrificMightOfTin
# --------------------------------------------------
# CIBBL-Achievement-SilverExcellence
# --------------------------------------------------
# CIBBL-Achievement-BronzeExcellence
# --------------------------------------------------
# CIBBL-Achievement-GoldExcellence
# --------------------------------------------------
# CIBBL-Achievement-DustDevil
# --------------------------------------------------
# CIBBL-Achievement-StickInTheMud
# --------------------------------------------------
# CIBBL-Achievement-RefinedExcellence
# --------------------------------------------------
# CIBBL-Achievement-CopperExcellence
# --------------------------------------------------
# CIBBL-Achievement-ClothExcellence
# --------------------------------------------------
# CIBBL-Achievement-SolidFoundation
# --------------------------------------------------
# CIBBL-Achievement-ClayExcellence
# --------------------------------------------------
# CIBBL-Achievement-ExcellentOnPaper
# --------------------------------------------------
# CIBBL-Achievement-ForgedGreatness
# --------------------------------------------------
# CIBBL-Achievement-WhispererInTheWoods
# --------------------------------------------------
# CIBBL-Achievement-YouthfulVibrance
# --------------------------------------------------
# CIBBL-Achievement-StarPlayer
# --------------------------------------------------
# --------------------------------------------------
# CIBBL-Achievement-MegaStarPlayer
# --------------------------------------------------
# --------------------------------------------------
# CIBBL-Achievement-SuperStarPlayer
# --------------------------------------------------
# --------------------------------------------------
# CIBBL-Achievement-Legend
# --------------------------------------------------
# --------------------------------------------------

# %%
print("-"*50)
for bracket, clss in playerac.items():
    for cls in clss:
        D = cls.defaultconfig_of_group(G)
        C = D._data
        aname = C.get("camelcasename",cls.__name__.split("_")[1])
        pagename = f'CIBBL-Achievement-{aname}'
        print(pagename)
        print("-"*50)
        if aname in {"BewareSupremeKiller", "TargetEliminated", "FameKiller"}:
            m0 = cls.__members__.values()
            m1 = sorted(m0, key=lambda a: (a.season.year.nr, a.season.nr, int(a.tournament.Id), a.subject))
            rows = []
            header = ["Tournament", "Match", "Player", "Position", "Team", "Prestige", "Status", "Victim"]
            header = [w.b(s) for s in header]
            align = "CCCCCCCC"
            rows = []
            for a in m0:
                if "transferred" in a["status"]:
                    continue
                if "proposed" in a["status"]:
                    continue
                if Se < a.tournament.season:
                    continue
                date = f'Y{a.season.year.nr} {a.season.name}'
                date = f'Y{a.season.year.nr} {a.season.name}'
                tournamentname = trim_tournament_name(a.tournament.shortname)
                tournament = w.tournament(a.tournament, tournamentname)
                stournament = f'{date}{w.br()}{w.i(tournament)}'
                team = et.team(a)
                scores = copy.copy(a.match.scores())
                teamofmatch = et.teamofmatch(a)
                oppoteam = et.oppoteam(a, team_=teamofmatch)
                if teamofmatch is None:
                    coach = ""
                    sscores = "?"              
                else:
                    coach = w.url(f'https://fumbbl.com/~{teamofmatch.coach_name}', teamofmatch.coach_name)
                    try:
                        sscores = f'{scores[teamofmatch]}-{scores[oppoteam]}'              
                    except KeyError:
                        sscores = ""
                if team == teamofmatch and hasattr(teamofmatch, "roster_name"):
                    roster = teamofmatch.roster_name
                elif team == "Star Player":
                    roster = team
                    team = teamofmatch
                else:
                    roster = ""
                match = w.url(f'https://fumbbl.com/p/match?id={a.match.Id}', sscores)
                prestige = a.prestige(season=Se)
                player_ = a.subject
                position = playerpositonnames[player_]
                status = playerstatuses[player_]
                if status == "Dead" and player_.nexts:
                    status = "Transf."
                elif player_ in deadstars:
                    status = "Dead"
                splayer = f'{w.player(player_)}'
                sroster = f'{roster}{w.br()}{w.i(position)}'
                steam = f'{w.team(team)}{w.br()}{w.i("(" + coach + ")")}'
                victim = a.victim
                svictim = f'{w.player(victim)}'
                rows.append([stournament, match, splayer, sroster, steam, prestige, status, svictim]) 
            stable = w.table(rows, header=header, align=align)
            parts = [
                "{center\n[https://fumbbl.com/i/646337]%%%\n}",
                w.dualcolumn(getcontent(cls), ""),
                stable,
                "",
            ]
            content = f'\n\n{w.br()}\n\n'.join(parts)
            #print(content)
            print("-"*50)
            cibblbibbl.session.helppage.edit(pagename, content) # uncomment to publish
# Out:
# --------------------------------------------------
# CIBBL-Achievement-TargetEliminated
# --------------------------------------------------
# --------------------------------------------------
# CIBBL-Achievement-MeanScoringMachine
# --------------------------------------------------
# CIBBL-Achievement-AerodynamicAim
# --------------------------------------------------
# CIBBL-Achievement-BewareSupremeKiller
# --------------------------------------------------
# --------------------------------------------------
# CIBBL-Achievement-TripleX
# --------------------------------------------------
# CIBBL-Achievement-Perfection
# --------------------------------------------------
# CIBBL-Achievement-FameKiller
# --------------------------------------------------
# --------------------------------------------------
# CIBBL-Achievement-ChildOfWinter
# --------------------------------------------------
# CIBBL-Achievement-GreatestOfVileVermin
# --------------------------------------------------
# CIBBL-Achievement-NorthernProwess
# --------------------------------------------------
# CIBBL-Achievement-SpillBloodAndRageOn
# --------------------------------------------------
# CIBBL-Achievement-BullsEye
# --------------------------------------------------
# CIBBL-Achievement-OrientalAesthetics
# --------------------------------------------------
# CIBBL-Achievement-TurnItUpToEleven
# --------------------------------------------------
# CIBBL-Achievement-ElementalMyDear
# --------------------------------------------------
# CIBBL-Achievement-SouthlandSalvation
# --------------------------------------------------
# CIBBL-Achievement-BugmansFinest
# --------------------------------------------------
# CIBBL-Achievement-Horrific
# --------------------------------------------------
# CIBBL-Achievement-EmpiresFameInfamy
# --------------------------------------------------
# CIBBL-Achievement-WithLoveFromLustria
# --------------------------------------------------
# CIBBL-Achievement-CavernClimber
# --------------------------------------------------
# CIBBL-Achievement-WastelandWarrior
# --------------------------------------------------
# CIBBL-Achievement-OldWorldValues
# --------------------------------------------------
# CIBBL-Achievement-TimelessDisplay
# --------------------------------------------------
# CIBBL-Achievement-SnakeCharmer
# --------------------------------------------------
# CIBBL-Achievement-DevastationFromBeyond
# --------------------------------------------------
# CIBBL-Achievement-BloodForTheBloodline
# --------------------------------------------------
# CIBBL-Achievement-WaveRider
# --------------------------------------------------
# CIBBL-Achievement-VerdantVibes
# --------------------------------------------------
# CIBBL-Achievement-BloodRage
# --------------------------------------------------
# CIBBL-Achievement-RisingOutOfCarnage
# --------------------------------------------------
# CIBBL-Achievement-AwakenedAtLast
# --------------------------------------------------
# CIBBL-Achievement-The1Percent
# --------------------------------------------------
# CIBBL-Achievement-Pathfinder
# --------------------------------------------------
# CIBBL-Achievement-FlyingColors
# --------------------------------------------------
# CIBBL-Achievement-ASpecialSpecimenIndeed
# --------------------------------------------------
# CIBBL-Achievement-ThumbUp
# --------------------------------------------------
# CIBBL-Achievement-MasterOfTheWhiteGate
# --------------------------------------------------
# CIBBL-Achievement-GutsNGlory
# --------------------------------------------------
# CIBBL-Achievement-Futuristic
# --------------------------------------------------
# CIBBL-Achievement-FinderOfTheWay
# --------------------------------------------------
# CIBBL-Achievement-LordsOfBalanceObsidian
# --------------------------------------------------
# CIBBL-Achievement-CabalVisionRatingAttraction
# --------------------------------------------------
# CIBBL-Achievement-StylePoints
# --------------------------------------------------
# CIBBL-Achievement-MagicMushroomMuncher
# --------------------------------------------------
# CIBBL-Achievement-LordsOfBalancePearl
# --------------------------------------------------
# CIBBL-Achievement-Gargantuan
# --------------------------------------------------
# CIBBL-Achievement-DeathOrGlory
# --------------------------------------------------
# CIBBL-Achievement-AllYouCanEat
# --------------------------------------------------
# CIBBL-Achievement-Escapist
# --------------------------------------------------
# CIBBL-Achievement-SCRIBBLsOutstandingPerformance
# --------------------------------------------------
# CIBBL-Achievement-BlueEagleAscending
# --------------------------------------------------
# CIBBL-Achievement-IceCold
# --------------------------------------------------
# CIBBL-Achievement-Slasher
# --------------------------------------------------
# CIBBL-Achievement-InspiredDrinker
# --------------------------------------------------
# CIBBL-Achievement-AltdorfCollegeHonoraryGraduate
# --------------------------------------------------
# CIBBL-Achievement-NotWithAWhimperButWithABang
# --------------------------------------------------
# CIBBL-Achievement-WakeUpCall
# --------------------------------------------------
# CIBBL-Achievement-PromiseOfGreatness
# --------------------------------------------------
# CIBBL-Achievement-MarkOfTheDragon
# --------------------------------------------------
# CIBBL-Achievement-NufflesBlessing
# --------------------------------------------------
# CIBBL-Achievement-ExemplarOfGlory
# --------------------------------------------------
# CIBBL-Achievement-Eternal
# --------------------------------------------------
# CIBBL-Achievement-MasterOfTheBlackGate
# --------------------------------------------------
# CIBBL-Achievement-GrowthPotential
# --------------------------------------------------
# CIBBL-Achievement-BlitzingBeauty
# --------------------------------------------------
# CIBBL-Achievement-Sleepless
# --------------------------------------------------
# CIBBL-Achievement-SippingTheWitchesBrew
# --------------------------------------------------
# CIBBL-Achievement-FungusSupreme
# --------------------------------------------------
# CIBBL-Achievement-FirstTry
# --------------------------------------------------
# CIBBL-Achievement-LeatherRebel
# --------------------------------------------------
# CIBBL-Achievement-TerrificMightOfTin
# --------------------------------------------------
# CIBBL-Achievement-SilverExcellence
# --------------------------------------------------
# CIBBL-Achievement-BronzeExcellence
# --------------------------------------------------
# CIBBL-Achievement-GoldExcellence
# --------------------------------------------------
# CIBBL-Achievement-DustDevil
# --------------------------------------------------
# CIBBL-Achievement-StickInTheMud
# --------------------------------------------------
# CIBBL-Achievement-RefinedExcellence
# --------------------------------------------------
# CIBBL-Achievement-CopperExcellence
# --------------------------------------------------
# CIBBL-Achievement-ClothExcellence
# --------------------------------------------------
# CIBBL-Achievement-SolidFoundation
# --------------------------------------------------
# CIBBL-Achievement-ClayExcellence
# --------------------------------------------------
# CIBBL-Achievement-ExcellentOnPaper
# --------------------------------------------------
# CIBBL-Achievement-ForgedGreatness
# --------------------------------------------------
# CIBBL-Achievement-WhispererInTheWoods
# --------------------------------------------------
# CIBBL-Achievement-YouthfulVibrance
# --------------------------------------------------
# CIBBL-Achievement-StarPlayer
# --------------------------------------------------
# CIBBL-Achievement-MegaStarPlayer
# --------------------------------------------------
# CIBBL-Achievement-SuperStarPlayer
# --------------------------------------------------
# CIBBL-Achievement-Legend
# --------------------------------------------------

# %%
print("-"*50)
for bracket, clss in playerac.items():
    for cls in clss:
        D = cls.defaultconfig_of_group(G)
        C = D._data
        aname = C.get("camelcasename",cls.__name__.split("_")[1])
        pagename = f'CIBBL-Achievement-{aname}'
        code = C.get("code")
        if code:
            print(cls)
# Out:
# --------------------------------------------------
# <class 'cibblbibbl.achievement.pa_bp.PA_BP_ChildOfWinter'>
# <class 'cibblbibbl.achievement.pa_bp.PA_BP_GreatestOfVileVermin'>
# <class 'cibblbibbl.achievement.pa_bp.PA_BP_NorthernProwess'>
# <class 'cibblbibbl.achievement.pa_bp.PA_BP_SpillBloodAndRageOn'>
# <class 'cibblbibbl.achievement.pa_bp.PA_BP_BullsEye'>
# <class 'cibblbibbl.achievement.pa_bp.PA_BP_OrientalAesthetics'>
# <class 'cibblbibbl.achievement.pa_bp.PA_BP_TurnItUpToEleven'>
# <class 'cibblbibbl.achievement.pa_bp.PA_BP_ElementalMyDear'>
# <class 'cibblbibbl.achievement.pa_bp.PA_BP_SouthlandSalvation'>
# <class 'cibblbibbl.achievement.pa_bp.PA_BP_BugmansFinest'>
# <class 'cibblbibbl.achievement.pa_bp.PA_BP_Horrific'>
# <class 'cibblbibbl.achievement.pa_bp.PA_BP_EmpiresFameInfamy'>
# <class 'cibblbibbl.achievement.pa_bp.PA_BP_WithLoveFromLustria'>
# <class 'cibblbibbl.achievement.pa_bp.PA_BP_CavernClimber'>
# <class 'cibblbibbl.achievement.pa_bp.PA_BP_WastelandWarrior'>
# <class 'cibblbibbl.achievement.pa_bp.PA_BP_OldWorldValues'>
# <class 'cibblbibbl.achievement.pa_bp.PA_BP_TimelessDisplay'>
# <class 'cibblbibbl.achievement.pa_bp.PA_BP_SnakeCharmer'>
# <class 'cibblbibbl.achievement.pa_bp.PA_BP_DevastationFromBeyond'>
# <class 'cibblbibbl.achievement.pa_bp.PA_BP_BloodForTheBloodline'>
# <class 'cibblbibbl.achievement.pa_bp.PA_BP_WaveRider'>
# <class 'cibblbibbl.achievement.pa_bp.PA_BP_VerdantVibes'>
# <class 'cibblbibbl.achievement.pa_bp.PA_BP_BloodRage'>
# <class 'cibblbibbl.achievement.pa_bp.PA_BP_RisingOutOfCarnage'>
# <class 'cibblbibbl.achievement.pa_bp.PA_BP_AwakenedAtLast'>
# <class 'cibblbibbl.achievement.pa_bp.PA_BP_The1Percent'>
# <class 'cibblbibbl.achievement.pa_bp.PA_BP_Pathfinder'>
# <class 'cibblbibbl.achievement.pa_bp.PA_BP_FlyingColors'>
# <class 'cibblbibbl.achievement.pa_bp.PA_BP_ASpecialSpecimenIndeed'>
# <class 'cibblbibbl.achievement.pa_bp.PA_BP_ThumbUp'>
# <class 'cibblbibbl.achievement.pa_bp.PA_BP_MasterOfTheWhiteGate'>
# <class 'cibblbibbl.achievement.pa_bp.PA_BP_Futuristic'>
# <class 'cibblbibbl.achievement.pa_bp.PA_BP_FinderOfTheWay'>
# <class 'cibblbibbl.achievement.pa_bp.PA_BP_LordsOfBalanceObsidian'>
# <class 'cibblbibbl.achievement.pa_bp.PA_BP_CabalVisionRatingAttraction'>
# <class 'cibblbibbl.achievement.pa_bp.PA_BP_StylePoints'>
# <class 'cibblbibbl.achievement.pa_bp.PA_BP_MagicMushroomMuncher'>
# <class 'cibblbibbl.achievement.pa_bp.PA_BP_LordsOfBalancePearl'>
# <class 'cibblbibbl.achievement.pa_bp.PA_BP_Gargantuan'>
# <class 'cibblbibbl.achievement.pa_bp.PA_BP_DeathOrGlory'>
# <class 'cibblbibbl.achievement.pa_bp.PA_BP_AllYouCanEat'>
# <class 'cibblbibbl.achievement.pa_bp.PA_BP_Escapist'>
# <class 'cibblbibbl.achievement.pa_bp.PA_BP_SCRIBBLsOutstandingPerformance'>
# <class 'cibblbibbl.achievement.pa_bp.PA_BP_BlueEagleAscending'>
# <class 'cibblbibbl.achievement.pa_bp.PA_BP_IceCold'>
# <class 'cibblbibbl.achievement.pa_bp.PA_BP_Slasher'>
# <class 'cibblbibbl.achievement.pa_bp.PA_BP_InspiredDrinker'>
# <class 'cibblbibbl.achievement.pa_bp.PA_BP_AltdorfCollegeHonoraryGraduate'>
# <class 'cibblbibbl.achievement.pa_bp.PA_BP_NotWithAWhimperButWithABang'>
# <class 'cibblbibbl.achievement.pa_bp.PA_BP_WakeUpCall'>
# <class 'cibblbibbl.achievement.pa_bp.PA_BP_PromiseOfGreatness'>
# <class 'cibblbibbl.achievement.pa_bp.PA_BP_MarkOfTheDragon'>
# <class 'cibblbibbl.achievement.pa_bp.PA_BP_NufflesBlessing'>
# <class 'cibblbibbl.achievement.pa_bp.PA_BP_ExemplarOfGlory'>
# <class 'cibblbibbl.achievement.pa_bp.PA_BP_Eternal'>
# <class 'cibblbibbl.achievement.pa_bp.PA_BP_MasterOfTheBlackGate'>
# <class 'cibblbibbl.achievement.pa_bp.PA_BP_GrowthPotential'>
# <class 'cibblbibbl.achievement.pa_bp.PA_BP_BlitzingBeauty'>
# <class 'cibblbibbl.achievement.pa_bp.PA_BP_Sleepless'>
# <class 'cibblbibbl.achievement.pa_bp.PA_BP_SippingTheWitchesBrew'>
# <class 'cibblbibbl.achievement.pa_bp.PA_BP_FungusSupreme'>
# <class 'cibblbibbl.achievement.pa_bp.PA_BP_FirstTry'>
# <class 'cibblbibbl.achievement.pa_bp.PA_BP_LeatherRebel'>
# <class 'cibblbibbl.achievement.pa_bp.PA_BP_TerrificMightOfTin'>
# <class 'cibblbibbl.achievement.pa_bp.PA_BP_SilverExcellence'>
# <class 'cibblbibbl.achievement.pa_bp.PA_BP_BronzeExcellence'>
# <class 'cibblbibbl.achievement.pa_bp.PA_BP_GoldExcellence'>
# <class 'cibblbibbl.achievement.pa_bp.PA_BP_DustDevil'>
# <class 'cibblbibbl.achievement.pa_bp.PA_BP_StickInTheMud'>
# <class 'cibblbibbl.achievement.pa_bp.PA_BP_RefinedExcellence'>
# <class 'cibblbibbl.achievement.pa_bp.PA_BP_CopperExcellence'>
# <class 'cibblbibbl.achievement.pa_bp.PA_BP_ClothExcellence'>
# <class 'cibblbibbl.achievement.pa_bp.PA_BP_SolidFoundation'>
# <class 'cibblbibbl.achievement.pa_bp.PA_BP_ClayExcellence'>
# <class 'cibblbibbl.achievement.pa_bp.PA_BP_ExcellentOnPaper'>
# <class 'cibblbibbl.achievement.pa_bp.PA_BP_ForgedGreatness'>
# <class 'cibblbibbl.achievement.pa_bp.PA_BP_WhispererInTheWoods'>
# <class 'cibblbibbl.achievement.pa_bp.PA_BP_YouthfulVibrance'>

# %%
print("-"*50)
for bracket, clss in playerac.items():
    for cls in clss:
        D = cls.defaultconfig_of_group(G)
        C = D._data
        aname = C.get("camelcasename",cls.__name__.split("_")[1])
        pagename = f'CIBBL-Achievement-{aname}'
        print(pagename)
        print("-"*50)
        code = C.get("code")
        if code:
            m0 = cls.__members__.values()
            m1 = sorted(m0, key=lambda a: (a.season.year.nr, a.season.nr, int(a.tournament.Id), a.subject))
            rows = []
            header = ["Tournament", "Player", "Position", "Team", "Prestige", "Status", "Categories"]
            header = [w.b(s) for s in header]
            align = "CCCCCCC"
            rows = []
            for a in m0:
                if "transferred" in a["status"]:
                    continue
                if "proposed" in a["status"]:
                    continue
                if Se < a.tournament.season:
                    continue
                date = f'Y{a.season.year.nr} {a.season.name}'
                date = f'Y{a.season.year.nr} {a.season.name}'
                tournamentname = trim_tournament_name(a.tournament.shortname)
                tournament = w.tournament(a.tournament, tournamentname)
                stournament = f'{date}{w.br()}{w.i(tournament)}'
                team = et.team(a)                   
                if team is None:
                    coach = ""
                elif isinstance(team, str):
                    coach = ""
                    steam = ""
                else:
                    coach = w.url(f'https://fumbbl.com/~{team.coach_name}', team.coach_name)
                    steam = f'{w.team(team)}{w.br()}{w.i("(" + coach + ")")}'
                if hasattr(team, "roster_name"):
                    roster = team.roster_name
                elif team == "Star Player":
                    roster = team
                    team = ""
                    steam = ""
                else:
                    roster = ""
                prestige = a.prestige(season=Se)
                player_ = a.subject
                position = playerpositonnames[player_]
                status = playerstatuses[player_]
                if status == "Dead" and player_.nexts:
                    status = "Transf."
                elif player_ in deadstars:
                    status = "Dead"
                splayer = f'{w.player(player_)}'
                sroster = f'{roster}{w.br()}{w.i(position)}'
                categs = a["categs"]
                scategs = f',{w.br()}'.join(categs)
                rows.append([stournament, splayer, sroster, steam, prestige, status, scategs]) 
            stable = w.table(rows, header=header, align=align)
            parts = [
                "{center\n[https://fumbbl.com/i/646337]%%%\n}",
                w.dualcolumn(getcontent(cls), ""),
                stable,
                "",
            ]
            content = f'\n\n{w.br()}\n\n'.join(parts)
            #print(content)
            print("-"*50)
            cibblbibbl.session.helppage.edit(pagename, content) # uncomment to publish
# Out:
# --------------------------------------------------
# CIBBL-Achievement-TargetEliminated
# --------------------------------------------------
# CIBBL-Achievement-MeanScoringMachine
# --------------------------------------------------
# CIBBL-Achievement-AerodynamicAim
# --------------------------------------------------
# CIBBL-Achievement-BewareSupremeKiller
# --------------------------------------------------
# CIBBL-Achievement-TripleX
# --------------------------------------------------
# CIBBL-Achievement-Perfection
# --------------------------------------------------
# CIBBL-Achievement-FameKiller
# --------------------------------------------------
# CIBBL-Achievement-ChildOfWinter
# --------------------------------------------------
# --------------------------------------------------
# CIBBL-Achievement-GreatestOfVileVermin
# --------------------------------------------------
# --------------------------------------------------
# CIBBL-Achievement-NorthernProwess
# --------------------------------------------------
# --------------------------------------------------
# CIBBL-Achievement-SpillBloodAndRageOn
# --------------------------------------------------
# --------------------------------------------------
# CIBBL-Achievement-BullsEye
# --------------------------------------------------
# --------------------------------------------------
# CIBBL-Achievement-OrientalAesthetics
# --------------------------------------------------
# --------------------------------------------------
# CIBBL-Achievement-TurnItUpToEleven
# --------------------------------------------------
# --------------------------------------------------
# CIBBL-Achievement-ElementalMyDear
# --------------------------------------------------
# --------------------------------------------------
# CIBBL-Achievement-SouthlandSalvation
# --------------------------------------------------
# --------------------------------------------------
# CIBBL-Achievement-BugmansFinest
# --------------------------------------------------
# --------------------------------------------------
# CIBBL-Achievement-Horrific
# --------------------------------------------------
# --------------------------------------------------
# CIBBL-Achievement-EmpiresFameInfamy
# --------------------------------------------------
# --------------------------------------------------
# CIBBL-Achievement-WithLoveFromLustria
# --------------------------------------------------
# --------------------------------------------------
# CIBBL-Achievement-CavernClimber
# --------------------------------------------------
# --------------------------------------------------
# CIBBL-Achievement-WastelandWarrior
# --------------------------------------------------
# --------------------------------------------------
# CIBBL-Achievement-OldWorldValues
# --------------------------------------------------
# --------------------------------------------------
# CIBBL-Achievement-TimelessDisplay
# --------------------------------------------------
# --------------------------------------------------
# CIBBL-Achievement-SnakeCharmer
# --------------------------------------------------
# --------------------------------------------------
# CIBBL-Achievement-DevastationFromBeyond
# --------------------------------------------------
# --------------------------------------------------
# CIBBL-Achievement-BloodForTheBloodline
# --------------------------------------------------
# --------------------------------------------------
# CIBBL-Achievement-WaveRider
# --------------------------------------------------
# --------------------------------------------------
# CIBBL-Achievement-VerdantVibes
# --------------------------------------------------
# --------------------------------------------------
# CIBBL-Achievement-BloodRage
# --------------------------------------------------
# --------------------------------------------------
# CIBBL-Achievement-RisingOutOfCarnage
# --------------------------------------------------
# --------------------------------------------------
# CIBBL-Achievement-AwakenedAtLast
# --------------------------------------------------
# --------------------------------------------------
# CIBBL-Achievement-The1Percent
# --------------------------------------------------
# --------------------------------------------------
# CIBBL-Achievement-Pathfinder
# --------------------------------------------------
# --------------------------------------------------
# CIBBL-Achievement-FlyingColors
# --------------------------------------------------
# --------------------------------------------------
# CIBBL-Achievement-ASpecialSpecimenIndeed
# --------------------------------------------------
# --------------------------------------------------
# CIBBL-Achievement-ThumbUp
# --------------------------------------------------
# --------------------------------------------------
# CIBBL-Achievement-MasterOfTheWhiteGate
# --------------------------------------------------
# --------------------------------------------------
# CIBBL-Achievement-GutsNGlory
# --------------------------------------------------
# CIBBL-Achievement-Futuristic
# --------------------------------------------------
# --------------------------------------------------
# CIBBL-Achievement-FinderOfTheWay
# --------------------------------------------------
# --------------------------------------------------
# CIBBL-Achievement-LordsOfBalanceObsidian
# --------------------------------------------------
# --------------------------------------------------
# CIBBL-Achievement-CabalVisionRatingAttraction
# --------------------------------------------------
# --------------------------------------------------
# CIBBL-Achievement-StylePoints
# --------------------------------------------------
# --------------------------------------------------
# CIBBL-Achievement-MagicMushroomMuncher
# --------------------------------------------------
# --------------------------------------------------
# CIBBL-Achievement-LordsOfBalancePearl
# --------------------------------------------------
# --------------------------------------------------
# CIBBL-Achievement-Gargantuan
# --------------------------------------------------
# --------------------------------------------------
# CIBBL-Achievement-DeathOrGlory
# --------------------------------------------------
# --------------------------------------------------
# CIBBL-Achievement-AllYouCanEat
# --------------------------------------------------
# --------------------------------------------------
# CIBBL-Achievement-Escapist
# --------------------------------------------------
# --------------------------------------------------
# CIBBL-Achievement-SCRIBBLsOutstandingPerformance
# --------------------------------------------------
# --------------------------------------------------
# CIBBL-Achievement-BlueEagleAscending
# --------------------------------------------------
# --------------------------------------------------
# CIBBL-Achievement-IceCold
# --------------------------------------------------
# --------------------------------------------------
# CIBBL-Achievement-Slasher
# --------------------------------------------------
# --------------------------------------------------
# CIBBL-Achievement-InspiredDrinker
# --------------------------------------------------
# --------------------------------------------------
# CIBBL-Achievement-AltdorfCollegeHonoraryGraduate
# --------------------------------------------------
# --------------------------------------------------
# CIBBL-Achievement-NotWithAWhimperButWithABang
# --------------------------------------------------
# --------------------------------------------------
# CIBBL-Achievement-WakeUpCall
# --------------------------------------------------
# --------------------------------------------------
# CIBBL-Achievement-PromiseOfGreatness
# --------------------------------------------------
# --------------------------------------------------
# CIBBL-Achievement-MarkOfTheDragon
# --------------------------------------------------
# --------------------------------------------------
# CIBBL-Achievement-NufflesBlessing
# --------------------------------------------------
# --------------------------------------------------
# CIBBL-Achievement-ExemplarOfGlory
# --------------------------------------------------
# --------------------------------------------------
# CIBBL-Achievement-Eternal
# --------------------------------------------------
# --------------------------------------------------
# CIBBL-Achievement-MasterOfTheBlackGate
# --------------------------------------------------
# --------------------------------------------------
# CIBBL-Achievement-GrowthPotential
# --------------------------------------------------
# --------------------------------------------------
# CIBBL-Achievement-BlitzingBeauty
# --------------------------------------------------
# --------------------------------------------------
# CIBBL-Achievement-Sleepless
# --------------------------------------------------
# --------------------------------------------------
# CIBBL-Achievement-SippingTheWitchesBrew
# --------------------------------------------------
# --------------------------------------------------
# CIBBL-Achievement-FungusSupreme
# --------------------------------------------------
# --------------------------------------------------
# CIBBL-Achievement-FirstTry
# --------------------------------------------------
# --------------------------------------------------
# CIBBL-Achievement-LeatherRebel
# --------------------------------------------------
# --------------------------------------------------
# CIBBL-Achievement-TerrificMightOfTin
# --------------------------------------------------
# --------------------------------------------------
# CIBBL-Achievement-SilverExcellence
# --------------------------------------------------
# --------------------------------------------------
# CIBBL-Achievement-BronzeExcellence
# --------------------------------------------------
# --------------------------------------------------
# CIBBL-Achievement-GoldExcellence
# --------------------------------------------------
# --------------------------------------------------
# CIBBL-Achievement-DustDevil
# --------------------------------------------------
# --------------------------------------------------
# CIBBL-Achievement-StickInTheMud
# --------------------------------------------------
# --------------------------------------------------
# CIBBL-Achievement-RefinedExcellence
# --------------------------------------------------
# --------------------------------------------------
# CIBBL-Achievement-CopperExcellence
# --------------------------------------------------
# --------------------------------------------------
# CIBBL-Achievement-ClothExcellence
# --------------------------------------------------
# --------------------------------------------------
# CIBBL-Achievement-SolidFoundation
# --------------------------------------------------
# --------------------------------------------------
# CIBBL-Achievement-ClayExcellence
# --------------------------------------------------
# --------------------------------------------------
# CIBBL-Achievement-ExcellentOnPaper
# --------------------------------------------------
# --------------------------------------------------
# CIBBL-Achievement-ForgedGreatness
# --------------------------------------------------
# --------------------------------------------------
# CIBBL-Achievement-WhispererInTheWoods
# --------------------------------------------------
# --------------------------------------------------
# CIBBL-Achievement-YouthfulVibrance
# --------------------------------------------------
# --------------------------------------------------
# CIBBL-Achievement-StarPlayer
# --------------------------------------------------
# CIBBL-Achievement-MegaStarPlayer
# --------------------------------------------------
# CIBBL-Achievement-SuperStarPlayer
# --------------------------------------------------
# CIBBL-Achievement-Legend
# --------------------------------------------------

# %%
print("-"*50)
for bracket, clss in playerac.items():
    for cls in clss:
        D = cls.defaultconfig_of_group(G)
        C = D._data
        aname = C.get("camelcasename",cls.__name__.split("_")[1])
        pagename = f'CIBBL-Achievement-{aname}'
        print(pagename)
        print("-"*50)
        code = C.get("code")
        if aname in {"GutsNGlory"}:
            m0 = cls.__members__.values()
            m1 = sorted(m0, key=lambda a: (a.season.year.nr, a.season.nr, int(a.tournament.Id), a.subject))
            rows = []
            header = ["Tournament", "Player", "Position", "Team", "Prestige", "Status"]
            header = [w.b(s) for s in header]
            align = "CCCCCC"
            rows = []
            for a in m0:
                if "transferred" in a["status"]:
                    continue
                if "proposed" in a["status"]:
                    continue
                if Se < a.tournament.season:
                    continue
                date = f'Y{a.season.year.nr} {a.season.name}'
                date = f'Y{a.season.year.nr} {a.season.name}'
                tournamentname = trim_tournament_name(a.tournament.shortname)
                tournament = w.tournament(a.tournament, tournamentname)
                stournament = f'{date}{w.br()}{w.i(tournament)}'
                team = et.team(a)                   
                if team is None:
                    coach = ""
                elif isinstance(team, str):
                    coach = ""
                    steam = ""
                else:
                    coach = w.url(f'https://fumbbl.com/~{team.coach_name}', team.coach_name)
                    steam = f'{w.team(team)}{w.br()}{w.i("(" + coach + ")")}'
                if hasattr(team, "roster_name"):
                    roster = team.roster_name
                elif team == "Star Player":
                    roster = team
                    team = ""
                    steam = ""
                else:
                    roster = ""
                prestige = a.prestige(season=Se)
                player_ = a.subject
                position = playerpositonnames[player_]
                status = playerstatuses[player_]
                if status == "Dead" and player_.nexts:
                    status = "Transf."
                elif player_ in deadstars:
                    status = "Dead"
                splayer = f'{w.player(player_)}'
                sroster = f'{roster}{w.br()}{w.i(position)}'
                rows.append([stournament, splayer, sroster, steam, prestige, status]) 
            stable = w.table(rows, header=header, align=align)
            parts = [
                "{center\n[https://fumbbl.com/i/646337]%%%\n}",
                w.dualcolumn(getcontent(cls), ""),
                stable,
                "",
            ]
            content = f'\n\n{w.br()}\n\n'.join(parts)
            print(content)
            print("-"*50)
            cibblbibbl.session.helppage.edit(pagename, content) # uncomment to publish
# Out:
# --------------------------------------------------
# CIBBL-Achievement-TargetEliminated
# --------------------------------------------------
# CIBBL-Achievement-MeanScoringMachine
# --------------------------------------------------
# CIBBL-Achievement-AerodynamicAim
# --------------------------------------------------
# CIBBL-Achievement-BewareSupremeKiller
# --------------------------------------------------
# CIBBL-Achievement-TripleX
# --------------------------------------------------
# CIBBL-Achievement-Perfection
# --------------------------------------------------
# CIBBL-Achievement-FameKiller
# --------------------------------------------------
# CIBBL-Achievement-ChildOfWinter
# --------------------------------------------------
# CIBBL-Achievement-GreatestOfVileVermin
# --------------------------------------------------
# CIBBL-Achievement-NorthernProwess
# --------------------------------------------------
# CIBBL-Achievement-SpillBloodAndRageOn
# --------------------------------------------------
# CIBBL-Achievement-BullsEye
# --------------------------------------------------
# CIBBL-Achievement-OrientalAesthetics
# --------------------------------------------------
# CIBBL-Achievement-TurnItUpToEleven
# --------------------------------------------------
# CIBBL-Achievement-ElementalMyDear
# --------------------------------------------------
# CIBBL-Achievement-SouthlandSalvation
# --------------------------------------------------
# CIBBL-Achievement-BugmansFinest
# --------------------------------------------------
# CIBBL-Achievement-Horrific
# --------------------------------------------------
# CIBBL-Achievement-EmpiresFameInfamy
# --------------------------------------------------
# CIBBL-Achievement-WithLoveFromLustria
# --------------------------------------------------
# CIBBL-Achievement-CavernClimber
# --------------------------------------------------
# CIBBL-Achievement-WastelandWarrior
# --------------------------------------------------
# CIBBL-Achievement-OldWorldValues
# --------------------------------------------------
# CIBBL-Achievement-TimelessDisplay
# --------------------------------------------------
# CIBBL-Achievement-SnakeCharmer
# --------------------------------------------------
# CIBBL-Achievement-DevastationFromBeyond
# --------------------------------------------------
# CIBBL-Achievement-BloodForTheBloodline
# --------------------------------------------------
# CIBBL-Achievement-WaveRider
# --------------------------------------------------
# CIBBL-Achievement-VerdantVibes
# --------------------------------------------------
# CIBBL-Achievement-BloodRage
# --------------------------------------------------
# CIBBL-Achievement-RisingOutOfCarnage
# --------------------------------------------------
# CIBBL-Achievement-AwakenedAtLast
# --------------------------------------------------
# CIBBL-Achievement-The1Percent
# --------------------------------------------------
# CIBBL-Achievement-Pathfinder
# --------------------------------------------------
# CIBBL-Achievement-FlyingColors
# --------------------------------------------------
# CIBBL-Achievement-ASpecialSpecimenIndeed
# --------------------------------------------------
# CIBBL-Achievement-ThumbUp
# --------------------------------------------------
# CIBBL-Achievement-MasterOfTheWhiteGate
# --------------------------------------------------
# CIBBL-Achievement-GutsNGlory
# --------------------------------------------------
# {center
# [https://fumbbl.com/i/646337]%%%
# }
#
# %%%
#
# <<<
#
# [https://fumbbl.com/i/513702]%%%
# __Guts 'n Glory__%%%
# ''Awarded to Dauntless player who earned most SPP in the Heart of Glory tournament. Worth 10 Prestige Points to the team as long as that player is on the team.''
#
# |||
#
#
#
# >>>
#
# %%%
#
# |^ __Tournament__ |^ __Player__ |^ __Position__ |^ __Team__ |^ __Prestige__ |^ __Status__
# |^ Y1 Summer%%%''[Heart of Glory | https://fumbbl.com/FUMBBL.php?page=group&op=view&showallrounds=1&at=1&group=10455&p=tournaments&show=42038]'' |^ [Ronin Headchopper | https://fumbbl.com/p/player?player_id=11474441] |^ Northern Nippon%%%''Samurai'' |^ [Secret Cult Of Shiamoto | https://fumbbl.com/p/team?team_id=854690]%%%''([Grin | https://fumbbl.com/~Grin])'' |^ 10 |^ Active
#
# %%%
#
#
# --------------------------------------------------
# CIBBL-Achievement-Futuristic
# --------------------------------------------------
# CIBBL-Achievement-FinderOfTheWay
# --------------------------------------------------
# CIBBL-Achievement-LordsOfBalanceObsidian
# --------------------------------------------------
# CIBBL-Achievement-CabalVisionRatingAttraction
# --------------------------------------------------
# CIBBL-Achievement-StylePoints
# --------------------------------------------------
# CIBBL-Achievement-MagicMushroomMuncher
# --------------------------------------------------
# CIBBL-Achievement-LordsOfBalancePearl
# --------------------------------------------------
# CIBBL-Achievement-Gargantuan
# --------------------------------------------------
# CIBBL-Achievement-DeathOrGlory
# --------------------------------------------------
# CIBBL-Achievement-AllYouCanEat
# --------------------------------------------------
# CIBBL-Achievement-Escapist
# --------------------------------------------------
# CIBBL-Achievement-SCRIBBLsOutstandingPerformance
# --------------------------------------------------
# CIBBL-Achievement-BlueEagleAscending
# --------------------------------------------------
# CIBBL-Achievement-IceCold
# --------------------------------------------------
# CIBBL-Achievement-Slasher
# --------------------------------------------------
# CIBBL-Achievement-InspiredDrinker
# --------------------------------------------------
# CIBBL-Achievement-AltdorfCollegeHonoraryGraduate
# --------------------------------------------------
# CIBBL-Achievement-NotWithAWhimperButWithABang
# --------------------------------------------------
# CIBBL-Achievement-WakeUpCall
# --------------------------------------------------
# CIBBL-Achievement-PromiseOfGreatness
# --------------------------------------------------
# CIBBL-Achievement-MarkOfTheDragon
# --------------------------------------------------
# CIBBL-Achievement-NufflesBlessing
# --------------------------------------------------
# CIBBL-Achievement-ExemplarOfGlory
# --------------------------------------------------
# CIBBL-Achievement-Eternal
# --------------------------------------------------
# CIBBL-Achievement-MasterOfTheBlackGate
# --------------------------------------------------
# CIBBL-Achievement-GrowthPotential
# --------------------------------------------------
# CIBBL-Achievement-BlitzingBeauty
# --------------------------------------------------
# CIBBL-Achievement-Sleepless
# --------------------------------------------------
# CIBBL-Achievement-SippingTheWitchesBrew
# --------------------------------------------------
# CIBBL-Achievement-FungusSupreme
# --------------------------------------------------
# CIBBL-Achievement-FirstTry
# --------------------------------------------------
# CIBBL-Achievement-LeatherRebel
# --------------------------------------------------
# CIBBL-Achievement-TerrificMightOfTin
# --------------------------------------------------
# CIBBL-Achievement-SilverExcellence
# --------------------------------------------------
# CIBBL-Achievement-BronzeExcellence
# --------------------------------------------------
# CIBBL-Achievement-GoldExcellence
# --------------------------------------------------
# CIBBL-Achievement-DustDevil
# --------------------------------------------------
# CIBBL-Achievement-StickInTheMud
# --------------------------------------------------
# CIBBL-Achievement-RefinedExcellence
# --------------------------------------------------
# CIBBL-Achievement-CopperExcellence
# --------------------------------------------------
# CIBBL-Achievement-ClothExcellence
# --------------------------------------------------
# CIBBL-Achievement-SolidFoundation
# --------------------------------------------------
# CIBBL-Achievement-ClayExcellence
# --------------------------------------------------
# CIBBL-Achievement-ExcellentOnPaper
# --------------------------------------------------
# CIBBL-Achievement-ForgedGreatness
# --------------------------------------------------
# CIBBL-Achievement-WhispererInTheWoods
# --------------------------------------------------
# CIBBL-Achievement-YouthfulVibrance
# --------------------------------------------------
# CIBBL-Achievement-StarPlayer
# --------------------------------------------------
# CIBBL-Achievement-MegaStarPlayer
# --------------------------------------------------
# CIBBL-Achievement-SuperStarPlayer
# --------------------------------------------------
# CIBBL-Achievement-Legend
# --------------------------------------------------
